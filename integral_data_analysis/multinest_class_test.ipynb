# %%
from astropy.coordinates import SkyCoord
import numpy as np
from IntegralQuery import SearchQuery, IntegralQuery, Filter, Range
from IntegralPointingClustering import ClusteredQuery
import astropy.io.fits as fits
from astropy.table import Table
from datetime import datetime
import matplotlib.pyplot as plt
import math
from numba import njit
from pyspi.utils.function_utils import find_response_version
from pyspi.utils.response.spi_response_data import ResponseDataRMF
from pyspi.utils.response.spi_response import ResponseRMFGenerator
from pyspi.utils.response.spi_drm import SPIDRM
from pyspi.utils.livedets import get_live_dets
from astromodels import Powerlaw, Log_uniform_prior, Uniform_prior, PointSource, SpectralComponent, Model
from chainconsumer import ChainConsumer
import pymultinest
import os
import astropy.time as at
from scipy.stats import poisson
import pickle
# Out:
# [WARNING ] The naima package is not available. Models that depend on it will not be available
# [WARNING ] The GSL library or the pygsl wrapper cannot be loaded. Models that depend on it will not be available.
# [WARNING ] The ebltable package is not available. Models that depend on it will not be available
# [INFO    ] Starting 3ML!
# [WARNING ] no display variable set. using backend for graphics without display (agg)
# [WARNING ] ROOT minimizer not available
# [WARNING ] PyGMO is not available
# [WARNING ] The cthreeML package is not installed. You will not be able to use plugins which require the C/C++ interface (currently HAWC)
# [WARNING ] Could not import plugin HAWCLike.py. Do you have the relative instrument software installed and configured?
# [WARNING ] Could not import plugin FermiLATLike.py. Do you have the relative instrument software installed and configured?
# [WARNING ] No fermitools installed
# [WARNING ] Env. variable OMP_NUM_THREADS is not set. Please set it to 1 for optimal performances in 3ML
# [WARNING ] Env. variable MKL_NUM_THREADS is not set. Please set it to 1 for optimal performances in 3ML
# [WARNING ] Env. variable NUMEXPR_NUM_THREADS is not set. Please set it to 1 for optimal performances in 3ML

# %%
rsp_bases = tuple([ResponseDataRMF.from_version(i) for i in range(5)])
# Out:
# Using the irfs that are valid between Start and 03/07/06 06:00:00 (YY/MM/DD HH:MM:SS)
# Using the irfs that are valid between 03/07/06 06:00:00 and 04/07/17 08:20:06 (YY/MM/DD HH:MM:SS)
# Using the irfs that are valid between 04/07/17 08:20:06 and 09/02/19 09:59:57 (YY/MM/DD HH:MM:SS)
# Using the irfs that are valid between 09/02/19 09:59:57 and 10/05/27 12:45:00 (YY/MM/DD HH:MM:SS)
# Using the irfs that are valid between 10/05/27 12:45:00 and present (YY/MM/DD HH:MM:SS)

# %%
@njit
def b_maxL_2(m, t, C):
    first = C[0]+C[1]-(m[0]+m[1])*(t[0]+t[1])
    root = (C[0]+C[1]+(m[0]-m[1])*(t[0]+t[1]))**2-4*C[0]*(m[0]-m[1])*(t[0]+t[1])
    res = (first+np.sqrt(root))/(2*(t[0]+t[1]))
    if res < 0:
        return 0
    return res

@njit #################### needs more testing, can do without error?
def b_maxL_3(m, t, C):
    mt = m[0] + m[1] + m[2]
    tt = t[0] + t[1] + t[2]
    Ct = C[0] + C[1] + C[2]
    a = -tt
    b = -tt*mt + Ct
    c = Ct*mt - C[0]*m[0] - C[1]*m[1] - C[2]*m[2] -tt*(m[0]*m[1] + m[1]*m[2] + m[2]*m[0])
    d = C[0]*m[1]*m[2] + C[1]*m[2]*m[0] + C[2]*m[0]*m[1] - tt*m[0]*m[1]*m[2]
    D0 = b**2 - 3*a*c
    D1 = 2*b**3 - 9*a*b*c + 27*(a**2)*d
        
    if D0 == 0. and D1 == 0.:
        return -b/(3*a)
    
    C0 = ((D1 + np.sqrt(D1**2 - 4*D0**3 + 0j)) / 2)**(1/3)
    
    if C0 == 0:
        C0 = ((D1 - np.sqrt(D1**2 - 4*D0**3 + 0j)) / 2)**(1/3)
        
    x0 = -1/(3*a) * (b + C0 + D0/C0)
    
    if x0.real < 0:
        return 0.
    
    return x0.real

# %%
@njit
def logLcore(
    spec_binned,
    pointings,
    dets,
    resp_mats,
    num_sources,
    t_elapsed,
    counts
):
    logL=0
    for p_i in range(len(pointings)):
        for d_i in range(len(dets[p_i])):
            n_p = len(pointings[p_i])
            m = np.zeros((n_p, len(resp_mats[p_i][0][0][0,0,:])))
            
            t_b = np.zeros(n_p)
            for t_i in range(n_p):
                t_b[t_i] = t_elapsed[p_i][t_i][d_i]
            C_b = np.zeros(n_p)
            
            for s_i in range(num_sources):
                for m_i in range(n_p):
                    m[m_i,:] += np.dot(spec_binned[s_i,:], resp_mats[p_i][s_i][m_i][d_i])
            for e_i in range(len(m[0])):
                m_b = m[:,e_i]
                for C_i in range(n_p):
                    C_b[C_i] = counts[p_i][C_i][d_i, e_i]
                    
                if n_p == 2:
                    b = b_maxL_2(m_b, t_b, C_b)
                elif n_p == 3:
                    b = b_maxL_3(m_b, t_b, C_b)
                else:
                    print()
                    print("b_maxL is not defined")
                    print()
                    return 0.
                for m_i in range(n_p):
                    logL += (counts[p_i][m_i][d_i, e_i]*math.log(t_elapsed[p_i][m_i][d_i]*(m[m_i,e_i]+b))
                            -t_elapsed[p_i][0][d_i]*(m[m_i,e_i]+b))
    return logL

# %%
def extract_pointing_info(path, p_id):
    num_dets = 19
    with fits.open(f"{path}/pointing.fits") as file:
        t = Table.read(file[1])
        index = np.argwhere(t["PTID_ISOC"]==p_id[:8])
        
        if len(index) < 1:
            raise Exception(f"{p_id} not found")

        pointing_info = t[index[-1][0]]
        
        t1 = at.Time(f'{pointing_info["TSTART"]+2451544.5}', format='jd').datetime
        time_start = datetime.strftime(t1,'%y%m%d %H%M%S')
            
    with fits.open(f"{path}/dead_time.fits") as file:
        t = Table.read(file[1])
        
        time_elapsed = np.zeros(num_dets)
        
        for i in range(num_dets):
            for j in index:
                time_elapsed[i] += t["LIVETIME"][j[0]*85 + i]
        
    with fits.open(f"{path}/energy_boundaries.fits") as file:
        t = Table.read(file[1])
        
        energy_bins = np.append(t["E_MIN"], t["E_MAX"][-1])
    
    with fits.open(f"{path}/evts_det_spec.fits") as file:
        t = Table.read(file[1])
        
        counts = np.zeros((num_dets, len(energy_bins)-1))
        for i in range(num_dets):
            for j in index:
                counts[i, : ] += t["COUNTS"][j[0]*85 + i]

    return time_start, time_elapsed, energy_bins, counts

# %%
def generate_resp_mat(
    rmfs,
    len_dets,
    len_ebs,
    len_emod,
    ra,
    dec,
):
    sds = np.empty(0)
    for d in range(len_dets):
        sd = SPIDRM(rmfs[d], ra, dec)
        sds = np.append(sds, sd.matrix.T)
    return sds.reshape((len_dets, len_emod-1, len_ebs-1))

# %%
def calc_mahalanobis_dist(summary, cov, true_vals):
    fit_val = np.array([summary[i][1] for i in true_vals[0]])
    fit_cov = cov[1]
    rel_distance = []
    
    for i in range(len(true_vals[1])):
        dif = fit_val - true_vals[1][i]
        
        rel_distance.append(np.sqrt(
            np.linalg.multi_dot([dif, np.linalg.inv(fit_cov), dif])
        ))
        
    return np.array(rel_distance)

# %%
class MultinestClusterFit:
    def __init__(
        self,
        pointings,
        source_model,
        binning_func,
        energy_range,
        emod,
        true_values=None,
        folder=None,
    ):
        self._pointings = pointings
        self._source_model = source_model
        self._binning_func = binning_func
        self._energy_range = energy_range
        self._emod = emod
        
        self._true_values = true_values
        self.set_folder(folder)
        
        self._prepare_fit_data()
        
        self._find_updatable_sources()
        
        self._initialize_resp_mats()
        
        self._run_multinest()
                
        self._extract_parameter_names_simple()
        self._parameter_names.extend(["$z$"])
            
        self._cc = ChainConsumer()
        self._chain = np.loadtxt('./chains/1-post_equal_weights.dat')
        self._cc.add_chain(self._chain, parameters=self._parameter_names, name='fit')
        
    def _run_multinest(self):
        num_sources = len(self._source_model.sources)
        
        def logLba_mult(trial_values, ndim=None, params=None):
            spec_binned = np.zeros((num_sources, len(self._emod)-1))
            for i, parameter in enumerate(self._source_model.free_parameters.values()):
                parameter.value = trial_values[i]
            for i, source in enumerate(self._source_model.sources.values()):
                spec = source(self._emod)
                spec_binned[i,:] = (self._emod[1:]-self._emod[:-1])*(spec[:-1]+spec[1:])/2
            if 1 in self._updatable_sources:
                self._update_resp_mats()
            return logLcore(
                spec_binned,
                self._pointings,
                self._dets,
                self._resp_mats,
                num_sources,
                self._t_elapsed,
                self._counts,
            )
        
        def prior(params, ndim=None, nparams=None):
            for i, parameter in enumerate(self._source_model.free_parameters.values()):
                try:
                    params[i] = parameter.prior.from_unit_cube(params[i])

                except AttributeError:
                    raise RuntimeError(
                        "The prior you are trying to use for parameter %s is "
                        "not compatible with sampling from a unitcube"
                        % parameter.path
                    )

        num_params = len(self._source_model.free_parameters)
        
        # ###
        # trial_values = [4.5e-3, -2.08, 7e-3, -2.5]
        # spec_binned = np.zeros((num_sources, len(self._emod)-1))
        # for i, parameter in enumerate(self._source_model.free_parameters.values()):
        #     parameter.value = trial_values[i]
        # for i, source in enumerate(self._source_model.sources.values()):
        #     spec = source(self._emod)
        #     spec_binned[i,:] = (self._emod[1:]-self._emod[:-1])*(spec[:-1]+spec[1:])/2
        # print(logLcore(
        #     spec_binned,
        #     self._pointings,
        #     self._dets,
        #     self._resp_mats,
        #     num_sources,
        #     self._t_elapsed,
        #     self._counts,
        # ))
        # return None
        # ###

        if not os.path.exists("./chains"):
            os.mkdir("chains")
        sampler = pymultinest.run(
            logLba_mult, prior, num_params, num_params, n_live_points=800, resume=False, verbose=True
        )
    
    def _prepare_fit_data(self):
        ebs = []
        counts = []
        dets = []
        t_elapsed = []
        t_start = []
            
        for combination in self._pointings:
            c_time_start, c_time_elapsed = [], []
            for p_i, pointing in enumerate(combination):
                time_start, time_elapsed, energy_bins, counts_f = extract_pointing_info(pointing[1], pointing[0])
                c_time_start.append(time_start)
                dets_temp = get_live_dets(time=time_start, event_types=["single"])
                c_time_elapsed.append(time_elapsed[dets_temp])
                
                if p_i == 0:
                    dets_0 = dets_temp
                    energy_bins_0 = energy_bins
                    c_counts_f = counts_f[dets_0]
                else:
                    c_counts_f = np.append(c_counts_f, counts_f[dets_0], axis=0)
                    assert np.array_equal(dets_0, dets_temp), f"Active detectors are not the same for {combination[0][0]} and {combination[p_i][0]}"
                    assert np.array_equal(energy_bins_0, energy_bins), f"Energy bins are not the same for {combination[0][0]} and {combination[p_i][0]}"
                
            eb, c = self._binning_func(
                energy_bins_0,
                c_counts_f,
                self._energy_range
            )
            nd = len(dets_0)
            counts.append(tuple([c[i*nd : (i+1)*nd] for i in range(len(combination))]))
            ebs.append(eb)
            
            t_start.append(tuple(c_time_start))
            dets.append(dets_0)
            t_elapsed.append(tuple(c_time_elapsed))
                            
                
            # time_start1, time_elapsed1, energy_bins1, counts_f1 = extract_pointing_info(pair[0], pair[1])
            # time_start2, time_elapsed2, energy_bins2, counts_f2 = extract_pointing_info(pair[0], pair[2])
            # t_start.append((time_start1, time_start2))
            
            # dets1 = get_live_dets(time=time_start1, event_types=["single"])
            # dets2 = get_live_dets(time=time_start2, event_types=["single"])
            # assert np.array_equal(dets1, dets2), f"Active detectors are not the same for {pair[1]} and {pair[2]}"
            # dets.append(dets1)
            
            # t_elapsed.append((time_elapsed1[dets1], time_elapsed2[dets1]))
            
            # assert np.array_equal(energy_bins1, energy_bins2), f"Energy bins are not the same for {pair[1]} and {pair[2]}"
            
            # eb, c = binning_func(
            #     energy_bins1,
            #     np.append(counts_f1[dets1], counts_f2[dets1], axis=0),
            #     energy_range)
            # counts.append((c[:len(dets1)], c[len(dets1):]))
            # ebs.append(eb)
                
        self._ebs = tuple(ebs) 
        self._counts = tuple(counts)
        self._dets = tuple(dets)
        self._t_elapsed = tuple(t_elapsed)
        self._t_start = tuple(t_start)
    
    def _initialize_resp_mats(self):
        # index order: tuple(combination, source, pointing, np_array(dets, e_in, e_out))
        resp_mats = []
        rmfs = []
        
        for count, combination in enumerate(self._pointings):
            # version1 = find_response_version(self._t_start[count][0])
            # for pointing in range(1, len(combination)):
            #     version2 = find_response_version(self._t_start[count][pointing])
            #     assert version1 == version2, f"Response versions are not equal for {combination[0][0]} and {combination[pointing][0]}"
            # rsp_base = rsp_bases[version1]
            
            source_resp_mats = []
            
            dets = self._dets[count]
            ebs = self._ebs[count]
            
            for source in self._source_model.sources.values():
                combination_resp_mats = []
                combination_rmfs = []
                
                for pointing in range(len(combination)):
                    time = self._t_start[count][pointing]
                    version = find_response_version(time)
                    rsp_base = rsp_bases[version]
                    
                    pointing_rmfs = []
                    for d in dets:
                        pointing_rmfs.append(ResponseRMFGenerator.from_time(time, d, ebs, self._emod, rsp_base))
                    pointing_rmfs = tuple(pointing_rmfs)
                                        
                    combination_resp_mats.append(
                        generate_resp_mat(
                            pointing_rmfs,
                            len(dets),
                            len(ebs),
                            len(self._emod),
                            source.position.get_ra(),
                            source.position.get_dec(),
                        )
                    )
                    combination_rmfs.append(pointing_rmfs)
                    
                source_resp_mats.append(tuple(combination_resp_mats))
                    
            resp_mats.append(tuple(source_resp_mats))
            rmfs.append(tuple(combination_rmfs))
            
        self._resp_mats = tuple(resp_mats)
        if 1 in self._updatable_sources:
            self._updatable_rmfs = tuple(rmfs)

    def _update_resp_mats(self):
        for count, combination in enumerate(self._pointings):
            for source_num, source in enumerate(self._source_model.sources.values()):
                if self._updatable_sources[source_num] == 1:
                    for pointing in range(len(combination)):
                        self._resp_mats[count][source_num][pointing][:,:,:] = generate_resp_mat(
                            self._updatable_rmfs[count][pointing],
                            len(self._dets[count]),
                            len(self._ebs[count]),
                            len(self._emod),
                            source.position.get_ra(),
                            source.position.get_dec(),
                        )

    def _find_updatable_sources(self):
        keywords = ["position"]
        self._updatable_sources = np.zeros(len(self._source_model.sources), np.int8)
        for s_i, source in enumerate(self._source_model.sources.values()):
            for parameter in source.free_parameters.values():
                first_pos = parameter.path.find(".")
                second_pos = parameter.path.find(".", first_pos+1)
                if parameter.path[first_pos+1 : second_pos] in keywords:
                    self._updatable_sources[s_i] = 1

    def parameter_fit_distribution(self):
        assert not self._folder is None, "folder is not set"
        
        fig = self._cc.plotter.plot(
            parameters=self._parameter_names[:-1],
            # truth={'Crab K':true_values_main[0,0], 'Crab index':true_values_main[0,1]},
            figsize=1.5
        )
        
        plt.savefig(f"{self._folder}/parameter_fit_distributions.pdf")
        plt.close()
        
    def text_summaries(
        self,
        reference_values=True,
        pointing_combinations=True,
        parameter_fit_constraints=True
    ):
        assert not self._folder is None, "folder is not set"
        
        summary = self._cc.analysis.get_summary(parameters=self._parameter_names[:-1])
        
        if reference_values:
            assert not self._true_values is None, "true_values not set"
            cov = self._cc.analysis.get_covariance(parameters=self._true_values[0])
            rel_distances = calc_mahalanobis_dist(summary, cov, self._true_values)
            
            with open(f"{self._folder}/reference_values", "w") as f:
                f.write(f"{' : '.join(self._true_values[0])} : Rel. Dist.\n")
                for i in range(self._true_values[1].shape[0]):
                    f.write(f"{' : '.join([f'{j:.3}' for j in self._true_values[1][i,:]])} : {rel_distances[i]:.3}\n")
                
        if pointing_combinations:
            with open(f"{self._folder}/pointing_combinations", "w") as f:
                for combination in self._pointings:
                    f.write(f'{"  ".join(i[0] for i in combination)}\n')
        
        if parameter_fit_constraints:
            with open(f"{self._folder}/parameter_fit_constraints", "w") as f:
                for param in self._parameter_names[:-1]:
                    f.write(f"{param}:\n")
                    try:
                        f.write(f"{summary[param][0]:.5}  {summary[param][1]:.5}  {summary[param][2]:.5}\n")
                    except:
                        f.write(f"None  {summary[param][1]:.5}  None\n")
    
    def ppc( # allow updatable sources!
        self,
        count_energy_plots=True,
        qq_plots=True
    ):
        assert self._folder is not None, "folder is not set"
        
        
        
        for c_i, combination in enumerate(self._pointings):
            s, b = self._calc_rates(
                self._resp_mats[c_i],
                self._ebs[c_i],
                self._counts[c_i],
                self._dets[c_i],
                self._t_elapsed[c_i],
            )
            
            if count_energy_plots:
                for p_i in range(len(combination)):
                    self._count_energy_plot(
                        b[p_i],
                        s[p_i],
                        self._ebs[c_i],
                        self._counts[c_i][p_i],
                        self._dets[c_i],
                        combination[p_i][0]
                    )
            if qq_plots:
                for p_i in range(len(combination)):
                    self._qq_plot(
                        b[p_i],
                        s[p_i],
                        self._counts[c_i][p_i],
                        self._dets[c_i],
                        combination[p_i][0]
                    )
            
    def _calc_rates(
        self,
        resp_mats,
        eb,
        counts,
        dets,
        t_elapsed,
    ):
        source_rate = np.zeros((len(counts), len(dets), len(eb)-1, len(self._chain)))
        background_rate = np.zeros((len(dets), len(eb)-1, len(self._chain)))
        
        num_sources = len(self._source_model.sources)
        
        for p_i, params in enumerate(self._chain):
            spec_binned = np.zeros((num_sources, len(self._emod)-1))
            for fp_i, parameter in enumerate(self._source_model.free_parameters.values()):
                parameter.value = params[fp_i]
            for s_i, source in enumerate(self._source_model.sources.values()):
                spec = source(self._emod)
                spec_binned[s_i,:] = (self._emod[1:]-self._emod[:-1])*(spec[:-1]+spec[1:])/2
                
            for d_i in range(len(dets)):
                for s_i in range(num_sources):
                    for m_i in range(len(counts)):
                        source_rate[m_i,d_i,:,p_i] += np.dot(spec_binned[s_i,:], resp_mats[s_i][m_i][d_i])
                for e_i in range(len(eb)-1):
                    s_b = np.array([source_rate[i,d_i,e_i,p_i] for i in range(len(counts))])
                    t_b = np.array([t_elapsed[i][d_i] for i in range(len(counts))])
                    C_b = np.array([counts[i][d_i, e_i] for i in range(len(counts))])
                    if len(counts) == 2:
                        background_rate[d_i,e_i,p_i] = b_maxL_2(s_b, t_b, C_b)
                    elif len(counts) == 3:
                        background_rate[d_i,e_i,p_i] = b_maxL_3(s_b, t_b, C_b)
                        
        source_rates = []
        background_rates = []
        for i in range(len(counts)):
            source_rates.append(
                np.average(source_rate[i], axis=2) * t_elapsed[i][:,np.newaxis]
            )
            background_rates.append(
                np.average(background_rate, axis=2) * t_elapsed[i][:,np.newaxis]
            )

        return source_rates, background_rates

    def _count_energy_plot(
        self,
        b,
        s,
        eb,
        c,
        dets,
        name
    ):
        fig, axes = plt.subplots(5,4, sharex=True, sharey=True, figsize=(10,10))
        axes = axes.flatten()
        
        predicted = b + s
        predicted_lower = poisson.ppf(0.05, predicted)
        predicted_upper = poisson.ppf(0.95, predicted)
        counts = c
        
        i=0
        for d in range(19):
            axes[d].text(.5,.9,f"Det {d}",horizontalalignment='center',transform=axes[d].transAxes)
            if d in dets:
                line1, = axes[d].step(eb[:-1], predicted[i], c="r")
                line2, = axes[d].step(eb[:-1], counts[i], c="k")
                axes[d].fill_between(eb[:-1], predicted_lower[i], predicted_upper[i], color="r", alpha=0.5)
                if i==0:
                    line1.set_label("Predicted Counts")
                    line2.set_label("Real Counts")
                i += 1
            axes[d].set_yscale("log")
        plt.subplots_adjust(hspace=0, wspace=0)
        plt.subplots_adjust(hspace=0, top=0.96, bottom=0.1)
        lgd = fig.legend(loc='center left', bbox_to_anchor=(0.9, 0.5), fontsize='x-large')
        
        fig.add_subplot(111, frameon=False)
        plt.tick_params(labelcolor='none', which='both', top=False, bottom=False, left=False, right=False)
        plt.xlabel("Detected Energy [keV]")
        plt.ylabel("Cumulative Counts")
        
        fig.savefig(f"{self._folder}/{name}_count_energy.pdf")
        plt.close()
    
    def _qq_plot(
        self,
        b,
        s,
        c,
        dets,
        name
    ):
        fig, axes = plt.subplots(5,4, sharex=True, sharey=True, figsize=(10,10))
        axes = axes.flatten()
        
        p = b + s
        predicted = np.cumsum(p, axis=1)
        predicted_lower = np.cumsum(poisson.ppf(0.05, p), axis=1)
        predicted_upper = np.cumsum(poisson.ppf(0.95, p), axis=1)
        counts = np.cumsum(c, axis=1)
        ma = np.amax(
            np.array([np.amax(counts, axis=1), np.amax(predicted, axis=1)]),
            axis=0
        )
        
        i=0
        for d in range(19):
            axes[d].text(.5,.9,f"Det {d}",horizontalalignment='center',transform=axes[d].transAxes)
            if d in dets:
                line2, = axes[d].plot([0, ma[i]], [0, ma[i]], ls="--", c="k")
                line1, = axes[d].plot(counts[i], predicted[i], c="r")
                axes[d].fill_between(counts[i], predicted_lower[i], predicted_upper[i], color="r", alpha=0.5)
                i += 1
        plt.subplots_adjust(hspace=0, wspace=0)
        plt.subplots_adjust(hspace=0, top=0.96, bottom=0.1)
                
        fig.add_subplot(111, frameon=False)
        plt.tick_params(labelcolor='none', which='both', top=False, bottom=False, left=False, right=False)
        plt.xlabel("Cumulative Real Counts")
        plt.ylabel("Cumulative Predicted Counts", labelpad=27)
        
        fig.savefig(f"{self._folder}/{name}_qq.pdf")
        plt.close()
        
    def _extract_parameter_names_simple(self):
        self._parameter_names = []
        for full_name in self._source_model.free_parameters.keys():
            source = full_name[ : full_name.find(".")]
            source = source[1:] if source[0]=="_" else source
            source = source.replace("__", "+").replace("_", " ")
            parameter = full_name[-1 * full_name[::-1].find(".") : ]
            self._parameter_names.extend([f"{source} {parameter}"])
    
    def set_folder(self, folder):
        if not folder is None:
            if not os.path.exists(f"./{folder}"):
                os.mkdir(folder)
        self._folder = folder

# %%
def rebin_data_exp(
    bins,
    counts,
    energy_range
):

    if energy_range[0]:
        for i, e in enumerate(bins):
            if e > energy_range[0]:
                bins = bins[i:]
                counts = counts[:,i:] ############should these be the same?
                break
    if energy_range[1]:
        for i, e in enumerate(bins):
            if e > energy_range[1]:
                bins = bins[:i]
                counts = counts[:,:i-1]
                assert i > 1, "Max Energy is too low"
                break
        
    min_counts = 5
    
    max_num_bins = 120
    min_num_bins = 1
    
    finished = False
    
    while not finished:
        num_bins = round((max_num_bins + min_num_bins) / 2)
        
        if num_bins == max_num_bins or num_bins == min_num_bins:
            num_bins = min_num_bins
            finished = True
        
        temp_bins = np.geomspace(bins[0], bins[-1], num_bins+1)
        
        new_bins, new_counts = rebin_closest(bins, counts, temp_bins)
        
        if np.amin(new_counts) < min_counts:
            max_num_bins = num_bins
        else:
            min_num_bins = num_bins
            
    return new_bins, new_counts
    
# @njit
def rebin_closest(bins, counts, temp_bins):
    counts = np.copy(counts)
    closest1 = len(bins) - 1
    for i in range(len(temp_bins)-2, 0, -1):
        closest2 = np.argpartition(
            np.absolute(bins - temp_bins[i]),
            0
        )[0]
        if closest1 - closest2 >= 2:
            counts[:,closest2] += np.sum(counts[:, closest2+1 : closest1], axis=1)
            counts = np.delete(
                counts,
                [j for j in range(closest2+1, closest1)],
                axis=1
            )
            bins = np.delete(
                bins,
                [j for j in range(closest2+1, closest1)]
            )
        closest1 = closest2
    return bins, counts


# counts = np.linspace(1,40,40).reshape((2,20))
# bins = np.linspace(1,21,21)
# temp_bins = np.geomspace(1,21,11)
# b, c = rebin_closest(bins, counts, temp_bins)
# print(bins)
# print(counts)
# print(np.sum(counts, axis=1))
# print(temp_bins)
# print(b)
# print(c)
# print(np.sum(c, axis=1))

# %%
def save_clusters(pointings, folder):
    if not os.path.exists(f"./{folder}"):
        os.mkdir(folder)
    with open(f"./{folder}/pointings.pickle", "wb") as f:
        pickle.dump(pointings, f)
        
def load_clusters(folder):
    with open(f"./{folder}/pointings.pickle", "rb") as f:
        pointings = pickle.load(f)
    return pointings

# %%
def extract_date_range(path):
    with fits.open(f"{path}/pointing.fits") as file:
        t = Table.read(file[1])
        t1 = at.Time(f'{t["TSTART"][0]+2451544.5}', format='jd')
        t1.format = "isot"
        t2 = at.Time(f'{t["TSTOP"][-1]+2451544.5}', format='jd')
        t2.format = "isot"
    return t1.value, t2.value

# %%
class PointingClusters: #add min time diff
    def __init__(
        self,
        orbit_paths,
        min_angle_dif,
        max_angle_dif,
        max_time_dif,
        radius_around_crab,
        min_time_elapsed,
        cluster_size_range,
        random_angle_dif_range=None,
    ):
        self._orbit_paths = orbit_paths
        self._min_angle_dif = min_angle_dif
        self._max_angle_dif = max_angle_dif
        self._max_time_dif = max_time_dif
        self._radius_around_crab = radius_around_crab
        self._min_time_elapsed = min_time_elapsed
        self._cluster_size_range = cluster_size_range
        self._random_angle_dif_range = random_angle_dif_range
        
        pointings = []
        self._get_scw_ids()
        cq = ClusteredQuery(
            self._scw_ids,
            angle_weight=0.,
            time_weight=1./self._max_time_dif,
            max_distance=1.,
            min_ang_distance=self._min_angle_dif,
            max_ang_distance=self._max_angle_dif,
            cluster_size_range = self._cluster_size_range,
            failed_improvements_max=3,
            suboptimal_cluster_size=max(1,self._cluster_size_range[0]),
            close_suboptimal_cluster_size=max(1,self._cluster_size_range[0])
        ).get_clustered_scw_ids()
        
        for size in range(self._cluster_size_range[0], self._cluster_size_range[1] + 1):
            for cluster in cq[size]:
                pointings.append(tuple([(i, f"crab_data/{i[:4]}") for i in cluster]))
                
        self.pointings = tuple(pointings)             
    
    def _get_scw_ids(self, print_results=False):
        p = SkyCoord(83.6333, 22.0144, frame="icrs", unit="deg")
        searchquerry = SearchQuery(position=p, radius=f"{self._radius_around_crab} degree",)
        cat = IntegralQuery(searchquerry)

        scw_ids_all = None
        for path in self._orbit_paths:
            f = Filter(
                SCW_TYPE="POINTING",
                TIME=Range(*extract_date_range(path))
            )
            if scw_ids_all:
                scw_ids_all = np.append(
                    scw_ids_all,
                    cat.apply_filter(f, return_coordinates=True, remove_duplicates=True),
                    axis=0
                )
            else:
                scw_ids_all = cat.apply_filter(f, return_coordinates=True, remove_duplicates=True)
        
        scw_ids = []
        
        multiple_files = []
        no_files = []
        no_pyspi = []
        
        num_dets = 19
        eb = np.geomspace(18, 2000, 5)
        emod = np.geomspace(18, 2000, 5)
        for scw_id in scw_ids_all:
            good = True
            with fits.open(f"{path}/pointing.fits") as file:
                t = Table.read(file[1])
                index = np.argwhere(t["PTID_ISOC"]==scw_id[0][:8])
                
                if len(index) < 1:
                    no_files.append(scw_id)
                    good = False
                    continue
                    
                elif len(index) > 1:
                    multiple_files.append(scw_id)
                    good = False
                                
                pointing_info = t[index[-1][0]]
            
                t1 = at.Time(f'{pointing_info["TSTART"]+2451544.5}', format='jd').datetime
                time_start = datetime.strftime(t1,'%y%m%d %H%M%S')
                                
                with fits.open(f"{path}/dead_time.fits") as file2:
                    t2 = Table.read(file2[1])
                    
                    time_elapsed = np.zeros(num_dets)
                    
                    for i in range(num_dets):
                        for j in index:
                            time_elapsed[i] += t2["LIVETIME"][j[0]*85 + i]
                                
                dets = get_live_dets(time=time_start, event_types=["single"])
                                
                if not np.amin(time_elapsed[dets]) > self._min_time_elapsed:
                    good = False
            
            try: # investigate why this is necessary
                version = find_response_version(time_start)
                rsp = ResponseRMFGenerator.from_time(time_start, dets[0], eb, emod, rsp_bases[version])
            except:
                no_pyspi.append(scw_id)
                good = False
                
            if good:
                scw_ids.append(scw_id)
                
        if print_results:
            print("Multiple Files:")
            print(multiple_files)
            print("No Files:")
            print(no_files)
            print("No PySpi:")
            print(no_pyspi)
            print("Good:")
            print(scw_ids)
        
        self._scw_ids = np.array(scw_ids)

# %%
def define_sources(source_funcs):    
    model = Model()
    for source_func, params in source_funcs:
        source_func(model, *params)
    return model

# %%
def crab_pl_fixed_pos(model, piv):
    ra, dec = 83.6333, 22.0144
    
    pl = Powerlaw()
    pl.piv = piv
    pl.K.prior = Log_uniform_prior(lower_bound=1e-6, upper_bound=1e0)
    pl.index.prior = Uniform_prior(lower_bound=-4, upper_bound=0)
    component1 = SpectralComponent("pl", shape=pl)
    ps = PointSource("Crab", ra=ra, dec=dec, components=[component1])
    
    model.add_source(ps)
    return model

def crab_pl_free_pos(model, piv):
    ra, dec = 83.6333, 22.0144
    angle_range = 5.
    
    pl = Powerlaw()
    pl.piv = piv
    pl.K.prior = Log_uniform_prior(lower_bound=1e-6, upper_bound=1e0)
    pl.index.prior = Uniform_prior(lower_bound=-4, upper_bound=0)
    component1 = SpectralComponent("pl", shape=pl)
    ps = PointSource("Crab", ra=ra, dec=dec, components=[component1])
    ps.position.ra.free = True
    ps.position.ra.prior = Uniform_prior(
        lower_bound = ra - abs(angle_range/np.cos(dec)),
        upper_bound = ra + abs(angle_range/np.cos(dec))
    )
    ps.position.dec.free = True
    ps.position.dec.prior = Uniform_prior(
        lower_bound = dec - angle_range,
        upper_bound = dec + angle_range
    )
    
    model.add_source(ps)
    return model

def _1A_0535_262_pl(model, piv):
    ra, dec = 84.7270, 26.3160
    
    pl = Powerlaw()
    pl.piv = piv
    pl.K.prior = Log_uniform_prior(lower_bound=1e-10, upper_bound=1e0)
    pl.index.prior = Uniform_prior(lower_bound=-4, upper_bound=0)
    component1 = SpectralComponent("pl", shape=pl)
    ps = PointSource("_1A_0535__262", ra=ra, dec=dec, components=[component1])
    
    model.add_source(ps)
    return model

def _4U_0517_17_pl(model, piv):
    ra, dec = 77.6896, 16.4986
    
    pl = Powerlaw()
    pl.piv = piv
    pl.index.min_value = -20.
    pl.K.prior = Log_uniform_prior(lower_bound=1e-10, upper_bound=1e-4)
    pl.index.prior = Uniform_prior(lower_bound=-20, upper_bound=10)
    component1 = SpectralComponent("pl", shape=pl)
    ps = PointSource("_4U_0517__17", ra=ra, dec=dec, components=[component1])
    
    model.add_source(ps)
    return model

def _4U_0614_09_pl(model, piv):
    ra, dec = 94.2800, 9.13700
    
    pl = Powerlaw()
    pl.piv = piv
    pl.index.max_value = 20.
    pl.K.prior = Log_uniform_prior(lower_bound=1e-10, upper_bound=1e-4)
    pl.index.prior = Uniform_prior(lower_bound=-10, upper_bound=20)
    component1 = SpectralComponent("pl", shape=pl)
    ps = PointSource("_4U_0614__09", ra=ra, dec=dec, components=[component1])
    
    model.add_source(ps)
    return model

def geminga_pl(model, piv):
    ra, dec = 98.4750, 17.7670
    
    pl = Powerlaw()
    pl.piv = piv
    pl.index.max_value = 15.
    pl.K.prior = Log_uniform_prior(lower_bound=1e-15, upper_bound=1e-5)
    pl.index.prior = Uniform_prior(lower_bound=-10, upper_bound=15)
    component1 = SpectralComponent("pl", shape=pl)
    ps = PointSource("Geminga", ra=ra, dec=dec, components=[component1])
    
    model.add_source(ps)
    return model

# %%
def true_values():
    piv = 40
    
    crab_parameters = np.array([[9.3, 1, -2.08],
                                [7.52e-4, 100, -1.99],
                                [11.03, 1, -2.1]])
    
    crab_values = np.zeros((len(crab_parameters),2))
    crab_values[:,0] = crab_parameters[:,0] * (piv / crab_parameters[:,1])**crab_parameters[:,2]
    crab_values[:,1] = crab_parameters[:,2]
    
    crab_values = (["Crab K", "Crab index"], crab_values)
    
    return crab_values

# %%
folder = "orbit_1019"

# pointings = PointingClusters(
#     ("crab_data/1019",),
#     min_angle_dif=1.5,
#     max_angle_dif=4.,
#     max_time_dif=0.2,
#     radius_around_crab=5.,
#     min_time_elapsed=600.,
#     cluster_size_range=(2,2),
# ).pointings
# save_clusters(pointings, folder)

pointings = load_clusters(folder)
source_model = define_sources((
    (crab_pl_fixed_pos, (40,)),
    (_1A_0535_262_pl, (40,)),
))

multinest_fit = MultinestClusterFit(
    pointings,
    source_model,
    rebin_data_exp,
    (None, 80),
    np.geomspace(18, 150, 50),
    true_values(),
    folder,
)

multinest_fit.parameter_fit_distribution()
multinest_fit.text_summaries()
multinest_fit.ppc()
# Out:
#  *****************************************************
#  MultiNest v3.10
#  Copyright Farhan Feroz & Mike Hobson
#  Release Jul 2015
#
#  no. of live points =  800
#  dimensionality =    4
#  *****************************************************
#  Starting MultiNest
#  generating live points
#  live points generated, starting sampling
# Acceptance Rate:                        0.998825
# Replacements:                                850
# Total Samples:                               851
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999412
# Acceptance Rate:                        0.998890
# Replacements:                                900
# Total Samples:                               901
# Nested Sampling ln(Z):            5172337.139658
# Importance Nested Sampling ln(Z): ************** +/-  0.999445
# Acceptance Rate:                        0.989583
# Replacements:                                950
# Total Samples:                               960
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999479
# Acceptance Rate:                        0.978474
# Replacements:                               1000
# Total Samples:                              1022
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999511
# Acceptance Rate:                        0.958904
# Replacements:                               1050
# Total Samples:                              1095
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999543
# Acceptance Rate:                        0.941781
# Replacements:                               1100
# Total Samples:                              1168
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999572
# Acceptance Rate:                        0.922953
# Replacements:                               1150
# Total Samples:                              1246
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999599
# Acceptance Rate:                        0.911854
# Replacements:                               1200
# Total Samples:                              1316
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999620
# Acceptance Rate:                        0.892220
# Replacements:                               1250
# Total Samples:                              1401
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999643
# Acceptance Rate:                        0.884956
# Replacements:                               1300
# Total Samples:                              1469
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999660
# Acceptance Rate:                        0.877763
# Replacements:                               1350
# Total Samples:                              1538
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999675
# Acceptance Rate:                        0.869565
# Replacements:                               1400
# Total Samples:                              1610
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999689
# Acceptance Rate:                        0.862582
# Replacements:                               1450
# Total Samples:                              1681
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999703
# Acceptance Rate:                        0.858615
# Replacements:                               1500
# Total Samples:                              1747
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999714
# Acceptance Rate:                        0.849781
# Replacements:                               1550
# Total Samples:                              1824
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999726
# Acceptance Rate:                        0.838135
# Replacements:                               1600
# Total Samples:                              1909
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999738
# Acceptance Rate:                        0.830816
# Replacements:                               1650
# Total Samples:                              1986
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999748
# Acceptance Rate:                        0.828864
# Replacements:                               1700
# Total Samples:                              2051
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999756
# Acceptance Rate:                        0.821211
# Replacements:                               1750
# Total Samples:                              2131
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999765
# Acceptance Rate:                        0.814111
# Replacements:                               1800
# Total Samples:                              2211
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999774
# Acceptance Rate:                        0.808920
# Replacements:                               1850
# Total Samples:                              2287
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999781
# Acceptance Rate:                        0.798991
# Replacements:                               1900
# Total Samples:                              2378
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999790
# Acceptance Rate:                        0.794297
# Replacements:                               1950
# Total Samples:                              2455
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999796
# Acceptance Rate:                        0.786782
# Replacements:                               2000
# Total Samples:                              2542
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999803
# Acceptance Rate:                        0.781548
# Replacements:                               2050
# Total Samples:                              2623
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999809
# Acceptance Rate:                        0.778066
# Replacements:                               2100
# Total Samples:                              2699
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999815
# Acceptance Rate:                        0.769506
# Replacements:                               2150
# Total Samples:                              2794
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999821
# Acceptance Rate:                        0.764951
# Replacements:                               2200
# Total Samples:                              2876
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999826
# Acceptance Rate:                        0.758853
# Replacements:                               2250
# Total Samples:                              2965
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999831
# Acceptance Rate:                        0.757576
# Replacements:                               2300
# Total Samples:                              3036
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999835
# Acceptance Rate:                        0.753688
# Replacements:                               2350
# Total Samples:                              3118
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999840
# Acceptance Rate:                        0.750469
# Replacements:                               2400
# Total Samples:                              3198
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999844
# Acceptance Rate:                        0.745587
# Replacements:                               2450
# Total Samples:                              3286
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999848
# Acceptance Rate:                        0.744269
# Replacements:                               2500
# Total Samples:                              3359
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999851
# Acceptance Rate:                        0.741710
# Replacements:                               2550
# Total Samples:                              3438
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999855
# Acceptance Rate:                        0.739266
# Replacements:                               2600
# Total Samples:                              3517
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999858
# Acceptance Rate:                        0.737340
# Replacements:                               2650
# Total Samples:                              3594
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999861
# Acceptance Rate:                        0.733297
# Replacements:                               2700
# Total Samples:                              3682
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999864
# Acceptance Rate:                        0.732162
# Replacements:                               2750
# Total Samples:                              3756
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999867
# Acceptance Rate:                        0.729737
# Replacements:                               2800
# Total Samples:                              3837
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999870
# Acceptance Rate:                        0.726855
# Replacements:                               2850
# Total Samples:                              3921
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999872
# Acceptance Rate:                        0.727364
# Replacements:                               2900
# Total Samples:                              3987
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999875
# Acceptance Rate:                        0.726243
# Replacements:                               2950
# Total Samples:                              4062
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999877
# Acceptance Rate:                        0.722892
# Replacements:                               3000
# Total Samples:                              4150
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999880
# Acceptance Rate:                        0.721381
# Replacements:                               3050
# Total Samples:                              4228
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999882
# Acceptance Rate:                        0.720093
# Replacements:                               3100
# Total Samples:                              4305
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999884
# Acceptance Rate:                        0.719835
# Replacements:                               3150
# Total Samples:                              4376
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999886
# Acceptance Rate:                        0.718133
# Replacements:                               3200
# Total Samples:                              4456
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999888
# Acceptance Rate:                        0.715386
# Replacements:                               3250
# Total Samples:                              4543
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999890
# Acceptance Rate:                        0.712743
# Replacements:                               3300
# Total Samples:                              4630
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999892
# Acceptance Rate:                        0.709595
# Replacements:                               3350
# Total Samples:                              4721
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999894
# Acceptance Rate:                        0.709368
# Replacements:                               3400
# Total Samples:                              4793
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999896
# Acceptance Rate:                        0.707983
# Replacements:                               3450
# Total Samples:                              4873
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999897
# Acceptance Rate:                        0.706928
# Replacements:                               3500
# Total Samples:                              4951
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999899
# Acceptance Rate:                        0.704785
# Replacements:                               3550
# Total Samples:                              5037
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999901
# Acceptance Rate:                        0.704225
# Replacements:                               3600
# Total Samples:                              5112
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999902
# Acceptance Rate:                        0.701249
# Replacements:                               3650
# Total Samples:                              5205
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999904
# Acceptance Rate:                        0.700095
# Replacements:                               3700
# Total Samples:                              5285
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999905
# Acceptance Rate:                        0.699236
# Replacements:                               3750
# Total Samples:                              5363
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999907
# Acceptance Rate:                        0.697888
# Replacements:                               3800
# Total Samples:                              5445
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999908
# Acceptance Rate:                        0.695574
# Replacements:                               3850
# Total Samples:                              5535
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999910
# Acceptance Rate:                        0.694568
# Replacements:                               3900
# Total Samples:                              5615
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999911
# Acceptance Rate:                        0.694444
# Replacements:                               3950
# Total Samples:                              5688
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999912
# Acceptance Rate:                        0.694203
# Replacements:                               4000
# Total Samples:                              5762
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999913
# Acceptance Rate:                        0.691953
# Replacements:                               4050
# Total Samples:                              5853
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999915
# Acceptance Rate:                        0.690120
# Replacements:                               4100
# Total Samples:                              5941
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999916
# Acceptance Rate:                        0.686859
# Replacements:                               4150
# Total Samples:                              6042
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999917
# Acceptance Rate:                        0.686499
# Replacements:                               4200
# Total Samples:                              6118
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999918
# Acceptance Rate:                        0.684821
# Replacements:                               4250
# Total Samples:                              6206
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999919
# Acceptance Rate:                        0.682973
# Replacements:                               4300
# Total Samples:                              6296
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999921
# Acceptance Rate:                        0.682246
# Replacements:                               4350
# Total Samples:                              6376
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999922
# Acceptance Rate:                        0.681009
# Replacements:                               4400
# Total Samples:                              6461
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999923
# Acceptance Rate:                        0.679701
# Replacements:                               4450
# Total Samples:                              6547
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999924
# Acceptance Rate:                        0.679040
# Replacements:                               4500
# Total Samples:                              6627
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999925
# Acceptance Rate:                        0.677890
# Replacements:                               4550
# Total Samples:                              6712
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999926
# Acceptance Rate:                        0.678566
# Replacements:                               4600
# Total Samples:                              6779
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999926
# Acceptance Rate:                        0.677250
# Replacements:                               4650
# Total Samples:                              6866
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999927
# Acceptance Rate:                        0.675967
# Replacements:                               4700
# Total Samples:                              6953
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999928
# Acceptance Rate:                        0.675291
# Replacements:                               4750
# Total Samples:                              7034
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999929
# Acceptance Rate:                        0.674347
# Replacements:                               4800
# Total Samples:                              7118
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999930
# Acceptance Rate:                        0.674736
# Replacements:                               4850
# Total Samples:                              7188
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999930
# Acceptance Rate:                        0.673447
# Replacements:                               4900
# Total Samples:                              7276
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999931
# Acceptance Rate:                        0.673103
# Replacements:                               4950
# Total Samples:                              7354
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999932
# Acceptance Rate:                        0.672766
# Replacements:                               5000
# Total Samples:                              7432
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999933
# Acceptance Rate:                        0.672347
# Replacements:                               5050
# Total Samples:                              7511
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999933
# Acceptance Rate:                        0.671671
# Replacements:                               5100
# Total Samples:                              7593
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999934
# Acceptance Rate:                        0.671622
# Replacements:                               5150
# Total Samples:                              7668
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999935
# Acceptance Rate:                        0.671054
# Replacements:                               5200
# Total Samples:                              7749
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999935
# Acceptance Rate:                        0.670156
# Replacements:                               5250
# Total Samples:                              7834
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999936
# Acceptance Rate:                        0.669699
# Replacements:                               5300
# Total Samples:                              7914
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999937
# Acceptance Rate:                        0.669252
# Replacements:                               5350
# Total Samples:                              7994
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999937
# Acceptance Rate:                        0.669477
# Replacements:                               5400
# Total Samples:                              8066
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999938
# Acceptance Rate:                        0.668630
# Replacements:                               5450
# Total Samples:                              8151
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999939
# Acceptance Rate:                        0.668856
# Replacements:                               5500
# Total Samples:                              8223
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999939
# Acceptance Rate:                        0.668916
# Replacements:                               5550
# Total Samples:                              8297
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999940
# Acceptance Rate:                        0.667620
# Replacements:                               5600
# Total Samples:                              8388
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999940
# Acceptance Rate:                        0.667849
# Replacements:                               5650
# Total Samples:                              8460
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999941
# Acceptance Rate:                        0.667682
# Replacements:                               5700
# Total Samples:                              8537
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999941
# Acceptance Rate:                        0.665972
# Replacements:                               5750
# Total Samples:                              8634
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999942
# Acceptance Rate:                        0.665672
# Replacements:                               5800
# Total Samples:                              8713
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999943
# Acceptance Rate:                        0.665151
# Replacements:                               5850
# Total Samples:                              8795
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999943
# Acceptance Rate:                        0.664639
# Replacements:                               5900
# Total Samples:                              8877
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999944
# Acceptance Rate:                        0.663618
# Replacements:                               5950
# Total Samples:                              8966
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999944
# Acceptance Rate:                        0.663350
# Replacements:                               6000
# Total Samples:                              9045
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999945
# Acceptance Rate:                        0.661781
# Replacements:                               6050
# Total Samples:                              9142
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999945
# Acceptance Rate:                        0.660960
# Replacements:                               6100
# Total Samples:                              9229
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999946
# Acceptance Rate:                        0.661148
# Replacements:                               6150
# Total Samples:                              9302
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999946
# Acceptance Rate:                        0.661051
# Replacements:                               6200
# Total Samples:                              9379
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999947
# Acceptance Rate:                        0.661236
# Replacements:                               6250
# Total Samples:                              9452
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999947
# Acceptance Rate:                        0.660516
# Replacements:                               6300
# Total Samples:                              9538
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999948
# Acceptance Rate:                        0.660015
# Replacements:                               6350
# Total Samples:                              9621
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999948
# Acceptance Rate:                        0.658165
# Replacements:                               6400
# Total Samples:                              9724
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999949
# Acceptance Rate:                        0.657425
# Replacements:                               6450
# Total Samples:                              9811
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999949
# Acceptance Rate:                        0.657495
# Replacements:                               6500
# Total Samples:                              9886
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999949
# Acceptance Rate:                        0.657103
# Replacements:                               6550
# Total Samples:                              9968
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999950
# Acceptance Rate:                        0.657240
# Replacements:                               6600
# Total Samples:                             10042
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999950
# Acceptance Rate:                        0.657050
# Replacements:                               6650
# Total Samples:                             10121
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999951
# Acceptance Rate:                        0.657056
# Replacements:                               6700
# Total Samples:                             10197
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999951
# Acceptance Rate:                        0.656743
# Replacements:                               6750
# Total Samples:                             10278
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999951
# Acceptance Rate:                        0.656878
# Replacements:                               6800
# Total Samples:                             10352
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999952
# Acceptance Rate:                        0.657453
# Replacements:                               6850
# Total Samples:                             10419
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999952
# Acceptance Rate:                        0.656705
# Replacements:                               6900
# Total Samples:                             10507
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999952
# Acceptance Rate:                        0.656341
# Replacements:                               6950
# Total Samples:                             10589
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999953
# Acceptance Rate:                        0.655553
# Replacements:                               7000
# Total Samples:                             10678
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999953
# Acceptance Rate:                        0.654961
# Replacements:                               7050
# Total Samples:                             10764
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999954
# Acceptance Rate:                        0.654800
# Replacements:                               7100
# Total Samples:                             10843
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999954
# Acceptance Rate:                        0.654522
# Replacements:                               7150
# Total Samples:                             10924
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999954
# Acceptance Rate:                        0.653951
# Replacements:                               7200
# Total Samples:                             11010
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999955
# Acceptance Rate:                        0.651217
# Replacements:                               7250
# Total Samples:                             11133
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999955
# Acceptance Rate:                        0.649408
# Replacements:                               7300
# Total Samples:                             11241
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999956
# Acceptance Rate:                        0.647406
# Replacements:                               7350
# Total Samples:                             11353
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999956
# Acceptance Rate:                        0.647023
# Replacements:                               7400
# Total Samples:                             11437
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999956
# Acceptance Rate:                        0.645413
# Replacements:                               7450
# Total Samples:                             11543
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999758
# Acceptance Rate:                        0.644275
# Replacements:                               7500
# Total Samples:                             11641
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999759
# Acceptance Rate:                        0.642991
# Replacements:                               7550
# Total Samples:                             11742
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999759
# Acceptance Rate:                        0.641026
# Replacements:                               7600
# Total Samples:                             11856
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999759
# Acceptance Rate:                        0.639846
# Replacements:                               7650
# Total Samples:                             11956
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999760
# Acceptance Rate:                        0.635576
# Replacements:                               7700
# Total Samples:                             12115
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.910604
# Acceptance Rate:                        0.634051
# Replacements:                               7750
# Total Samples:                             12223
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.910612
# Acceptance Rate:                        0.633271
# Replacements:                               7800
# Total Samples:                             12317
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.910618
# Acceptance Rate:                        0.632503
# Replacements:                               7850
# Total Samples:                             12411
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.910623
# Acceptance Rate:                        0.631798
# Replacements:                               7900
# Total Samples:                             12504
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.910629
# Acceptance Rate:                        0.631002
# Replacements:                               7950
# Total Samples:                             12599
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.910634
# Acceptance Rate:                        0.630567
# Replacements:                               8000
# Total Samples:                             12687
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.910640
# Acceptance Rate:                        0.629841
# Replacements:                               8050
# Total Samples:                             12781
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999961
# Acceptance Rate:                        0.629468
# Replacements:                               8100
# Total Samples:                             12868
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999961
# Acceptance Rate:                        0.628907
# Replacements:                               8150
# Total Samples:                             12959
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999961
# Acceptance Rate:                        0.628112
# Replacements:                               8200
# Total Samples:                             13055
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999961
# Acceptance Rate:                        0.627758
# Replacements:                               8250
# Total Samples:                             13142
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999961
# Acceptance Rate:                        0.627125
# Replacements:                               8300
# Total Samples:                             13235
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999962
# Acceptance Rate:                        0.627065
# Replacements:                               8350
# Total Samples:                             13316
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999962
# Acceptance Rate:                        0.626772
# Replacements:                               8400
# Total Samples:                             13402
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999962
# Acceptance Rate:                        0.626343
# Replacements:                               8450
# Total Samples:                             13491
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999962
# Acceptance Rate:                        0.626197
# Replacements:                               8500
# Total Samples:                             13574
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999963
# Acceptance Rate:                        0.625915
# Replacements:                               8550
# Total Samples:                             13660
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999963
# Acceptance Rate:                        0.626001
# Replacements:                               8600
# Total Samples:                             13738
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999963
# Acceptance Rate:                        0.625904
# Replacements:                               8650
# Total Samples:                             13820
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999963
# Acceptance Rate:                        0.625899
# Replacements:                               8700
# Total Samples:                             13900
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999963
# Acceptance Rate:                        0.625760
# Replacements:                               8750
# Total Samples:                             13983
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999964
# Acceptance Rate:                        0.625800
# Replacements:                               8800
# Total Samples:                             14062
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999964
# Acceptance Rate:                        0.625397
# Replacements:                               8850
# Total Samples:                             14151
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999964
# Acceptance Rate:                        0.625088
# Replacements:                               8900
# Total Samples:                             14238
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999964
# Acceptance Rate:                        0.625437
# Replacements:                               8950
# Total Samples:                             14310
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999964
# Acceptance Rate:                        0.625087
# Replacements:                               9000
# Total Samples:                             14398
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999965
# Acceptance Rate:                        0.624267
# Replacements:                               9050
# Total Samples:                             14497
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999965
# Acceptance Rate:                        0.624442
# Replacements:                               9100
# Total Samples:                             14573
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999965
# Acceptance Rate:                        0.624829
# Replacements:                               9150
# Total Samples:                             14644
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999965
# Acceptance Rate:                        0.625723
# Replacements:                               9200
# Total Samples:                             14703
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999965
# Acceptance Rate:                        0.625761
# Replacements:                               9250
# Total Samples:                             14782
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.905304
# Acceptance Rate:                        0.625799
# Replacements:                               9300
# Total Samples:                             14861
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.905304
# Acceptance Rate:                        0.626088
# Replacements:                               9350
# Total Samples:                             14934
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.905304
# Acceptance Rate:                        0.625541
# Replacements:                               9400
# Total Samples:                             15027
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.905305
# Acceptance Rate:                        0.626492
# Replacements:                               9450
# Total Samples:                             15084
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.905305
# Acceptance Rate:                        0.626525
# Replacements:                               9500
# Total Samples:                             15163
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.905305
# Acceptance Rate:                        0.626764
# Replacements:                               9550
# Total Samples:                             15237
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.905305
# Acceptance Rate:                        0.626877
# Replacements:                               9600
# Total Samples:                             15314
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.907179
# Acceptance Rate:                        0.627520
# Replacements:                               9650
# Total Samples:                             15378
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.907179
# Acceptance Rate:                        0.627954
# Replacements:                               9700
# Total Samples:                             15447
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.907179
# Acceptance Rate:                        0.628060
# Replacements:                               9750
# Total Samples:                             15524
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.907179
# Acceptance Rate:                        0.628326
# Replacements:                               9800
# Total Samples:                             15597
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.907179
# Acceptance Rate:                        0.628509
# Replacements:                               9850
# Total Samples:                             15672
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.907179
# Acceptance Rate:                        0.629051
# Replacements:                               9900
# Total Samples:                             15738
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.907180
# Acceptance Rate:                        0.629349
# Replacements:                               9950
# Total Samples:                             15810
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.907180
# Acceptance Rate:                        0.629763
# Replacements:                              10000
# Total Samples:                             15879
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.907180
# ...
# Acceptance Rate:                        0.665997
# Replacements:                              17250
# Total Samples:                             25901
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.073578
# Acceptance Rate:                        0.665948
# Replacements:                              17300
# Total Samples:                             25978
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.070344
# Acceptance Rate:                        0.666129
# Replacements:                              17350
# Total Samples:                             26046
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.068292
# Acceptance Rate:                        0.666258
# Replacements:                              17400
# Total Samples:                             26116
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.066112
# Acceptance Rate:                        0.666183
# Replacements:                              17450
# Total Samples:                             26194
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.063542
# Acceptance Rate:                        0.666159
# Replacements:                              17500
# Total Samples:                             26270
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.061663
# Acceptance Rate:                        0.666414
# Replacements:                              17550
# Total Samples:                             26335
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.059931
# Acceptance Rate:                        0.666490
# Replacements:                              17600
# Total Samples:                             26407
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.058216
# Acceptance Rate:                        0.666516
# Replacements:                              17650
# Total Samples:                             26481
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.056580
# Acceptance Rate:                        0.666717
# Replacements:                              17700
# Total Samples:                             26548
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.054553
# Acceptance Rate:                        0.666792
# Replacements:                              17750
# Total Samples:                             26620
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.052715
# Acceptance Rate:                        0.666866
# Replacements:                              17800
# Total Samples:                             26692
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.050971
# Acceptance Rate:                        0.666318
# Replacements:                              17850
# Total Samples:                             26789
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.049131
# Acceptance Rate:                        0.666047
# Replacements:                              17900
# Total Samples:                             26875
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.047492
# Acceptance Rate:                        0.666122
# Replacements:                              17950
# Total Samples:                             26947
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.045821
# Acceptance Rate:                        0.666124
# Replacements:                              18000
# Total Samples:                             27022
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.045019
# Acceptance Rate:                        0.665880
# Replacements:                              18050
# Total Samples:                             27107
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.043229
# Acceptance Rate:                        0.665759
# Replacements:                              18100
# Total Samples:                             27187
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.042106
# Acceptance Rate:                        0.665737
# Replacements:                              18150
# Total Samples:                             27263
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.040568
# Acceptance Rate:                        0.665764
# Replacements:                              18200
# Total Samples:                             27337
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.039194
# Acceptance Rate:                        0.665767
# Replacements:                              18250
# Total Samples:                             27412
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.038122
# Acceptance Rate:                        0.665866
# Replacements:                              18300
# Total Samples:                             27483
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.036823
# Acceptance Rate:                        0.666062
# Replacements:                              18350
# Total Samples:                             27550
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.035595
# Acceptance Rate:                        0.666449
# Replacements:                              18400
# Total Samples:                             27609
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.035013
# Acceptance Rate:                        0.666618
# Replacements:                              18450
# Total Samples:                             27677
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.033891
# Acceptance Rate:                        0.666739
# Replacements:                              18500
# Total Samples:                             27747
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.032814
# Acceptance Rate:                        0.666786
# Replacements:                              18550
# Total Samples:                             27820
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.031682
# Acceptance Rate:                        0.667049
# Replacements:                              18600
# Total Samples:                             27884
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.030806
# Acceptance Rate:                        0.667382
# Replacements:                              18650
# Total Samples:                             27945
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.029952
# Acceptance Rate:                        0.667738
# Replacements:                              18700
# Total Samples:                             28005
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.029146
# Acceptance Rate:                        0.667759
# Replacements:                              18750
# Total Samples:                             28079
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.028161
# Acceptance Rate:                        0.667946
# Replacements:                              18800
# Total Samples:                             28146
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.027283
# Acceptance Rate:                        0.668226
# Replacements:                              18850
# Total Samples:                             28209
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.026447
# Acceptance Rate:                        0.668506
# Replacements:                              18900
# Total Samples:                             28272
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.025751
# Acceptance Rate:                        0.668713
# Replacements:                              18950
# Total Samples:                             28338
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.024969
# Acceptance Rate:                        0.668991
# Replacements:                              19000
# Total Samples:                             28401
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.024355
# Acceptance Rate:                        0.669172
# Replacements:                              19050
# Total Samples:                             28468
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.023584
# Acceptance Rate:                        0.669213
# Replacements:                              19100
# Total Samples:                             28541
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.022834
# Acceptance Rate:                        0.669346
# Replacements:                              19150
# Total Samples:                             28610
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.022172
# Acceptance Rate:                        0.669596
# Replacements:                              19200
# Total Samples:                             28674
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.021656
# Acceptance Rate:                        0.669821
# Replacements:                              19250
# Total Samples:                             28739
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.021040
# Acceptance Rate:                        0.669976
# Replacements:                              19300
# Total Samples:                             28807
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.020454
# Acceptance Rate:                        0.670083
# Replacements:                              19350
# Total Samples:                             28877
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.019902
# Acceptance Rate:                        0.670260
# Replacements:                              19400
# Total Samples:                             28944
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.019347
# Acceptance Rate:                        0.670458
# Replacements:                              19450
# Total Samples:                             29010
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.018856
# Acceptance Rate:                        0.670748
# Replacements:                              19500
# Total Samples:                             29072
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.018426
# Acceptance Rate:                        0.670945
# Replacements:                              19550
# Total Samples:                             29138
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.017964
# Acceptance Rate:                        0.671233
# Replacements:                              19600
# Total Samples:                             29200
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.017551
# Acceptance Rate:                        0.671313
# Replacements:                              19650
# Total Samples:                             29271
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.017112
# Acceptance Rate:                        0.671278
# Replacements:                              19700
# Total Samples:                             29347
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.016661
# Acceptance Rate:                        0.671472
# Replacements:                              19750
# Total Samples:                             29413
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.016304
# Acceptance Rate:                        0.671323
# Replacements:                              19800
# Total Samples:                             29494
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.015877
# Acceptance Rate:                        0.671606
# Replacements:                              19850
# Total Samples:                             29556
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.015587
# Acceptance Rate:                        0.671843
# Replacements:                              19900
# Total Samples:                             29620
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.015302
# Acceptance Rate:                        0.672238
# Replacements:                              19950
# Total Samples:                             29677
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.015071
# Acceptance Rate:                        0.672382
# Replacements:                              20000
# Total Samples:                             29745
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.014795
# Acceptance Rate:                        0.672706
# Replacements:                              20050
# Total Samples:                             29805
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.014579
# Acceptance Rate:                        0.672826
# Replacements:                              20100
# Total Samples:                             29874
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.014338
# Acceptance Rate:                        0.672968
# Replacements:                              20150
# Total Samples:                             29942
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.014125
# Acceptance Rate:                        0.673087
# Replacements:                              20200
# Total Samples:                             30011
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.013917
# Acceptance Rate:                        0.673087
# Replacements:                              20233
# Total Samples:                             30060
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.013779
#  ln(ev)=   50323307.596470840      +/-  0.14965032578563739
#  Total Likelihood Evaluations:        30060
#  Sampling finished. Exiting MultiNest

# %%
folder = "triple_1019"

# save_clusters(
#     ((('101900550010', "crab_data/1019"), ('101900590010', "crab_data/1019"), ('101900600010', "crab_data/1019")),),
#     folder
# )

pointings = load_clusters(folder)
source_model = define_sources((
    (crab_pl_fixed_pos, (40,)),
    (_1A_0535_262_pl, (40,)),
))

multinest_fit = MultinestClusterFit(
    pointings,
    source_model,
    rebin_data_exp,
    (None, 80),
    np.geomspace(18, 150, 50),
    true_values(),
    folder,
)

multinest_fit.parameter_fit_distribution()
multinest_fit.text_summaries()
multinest_fit.ppc()
# Out:
#  *****************************************************
#  MultiNest v3.10
#  Copyright Farhan Feroz & Mike Hobson
#  Release Jul 2015
#
#  no. of live points =  800
#  dimensionality =    4
#  *****************************************************
#  Starting MultiNest
#  generating live points
#  live points generated, starting sampling
# Acceptance Rate:                        0.998825
# Replacements:                                850
# Total Samples:                               851
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): 6374889.799701 +/-  0.999412
# Acceptance Rate:                        0.994475
# Replacements:                                900
# Total Samples:                               905
# Nested Sampling ln(Z):            1477036.659670
# Importance Nested Sampling ln(Z): 6374889.738178 +/-  0.999447
# Acceptance Rate:                        0.986501
# Replacements:                                950
# Total Samples:                               963
# Nested Sampling ln(Z):            4106042.630487
# Importance Nested Sampling ln(Z): 6374889.676059 +/-  0.999481
# Acceptance Rate:                        0.972763
# Replacements:                               1000
# Total Samples:                              1028
# Nested Sampling ln(Z):            5242986.706873
# Importance Nested Sampling ln(Z): 6374889.610742 +/-  0.999514
# Acceptance Rate:                        0.953678
# Replacements:                               1050
# Total Samples:                              1101
# Nested Sampling ln(Z):            5858180.712054
# Importance Nested Sampling ln(Z): 6375077.447583 +/-  0.999546
# Acceptance Rate:                        0.933786
# Replacements:                               1100
# Total Samples:                              1178
# Nested Sampling ln(Z):            6121800.718316
# Importance Nested Sampling ln(Z): 6375077.376915 +/-  0.999575
# Acceptance Rate:                        0.919265
# Replacements:                               1150
# Total Samples:                              1251
# Nested Sampling ln(Z):            6269156.587727
# Importance Nested Sampling ln(Z): 6375077.289056 +/-  0.999600
# Acceptance Rate:                        0.913938
# Replacements:                               1200
# Total Samples:                              1313
# Nested Sampling ln(Z):            6326697.226648
# Importance Nested Sampling ln(Z): 6375077.207650 +/-  0.999619
# Acceptance Rate:                        0.899281
# Replacements:                               1250
# Total Samples:                              1390
# Nested Sampling ln(Z):            6352570.522858
# Importance Nested Sampling ln(Z): 6375077.109941 +/-  0.999640
# Acceptance Rate:                        0.881356
# Replacements:                               1300
# Total Samples:                              1475
# Nested Sampling ln(Z):            6364399.031620
# Importance Nested Sampling ln(Z): 6375077.005434 +/-  0.999661
# Acceptance Rate:                        0.867609
# Replacements:                               1350
# Total Samples:                              1556
# Nested Sampling ln(Z):            6370535.328450
# Importance Nested Sampling ln(Z): 6375076.919585 +/-  0.999679
# Acceptance Rate:                        0.848485
# Replacements:                               1400
# Total Samples:                              1650
# Nested Sampling ln(Z):            6372168.539112
# Importance Nested Sampling ln(Z): 6375076.814926 +/-  0.999697
# Acceptance Rate:                        0.845481
# Replacements:                               1450
# Total Samples:                              1715
# Nested Sampling ln(Z):            6372753.563452
# Importance Nested Sampling ln(Z): 6375076.748416 +/-  0.999708
# Acceptance Rate:                        0.837054
# Replacements:                               1500
# Total Samples:                              1792
# Nested Sampling ln(Z):            6372755.746644
# Importance Nested Sampling ln(Z): 6375076.662159 +/-  0.999721
# Acceptance Rate:                        0.826226
# Replacements:                               1550
# Total Samples:                              1876
# Nested Sampling ln(Z):            6372756.948406
# Importance Nested Sampling ln(Z): 6375076.581013 +/-  0.999733
# Acceptance Rate:                        0.813835
# Replacements:                               1600
# Total Samples:                              1966
# Nested Sampling ln(Z):            6372758.606293
# Importance Nested Sampling ln(Z): 6375076.492103 +/-  0.999746
# Acceptance Rate:                        0.808031
# Replacements:                               1650
# Total Samples:                              2042
# Nested Sampling ln(Z):            6372761.475989
# Importance Nested Sampling ln(Z): 6375076.423614 +/-  0.999755
# Acceptance Rate:                        0.805687
# Replacements:                               1700
# Total Samples:                              2110
# Nested Sampling ln(Z):            6372764.891967
# Importance Nested Sampling ln(Z): 6375076.365138 +/-  0.999763
# Acceptance Rate:                        0.799452
# Replacements:                               1750
# Total Samples:                              2189
# Nested Sampling ln(Z):            6372768.872164
# Importance Nested Sampling ln(Z): 6375076.293162 +/-  0.999772
# Acceptance Rate:                        0.794001
# Replacements:                               1800
# Total Samples:                              2267
# Nested Sampling ln(Z):            6372774.202635
# Importance Nested Sampling ln(Z): 6375076.224603 +/-  0.999779
# Acceptance Rate:                        0.789923
# Replacements:                               1850
# Total Samples:                              2342
# Nested Sampling ln(Z):            6372780.140406
# Importance Nested Sampling ln(Z): 6375076.160317 +/-  0.999786
# Acceptance Rate:                        0.785773
# Replacements:                               1900
# Total Samples:                              2418
# Nested Sampling ln(Z):            6372787.876410
# Importance Nested Sampling ln(Z): 6375076.093354 +/-  0.999793
# Acceptance Rate:                        0.779688
# Replacements:                               1950
# Total Samples:                              2501
# Nested Sampling ln(Z):            6372798.097292
# Importance Nested Sampling ln(Z): 6375076.019820 +/-  0.999800
# Acceptance Rate:                        0.777001
# Replacements:                               2000
# Total Samples:                              2574
# Nested Sampling ln(Z):            6372808.191043
# Importance Nested Sampling ln(Z): 6375075.958387 +/-  0.999806
# Acceptance Rate:                        0.774169
# Replacements:                               2050
# Total Samples:                              2648
# Nested Sampling ln(Z):            6372821.555094
# Importance Nested Sampling ln(Z): 6375075.890437 +/-  0.999811
# Acceptance Rate:                        0.770077
# Replacements:                               2100
# Total Samples:                              2727
# Nested Sampling ln(Z):            6372835.881401
# Importance Nested Sampling ln(Z): 6375075.827629 +/-  0.999817
# Acceptance Rate:                        0.768131
# Replacements:                               2150
# Total Samples:                              2799
# Nested Sampling ln(Z):            6372849.865460
# Importance Nested Sampling ln(Z): 6375075.761297 +/-  0.999821
# Acceptance Rate:                        0.767353
# Replacements:                               2200
# Total Samples:                              2867
# Nested Sampling ln(Z):            6372864.489444
# Importance Nested Sampling ln(Z): 6375075.706408 +/-  0.999826
# Acceptance Rate:                        0.765306
# Replacements:                               2250
# Total Samples:                              2940
# Nested Sampling ln(Z):            6372879.423630
# Importance Nested Sampling ln(Z): 6375075.643983 +/-  0.999829
# Acceptance Rate:                        0.762852
# Replacements:                               2300
# Total Samples:                              3015
# Nested Sampling ln(Z):            6372891.340606
# Importance Nested Sampling ln(Z): 6375075.575663 +/-  0.999834
# Acceptance Rate:                        0.756600
# Replacements:                               2350
# Total Samples:                              3106
# Nested Sampling ln(Z):            6372905.833353
# Importance Nested Sampling ln(Z): 6375075.492848 +/-  0.999839
# Acceptance Rate:                        0.755668
# Replacements:                               2400
# Total Samples:                              3176
# Nested Sampling ln(Z):            6372920.349769
# Importance Nested Sampling ln(Z): 6375075.430141 +/-  0.999842
# Acceptance Rate:                        0.753151
# Replacements:                               2450
# Total Samples:                              3253
# Nested Sampling ln(Z):            6372935.190679
# Importance Nested Sampling ln(Z): 6375075.366902 +/-  0.999846
# Acceptance Rate:                        0.751428
# Replacements:                               2500
# Total Samples:                              3327
# Nested Sampling ln(Z):            6372948.331488
# Importance Nested Sampling ln(Z): 6375075.305574 +/-  0.999849
# Acceptance Rate:                        0.751105
# Replacements:                               2550
# Total Samples:                              3395
# Nested Sampling ln(Z):            6372961.664340
# Importance Nested Sampling ln(Z): 6375075.243577 +/-  0.999852
# Acceptance Rate:                        0.749712
# Replacements:                               2600
# Total Samples:                              3468
# Nested Sampling ln(Z):            6372972.591421
# Importance Nested Sampling ln(Z): 6375075.182204 +/-  0.999855
# Acceptance Rate:                        0.748165
# Replacements:                               2650
# Total Samples:                              3542
# Nested Sampling ln(Z):            6372989.658087
# Importance Nested Sampling ln(Z): 6375075.197593 +/-  0.921234
# Acceptance Rate:                        0.740944
# Replacements:                               2700
# Total Samples:                              3644
# Nested Sampling ln(Z):            6373003.763996
# Importance Nested Sampling ln(Z): 6375075.100663 +/-  0.921232
# Acceptance Rate:                        0.740641
# Replacements:                               2750
# Total Samples:                              3713
# Nested Sampling ln(Z):            6373016.768064
# Importance Nested Sampling ln(Z): 6375075.037107 +/-  0.921231
# Acceptance Rate:                        0.739372
# Replacements:                               2800
# Total Samples:                              3787
# Nested Sampling ln(Z):            6373026.966145
# Importance Nested Sampling ln(Z): 6375197.322050 +/-  0.999868
# Acceptance Rate:                        0.737196
# Replacements:                               2850
# Total Samples:                              3866
# Nested Sampling ln(Z):            6373036.072936
# Importance Nested Sampling ln(Z): 6375197.253772 +/-  0.999871
# Acceptance Rate:                        0.735108
# Replacements:                               2900
# Total Samples:                              3945
# Nested Sampling ln(Z):            6373046.001115
# Importance Nested Sampling ln(Z): 6375197.184931 +/-  0.999873
# Acceptance Rate:                        0.732373
# Replacements:                               2950
# Total Samples:                              4028
# Nested Sampling ln(Z):            6373056.274047
# Importance Nested Sampling ln(Z): 6375197.112126 +/-  0.999876
# Acceptance Rate:                        0.730994
# Replacements:                               3000
# Total Samples:                              4104
# Nested Sampling ln(Z):            6373065.752781
# Importance Nested Sampling ln(Z): 6375197.042325 +/-  0.999878
# Acceptance Rate:                        0.728271
# Replacements:                               3050
# Total Samples:                              4188
# Nested Sampling ln(Z):            6373088.330836
# Importance Nested Sampling ln(Z): 6375196.970873 +/-  0.999881
# Acceptance Rate:                        0.727358
# Replacements:                               3100
# Total Samples:                              4262
# Nested Sampling ln(Z):            6373115.101398
# Importance Nested Sampling ln(Z): 6375196.908755 +/-  0.999883
# Acceptance Rate:                        0.724971
# Replacements:                               3150
# Total Samples:                              4345
# Nested Sampling ln(Z):            6373150.175604
# Importance Nested Sampling ln(Z): 6375196.837803 +/-  0.999885
# Acceptance Rate:                        0.725130
# Replacements:                               3200
# Total Samples:                              4413
# Nested Sampling ln(Z):            6373182.858789
# Importance Nested Sampling ln(Z): 6375196.783014 +/-  0.999887
# Acceptance Rate:                        0.726744
# Replacements:                               3250
# Total Samples:                              4472
# Nested Sampling ln(Z):            6373214.090984
# Importance Nested Sampling ln(Z): 6375196.727495 +/-  0.999888
# Acceptance Rate:                        0.725434
# Replacements:                               3300
# Total Samples:                              4549
# Nested Sampling ln(Z):            6373239.888668
# Importance Nested Sampling ln(Z): 6375196.659608 +/-  0.999890
# Acceptance Rate:                        0.723698
# Replacements:                               3350
# Total Samples:                              4629
# Nested Sampling ln(Z):            6373276.498075
# Importance Nested Sampling ln(Z): 6375196.590634 +/-  0.999892
# Acceptance Rate:                        0.720950
# Replacements:                               3400
# Total Samples:                              4716
# Nested Sampling ln(Z):            6373310.698700
# Importance Nested Sampling ln(Z): 6375196.521621 +/-  0.999894
# Acceptance Rate:                        0.719199
# Replacements:                               3450
# Total Samples:                              4797
# Nested Sampling ln(Z):            6373344.811396
# Importance Nested Sampling ln(Z): 6375196.455593 +/-  0.999896
# Acceptance Rate:                        0.717507
# Replacements:                               3500
# Total Samples:                              4878
# Nested Sampling ln(Z):            6373373.503167
# Importance Nested Sampling ln(Z): 6375257.027969 +/-  0.999897
# Acceptance Rate:                        0.715293
# Replacements:                               3550
# Total Samples:                              4963
# Nested Sampling ln(Z):            6373404.088450
# Importance Nested Sampling ln(Z): 6375256.955415 +/-  0.999899
# Acceptance Rate:                        0.712871
# Replacements:                               3600
# Total Samples:                              5050
# Nested Sampling ln(Z):            6373439.699075
# Importance Nested Sampling ln(Z): 6375256.877533 +/-  0.999901
# Acceptance Rate:                        0.712334
# Replacements:                               3650
# Total Samples:                              5124
# Nested Sampling ln(Z):            6373470.056635
# Importance Nested Sampling ln(Z): 6375256.814769 +/-  0.999902
# Acceptance Rate:                        0.711675
# Replacements:                               3700
# Total Samples:                              5199
# Nested Sampling ln(Z):            6373501.108920
# Importance Nested Sampling ln(Z): 6375256.750042 +/-  0.999904
# Acceptance Rate:                        0.710766
# Replacements:                               3750
# Total Samples:                              5276
# Nested Sampling ln(Z):            6373533.676140
# Importance Nested Sampling ln(Z): 6375256.684825 +/-  0.999905
# Acceptance Rate:                        0.707899
# Replacements:                               3800
# Total Samples:                              5368
# Nested Sampling ln(Z):            6373568.826808
# Importance Nested Sampling ln(Z): 6375256.611126 +/-  0.999907
# Acceptance Rate:                        0.706292
# Replacements:                               3850
# Total Samples:                              5451
# Nested Sampling ln(Z):            6373602.191244
# Importance Nested Sampling ln(Z): 6375256.544375 +/-  0.999908
# Acceptance Rate:                        0.705499
# Replacements:                               3900
# Total Samples:                              5528
# Nested Sampling ln(Z):            6373628.478630
# Importance Nested Sampling ln(Z): 6375256.483706 +/-  0.999910
# Acceptance Rate:                        0.704100
# Replacements:                               3950
# Total Samples:                              5610
# Nested Sampling ln(Z):            6373656.898306
# Importance Nested Sampling ln(Z): 6375256.420275 +/-  0.999911
# Acceptance Rate:                        0.703977
# Replacements:                               4000
# Total Samples:                              5682
# Nested Sampling ln(Z):            6373682.428253
# Importance Nested Sampling ln(Z): 6375256.359162 +/-  0.999912
# Acceptance Rate:                        0.704103
# Replacements:                               4050
# Total Samples:                              5752
# Nested Sampling ln(Z):            6373713.636670
# Importance Nested Sampling ln(Z): 6375256.304076 +/-  0.999913
# Acceptance Rate:                        0.702897
# Replacements:                               4100
# Total Samples:                              5833
# Nested Sampling ln(Z):            6373736.532323
# Importance Nested Sampling ln(Z): 6375256.238727 +/-  0.999914
# Acceptance Rate:                        0.701725
# Replacements:                               4150
# Total Samples:                              5914
# Nested Sampling ln(Z):            6373763.592920
# Importance Nested Sampling ln(Z): 6375256.175614 +/-  0.999915
# Acceptance Rate:                        0.700350
# Replacements:                               4200
# Total Samples:                              5997
# Nested Sampling ln(Z):            6373788.702310
# Importance Nested Sampling ln(Z): 6375263.056251 +/-  0.998954
# Acceptance Rate:                        0.699819
# Replacements:                               4250
# Total Samples:                              6073
# Nested Sampling ln(Z):            6373813.630897
# Importance Nested Sampling ln(Z): 6375262.990020 +/-  0.998955
# Acceptance Rate:                        0.697599
# Replacements:                               4300
# Total Samples:                              6164
# Nested Sampling ln(Z):            6373833.991920
# Importance Nested Sampling ln(Z): 6375262.916832 +/-  0.998956
# Acceptance Rate:                        0.697786
# Replacements:                               4350
# Total Samples:                              6234
# Nested Sampling ln(Z):            6373852.183274
# Importance Nested Sampling ln(Z): 6375262.861022 +/-  0.998957
# Acceptance Rate:                        0.697416
# Replacements:                               4400
# Total Samples:                              6309
# Nested Sampling ln(Z):            6373868.333939
# Importance Nested Sampling ln(Z): 6375262.803775 +/-  0.998958
# Acceptance Rate:                        0.695639
# Replacements:                               4450
# Total Samples:                              6397
# Nested Sampling ln(Z):            6373888.579205
# Importance Nested Sampling ln(Z): 6375262.733349 +/-  0.998959
# Acceptance Rate:                        0.694337
# Replacements:                               4500
# Total Samples:                              6481
# Nested Sampling ln(Z):            6373905.769055
# Importance Nested Sampling ln(Z): 6375262.665122 +/-  0.998960
# Acceptance Rate:                        0.693703
# Replacements:                               4550
# Total Samples:                              6559
# Nested Sampling ln(Z):            6373921.051409
# Importance Nested Sampling ln(Z): 6375262.604604 +/-  0.998961
# Acceptance Rate:                        0.692146
# Replacements:                               4600
# Total Samples:                              6646
# Nested Sampling ln(Z):            6373935.635332
# Importance Nested Sampling ln(Z): 6375262.533363 +/-  0.998962
# Acceptance Rate:                        0.690423
# Replacements:                               4650
# Total Samples:                              6735
# Nested Sampling ln(Z):            6373953.928518
# Importance Nested Sampling ln(Z): 6375262.463959 +/-  0.998963
# Acceptance Rate:                        0.689554
# Replacements:                               4700
# Total Samples:                              6816
# Nested Sampling ln(Z):            6373978.051505
# Importance Nested Sampling ln(Z): 6375324.053131 +/-  0.999927
# Acceptance Rate:                        0.688206
# Replacements:                               4750
# Total Samples:                              6902
# Nested Sampling ln(Z):            6374000.323591
# Importance Nested Sampling ln(Z): 6375323.983948 +/-  0.999928
# Acceptance Rate:                        0.687581
# Replacements:                               4800
# Total Samples:                              6981
# Nested Sampling ln(Z):            6374026.582183
# Importance Nested Sampling ln(Z): 6375323.923806 +/-  0.999928
# Acceptance Rate:                        0.687651
# Replacements:                               4850
# Total Samples:                              7053
# Nested Sampling ln(Z):            6374054.145036
# Importance Nested Sampling ln(Z): 6375328.160497 +/-  0.986366
# Acceptance Rate:                        0.685411
# Replacements:                               4900
# Total Samples:                              7149
# Nested Sampling ln(Z):            6374082.540060
# Importance Nested Sampling ln(Z): 6375328.081738 +/-  0.986365
# Acceptance Rate:                        0.685026
# Replacements:                               4950
# Total Samples:                              7226
# Nested Sampling ln(Z):            6374112.777961
# Importance Nested Sampling ln(Z): 6375328.016770 +/-  0.986364
# Acceptance Rate:                        0.684463
# Replacements:                               5000
# Total Samples:                              7305
# Nested Sampling ln(Z):            6374135.569536
# Importance Nested Sampling ln(Z): 6375327.953588 +/-  0.986363
# Acceptance Rate:                        0.684282
# Replacements:                               5050
# Total Samples:                              7380
# Nested Sampling ln(Z):            6374165.288367
# Importance Nested Sampling ln(Z): 6375327.895539 +/-  0.986363
# Acceptance Rate:                        0.684013
# Replacements:                               5100
# Total Samples:                              7456
# Nested Sampling ln(Z):            6374191.553569
# Importance Nested Sampling ln(Z): 6375327.833905 +/-  0.986362
# Acceptance Rate:                        0.683931
# Replacements:                               5150
# Total Samples:                              7530
# Nested Sampling ln(Z):            6374219.350476
# Importance Nested Sampling ln(Z): 6375327.773946 +/-  0.986362
# Acceptance Rate:                        0.683671
# Replacements:                               5200
# Total Samples:                              7606
# Nested Sampling ln(Z):            6374250.100104
# Importance Nested Sampling ln(Z): 6375327.711095 +/-  0.986361
# Acceptance Rate:                        0.682527
# Replacements:                               5250
# Total Samples:                              7692
# Nested Sampling ln(Z):            6374285.088741
# Importance Nested Sampling ln(Z): 6375327.639156 +/-  0.986361
# Acceptance Rate:                        0.682023
# Replacements:                               5300
# Total Samples:                              7771
# Nested Sampling ln(Z):            6374315.055755
# Importance Nested Sampling ln(Z): 6375327.579960 +/-  0.986361
# Acceptance Rate:                        0.681789
# Replacements:                               5350
# Total Samples:                              7847
# Nested Sampling ln(Z):            6374348.637463
# Importance Nested Sampling ln(Z): 6375327.514823 +/-  0.986360
# Acceptance Rate:                        0.680101
# Replacements:                               5400
# Total Samples:                              7940
# Nested Sampling ln(Z):            6374382.587889
# Importance Nested Sampling ln(Z): 6375337.794497 +/-  0.999905
# Acceptance Rate:                        0.680060
# Replacements:                               5450
# Total Samples:                              8014
# Nested Sampling ln(Z):            6374415.631562
# Importance Nested Sampling ln(Z): 6375337.728366 +/-  0.999905
# Acceptance Rate:                        0.679432
# Replacements:                               5500
# Total Samples:                              8095
# Nested Sampling ln(Z):            6374446.567965
# Importance Nested Sampling ln(Z): 6375337.666127 +/-  0.999906
# Acceptance Rate:                        0.678982
# Replacements:                               5550
# Total Samples:                              8174
# Nested Sampling ln(Z):            6374470.672680
# Importance Nested Sampling ln(Z): 6375337.608902 +/-  0.999907
# Acceptance Rate:                        0.677474
# Replacements:                               5600
# Total Samples:                              8266
# Nested Sampling ln(Z):            6374501.767347
# Importance Nested Sampling ln(Z): 6375337.544746 +/-  0.999907
# Acceptance Rate:                        0.676323
# Replacements:                               5650
# Total Samples:                              8354
# Nested Sampling ln(Z):            6374526.420534
# Importance Nested Sampling ln(Z): 6375339.990303 +/-  0.922320
# Acceptance Rate:                        0.673759
# Replacements:                               5700
# Total Samples:                              8460
# Nested Sampling ln(Z):            6374550.755847
# Importance Nested Sampling ln(Z): 6375339.919806 +/-  0.922310
# Acceptance Rate:                        0.671415
# Replacements:                               5750
# Total Samples:                              8564
# Nested Sampling ln(Z):            6374570.285964
# Importance Nested Sampling ln(Z): 6375339.851887 +/-  0.922300
# Acceptance Rate:                        0.670055
# Replacements:                               5800
# Total Samples:                              8656
# Nested Sampling ln(Z):            6374599.196399
# Importance Nested Sampling ln(Z): 6375339.782436 +/-  0.922291
# Acceptance Rate:                        0.668037
# Replacements:                               5850
# Total Samples:                              8757
# Nested Sampling ln(Z):            6374626.185655
# Importance Nested Sampling ln(Z): 6375339.712200 +/-  0.922282
# Acceptance Rate:                        0.665614
# Replacements:                               5900
# Total Samples:                              8864
# Nested Sampling ln(Z):            6374650.502565
# Importance Nested Sampling ln(Z): 6375339.634266 +/-  0.922274
# Acceptance Rate:                        0.663544
# Replacements:                               5950
# Total Samples:                              8967
# Nested Sampling ln(Z):            6374670.058198
# Importance Nested Sampling ln(Z): 6375339.569671 +/-  0.922126
# Acceptance Rate:                        0.660502
# Replacements:                               6000
# Total Samples:                              9084
# Nested Sampling ln(Z):            6374691.351606
# Importance Nested Sampling ln(Z): 6375339.499609 +/-  0.922109
# Acceptance Rate:                        0.658253
# Replacements:                               6050
# Total Samples:                              9191
# Nested Sampling ln(Z):            6374710.007977
# Importance Nested Sampling ln(Z): 6375339.441919 +/-  0.919551
# Acceptance Rate:                        0.655773
# Replacements:                               6100
# Total Samples:                              9302
# Nested Sampling ln(Z):            6374728.355014
# Importance Nested Sampling ln(Z): 6375339.380528 +/-  0.919375
# Acceptance Rate:                        0.653213
# Replacements:                               6150
# Total Samples:                              9415
# Nested Sampling ln(Z):            6374748.049564
# Importance Nested Sampling ln(Z): 6375339.320290 +/-  0.919192
# Acceptance Rate:                        0.650850
# Replacements:                               6200
# Total Samples:                              9526
# Nested Sampling ln(Z):            6374765.595829
# Importance Nested Sampling ln(Z): 6375339.266000 +/-  0.919019
# Acceptance Rate:                        0.648139
# Replacements:                               6250
# Total Samples:                              9643
# Nested Sampling ln(Z):            6374782.053468
# Importance Nested Sampling ln(Z): 6375339.213539 +/-  0.918842
# Acceptance Rate:                        0.644765
# Replacements:                               6300
# Total Samples:                              9771
# Nested Sampling ln(Z):            6374800.164002
# Importance Nested Sampling ln(Z): 6375339.169083 +/-  0.918685
# Acceptance Rate:                        0.643690
# Replacements:                               6350
# Total Samples:                              9865
# Nested Sampling ln(Z):            6374816.511659
# Importance Nested Sampling ln(Z): 6375339.133249 +/-  0.918554
# Acceptance Rate:                        0.642570
# Replacements:                               6400
# Total Samples:                              9960
# Nested Sampling ln(Z):            6374830.792578
# Importance Nested Sampling ln(Z): 6375339.096306 +/-  0.918414
# Acceptance Rate:                        0.638867
# Replacements:                               6450
# Total Samples:                             10096
# Nested Sampling ln(Z):            6374844.323984
# Importance Nested Sampling ln(Z): 6375339.045019 +/-  0.918211
# Acceptance Rate:                        0.636631
# Replacements:                               6500
# Total Samples:                             10210
# Nested Sampling ln(Z):            6374863.529594
# Importance Nested Sampling ln(Z): 6375339.003051 +/-  0.918037
# Acceptance Rate:                        0.634444
# Replacements:                               6550
# Total Samples:                             10324
# Nested Sampling ln(Z):            6374876.689652
# Importance Nested Sampling ln(Z): 6375338.956970 +/-  0.917837
# Acceptance Rate:                        0.633823
# Replacements:                               6600
# Total Samples:                             10413
# Nested Sampling ln(Z):            6374887.010278
# Importance Nested Sampling ln(Z): 6375356.511232 +/-  0.999952
# Acceptance Rate:                        0.632972
# Replacements:                               6650
# Total Samples:                             10506
# Nested Sampling ln(Z):            6374901.255216
# Importance Nested Sampling ln(Z): 6375356.449341 +/-  0.999952
# Acceptance Rate:                        0.631361
# Replacements:                               6700
# Total Samples:                             10612
# Nested Sampling ln(Z):            6374912.170819
# Importance Nested Sampling ln(Z): 6375356.384361 +/-  0.999953
# Acceptance Rate:                        0.629723
# Replacements:                               6750
# Total Samples:                             10719
# Nested Sampling ln(Z):            6374926.201832
# Importance Nested Sampling ln(Z): 6375356.320439 +/-  0.999953
# Acceptance Rate:                        0.628059
# Replacements:                               6800
# Total Samples:                             10827
# Nested Sampling ln(Z):            6374939.787559
# Importance Nested Sampling ln(Z): 6375356.256842 +/-  0.999954
# Acceptance Rate:                        0.626888
# Replacements:                               6850
# Total Samples:                             10927
# Nested Sampling ln(Z):            6374951.793851
# Importance Nested Sampling ln(Z): 6375356.205463 +/-  0.999954
# Acceptance Rate:                        0.624943
# Replacements:                               6900
# Total Samples:                             11041
# Nested Sampling ln(Z):            6374961.653634
# Importance Nested Sampling ln(Z): 6375356.161180 +/-  0.999955
# Acceptance Rate:                        0.623374
# Replacements:                               6950
# Total Samples:                             11149
# Nested Sampling ln(Z):            6374972.623861
# Importance Nested Sampling ln(Z): 6375356.115033 +/-  0.999955
# Acceptance Rate:                        0.620347
# Replacements:                               7000
# Total Samples:                             11284
# Nested Sampling ln(Z):            6374981.678925
# Importance Nested Sampling ln(Z): 6375356.061682 +/-  0.999101
# Acceptance Rate:                        0.618964
# Replacements:                               7050
# Total Samples:                             11390
# Nested Sampling ln(Z):            6374990.742519
# Importance Nested Sampling ln(Z): 6375356.013293 +/-  0.999102
# Acceptance Rate:                        0.617875
# Replacements:                               7100
# Total Samples:                             11491
# Nested Sampling ln(Z):            6375000.458366
# Importance Nested Sampling ln(Z): 6375355.967176 +/-  0.999102
# Acceptance Rate:                        0.616698
# Replacements:                               7150
# Total Samples:                             11594
# Nested Sampling ln(Z):            6375010.534329
# Importance Nested Sampling ln(Z): 6375355.919140 +/-  0.999102
# Acceptance Rate:                        0.614912
# Replacements:                               7200
# Total Samples:                             11709
# Nested Sampling ln(Z):            6375021.964574
# Importance Nested Sampling ln(Z): 6375355.866876 +/-  0.999102
# Acceptance Rate:                        0.613212
# Replacements:                               7250
# Total Samples:                             11823
# Nested Sampling ln(Z):            6375031.177464
# Importance Nested Sampling ln(Z): 6375355.814988 +/-  0.999103
# Acceptance Rate:                        0.612211
# Replacements:                               7300
# Total Samples:                             11924
# Nested Sampling ln(Z):            6375039.931315
# Importance Nested Sampling ln(Z): 6375355.767087 +/-  0.999073
# Acceptance Rate:                        0.610161
# Replacements:                               7350
# Total Samples:                             12046
# Nested Sampling ln(Z):            6375049.454468
# Importance Nested Sampling ln(Z): 6375355.712095 +/-  0.999073
# Acceptance Rate:                        0.607005
# Replacements:                               7400
# Total Samples:                             12191
# Nested Sampling ln(Z):            6375059.043254
# Importance Nested Sampling ln(Z): 6375355.649516 +/-  0.999073
# Acceptance Rate:                        0.605199
# Replacements:                               7450
# Total Samples:                             12310
# Nested Sampling ln(Z):            6375069.328010
# Importance Nested Sampling ln(Z): 6375355.597304 +/-  0.999071
# Acceptance Rate:                        0.602555
# Replacements:                               7500
# Total Samples:                             12447
# Nested Sampling ln(Z):            6375077.455773
# Importance Nested Sampling ln(Z): 6375355.538391 +/-  0.999068
# Acceptance Rate:                        0.601881
# Replacements:                               7550
# Total Samples:                             12544
# Nested Sampling ln(Z):            6375086.274459
# Importance Nested Sampling ln(Z): 6375355.485017 +/-  0.999069
# Acceptance Rate:                        0.601028
# Replacements:                               7600
# Total Samples:                             12645
# Nested Sampling ln(Z):            6375094.441119
# Importance Nested Sampling ln(Z): 6375355.430740 +/-  0.999063
# Acceptance Rate:                        0.600518
# Replacements:                               7650
# Total Samples:                             12739
# Nested Sampling ln(Z):            6375102.598274
# Importance Nested Sampling ln(Z): 6375355.379757 +/-  0.999063
# Acceptance Rate:                        0.600203
# Replacements:                               7700
# Total Samples:                             12829
# Nested Sampling ln(Z):            6375109.645108
# Importance Nested Sampling ln(Z): 6375355.323419 +/-  0.999064
# Acceptance Rate:                        0.600496
# Replacements:                               7750
# Total Samples:                             12906
# Nested Sampling ln(Z):            6375117.249978
# Importance Nested Sampling ln(Z): 6375355.274791 +/-  0.999064
# Acceptance Rate:                        0.599769
# Replacements:                               7800
# Total Samples:                             13005
# Nested Sampling ln(Z):            6375126.154662
# Importance Nested Sampling ln(Z): 6375355.216784 +/-  0.996558
# Acceptance Rate:                        0.598643
# Replacements:                               7850
# Total Samples:                             13113
# Nested Sampling ln(Z):            6375132.420836
# Importance Nested Sampling ln(Z): 6375355.148520 +/-  0.996559
# Acceptance Rate:                        0.598802
# Replacements:                               7900
# Total Samples:                             13193
# Nested Sampling ln(Z):            6375138.525533
# Importance Nested Sampling ln(Z): 6375355.099483 +/-  0.996559
# Acceptance Rate:                        0.598374
# Replacements:                               7950
# Total Samples:                             13286
# Nested Sampling ln(Z):            6375144.118895
# Importance Nested Sampling ln(Z): 6375355.044478 +/-  0.996557
# Acceptance Rate:                        0.596525
# Replacements:                               8000
# Total Samples:                             13411
# Nested Sampling ln(Z):            6375151.690818
# Importance Nested Sampling ln(Z): 6375354.975001 +/-  0.996557
# Acceptance Rate:                        0.595326
# Replacements:                               8050
# Total Samples:                             13522
# Nested Sampling ln(Z):            6375158.355809
# Importance Nested Sampling ln(Z): 6375354.916324 +/-  0.996554
# Acceptance Rate:                        0.594408
# Replacements:                               8100
# Total Samples:                             13627
# Nested Sampling ln(Z):            6375164.505624
# Importance Nested Sampling ln(Z): 6375354.861825 +/-  0.996554
# Acceptance Rate:                        0.592598
# Replacements:                               8150
# Total Samples:                             13753
# Nested Sampling ln(Z):            6375169.458042
# Importance Nested Sampling ln(Z): 6375354.798204 +/-  0.996554
# Acceptance Rate:                        0.591503
# Replacements:                               8200
# Total Samples:                             13863
# Nested Sampling ln(Z):            6375174.627335
# Importance Nested Sampling ln(Z): 6375354.740565 +/-  0.996555
# Acceptance Rate:                        0.590805
# Replacements:                               8250
# Total Samples:                             13964
# Nested Sampling ln(Z):            6375181.004928
# Importance Nested Sampling ln(Z): 6375354.679480 +/-  0.996311
# Acceptance Rate:                        0.590579
# Replacements:                               8300
# Total Samples:                             14054
# Nested Sampling ln(Z):            6375187.061344
# Importance Nested Sampling ln(Z): 6375354.623636 +/-  0.996287
# Acceptance Rate:                        0.590732
# Replacements:                               8350
# Total Samples:                             14135
# Nested Sampling ln(Z):            6375191.977850
# Importance Nested Sampling ln(Z): 6375354.569281 +/-  0.996287
# Acceptance Rate:                        0.591008
# Replacements:                               8400
# Total Samples:                             14213
# Nested Sampling ln(Z):            6375197.461786
# Importance Nested Sampling ln(Z): 6375355.997953 +/-  0.806233
# Acceptance Rate:                        0.591323
# Replacements:                               8450
# Total Samples:                             14290
# Nested Sampling ln(Z):            6375202.303845
# Importance Nested Sampling ln(Z): 6375355.937347 +/-  0.806231
# Acceptance Rate:                        0.591099
# Replacements:                               8500
# Total Samples:                             14380
# Nested Sampling ln(Z):            6375206.539196
# Importance Nested Sampling ln(Z): 6375355.870869 +/-  0.806232
# Acceptance Rate:                        0.591041
# Replacements:                               8550
# Total Samples:                             14466
# Nested Sampling ln(Z):            6375211.109795
# Importance Nested Sampling ln(Z): 6375355.807963 +/-  0.806227
# Acceptance Rate:                        0.591472
# Replacements:                               8600
# Total Samples:                             14540
# Nested Sampling ln(Z):            6375216.152704
# Importance Nested Sampling ln(Z): 6375355.762786 +/-  0.795661
# Acceptance Rate:                        0.591130
# Replacements:                               8650
# Total Samples:                             14633
# Nested Sampling ln(Z):            6375219.507064
# Importance Nested Sampling ln(Z): 6375355.691588 +/-  0.794802
# Acceptance Rate:                        0.591394
# Replacements:                               8700
# Total Samples:                             14711
# Nested Sampling ln(Z):            6375223.470726
# Importance Nested Sampling ln(Z): 6375357.058050 +/-  0.782886
# Acceptance Rate:                        0.591056
# Replacements:                               8750
# Total Samples:                             14804
# Nested Sampling ln(Z):            6375227.204477
# Importance Nested Sampling ln(Z): 6375356.992102 +/-  0.782886
# Acceptance Rate:                        0.591159
# Replacements:                               8800
# Total Samples:                             14886
# Nested Sampling ln(Z):            6375231.065413
# Importance Nested Sampling ln(Z): 6375356.934446 +/-  0.782887
# Acceptance Rate:                        0.591657
# Replacements:                               8850
# Total Samples:                             14958
# Nested Sampling ln(Z):            6375234.711855
# Importance Nested Sampling ln(Z): 6375356.880616 +/-  0.782887
# Acceptance Rate:                        0.592267
# Replacements:                               8900
# Total Samples:                             15027
# Nested Sampling ln(Z):            6375237.967203
# Importance Nested Sampling ln(Z): 6375357.067403 +/-  0.648862
# Acceptance Rate:                        0.592951
# Replacements:                               8950
# Total Samples:                             15094
# Nested Sampling ln(Z):            6375241.771704
# Importance Nested Sampling ln(Z): 6375357.049542 +/-  0.625850
# Acceptance Rate:                        0.593120
# Replacements:                               9000
# Total Samples:                             15174
# Nested Sampling ln(Z):            6375246.769198
# Importance Nested Sampling ln(Z): 6375356.983251 +/-  0.625850
# Acceptance Rate:                        0.593209
# Replacements:                               9050
# Total Samples:                             15256
# Nested Sampling ln(Z):            6375251.076625
# Importance Nested Sampling ln(Z): 6375357.396627 +/-  0.481614
# Acceptance Rate:                        0.593375
# Replacements:                               9100
# Total Samples:                             15336
# Nested Sampling ln(Z):            6375254.792189
# Importance Nested Sampling ln(Z): 6375357.354795 +/-  0.470857
# Acceptance Rate:                        0.593847
# Replacements:                               9150
# Total Samples:                             15408
# Nested Sampling ln(Z):            6375257.616818
# Importance Nested Sampling ln(Z): 6375357.297146 +/-  0.470847
# Acceptance Rate:                        0.594085
# Replacements:                               9200
# Total Samples:                             15486
# Nested Sampling ln(Z):            6375261.244254
# Importance Nested Sampling ln(Z): 6375357.236966 +/-  0.470842
# Acceptance Rate:                        0.593939
# Replacements:                               9250
# Total Samples:                             15574
# Nested Sampling ln(Z):            6375264.711737
# Importance Nested Sampling ln(Z): 6375357.304954 +/-  0.422440
# Acceptance Rate:                        0.594363
# Replacements:                               9300
# Total Samples:                             15647
# Nested Sampling ln(Z):            6375267.376198
# Importance Nested Sampling ln(Z): 6375357.245658 +/-  0.422409
# Acceptance Rate:                        0.594443
# Replacements:                               9350
# Total Samples:                             15729
# Nested Sampling ln(Z):            6375270.636711
# Importance Nested Sampling ln(Z): 6375357.182459 +/-  0.421377
# Acceptance Rate:                        0.594485
# Replacements:                               9400
# Total Samples:                             15812
# Nested Sampling ln(Z):            6375273.981819
# Importance Nested Sampling ln(Z): 6375360.632496 +/-  0.970385
# Acceptance Rate:                        0.594789
# Replacements:                               9450
# Total Samples:                             15888
# Nested Sampling ln(Z):            6375276.896340
# Importance Nested Sampling ln(Z): 6375360.571603 +/-  0.970223
# Acceptance Rate:                        0.594233
# Replacements:                               9500
# Total Samples:                             15987
# Nested Sampling ln(Z):            6375280.099115
# Importance Nested Sampling ln(Z): 6375360.495712 +/-  0.970223
# Acceptance Rate:                        0.594460
# Replacements:                               9550
# Total Samples:                             16065
# Nested Sampling ln(Z):            6375282.167882
# Importance Nested Sampling ln(Z): 6375360.471481 +/-  0.940017
# Acceptance Rate:                        0.594611
# Replacements:                               9600
# Total Samples:                             16145
# Nested Sampling ln(Z):            6375284.441764
# Importance Nested Sampling ln(Z): 6375360.421062 +/-  0.932712
# Acceptance Rate:                        0.594834
# Replacements:                               9650
# Total Samples:                             16223
# Nested Sampling ln(Z):            6375286.684878
# Importance Nested Sampling ln(Z): 6375360.409202 +/-  0.892316
# Acceptance Rate:                        0.595165
# Replacements:                               9700
# Total Samples:                             16298
# Nested Sampling ln(Z):            6375288.910666
# Importance Nested Sampling ln(Z): 6375360.418687 +/-  0.839355
# Acceptance Rate:                        0.594802
# Replacements:                               9750
# Total Samples:                             16392
# Nested Sampling ln(Z):            6375290.815472
# Importance Nested Sampling ln(Z): 6375360.353111 +/-  0.838830
# Acceptance Rate:                        0.594949
# Replacements:                               9800
# Total Samples:                             16472
# Nested Sampling ln(Z):            6375292.939036
# Importance Nested Sampling ln(Z): 6375360.320641 +/-  0.821039
# Acceptance Rate:                        0.594555
# Replacements:                               9850
# Total Samples:                             16567
# Nested Sampling ln(Z):            6375294.989333
# Importance Nested Sampling ln(Z): 6375360.258280 +/-  0.820565
# Acceptance Rate:                        0.595023
# Replacements:                               9900
# Total Samples:                             16638
# Nested Sampling ln(Z):            6375297.332364
# Importance Nested Sampling ln(Z): 6375360.585859 +/-  0.643039
# Acceptance Rate:                        0.595630
# Replacements:                               9950
# Total Samples:                             16705
# Nested Sampling ln(Z):            6375299.208068
# Importance Nested Sampling ln(Z): 6375360.530488 +/-  0.642862
# Acceptance Rate:                        0.595806
# Replacements:                              10000
# Total Samples:                             16784
# Nested Sampling ln(Z):            6375301.042412
# Importance Nested Sampling ln(Z): 6375360.471237 +/-  0.638547
# ...
# Acceptance Rate:                        0.612028
# Replacements:                              13800
# Total Samples:                             22548
# Nested Sampling ln(Z):            6375357.292894
# Importance Nested Sampling ln(Z): 6375361.147225 +/-  0.069246
# Acceptance Rate:                        0.612019
# Replacements:                              13850
# Total Samples:                             22630
# Nested Sampling ln(Z):            6375357.459145
# Importance Nested Sampling ln(Z): 6375361.141111 +/-  0.067186
# Acceptance Rate:                        0.611984
# Replacements:                              13900
# Total Samples:                             22713
# Nested Sampling ln(Z):            6375357.620717
# Importance Nested Sampling ln(Z): 6375361.125531 +/-  0.065323
# Acceptance Rate:                        0.611440
# Replacements:                              13950
# Total Samples:                             22815
# Nested Sampling ln(Z):            6375357.778444
# Importance Nested Sampling ln(Z): 6375361.097168 +/-  0.062655
# Acceptance Rate:                        0.611461
# Replacements:                              14000
# Total Samples:                             22896
# Nested Sampling ln(Z):            6375357.929077
# Importance Nested Sampling ln(Z): 6375361.099094 +/-  0.060554
# Acceptance Rate:                        0.611721
# Replacements:                              14050
# Total Samples:                             22968
# Nested Sampling ln(Z):            6375358.068394
# Importance Nested Sampling ln(Z): 6375361.094845 +/-  0.058409
# Acceptance Rate:                        0.611899
# Replacements:                              14100
# Total Samples:                             23043
# Nested Sampling ln(Z):            6375358.201240
# Importance Nested Sampling ln(Z): 6375361.085571 +/-  0.056781
# Acceptance Rate:                        0.611813
# Replacements:                              14150
# Total Samples:                             23128
# Nested Sampling ln(Z):            6375358.328576
# Importance Nested Sampling ln(Z): 6375361.081672 +/-  0.054755
# Acceptance Rate:                        0.611832
# Replacements:                              14200
# Total Samples:                             23209
# Nested Sampling ln(Z):            6375358.450132
# Importance Nested Sampling ln(Z): 6375361.085424 +/-  0.052708
# Acceptance Rate:                        0.611903
# Replacements:                              14250
# Total Samples:                             23288
# Nested Sampling ln(Z):            6375358.567134
# Importance Nested Sampling ln(Z): 6375361.084857 +/-  0.051399
# Acceptance Rate:                        0.611843
# Replacements:                              14300
# Total Samples:                             23372
# Nested Sampling ln(Z):            6375358.679969
# Importance Nested Sampling ln(Z): 6375361.102096 +/-  0.050317
# Acceptance Rate:                        0.611862
# Replacements:                              14350
# Total Samples:                             23453
# Nested Sampling ln(Z):            6375358.788782
# Importance Nested Sampling ln(Z): 6375361.091781 +/-  0.048696
# Acceptance Rate:                        0.612141
# Replacements:                              14400
# Total Samples:                             23524
# Nested Sampling ln(Z):            6375358.894923
# Importance Nested Sampling ln(Z): 6375361.100420 +/-  0.047229
# Acceptance Rate:                        0.612392
# Replacements:                              14450
# Total Samples:                             23596
# Nested Sampling ln(Z):            6375358.995908
# Importance Nested Sampling ln(Z): 6375361.108554 +/-  0.046094
# Acceptance Rate:                        0.612279
# Replacements:                              14500
# Total Samples:                             23682
# Nested Sampling ln(Z):            6375359.093770
# Importance Nested Sampling ln(Z): 6375361.104446 +/-  0.044732
# Acceptance Rate:                        0.612374
# Replacements:                              14550
# Total Samples:                             23760
# Nested Sampling ln(Z):            6375359.187330
# Importance Nested Sampling ln(Z): 6375361.101264 +/-  0.043527
# Acceptance Rate:                        0.612776
# Replacements:                              14600
# Total Samples:                             23826
# Nested Sampling ln(Z):            6375359.275371
# Importance Nested Sampling ln(Z): 6375361.094328 +/-  0.042410
# Acceptance Rate:                        0.612561
# Replacements:                              14650
# Total Samples:                             23916
# Nested Sampling ln(Z):            6375359.360512
# Importance Nested Sampling ln(Z): 6375361.090834 +/-  0.041123
# Acceptance Rate:                        0.612398
# Replacements:                              14700
# Total Samples:                             24004
# Nested Sampling ln(Z):            6375359.440284
# Importance Nested Sampling ln(Z): 6375361.094676 +/-  0.040399
# Acceptance Rate:                        0.612643
# Replacements:                              14750
# Total Samples:                             24076
# Nested Sampling ln(Z):            6375359.517828
# Importance Nested Sampling ln(Z): 6375361.083639 +/-  0.039229
# Acceptance Rate:                        0.612456
# Replacements:                              14800
# Total Samples:                             24165
# Nested Sampling ln(Z):            6375359.592844
# Importance Nested Sampling ln(Z): 6375361.072114 +/-  0.037850
# Acceptance Rate:                        0.612447
# Replacements:                              14850
# Total Samples:                             24247
# Nested Sampling ln(Z):            6375359.667326
# Importance Nested Sampling ln(Z): 6375361.065132 +/-  0.036480
# Acceptance Rate:                        0.612488
# Replacements:                              14900
# Total Samples:                             24327
# Nested Sampling ln(Z):            6375359.740384
# Importance Nested Sampling ln(Z): 6375361.054571 +/-  0.035214
# Acceptance Rate:                        0.612429
# Replacements:                              14950
# Total Samples:                             24411
# Nested Sampling ln(Z):            6375359.810612
# Importance Nested Sampling ln(Z): 6375361.049048 +/-  0.033996
# Acceptance Rate:                        0.612070
# Replacements:                              15000
# Total Samples:                             24507
# Nested Sampling ln(Z):            6375359.878233
# Importance Nested Sampling ln(Z): 6375361.046044 +/-  0.032907
# Acceptance Rate:                        0.611938
# Replacements:                              15050
# Total Samples:                             24594
# Nested Sampling ln(Z):            6375359.943180
# Importance Nested Sampling ln(Z): 6375361.050108 +/-  0.031869
# Acceptance Rate:                        0.611608
# Replacements:                              15100
# Total Samples:                             24689
# Nested Sampling ln(Z):            6375360.004823
# Importance Nested Sampling ln(Z): 6375361.046049 +/-  0.030821
# Acceptance Rate:                        0.611775
# Replacements:                              15150
# Total Samples:                             24764
# Nested Sampling ln(Z):            6375360.064489
# Importance Nested Sampling ln(Z): 6375361.045633 +/-  0.029915
# Acceptance Rate:                        0.611966
# Replacements:                              15200
# Total Samples:                             24838
# Nested Sampling ln(Z):            6375360.121638
# Importance Nested Sampling ln(Z): 6375361.056079 +/-  0.029186
# Acceptance Rate:                        0.612007
# Replacements:                              15250
# Total Samples:                             24918
# Nested Sampling ln(Z):            6375360.176415
# Importance Nested Sampling ln(Z): 6375361.057975 +/-  0.028350
# Acceptance Rate:                        0.611486
# Replacements:                              15300
# Total Samples:                             25021
# Nested Sampling ln(Z):            6375360.229146
# Importance Nested Sampling ln(Z): 6375361.049829 +/-  0.027261
# Acceptance Rate:                        0.611189
# Replacements:                              15350
# Total Samples:                             25115
# Nested Sampling ln(Z):            6375360.279452
# Importance Nested Sampling ln(Z): 6375361.046356 +/-  0.026384
# Acceptance Rate:                        0.610844
# Replacements:                              15400
# Total Samples:                             25211
# Nested Sampling ln(Z):            6375360.327858
# Importance Nested Sampling ln(Z): 6375361.046236 +/-  0.025540
# Acceptance Rate:                        0.610841
# Replacements:                              15450
# Total Samples:                             25293
# Nested Sampling ln(Z):            6375360.373907
# Importance Nested Sampling ln(Z): 6375361.047625 +/-  0.024771
# Acceptance Rate:                        0.610982
# Replacements:                              15500
# Total Samples:                             25369
# Nested Sampling ln(Z):            6375360.418218
# Importance Nested Sampling ln(Z): 6375361.050288 +/-  0.024093
# Acceptance Rate:                        0.610858
# Replacements:                              15550
# Total Samples:                             25456
# Nested Sampling ln(Z):            6375360.460808
# Importance Nested Sampling ln(Z): 6375361.051728 +/-  0.023431
# Acceptance Rate:                        0.610830
# Replacements:                              15600
# Total Samples:                             25539
# Nested Sampling ln(Z):            6375360.501450
# Importance Nested Sampling ln(Z): 6375361.050468 +/-  0.022686
# Acceptance Rate:                        0.610756
# Replacements:                              15650
# Total Samples:                             25624
# Nested Sampling ln(Z):            6375360.540264
# Importance Nested Sampling ln(Z): 6375361.050540 +/-  0.022044
# Acceptance Rate:                        0.610681
# Replacements:                              15700
# Total Samples:                             25709
# Nested Sampling ln(Z):            6375360.577324
# Importance Nested Sampling ln(Z): 6375361.046412 +/-  0.021360
# Acceptance Rate:                        0.610394
# Replacements:                              15750
# Total Samples:                             25803
# Nested Sampling ln(Z):            6375360.613143
# Importance Nested Sampling ln(Z): 6375361.040965 +/-  0.020633
# Acceptance Rate:                        0.610062
# Replacements:                              15800
# Total Samples:                             25899
# Nested Sampling ln(Z):            6375360.647293
# Importance Nested Sampling ln(Z): 6375361.035716 +/-  0.019904
# Acceptance Rate:                        0.609639
# Replacements:                              15850
# Total Samples:                             25999
# Nested Sampling ln(Z):            6375360.679936
# Importance Nested Sampling ln(Z): 6375361.034101 +/-  0.019277
# Acceptance Rate:                        0.609476
# Replacements:                              15900
# Total Samples:                             26088
# Nested Sampling ln(Z):            6375360.711080
# Importance Nested Sampling ln(Z): 6375361.035955 +/-  0.018744
# Acceptance Rate:                        0.609337
# Replacements:                              15950
# Total Samples:                             26176
# Nested Sampling ln(Z):            6375360.740682
# Importance Nested Sampling ln(Z): 6375361.035136 +/-  0.018196
# Acceptance Rate:                        0.609547
# Replacements:                              16000
# Total Samples:                             26249
# Nested Sampling ln(Z):            6375360.769027
# Importance Nested Sampling ln(Z): 6375361.038128 +/-  0.017798
# Acceptance Rate:                        0.609455
# Replacements:                              16050
# Total Samples:                             26335
# Nested Sampling ln(Z):            6375360.796098
# Importance Nested Sampling ln(Z): 6375361.037497 +/-  0.017310
# Acceptance Rate:                        0.608995
# Replacements:                              16100
# Total Samples:                             26437
# Nested Sampling ln(Z):            6375360.821788
# Importance Nested Sampling ln(Z): 6375361.038050 +/-  0.016809
# Acceptance Rate:                        0.608860
# Replacements:                              16150
# Total Samples:                             26525
# Nested Sampling ln(Z):            6375360.846243
# Importance Nested Sampling ln(Z): 6375361.038847 +/-  0.016389
# Acceptance Rate:                        0.609000
# Replacements:                              16200
# Total Samples:                             26601
# Nested Sampling ln(Z):            6375360.869614
# Importance Nested Sampling ln(Z): 6375361.038349 +/-  0.016006
# Acceptance Rate:                        0.609070
# Replacements:                              16250
# Total Samples:                             26680
# Nested Sampling ln(Z):            6375360.891889
# Importance Nested Sampling ln(Z): 6375361.038969 +/-  0.015656
# Acceptance Rate:                        0.608822
# Replacements:                              16300
# Total Samples:                             26773
# Nested Sampling ln(Z):            6375360.913179
# Importance Nested Sampling ln(Z): 6375361.037811 +/-  0.015261
# Acceptance Rate:                        0.608576
# Replacements:                              16350
# Total Samples:                             26866
# Nested Sampling ln(Z):            6375360.933548
# Importance Nested Sampling ln(Z): 6375361.037547 +/-  0.014898
# Acceptance Rate:                        0.608399
# Replacements:                              16400
# Total Samples:                             26956
# Nested Sampling ln(Z):            6375360.953033
# Importance Nested Sampling ln(Z): 6375361.038684 +/-  0.014580
# Acceptance Rate:                        0.608268
# Replacements:                              16450
# Total Samples:                             27044
# Nested Sampling ln(Z):            6375360.971654
# Importance Nested Sampling ln(Z): 6375361.038746 +/-  0.014273
# Acceptance Rate:                        0.608385
# Replacements:                              16500
# Total Samples:                             27121
# Nested Sampling ln(Z):            6375360.989325
# Importance Nested Sampling ln(Z): 6375361.040426 +/-  0.014031
# Acceptance Rate:                        0.608076
# Replacements:                              16550
# Total Samples:                             27217
# Nested Sampling ln(Z):            6375361.006143
# Importance Nested Sampling ln(Z): 6375361.039082 +/-  0.013725
# Acceptance Rate:                        0.608059
# Replacements:                              16600
# Total Samples:                             27300
# Nested Sampling ln(Z):            6375361.022206
# Importance Nested Sampling ln(Z): 6375361.037983 +/-  0.013473
# Acceptance Rate:                        0.607975
# Replacements:                              16650
# Total Samples:                             27386
# Nested Sampling ln(Z):            6375361.037625
# Importance Nested Sampling ln(Z): 6375361.037631 +/-  0.013235
# Acceptance Rate:                        0.607914
# Replacements:                              16700
# Total Samples:                             27471
# Nested Sampling ln(Z):            6375361.052275
# Importance Nested Sampling ln(Z): 6375361.038987 +/-  0.013010
# Acceptance Rate:                        0.607831
# Replacements:                              16750
# Total Samples:                             27557
# Nested Sampling ln(Z):            6375361.066189
# Importance Nested Sampling ln(Z): 6375361.040255 +/-  0.012803
# Acceptance Rate:                        0.607888
# Replacements:                              16785
# Total Samples:                             27612
# Nested Sampling ln(Z):            6375361.075608
# Importance Nested Sampling ln(Z): 6375361.040506 +/-  0.012672
#  ln(ev)=   6375361.3293437231      +/-  0.14651604643011604
#  Total Likelihood Evaluations:        27612
#  Sampling finished. Exiting MultiNest

# %%
folder = "orbit_1019_extended"

# pointings = PointingClusters(
#     ("crab_data/1019",),
#     min_angle_dif=1.5,
#     max_angle_dif=4.,
#     max_time_dif=0.2,
#     radius_around_crab=5.,
#     min_time_elapsed=600.,
#     cluster_size_range=(2,2),
# ).pointings
# save_clusters(pointings, folder)

pointings = load_clusters(folder)
source_model = define_sources((
    (crab_pl_free_pos, (40,)),
    (_1A_0535_262_pl, (40,)),
    (geminga_pl, (40,)),
    (_4U_0517_17_pl, (40,)),
    (_4U_0614_09_pl, (40,)),
))

multinest_fit = MultinestClusterFit(
    pointings,
    source_model,
    rebin_data_exp,
    (None, 80),
    np.geomspace(18, 150, 50),
    true_values(),
    folder,
)

multinest_fit.parameter_fit_distribution()
multinest_fit.text_summaries()
multinest_fit.ppc()
# Out:
#  *****************************************************
#  MultiNest v3.10
#  Copyright Farhan Feroz & Mike Hobson
#  Release Jul 2015
#
#  no. of live points =  800
#  dimensionality =   12
#  *****************************************************
#  Starting MultiNest
#  generating live points
#  live points generated, starting sampling
# Acceptance Rate:                        0.997653
# Replacements:                                850
# Total Samples:                               852
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999413
# Acceptance Rate:                        0.994475
# Replacements:                                900
# Total Samples:                               905
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999447
# Acceptance Rate:                        0.988554
# Replacements:                                950
# Total Samples:                               961
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999480
# Acceptance Rate:                        0.980392
# Replacements:                               1000
# Total Samples:                              1020
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999510
# Acceptance Rate:                        0.962420
# Replacements:                               1050
# Total Samples:                              1091
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999542
# Acceptance Rate:                        0.945830
# Replacements:                               1100
# Total Samples:                              1163
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999570
# Acceptance Rate:                        0.925181
# Replacements:                               1150
# Total Samples:                              1243
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999598
# ERROR: Interrupt received: Terminating
# Exception ignored on calling ctypes callback function: <function run.<locals>.loglike at 0x7f37743ef310>
# Traceback (most recent call last):
#   File "/home/moej56153/.pyenv/versions/MT/lib/python3.9/site-packages/pymultinest/run.py", line 221, in loglike
#     return LogLikelihood(cube, ndim, nparams)
#   File "/tmp/ipykernel_326/1986421315.py", line 47, in logLba_mult
#   File "/tmp/ipykernel_326/1986421315.py", line 219, in _update_resp_mats
#   File "/tmp/ipykernel_326/3405850027.py", line 11, in generate_resp_mat
#   File "/home/moej56153/.pyenv/versions/MT/lib/python3.9/site-packages/pyspi/utils/response/spi_drm.py", line 18, in __init__
#     self._drm_generator.set_location(ra, dec)
#   File "/home/moej56153/.pyenv/versions/MT/lib/python3.9/site-packages/pyspi/utils/response/spi_response.py", line 282, in set_location
#     self._recalculate_response()
#   File "/home/moej56153/.pyenv/versions/MT/lib/python3.9/site-packages/pyspi/utils/response/spi_response.py", line 686, in _recalculate_response
#     self._transpose_matrix = mat1+mat2+(interph*self._ph_matrix.T).T
#   File "/home/moej56153/.pyenv/versions/MT/lib/python3.9/site-packages/pymultinest/run.py", line 70, in interrupt_handler
#     sys.exit(1)
# SystemExit: 1
# Acceptance Rate:                        0.916730
# Replacements:                               1200
# Total Samples:                              1309
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999618
# Acceptance Rate:                        0.899928
# Replacements:                               1250
# Total Samples:                              1389
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999640
# Acceptance Rate:                        0.890411
# Replacements:                               1300
# Total Samples:                              1460
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999657
# Acceptance Rate:                        0.886991
# Replacements:                               1350
# Total Samples:                              1522
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999671

# %%
folder = "movable_crab_1644_pair"

# save_clusters(
#     ((('164400150010', "crab_data/1644"), ('164400220010', "crab_data/1644")),),
#     folder
# )

pointings = load_clusters(folder)
source_model = define_sources((
    (crab_pl_free_pos, (40,)),
))

multinest_fit = MultinestClusterFit(
    pointings,
    source_model,
    rebin_data_exp,
    (None, 80),
    np.geomspace(18, 150, 50),
    true_values(),
    folder,
)

multinest_fit.parameter_fit_distribution()
multinest_fit.text_summaries()
multinest_fit.ppc()
# Out:
#  *****************************************************
#  MultiNest v3.10
#  Copyright Farhan Feroz & Mike Hobson
#  Release Jul 2015
#
#  no. of live points =  800
#  dimensionality =    4
#  *****************************************************
#  Starting MultiNest
#  generating live points
#  live points generated, starting sampling
# Acceptance Rate:                        0.996483
# Replacements:                                850
# Total Samples:                               853
# Nested Sampling ln(Z):            -747280.107210
# Importance Nested Sampling ln(Z): 3534013.038974 +/-  0.999414
# Acceptance Rate:                        0.992282
# Replacements:                                900
# Total Samples:                               907
# Nested Sampling ln(Z):            1840809.910117
# Importance Nested Sampling ln(Z): 3534012.977591 +/-  0.999449
# Acceptance Rate:                        0.981405
# Replacements:                                950
# Total Samples:                               968
# Nested Sampling ln(Z):            2965130.461089
# Importance Nested Sampling ln(Z): 3534012.912501 +/-  0.999483
# Acceptance Rate:                        0.969932
# Replacements:                               1000
# Total Samples:                              1031
# Nested Sampling ln(Z):            3297291.415486
# Importance Nested Sampling ln(Z): 3534012.849449 +/-  0.999515
# Acceptance Rate:                        0.951949
# Replacements:                               1050
# Total Samples:                              1103
# Nested Sampling ln(Z):            3455543.088906
# Importance Nested Sampling ln(Z): 3534012.781945 +/-  0.999547
# Acceptance Rate:                        0.940975
# Replacements:                               1100
# Total Samples:                              1169
# Nested Sampling ln(Z):            3514756.714681
# Importance Nested Sampling ln(Z): 3534012.723830 +/-  0.999572
# Acceptance Rate:                        0.920000
# Replacements:                               1150
# Total Samples:                              1250
# Nested Sampling ln(Z):            3528419.516208
# Importance Nested Sampling ln(Z): 3534012.656835 +/-  0.999600
# Acceptance Rate:                        0.904977
# Replacements:                               1200
# Total Samples:                              1326
# Nested Sampling ln(Z):            3531837.860787
# Importance Nested Sampling ln(Z): 3534012.597811 +/-  0.999623
# Acceptance Rate:                        0.887784
# Replacements:                               1250
# Total Samples:                              1408
# Nested Sampling ln(Z):            3533061.380487
# Importance Nested Sampling ln(Z): 3534012.537808 +/-  0.999645
# Acceptance Rate:                        0.859788
# Replacements:                               1300
# Total Samples:                              1512
# Nested Sampling ln(Z):            3533488.161737
# Importance Nested Sampling ln(Z): 3534012.466545 +/-  0.999669
# Acceptance Rate:                        0.839552
# Replacements:                               1350
# Total Samples:                              1608
# Nested Sampling ln(Z):            3533586.747192
# Importance Nested Sampling ln(Z): 3534012.404987 +/-  0.999689
# Acceptance Rate:                        0.824985
# Replacements:                               1400
# Total Samples:                              1697
# Nested Sampling ln(Z):            3533627.399741
# Importance Nested Sampling ln(Z): 3534012.328321 +/-  0.999705
# Acceptance Rate:                        0.819672
# Replacements:                               1450
# Total Samples:                              1769
# Nested Sampling ln(Z):            3533643.801737
# Importance Nested Sampling ln(Z): 3534012.228595 +/-  0.999717
# Acceptance Rate:                        0.817439
# Replacements:                               1500
# Total Samples:                              1835
# Nested Sampling ln(Z):            3533650.606706
# Importance Nested Sampling ln(Z): 3534012.138857 +/-  0.999727
# Acceptance Rate:                        0.811094
# Replacements:                               1550
# Total Samples:                              1911
# Nested Sampling ln(Z):            3533654.759851
# Importance Nested Sampling ln(Z): 3534012.039832 +/-  0.999738
# Acceptance Rate:                        0.804020
# Replacements:                               1600
# Total Samples:                              1990
# Nested Sampling ln(Z):            3533657.104977
# Importance Nested Sampling ln(Z): 3534011.949132 +/-  0.999749
# Acceptance Rate:                        0.800194
# Replacements:                               1650
# Total Samples:                              2062
# Nested Sampling ln(Z):            3533658.306812
# Importance Nested Sampling ln(Z): 3534011.858808 +/-  0.999757
# Acceptance Rate:                        0.798122
# Replacements:                               1700
# Total Samples:                              2130
# Nested Sampling ln(Z):            3533659.139837
# Importance Nested Sampling ln(Z): 3534074.278153 +/-  0.999765
# Acceptance Rate:                        0.791139
# Replacements:                               1750
# Total Samples:                              2212
# Nested Sampling ln(Z):            3533659.705322
# Importance Nested Sampling ln(Z): 3534074.192371 +/-  0.999774
# Acceptance Rate:                        0.787057
# Replacements:                               1800
# Total Samples:                              2287
# Nested Sampling ln(Z):            3533660.097606
# Importance Nested Sampling ln(Z): 3534074.119553 +/-  0.999781
# Acceptance Rate:                        0.783235
# Replacements:                               1850
# Total Samples:                              2362
# Nested Sampling ln(Z):            3533660.398334
# Importance Nested Sampling ln(Z): 3534168.079673 +/-  0.999788
# Acceptance Rate:                        0.778051
# Replacements:                               1900
# Total Samples:                              2442
# Nested Sampling ln(Z):            3533660.636489
# Importance Nested Sampling ln(Z): 3534167.999365 +/-  0.999795
# Acceptance Rate:                        0.773196
# Replacements:                               1950
# Total Samples:                              2522
# Nested Sampling ln(Z):            3533660.831008
# Importance Nested Sampling ln(Z): 3534167.917225 +/-  0.999802
# Acceptance Rate:                        0.768344
# Replacements:                               2000
# Total Samples:                              2603
# Nested Sampling ln(Z):            3533660.994014
# Importance Nested Sampling ln(Z): 3534167.835258 +/-  0.999808
# Acceptance Rate:                        0.762649
# Replacements:                               2050
# Total Samples:                              2688
# Nested Sampling ln(Z):            3533661.133958
# Importance Nested Sampling ln(Z): 3534167.751975 +/-  0.999814
# Acceptance Rate:                        0.755124
# Replacements:                               2100
# Total Samples:                              2781
# Nested Sampling ln(Z):            3533661.256030
# Importance Nested Sampling ln(Z): 3534167.663153 +/-  0.999820
# Acceptance Rate:                        0.748607
# Replacements:                               2150
# Total Samples:                              2872
# Nested Sampling ln(Z):            3533661.364983
# Importance Nested Sampling ln(Z): 3534167.577841 +/-  0.999826
# Acceptance Rate:                        0.746016
# Replacements:                               2200
# Total Samples:                              2949
# Nested Sampling ln(Z):            3533661.464360
# Importance Nested Sampling ln(Z): 3534233.742358 +/-  0.999830
# Acceptance Rate:                        0.739402
# Replacements:                               2250
# Total Samples:                              3043
# Nested Sampling ln(Z):            3533661.559795
# Importance Nested Sampling ln(Z): 3534233.661002 +/-  0.999836
# Acceptance Rate:                        0.733418
# Replacements:                               2300
# Total Samples:                              3136
# Nested Sampling ln(Z):            3533661.651990
# Importance Nested Sampling ln(Z): 3534275.311974 +/-  0.999841
# Acceptance Rate:                        0.729587
# Replacements:                               2350
# Total Samples:                              3221
# Nested Sampling ln(Z):            3533661.743176
# Importance Nested Sampling ln(Z): 3534275.242767 +/-  0.999845
# Acceptance Rate:                        0.726172
# Replacements:                               2400
# Total Samples:                              3305
# Nested Sampling ln(Z):            3533661.840073
# Importance Nested Sampling ln(Z): 3534275.176059 +/-  0.999849
# Acceptance Rate:                        0.720800
# Replacements:                               2450
# Total Samples:                              3399
# Nested Sampling ln(Z):            3533661.946459
# Importance Nested Sampling ln(Z): 3534275.097111 +/-  0.999853
# Acceptance Rate:                        0.714082
# Replacements:                               2500
# Total Samples:                              3501
# Nested Sampling ln(Z):            3533662.073433
# Importance Nested Sampling ln(Z): 3534275.017320 +/-  0.999857
# Acceptance Rate:                        0.710504
# Replacements:                               2550
# Total Samples:                              3589
# Nested Sampling ln(Z):            3533662.239026
# Importance Nested Sampling ln(Z): 3534274.940532 +/-  0.999861
# Acceptance Rate:                        0.706330
# Replacements:                               2600
# Total Samples:                              3681
# Nested Sampling ln(Z):            3533662.442540
# Importance Nested Sampling ln(Z): 3534402.569021 +/-  0.999864
# Acceptance Rate:                        0.703291
# Replacements:                               2650
# Total Samples:                              3768
# Nested Sampling ln(Z):            3533662.711241
# Importance Nested Sampling ln(Z): 3534402.498401 +/-  0.999867
# Acceptance Rate:                        0.698396
# Replacements:                               2700
# Total Samples:                              3866
# Nested Sampling ln(Z):            3533663.079437
# Importance Nested Sampling ln(Z): 3534402.422717 +/-  0.999871
# Acceptance Rate:                        0.695674
# Replacements:                               2750
# Total Samples:                              3953
# Nested Sampling ln(Z):            3533663.712785
# Importance Nested Sampling ln(Z): 3534402.355218 +/-  0.999874
# Acceptance Rate:                        0.693241
# Replacements:                               2800
# Total Samples:                              4039
# Nested Sampling ln(Z):            3533664.575005
# Importance Nested Sampling ln(Z): 3534402.288113 +/-  0.999876
# Acceptance Rate:                        0.691916
# Replacements:                               2850
# Total Samples:                              4119
# Nested Sampling ln(Z):            3533665.857731
# Importance Nested Sampling ln(Z): 3534402.228345 +/-  0.999879
# Acceptance Rate:                        0.689000
# Replacements:                               2900
# Total Samples:                              4209
# Nested Sampling ln(Z):            3533667.315041
# Importance Nested Sampling ln(Z): 3534402.162561 +/-  0.999881
# Acceptance Rate:                        0.682712
# Replacements:                               2950
# Total Samples:                              4321
# Nested Sampling ln(Z):            3533668.938763
# Importance Nested Sampling ln(Z): 3534402.085006 +/-  0.999884
# Acceptance Rate:                        0.677201
# Replacements:                               3000
# Total Samples:                              4430
# Nested Sampling ln(Z):            3533670.864291
# Importance Nested Sampling ln(Z): 3534402.010714 +/-  0.999887
# Acceptance Rate:                        0.677176
# Replacements:                               3050
# Total Samples:                              4504
# Nested Sampling ln(Z):            3533672.790072
# Importance Nested Sampling ln(Z): 3534401.956835 +/-  0.999889
# Acceptance Rate:                        0.676265
# Replacements:                               3100
# Total Samples:                              4584
# Nested Sampling ln(Z):            3533674.848125
# Importance Nested Sampling ln(Z): 3534401.897226 +/-  0.999891
# Acceptance Rate:                        0.671069
# Replacements:                               3150
# Total Samples:                              4694
# Nested Sampling ln(Z):            3533676.949588
# Importance Nested Sampling ln(Z): 3534401.816307 +/-  0.999893
# Acceptance Rate:                        0.668896
# Replacements:                               3200
# Total Samples:                              4784
# Nested Sampling ln(Z):            3533679.191911
# Importance Nested Sampling ln(Z): 3534401.754100 +/-  0.999895
# Acceptance Rate:                        0.667214
# Replacements:                               3250
# Total Samples:                              4871
# Nested Sampling ln(Z):            3533681.239608
# Importance Nested Sampling ln(Z): 3534401.693778 +/-  0.999897
# Acceptance Rate:                        0.662917
# Replacements:                               3300
# Total Samples:                              4978
# Nested Sampling ln(Z):            3533684.317096
# Importance Nested Sampling ln(Z): 3534401.623215 +/-  0.999900
# Acceptance Rate:                        0.661663
# Replacements:                               3350
# Total Samples:                              5063
# Nested Sampling ln(Z):            3533687.204816
# Importance Nested Sampling ln(Z): 3534401.566647 +/-  0.999901
# Acceptance Rate:                        0.658277
# Replacements:                               3400
# Total Samples:                              5165
# Nested Sampling ln(Z):            3533690.233775
# Importance Nested Sampling ln(Z): 3534401.489587 +/-  0.999903
# Acceptance Rate:                        0.657895
# Replacements:                               3450
# Total Samples:                              5244
# Nested Sampling ln(Z):            3533693.090529
# Importance Nested Sampling ln(Z): 3534401.433691 +/-  0.999905
# Acceptance Rate:                        0.656660
# Replacements:                               3500
# Total Samples:                              5330
# Nested Sampling ln(Z):            3533696.585777
# Importance Nested Sampling ln(Z): 3534401.374201 +/-  0.999906
# Acceptance Rate:                        0.654740
# Replacements:                               3550
# Total Samples:                              5422
# Nested Sampling ln(Z):            3533700.412617
# Importance Nested Sampling ln(Z): 3534401.310224 +/-  0.999908
# Acceptance Rate:                        0.651466
# Replacements:                               3600
# Total Samples:                              5526
# Nested Sampling ln(Z):            3533704.803154
# Importance Nested Sampling ln(Z): 3534401.241666 +/-  0.999910
# Acceptance Rate:                        0.648082
# Replacements:                               3650
# Total Samples:                              5632
# Nested Sampling ln(Z):            3533707.756456
# Importance Nested Sampling ln(Z): 3534401.177297 +/-  0.999911
# Acceptance Rate:                        0.644599
# Replacements:                               3700
# Total Samples:                              5740
# Nested Sampling ln(Z):            3533710.919240
# Importance Nested Sampling ln(Z): 3534401.114917 +/-  0.999913
# Acceptance Rate:                        0.639713
# Replacements:                               3750
# Total Samples:                              5862
# Nested Sampling ln(Z):            3533715.401988
# Importance Nested Sampling ln(Z): 3534401.045169 +/-  0.999915
# Acceptance Rate:                        0.634603
# Replacements:                               3800
# Total Samples:                              5988
# Nested Sampling ln(Z):            3533720.536828
# Importance Nested Sampling ln(Z): 3534400.978865 +/-  0.999916
# Acceptance Rate:                        0.630837
# Replacements:                               3850
# Total Samples:                              6103
# Nested Sampling ln(Z):            3533726.473596
# Importance Nested Sampling ln(Z): 3534400.927068 +/-  0.990488
# Acceptance Rate:                        0.626607
# Replacements:                               3900
# Total Samples:                              6224
# Nested Sampling ln(Z):            3533732.522604
# Importance Nested Sampling ln(Z): 3534400.869193 +/-  0.990489
# Acceptance Rate:                        0.623816
# Replacements:                               3950
# Total Samples:                              6332
# Nested Sampling ln(Z):            3533738.445468
# Importance Nested Sampling ln(Z): 3534400.817135 +/-  0.990491
# Acceptance Rate:                        0.621022
# Replacements:                               4000
# Total Samples:                              6441
# Nested Sampling ln(Z):            3533743.415257
# Importance Nested Sampling ln(Z): 3534400.765784 +/-  0.990492
# Acceptance Rate:                        0.620785
# Replacements:                               4050
# Total Samples:                              6524
# Nested Sampling ln(Z):            3533749.662451
# Importance Nested Sampling ln(Z): 3534400.719893 +/-  0.990493
# Acceptance Rate:                        0.618868
# Replacements:                               4100
# Total Samples:                              6625
# Nested Sampling ln(Z):            3533755.211020
# Importance Nested Sampling ln(Z): 3534416.356949 +/-  0.999924
# Acceptance Rate:                        0.617100
# Replacements:                               4150
# Total Samples:                              6725
# Nested Sampling ln(Z):            3533760.005451
# Importance Nested Sampling ln(Z): 3534416.303071 +/-  0.999925
# Acceptance Rate:                        0.612423
# Replacements:                               4200
# Total Samples:                              6858
# Nested Sampling ln(Z):            3533766.570424
# Importance Nested Sampling ln(Z): 3534447.381542 +/-  0.999927
# Acceptance Rate:                        0.611511
# Replacements:                               4250
# Total Samples:                              6950
# Nested Sampling ln(Z):            3533774.208674
# Importance Nested Sampling ln(Z): 3534447.331530 +/-  0.999928
# Acceptance Rate:                        0.609497
# Replacements:                               4300
# Total Samples:                              7055
# Nested Sampling ln(Z):            3533781.758252
# Importance Nested Sampling ln(Z): 3534447.277016 +/-  0.999929
# Acceptance Rate:                        0.608221
# Replacements:                               4350
# Total Samples:                              7152
# Nested Sampling ln(Z):            3533787.100989
# Importance Nested Sampling ln(Z): 3534447.220646 +/-  0.999930
# Acceptance Rate:                        0.607064
# Replacements:                               4400
# Total Samples:                              7248
# Nested Sampling ln(Z):            3533794.123293
# Importance Nested Sampling ln(Z): 3534447.163460 +/-  0.999931
# Acceptance Rate:                        0.605277
# Replacements:                               4450
# Total Samples:                              7352
# Nested Sampling ln(Z):            3533799.952200
# Importance Nested Sampling ln(Z): 3534451.469459 +/-  0.987328
# Acceptance Rate:                        0.604189
# Replacements:                               4500
# Total Samples:                              7448
# Nested Sampling ln(Z):            3533806.850461
# Importance Nested Sampling ln(Z): 3534451.413716 +/-  0.987330
# Acceptance Rate:                        0.602889
# Replacements:                               4550
# Total Samples:                              7547
# Nested Sampling ln(Z):            3533814.309868
# Importance Nested Sampling ln(Z): 3534451.357383 +/-  0.987331
# Acceptance Rate:                        0.601858
# Replacements:                               4600
# Total Samples:                              7643
# Nested Sampling ln(Z):            3533821.181393
# Importance Nested Sampling ln(Z): 3534451.303068 +/-  0.987333
# Acceptance Rate:                        0.600000
# Replacements:                               4650
# Total Samples:                              7750
# Nested Sampling ln(Z):            3533828.217990
# Importance Nested Sampling ln(Z): 3534451.246103 +/-  0.987334
# Acceptance Rate:                        0.600026
# Replacements:                               4700
# Total Samples:                              7833
# Nested Sampling ln(Z):            3533834.460990
# Importance Nested Sampling ln(Z): 3534451.192091 +/-  0.987336
# Acceptance Rate:                        0.598538
# Replacements:                               4750
# Total Samples:                              7936
# Nested Sampling ln(Z):            3533843.589317
# Importance Nested Sampling ln(Z): 3534451.132147 +/-  0.987394
# Acceptance Rate:                        0.598578
# Replacements:                               4800
# Total Samples:                              8019
# Nested Sampling ln(Z):            3533851.840812
# Importance Nested Sampling ln(Z): 3534451.131347 +/-  0.988174
# Acceptance Rate:                        0.599283
# Replacements:                               4850
# Total Samples:                              8093
# Nested Sampling ln(Z):            3533860.352884
# Importance Nested Sampling ln(Z): 3534451.130735 +/-  0.988773
# Acceptance Rate:                        0.599755
# Replacements:                               4900
# Total Samples:                              8170
# Nested Sampling ln(Z):            3533869.696442
# Importance Nested Sampling ln(Z): 3534451.130125 +/-  0.989370
# Acceptance Rate:                        0.598549
# Replacements:                               4950
# Total Samples:                              8270
# Nested Sampling ln(Z):            3533880.101140
# Importance Nested Sampling ln(Z): 3534451.129410 +/-  0.990071
# Acceptance Rate:                        0.599089
# Replacements:                               5000
# Total Samples:                              8346
# Nested Sampling ln(Z):            3533889.410439
# Importance Nested Sampling ln(Z): 3534451.128844 +/-  0.990627
# Acceptance Rate:                        0.599478
# Replacements:                               5050
# Total Samples:                              8424
# Nested Sampling ln(Z):            3533899.882018
# Importance Nested Sampling ln(Z): 3534451.128332 +/-  0.991130
# Acceptance Rate:                        0.599859
# Replacements:                               5100
# Total Samples:                              8502
# Nested Sampling ln(Z):            3533910.290394
# Importance Nested Sampling ln(Z): 3534451.127837 +/-  0.991617
# Acceptance Rate:                        0.599465
# Replacements:                               5150
# Total Samples:                              8591
# Nested Sampling ln(Z):            3533920.477249
# Importance Nested Sampling ln(Z): 3534451.127319 +/-  0.992128
# Acceptance Rate:                        0.597770
# Replacements:                               5200
# Total Samples:                              8699
# Nested Sampling ln(Z):            3533934.929129
# Importance Nested Sampling ln(Z): 3534451.126768 +/-  0.992671
# Acceptance Rate:                        0.597950
# Replacements:                               5250
# Total Samples:                              8780
# Nested Sampling ln(Z):            3533943.327203
# Importance Nested Sampling ln(Z): 3534451.126400 +/-  0.993034
# Acceptance Rate:                        0.598329
# Replacements:                               5300
# Total Samples:                              8858
# Nested Sampling ln(Z):            3533950.549021
# Importance Nested Sampling ln(Z): 3534451.126113 +/-  0.993318
# Acceptance Rate:                        0.597966
# Replacements:                               5350
# Total Samples:                              8947
# Nested Sampling ln(Z):            3533961.237631
# Importance Nested Sampling ln(Z): 3534451.125790 +/-  0.993638
# Acceptance Rate:                        0.598603
# Replacements:                               5400
# Total Samples:                              9021
# Nested Sampling ln(Z):            3533971.800585
# Importance Nested Sampling ln(Z): 3534451.125472 +/-  0.993951
# Acceptance Rate:                        0.598112
# Replacements:                               5450
# Total Samples:                              9112
# Nested Sampling ln(Z):            3533980.317847
# Importance Nested Sampling ln(Z): 3534451.125112 +/-  0.994308
# Acceptance Rate:                        0.597047
# Replacements:                               5500
# Total Samples:                              9212
# Nested Sampling ln(Z):            3533990.457843
# Importance Nested Sampling ln(Z): 3534451.124765 +/-  0.994652
# Acceptance Rate:                        0.595494
# Replacements:                               5550
# Total Samples:                              9320
# Nested Sampling ln(Z):            3534001.596912
# Importance Nested Sampling ln(Z): 3534451.124428 +/-  0.994986
# Acceptance Rate:                        0.592405
# Replacements:                               5600
# Total Samples:                              9453
# Nested Sampling ln(Z):            3534010.318781
# Importance Nested Sampling ln(Z): 3534451.124062 +/-  0.995350
# Acceptance Rate:                        0.591128
# Replacements:                               5650
# Total Samples:                              9558
# Nested Sampling ln(Z):            3534021.326923
# Importance Nested Sampling ln(Z): 3534451.123807 +/-  0.995602
# Acceptance Rate:                        0.590490
# Replacements:                               5700
# Total Samples:                              9653
# Nested Sampling ln(Z):            3534031.857775
# Importance Nested Sampling ln(Z): 3534451.123592 +/-  0.995816
# Acceptance Rate:                        0.588295
# Replacements:                               5750
# Total Samples:                              9774
# Nested Sampling ln(Z):            3534040.804660
# Importance Nested Sampling ln(Z): 3534451.123341 +/-  0.996066
# Acceptance Rate:                        0.588713
# Replacements:                               5800
# Total Samples:                              9852
# Nested Sampling ln(Z):            3534049.688983
# Importance Nested Sampling ln(Z): 3534451.123163 +/-  0.996243
# Acceptance Rate:                        0.588590
# Replacements:                               5850
# Total Samples:                              9939
# Nested Sampling ln(Z):            3534060.752955
# Importance Nested Sampling ln(Z): 3534451.122985 +/-  0.996420
# Acceptance Rate:                        0.586889
# Replacements:                               5900
# Total Samples:                             10053
# Nested Sampling ln(Z):            3534070.006299
# Importance Nested Sampling ln(Z): 3534451.122775 +/-  0.996629
# Acceptance Rate:                        0.585918
# Replacements:                               5950
# Total Samples:                             10155
# Nested Sampling ln(Z):            3534080.157776
# Importance Nested Sampling ln(Z): 3534451.122601 +/-  0.996802
# Acceptance Rate:                        0.584738
# Replacements:                               6000
# Total Samples:                             10261
# Nested Sampling ln(Z):            3534089.853751
# Importance Nested Sampling ln(Z): 3534451.122429 +/-  0.996975
# Acceptance Rate:                        0.584654
# Replacements:                               6050
# Total Samples:                             10348
# Nested Sampling ln(Z):            3534096.312995
# Importance Nested Sampling ln(Z): 3534451.122302 +/-  0.997101
# Acceptance Rate:                        0.584515
# Replacements:                               6100
# Total Samples:                             10436
# Nested Sampling ln(Z):            3534105.492237
# Importance Nested Sampling ln(Z): 3534451.122199 +/-  0.997204
# Acceptance Rate:                        0.584434
# Replacements:                               6150
# Total Samples:                             10523
# Nested Sampling ln(Z):            3534115.814426
# Importance Nested Sampling ln(Z): 3534451.122092 +/-  0.997311
# Acceptance Rate:                        0.584906
# Replacements:                               6200
# Total Samples:                             10600
# Nested Sampling ln(Z):            3534124.061770
# Importance Nested Sampling ln(Z): 3534451.122217 +/-  0.997186
# Acceptance Rate:                        0.583785
# Replacements:                               6250
# Total Samples:                             10706
# Nested Sampling ln(Z):            3534134.580049
# Importance Nested Sampling ln(Z): 3534451.122092 +/-  0.997311
# Acceptance Rate:                        0.583495
# Replacements:                               6300
# Total Samples:                             10797
# Nested Sampling ln(Z):            3534143.448047
# Importance Nested Sampling ln(Z): 3534451.121992 +/-  0.997411
# Acceptance Rate:                        0.582676
# Replacements:                               6350
# Total Samples:                             10898
# Nested Sampling ln(Z):            3534152.033465
# Importance Nested Sampling ln(Z): 3534451.121880 +/-  0.997523
# Acceptance Rate:                        0.582454
# Replacements:                               6400
# Total Samples:                             10988
# Nested Sampling ln(Z):            3534159.165815
# Importance Nested Sampling ln(Z): 3534451.121778 +/-  0.997625
# Acceptance Rate:                        0.581553
# Replacements:                               6450
# Total Samples:                             11091
# Nested Sampling ln(Z):            3534166.758254
# Importance Nested Sampling ln(Z): 3534451.121669 +/-  0.997733
# Acceptance Rate:                        0.581239
# Replacements:                               6500
# Total Samples:                             11183
# Nested Sampling ln(Z):            3534172.487123
# Importance Nested Sampling ln(Z): 3534451.121515 +/-  0.997887
# Acceptance Rate:                        0.581550
# Replacements:                               6550
# Total Samples:                             11263
# Nested Sampling ln(Z):            3534179.137317
# Importance Nested Sampling ln(Z): 3534451.121649 +/-  0.997754
# Acceptance Rate:                        0.581191
# Replacements:                               6600
# Total Samples:                             11356
# Nested Sampling ln(Z):            3534185.674702
# Importance Nested Sampling ln(Z): 3534451.121476 +/-  0.997927
# Acceptance Rate:                        0.581395
# Replacements:                               6650
# Total Samples:                             11438
# Nested Sampling ln(Z):            3534193.911498
# Importance Nested Sampling ln(Z): 3534451.121348 +/-  0.998055
# Acceptance Rate:                        0.581446
# Replacements:                               6700
# Total Samples:                             11523
# Nested Sampling ln(Z):            3534202.260734
# Importance Nested Sampling ln(Z): 3534451.121226 +/-  0.998176
# Acceptance Rate:                        0.581145
# Replacements:                               6750
# Total Samples:                             11615
# Nested Sampling ln(Z):            3534207.755283
# Importance Nested Sampling ln(Z): 3534451.121108 +/-  0.998294
# Acceptance Rate:                        0.581246
# Replacements:                               6800
# Total Samples:                             11699
# Nested Sampling ln(Z):            3534214.280454
# Importance Nested Sampling ln(Z): 3534451.121013 +/-  0.998389
# Acceptance Rate:                        0.580508
# Replacements:                               6850
# Total Samples:                             11800
# Nested Sampling ln(Z):            3534220.141802
# Importance Nested Sampling ln(Z): 3534451.120908 +/-  0.998495
# Acceptance Rate:                        0.580124
# Replacements:                               6900
# Total Samples:                             11894
# Nested Sampling ln(Z):            3534226.514125
# Importance Nested Sampling ln(Z): 3534452.069383 +/-  0.724504
# Acceptance Rate:                        0.579505
# Replacements:                               6950
# Total Samples:                             11993
# Nested Sampling ln(Z):            3534233.928094
# Importance Nested Sampling ln(Z): 3534452.033098 +/-  0.720328
# Acceptance Rate:                        0.579135
# Replacements:                               7000
# Total Samples:                             12087
# Nested Sampling ln(Z):            3534240.129802
# Importance Nested Sampling ln(Z): 3534451.999717 +/-  0.707673
# Acceptance Rate:                        0.578485
# Replacements:                               7050
# Total Samples:                             12187
# Nested Sampling ln(Z):            3534247.773775
# Importance Nested Sampling ln(Z): 3534451.955119 +/-  0.704224
# Acceptance Rate:                        0.577705
# Replacements:                               7100
# Total Samples:                             12290
# Nested Sampling ln(Z):            3534254.142955
# Importance Nested Sampling ln(Z): 3534451.912937 +/-  0.701780
# Acceptance Rate:                        0.576659
# Replacements:                               7150
# Total Samples:                             12399
# Nested Sampling ln(Z):            3534259.892140
# Importance Nested Sampling ln(Z): 3534452.084111 +/-  0.597858
# Acceptance Rate:                        0.575816
# Replacements:                               7200
# Total Samples:                             12504
# Nested Sampling ln(Z):            3534265.572241
# Importance Nested Sampling ln(Z): 3534452.042107 +/-  0.599248
# Acceptance Rate:                        0.575306
# Replacements:                               7250
# Total Samples:                             12602
# Nested Sampling ln(Z):            3534270.574552
# Importance Nested Sampling ln(Z): 3534452.005582 +/-  0.601097
# Acceptance Rate:                        0.574758
# Replacements:                               7300
# Total Samples:                             12701
# Nested Sampling ln(Z):            3534275.430761
# Importance Nested Sampling ln(Z): 3534451.972368 +/-  0.603348
# Acceptance Rate:                        0.574533
# Replacements:                               7350
# Total Samples:                             12793
# Nested Sampling ln(Z):            3534282.192747
# Importance Nested Sampling ln(Z): 3534452.138731 +/-  0.527807
# Acceptance Rate:                        0.574802
# Replacements:                               7400
# Total Samples:                             12874
# Nested Sampling ln(Z):            3534288.108958
# Importance Nested Sampling ln(Z): 3534452.094496 +/-  0.532111
# Acceptance Rate:                        0.574225
# Replacements:                               7450
# Total Samples:                             12974
# Nested Sampling ln(Z):            3534294.195824
# Importance Nested Sampling ln(Z): 3534458.971159 +/-  0.998980
# Acceptance Rate:                        0.573614
# Replacements:                               7500
# Total Samples:                             13075
# Nested Sampling ln(Z):            3534300.504681
# Importance Nested Sampling ln(Z): 3534458.892174 +/-  0.998949
# Acceptance Rate:                        0.573403
# Replacements:                               7550
# Total Samples:                             13167
# Nested Sampling ln(Z):            3534306.339431
# Importance Nested Sampling ln(Z): 3534458.822464 +/-  0.998918
# Acceptance Rate:                        0.573585
# Replacements:                               7600
# Total Samples:                             13250
# Nested Sampling ln(Z):            3534310.943830
# Importance Nested Sampling ln(Z): 3534458.762178 +/-  0.998891
# Acceptance Rate:                        0.572862
# Replacements:                               7650
# Total Samples:                             13354
# Nested Sampling ln(Z):            3534316.349981
# Importance Nested Sampling ln(Z): 3534458.691540 +/-  0.998856
# Acceptance Rate:                        0.572491
# Replacements:                               7700
# Total Samples:                             13450
# Nested Sampling ln(Z):            3534321.869468
# Importance Nested Sampling ln(Z): 3534458.631148 +/-  0.997434
# Acceptance Rate:                        0.571408
# Replacements:                               7750
# Total Samples:                             13563
# Nested Sampling ln(Z):            3534326.728920
# Importance Nested Sampling ln(Z): 3534458.562318 +/-  0.996826
# Acceptance Rate:                        0.569302
# Replacements:                               7800
# Total Samples:                             13701
# Nested Sampling ln(Z):            3534331.276217
# Importance Nested Sampling ln(Z): 3534458.482827 +/-  0.996778
# Acceptance Rate:                        0.568552
# Replacements:                               7850
# Total Samples:                             13807
# Nested Sampling ln(Z):            3534336.109684
# Importance Nested Sampling ln(Z): 3534458.434652 +/-  0.996747
# Acceptance Rate:                        0.568468
# Replacements:                               7900
# Total Samples:                             13897
# Nested Sampling ln(Z):            3534339.701728
# Importance Nested Sampling ln(Z): 3534458.395053 +/-  0.996720
# Acceptance Rate:                        0.568426
# Replacements:                               7950
# Total Samples:                             13986
# Nested Sampling ln(Z):            3534343.017401
# Importance Nested Sampling ln(Z): 3534459.424042 +/-  0.740508
# Acceptance Rate:                        0.567658
# Replacements:                               8000
# Total Samples:                             14093
# Nested Sampling ln(Z):            3534345.876058
# Importance Nested Sampling ln(Z): 3534459.375645 +/-  0.740495
# Acceptance Rate:                        0.567181
# Replacements:                               8050
# Total Samples:                             14193
# Nested Sampling ln(Z):            3534348.946109
# Importance Nested Sampling ln(Z): 3534459.326934 +/-  0.740486
# Acceptance Rate:                        0.567147
# Replacements:                               8100
# Total Samples:                             14282
# Nested Sampling ln(Z):            3534352.570039
# Importance Nested Sampling ln(Z): 3534459.285699 +/-  0.740324
# Acceptance Rate:                        0.567193
# Replacements:                               8150
# Total Samples:                             14369
# Nested Sampling ln(Z):            3534355.970031
# Importance Nested Sampling ln(Z): 3534459.568045 +/-  0.602651
# Acceptance Rate:                        0.567082
# Replacements:                               8200
# Total Samples:                             14460
# Nested Sampling ln(Z):            3534358.927497
# Importance Nested Sampling ln(Z): 3534459.522672 +/-  0.602643
# Acceptance Rate:                        0.566971
# Replacements:                               8250
# Total Samples:                             14551
# Nested Sampling ln(Z):            3534362.163999
# Importance Nested Sampling ln(Z): 3534459.478662 +/-  0.602602
# Acceptance Rate:                        0.566282
# Replacements:                               8300
# Total Samples:                             14657
# Nested Sampling ln(Z):            3534365.009167
# Importance Nested Sampling ln(Z): 3534459.431609 +/-  0.600465
# Acceptance Rate:                        0.566102
# Replacements:                               8350
# Total Samples:                             14750
# Nested Sampling ln(Z):            3534367.769028
# Importance Nested Sampling ln(Z): 3534459.382002 +/-  0.600457
# Acceptance Rate:                        0.565657
# Replacements:                               8400
# Total Samples:                             14850
# Nested Sampling ln(Z):            3534370.203106
# Importance Nested Sampling ln(Z): 3534459.331001 +/-  0.600164
# Acceptance Rate:                        0.565255
# Replacements:                               8450
# Total Samples:                             14949
# Nested Sampling ln(Z):            3534372.446433
# Importance Nested Sampling ln(Z): 3534459.279072 +/-  0.600156
# Acceptance Rate:                        0.565348
# Replacements:                               8500
# Total Samples:                             15035
# Nested Sampling ln(Z):            3534374.596450
# Importance Nested Sampling ln(Z): 3534459.236053 +/-  0.600149
# Acceptance Rate:                        0.564990
# Replacements:                               8550
# Total Samples:                             15133
# Nested Sampling ln(Z):            3534376.879314
# Importance Nested Sampling ln(Z): 3534459.183579 +/-  0.600138
# Acceptance Rate:                        0.564638
# Replacements:                               8600
# Total Samples:                             15231
# Nested Sampling ln(Z):            3534379.385715
# Importance Nested Sampling ln(Z): 3534459.145306 +/-  0.590588
# Acceptance Rate:                        0.564032
# Replacements:                               8650
# Total Samples:                             15336
# Nested Sampling ln(Z):            3534381.794746
# Importance Nested Sampling ln(Z): 3534459.089885 +/-  0.590578
# Acceptance Rate:                        0.563983
# Replacements:                               8700
# Total Samples:                             15426
# Nested Sampling ln(Z):            3534384.469941
# Importance Nested Sampling ln(Z): 3534459.041011 +/-  0.590568
# Acceptance Rate:                        0.564043
# Replacements:                               8750
# Total Samples:                             15513
# Nested Sampling ln(Z):            3534386.635342
# Importance Nested Sampling ln(Z): 3534459.021932 +/-  0.572246
# Acceptance Rate:                        0.564030
# Replacements:                               8800
# Total Samples:                             15602
# Nested Sampling ln(Z):            3534388.800372
# Importance Nested Sampling ln(Z): 3534458.972206 +/-  0.571651
# Acceptance Rate:                        0.563730
# Replacements:                               8850
# Total Samples:                             15699
# Nested Sampling ln(Z):            3534390.769467
# Importance Nested Sampling ln(Z): 3534458.939898 +/-  0.558389
# Acceptance Rate:                        0.563255
# Replacements:                               8900
# Total Samples:                             15801
# Nested Sampling ln(Z):            3534393.059436
# Importance Nested Sampling ln(Z): 3534458.883080 +/-  0.558367
# Acceptance Rate:                        0.563425
# Replacements:                               8950
# Total Samples:                             15885
# Nested Sampling ln(Z):            3534395.018156
# Importance Nested Sampling ln(Z): 3534458.961745 +/-  0.502108
# Acceptance Rate:                        0.563275
# Replacements:                               9000
# Total Samples:                             15978
# Nested Sampling ln(Z):            3534397.281563
# Importance Nested Sampling ln(Z): 3534458.988687 +/-  0.468034
# Acceptance Rate:                        0.563266
# Replacements:                               9050
# Total Samples:                             16067
# Nested Sampling ln(Z):            3534399.146083
# Importance Nested Sampling ln(Z): 3534458.935570 +/-  0.467822
# Acceptance Rate:                        0.563154
# Replacements:                               9100
# Total Samples:                             16159
# Nested Sampling ln(Z):            3534400.572262
# Importance Nested Sampling ln(Z): 3534458.890683 +/-  0.464148
# Acceptance Rate:                        0.563077
# Replacements:                               9150
# Total Samples:                             16250
# Nested Sampling ln(Z):            3534402.061541
# Importance Nested Sampling ln(Z): 3534458.836134 +/-  0.464101
# Acceptance Rate:                        0.562382
# Replacements:                               9200
# Total Samples:                             16359
# Nested Sampling ln(Z):            3534403.704806
# Importance Nested Sampling ln(Z): 3534458.776081 +/-  0.463041
# Acceptance Rate:                        0.562584
# Replacements:                               9250
# Total Samples:                             16442
# Nested Sampling ln(Z):            3534405.240436
# Importance Nested Sampling ln(Z): 3534458.860404 +/-  0.423870
# Acceptance Rate:                        0.562511
# Replacements:                               9300
# Total Samples:                             16533
# Nested Sampling ln(Z):            3534406.823919
# Importance Nested Sampling ln(Z): 3534458.807732 +/-  0.423831
# Acceptance Rate:                        0.562982
# Replacements:                               9350
# Total Samples:                             16608
# Nested Sampling ln(Z):            3534408.437245
# Importance Nested Sampling ln(Z): 3534458.820407 +/-  0.401565
# Acceptance Rate:                        0.563212
# Replacements:                               9400
# Total Samples:                             16690
# Nested Sampling ln(Z):            3534410.113844
# Importance Nested Sampling ln(Z): 3534458.765705 +/-  0.401533
# Acceptance Rate:                        0.563439
# Replacements:                               9450
# Total Samples:                             16772
# Nested Sampling ln(Z):            3534411.838254
# Importance Nested Sampling ln(Z): 3534458.903727 +/-  0.374392
# Acceptance Rate:                        0.563531
# Replacements:                               9500
# Total Samples:                             16858
# Nested Sampling ln(Z):            3534413.596028
# Importance Nested Sampling ln(Z): 3534458.975612 +/-  0.350521
# Acceptance Rate:                        0.563355
# Replacements:                               9550
# Total Samples:                             16952
# Nested Sampling ln(Z):            3534415.156384
# Importance Nested Sampling ln(Z): 3534459.060137 +/-  0.326876
# Acceptance Rate:                        0.563116
# Replacements:                               9600
# Total Samples:                             17048
# Nested Sampling ln(Z):            3534416.516094
# Importance Nested Sampling ln(Z): 3534459.002336 +/-  0.326514
# Acceptance Rate:                        0.562781
# Replacements:                               9650
# Total Samples:                             17147
# Nested Sampling ln(Z):            3534417.962312
# Importance Nested Sampling ln(Z): 3534458.949386 +/-  0.322718
# Acceptance Rate:                        0.562776
# Replacements:                               9700
# Total Samples:                             17236
# Nested Sampling ln(Z):            3534419.363599
# Importance Nested Sampling ln(Z): 3534458.896748 +/-  0.321142
# Acceptance Rate:                        0.563031
# Replacements:                               9750
# Total Samples:                             17317
# Nested Sampling ln(Z):            3534420.886906
# Importance Nested Sampling ln(Z): 3534458.898986 +/-  0.307825
# Acceptance Rate:                        0.563348
# Replacements:                               9800
# Total Samples:                             17396
# Nested Sampling ln(Z):            3534422.276466
# Importance Nested Sampling ln(Z): 3534458.843055 +/-  0.307596
# Acceptance Rate:                        0.563276
# Replacements:                               9850
# Total Samples:                             17487
# Nested Sampling ln(Z):            3534423.578557
# Importance Nested Sampling ln(Z): 3534458.834557 +/-  0.295061
# Acceptance Rate:                        0.563268
# Replacements:                               9900
# Total Samples:                             17576
# Nested Sampling ln(Z):            3534424.840092
# Importance Nested Sampling ln(Z): 3534458.855956 +/-  0.277288
# Acceptance Rate:                        0.563388
# Replacements:                               9950
# Total Samples:                             17661
# Nested Sampling ln(Z):            3534425.927392
# Importance Nested Sampling ln(Z): 3534459.146130 +/-  0.353816
# Acceptance Rate:                        0.563253
# Replacements:                              10000
# Total Samples:                             17754
# Nested Sampling ln(Z):            3534426.860330
# Importance Nested Sampling ln(Z): 3534459.232672 +/-  0.334986
# ...
# Acceptance Rate:                        0.581808
# Replacements:                              13100
# Total Samples:                             22516
# Nested Sampling ln(Z):            3534456.753224
# Importance Nested Sampling ln(Z): 3534460.206148 +/-  0.067288
# Acceptance Rate:                        0.582245
# Replacements:                              13150
# Total Samples:                             22585
# Nested Sampling ln(Z):            3534456.891582
# Importance Nested Sampling ln(Z): 3534460.209113 +/-  0.065777
# Acceptance Rate:                        0.582756
# Replacements:                              13200
# Total Samples:                             22651
# Nested Sampling ln(Z):            3534457.025404
# Importance Nested Sampling ln(Z): 3534460.217178 +/-  0.063930
# Acceptance Rate:                        0.583135
# Replacements:                              13250
# Total Samples:                             22722
# Nested Sampling ln(Z):            3534457.154663
# Importance Nested Sampling ln(Z): 3534460.215096 +/-  0.061316
# Acceptance Rate:                        0.583308
# Replacements:                              13300
# Total Samples:                             22801
# Nested Sampling ln(Z):            3534457.279086
# Importance Nested Sampling ln(Z): 3534460.201274 +/-  0.059002
# Acceptance Rate:                        0.583607
# Replacements:                              13350
# Total Samples:                             22875
# Nested Sampling ln(Z):            3534457.400297
# Importance Nested Sampling ln(Z): 3534460.197914 +/-  0.056720
# Acceptance Rate:                        0.584005
# Replacements:                              13400
# Total Samples:                             22945
# Nested Sampling ln(Z):            3534457.515245
# Importance Nested Sampling ln(Z): 3534460.190416 +/-  0.054742
# Acceptance Rate:                        0.584198
# Replacements:                              13450
# Total Samples:                             23023
# Nested Sampling ln(Z):            3534457.625361
# Importance Nested Sampling ln(Z): 3534460.189675 +/-  0.053651
# Acceptance Rate:                        0.584314
# Replacements:                              13500
# Total Samples:                             23104
# Nested Sampling ln(Z):            3534457.731984
# Importance Nested Sampling ln(Z): 3534460.180855 +/-  0.051462
# Acceptance Rate:                        0.584556
# Replacements:                              13550
# Total Samples:                             23180
# Nested Sampling ln(Z):            3534457.834781
# Importance Nested Sampling ln(Z): 3534460.161818 +/-  0.050318
# Acceptance Rate:                        0.584720
# Replacements:                              13600
# Total Samples:                             23259
# Nested Sampling ln(Z):            3534457.933682
# Importance Nested Sampling ln(Z): 3534460.163400 +/-  0.049199
# Acceptance Rate:                        0.585059
# Replacements:                              13650
# Total Samples:                             23331
# Nested Sampling ln(Z):            3534458.027960
# Importance Nested Sampling ln(Z): 3534460.171912 +/-  0.047874
# Acceptance Rate:                        0.585320
# Replacements:                              13700
# Total Samples:                             23406
# Nested Sampling ln(Z):            3534458.117147
# Importance Nested Sampling ln(Z): 3534460.184954 +/-  0.046427
# Acceptance Rate:                        0.585879
# Replacements:                              13750
# Total Samples:                             23469
# Nested Sampling ln(Z):            3534458.201874
# Importance Nested Sampling ln(Z): 3534460.190251 +/-  0.045011
# Acceptance Rate:                        0.586161
# Replacements:                              13800
# Total Samples:                             23543
# Nested Sampling ln(Z):            3534458.281203
# Importance Nested Sampling ln(Z): 3534460.184343 +/-  0.043387
# Acceptance Rate:                        0.586442
# Replacements:                              13850
# Total Samples:                             23617
# Nested Sampling ln(Z):            3534458.357416
# Importance Nested Sampling ln(Z): 3534460.179552 +/-  0.041737
# Acceptance Rate:                        0.586745
# Replacements:                              13900
# Total Samples:                             23690
# Nested Sampling ln(Z):            3534458.430818
# Importance Nested Sampling ln(Z): 3534460.176795 +/-  0.040398
# Acceptance Rate:                        0.586652
# Replacements:                              13950
# Total Samples:                             23779
# Nested Sampling ln(Z):            3534458.501263
# Importance Nested Sampling ln(Z): 3534460.184938 +/-  0.038968
# Acceptance Rate:                        0.586658
# Replacements:                              14000
# Total Samples:                             23864
# Nested Sampling ln(Z):            3534458.569546
# Importance Nested Sampling ln(Z): 3534460.189086 +/-  0.037563
# Acceptance Rate:                        0.586786
# Replacements:                              14050
# Total Samples:                             23944
# Nested Sampling ln(Z):            3534458.634202
# Importance Nested Sampling ln(Z): 3534460.183729 +/-  0.036458
# Acceptance Rate:                        0.587084
# Replacements:                              14100
# Total Samples:                             24017
# Nested Sampling ln(Z):            3534458.696507
# Importance Nested Sampling ln(Z): 3534460.186008 +/-  0.035422
# Acceptance Rate:                        0.587381
# Replacements:                              14150
# Total Samples:                             24090
# Nested Sampling ln(Z):            3534458.756518
# Importance Nested Sampling ln(Z): 3534460.186192 +/-  0.034283
# Acceptance Rate:                        0.587602
# Replacements:                              14200
# Total Samples:                             24166
# Nested Sampling ln(Z):            3534458.813936
# Importance Nested Sampling ln(Z): 3534460.195848 +/-  0.033210
# Acceptance Rate:                        0.587896
# Replacements:                              14250
# Total Samples:                             24239
# Nested Sampling ln(Z):            3534458.868962
# Importance Nested Sampling ln(Z): 3534460.206166 +/-  0.032228
# Acceptance Rate:                        0.588284
# Replacements:                              14300
# Total Samples:                             24308
# Nested Sampling ln(Z):            3534458.921687
# Importance Nested Sampling ln(Z): 3534460.207796 +/-  0.031199
# Acceptance Rate:                        0.588332
# Replacements:                              14350
# Total Samples:                             24391
# Nested Sampling ln(Z):            3534458.971472
# Importance Nested Sampling ln(Z): 3534460.203650 +/-  0.030249
# Acceptance Rate:                        0.588524
# Replacements:                              14400
# Total Samples:                             24468
# Nested Sampling ln(Z):            3534459.019675
# Importance Nested Sampling ln(Z): 3534460.202273 +/-  0.029311
# Acceptance Rate:                        0.588859
# Replacements:                              14450
# Total Samples:                             24539
# Nested Sampling ln(Z):            3534459.066577
# Importance Nested Sampling ln(Z): 3534460.201507 +/-  0.028536
# Acceptance Rate:                        0.588952
# Replacements:                              14500
# Total Samples:                             24620
# Nested Sampling ln(Z):            3534459.111452
# Importance Nested Sampling ln(Z): 3534460.201527 +/-  0.027576
# Acceptance Rate:                        0.589164
# Replacements:                              14550
# Total Samples:                             24696
# Nested Sampling ln(Z):            3534459.154993
# Importance Nested Sampling ln(Z): 3534460.198741 +/-  0.026655
# Acceptance Rate:                        0.589423
# Replacements:                              14600
# Total Samples:                             24770
# Nested Sampling ln(Z):            3534459.197017
# Importance Nested Sampling ln(Z): 3534460.200735 +/-  0.025888
# Acceptance Rate:                        0.589442
# Replacements:                              14650
# Total Samples:                             24854
# Nested Sampling ln(Z):            3534459.238054
# Importance Nested Sampling ln(Z): 3534460.198182 +/-  0.024998
# Acceptance Rate:                        0.589651
# Replacements:                              14700
# Total Samples:                             24930
# Nested Sampling ln(Z):            3534459.277905
# Importance Nested Sampling ln(Z): 3534460.199833 +/-  0.024331
# Acceptance Rate:                        0.589953
# Replacements:                              14750
# Total Samples:                             25002
# Nested Sampling ln(Z):            3534459.315988
# Importance Nested Sampling ln(Z): 3534460.205200 +/-  0.023661
# Acceptance Rate:                        0.590182
# Replacements:                              14800
# Total Samples:                             25077
# Nested Sampling ln(Z):            3534459.352641
# Importance Nested Sampling ln(Z): 3534460.208505 +/-  0.023085
# Acceptance Rate:                        0.590434
# Replacements:                              14850
# Total Samples:                             25151
# Nested Sampling ln(Z):            3534459.387825
# Importance Nested Sampling ln(Z): 3534460.213255 +/-  0.022547
# Acceptance Rate:                        0.590614
# Replacements:                              14900
# Total Samples:                             25228
# Nested Sampling ln(Z):            3534459.421871
# Importance Nested Sampling ln(Z): 3534460.211653 +/-  0.021837
# Acceptance Rate:                        0.590582
# Replacements:                              14950
# Total Samples:                             25314
# Nested Sampling ln(Z):            3534459.454582
# Importance Nested Sampling ln(Z): 3534460.212867 +/-  0.021179
# Acceptance Rate:                        0.590830
# Replacements:                              15000
# Total Samples:                             25388
# Nested Sampling ln(Z):            3534459.486105
# Importance Nested Sampling ln(Z): 3534460.217305 +/-  0.020674
# Acceptance Rate:                        0.591030
# Replacements:                              15050
# Total Samples:                             25464
# Nested Sampling ln(Z):            3534459.516441
# Importance Nested Sampling ln(Z): 3534460.221685 +/-  0.020151
# Acceptance Rate:                        0.591137
# Replacements:                              15100
# Total Samples:                             25544
# Nested Sampling ln(Z):            3534459.545594
# Importance Nested Sampling ln(Z): 3534460.225388 +/-  0.019623
# Acceptance Rate:                        0.591520
# Replacements:                              15150
# Total Samples:                             25612
# Nested Sampling ln(Z):            3534459.573298
# Importance Nested Sampling ln(Z): 3534460.222848 +/-  0.019080
# Acceptance Rate:                        0.591877
# Replacements:                              15200
# Total Samples:                             25681
# Nested Sampling ln(Z):            3534459.599823
# Importance Nested Sampling ln(Z): 3534460.224976 +/-  0.018617
# Acceptance Rate:                        0.591957
# Replacements:                              15250
# Total Samples:                             25762
# Nested Sampling ln(Z):            3534459.625249
# Importance Nested Sampling ln(Z): 3534460.224617 +/-  0.018068
# Acceptance Rate:                        0.592128
# Replacements:                              15300
# Total Samples:                             25839
# Nested Sampling ln(Z):            3534459.649517
# Importance Nested Sampling ln(Z): 3534460.225413 +/-  0.017596
# Acceptance Rate:                        0.591659
# Replacements:                              15350
# Total Samples:                             25944
# Nested Sampling ln(Z):            3534459.672774
# Importance Nested Sampling ln(Z): 3534460.223205 +/-  0.017025
# Acceptance Rate:                        0.591761
# Replacements:                              15400
# Total Samples:                             26024
# Nested Sampling ln(Z):            3534459.695163
# Importance Nested Sampling ln(Z): 3534460.223938 +/-  0.016598
# Acceptance Rate:                        0.591773
# Replacements:                              15450
# Total Samples:                             26108
# Nested Sampling ln(Z):            3534459.716588
# Importance Nested Sampling ln(Z): 3534460.225035 +/-  0.016212
# Acceptance Rate:                        0.592213
# Replacements:                              15500
# Total Samples:                             26173
# Nested Sampling ln(Z):            3534459.737156
# Importance Nested Sampling ln(Z): 3534460.227893 +/-  0.015918
# Acceptance Rate:                        0.592494
# Replacements:                              15550
# Total Samples:                             26245
# Nested Sampling ln(Z):            3534459.756929
# Importance Nested Sampling ln(Z): 3534460.227576 +/-  0.015559
# Acceptance Rate:                        0.592390
# Replacements:                              15600
# Total Samples:                             26334
# Nested Sampling ln(Z):            3534459.775834
# Importance Nested Sampling ln(Z): 3534460.225554 +/-  0.015159
# Acceptance Rate:                        0.592466
# Replacements:                              15650
# Total Samples:                             26415
# Nested Sampling ln(Z):            3534459.793923
# Importance Nested Sampling ln(Z): 3534460.226944 +/-  0.014853
# Acceptance Rate:                        0.592676
# Replacements:                              15700
# Total Samples:                             26490
# Nested Sampling ln(Z):            3534459.811177
# Importance Nested Sampling ln(Z): 3534460.228123 +/-  0.014575
# Acceptance Rate:                        0.592707
# Replacements:                              15750
# Total Samples:                             26573
# Nested Sampling ln(Z):            3534459.827691
# Importance Nested Sampling ln(Z): 3534460.227667 +/-  0.014269
# Acceptance Rate:                        0.592759
# Replacements:                              15800
# Total Samples:                             26655
# Nested Sampling ln(Z):            3534459.843480
# Importance Nested Sampling ln(Z): 3534460.227908 +/-  0.013983
# Acceptance Rate:                        0.592678
# Replacements:                              15850
# Total Samples:                             26743
# Nested Sampling ln(Z):            3534459.858577
# Importance Nested Sampling ln(Z): 3534460.227607 +/-  0.013704
# Acceptance Rate:                        0.592996
# Replacements:                              15900
# Total Samples:                             26813
# Nested Sampling ln(Z):            3534459.872908
# Importance Nested Sampling ln(Z): 3534460.229188 +/-  0.013512
# Acceptance Rate:                        0.593157
# Replacements:                              15950
# Total Samples:                             26890
# Nested Sampling ln(Z):            3534459.886536
# Importance Nested Sampling ln(Z): 3534460.230609 +/-  0.013297
# Acceptance Rate:                        0.593340
# Replacements:                              16000
# Total Samples:                             26966
# Nested Sampling ln(Z):            3534459.899630
# Importance Nested Sampling ln(Z): 3534460.230921 +/-  0.013082
# Acceptance Rate:                        0.593543
# Replacements:                              16050
# Total Samples:                             27041
# Nested Sampling ln(Z):            3534459.912260
# Importance Nested Sampling ln(Z): 3534460.229654 +/-  0.012874
# Acceptance Rate:                        0.593890
# Replacements:                              16095
# Total Samples:                             27101
# Nested Sampling ln(Z):            3534459.923147
# Importance Nested Sampling ln(Z): 3534460.230687 +/-  0.012740
#  ln(ev)=   3534460.1570664272      +/-  0.14153655787885838
#  Total Likelihood Evaluations:        27101
#  Sampling finished. Exiting MultiNest
