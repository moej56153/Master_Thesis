# %%
from astropy.coordinates import SkyCoord
import numpy as np
from IntegralQuery import SearchQuery, IntegralQuery, Filter, Range
from IntegralPointingClustering import ClusteredQuery
import astropy.io.fits as fits
from astropy.table import Table
from datetime import datetime
import matplotlib.pyplot as plt
import math
from numba import njit
from pyspi.utils.function_utils import find_response_version
from pyspi.utils.response.spi_response_data import ResponseDataRMF
from pyspi.utils.response.spi_response import ResponseRMFGenerator
from pyspi.utils.response.spi_drm import SPIDRM
from pyspi.utils.livedets import get_live_dets
from astromodels import Powerlaw, Log_uniform_prior, Uniform_prior, PointSource, SpectralComponent, Model
from chainconsumer import ChainConsumer
import pymultinest
import os
import astropy.time as at
from scipy.stats import poisson
import pickle
# Out:
# [WARNING ] The naima package is not available. Models that depend on it will not be available
# [WARNING ] The GSL library or the pygsl wrapper cannot be loaded. Models that depend on it will not be available.
# [WARNING ] The ebltable package is not available. Models that depend on it will not be available
# [INFO    ] Starting 3ML!
# [WARNING ] no display variable set. using backend for graphics without display (agg)
# [WARNING ] ROOT minimizer not available
# [WARNING ] PyGMO is not available
# [WARNING ] The cthreeML package is not installed. You will not be able to use plugins which require the C/C++ interface (currently HAWC)
# [WARNING ] Could not import plugin HAWCLike.py. Do you have the relative instrument software installed and configured?
# [WARNING ] Could not import plugin FermiLATLike.py. Do you have the relative instrument software installed and configured?
# [WARNING ] No fermitools installed
# [WARNING ] Env. variable OMP_NUM_THREADS is not set. Please set it to 1 for optimal performances in 3ML
# [WARNING ] Env. variable MKL_NUM_THREADS is not set. Please set it to 1 for optimal performances in 3ML
# [WARNING ] Env. variable NUMEXPR_NUM_THREADS is not set. Please set it to 1 for optimal performances in 3ML

# %%
rsp_bases = tuple([ResponseDataRMF.from_version(i) for i in range(5)])
# Out:
# Using the irfs that are valid between Start and 03/07/06 06:00:00 (YY/MM/DD HH:MM:SS)
# Using the irfs that are valid between 03/07/06 06:00:00 and 04/07/17 08:20:06 (YY/MM/DD HH:MM:SS)
# Using the irfs that are valid between 04/07/17 08:20:06 and 09/02/19 09:59:57 (YY/MM/DD HH:MM:SS)
# Using the irfs that are valid between 09/02/19 09:59:57 and 10/05/27 12:45:00 (YY/MM/DD HH:MM:SS)
# Using the irfs that are valid between 10/05/27 12:45:00 and present (YY/MM/DD HH:MM:SS)

# %%
@njit
def b_maxL_2(m, t, C):
    first = C[0]+C[1]-(m[0]+m[1])*(t[0]+t[1])
    root = (C[0]+C[1]+(m[0]-m[1])*(t[0]+t[1]))**2-4*C[0]*(m[0]-m[1])*(t[0]+t[1])
    res = (first+np.sqrt(root))/(2*(t[0]+t[1]))
    if res < 0:
        return 0
    return res

@njit #################### needs more testing, can do without error?
def b_maxL_3(m, t, C):
    mt = m[0] + m[1] + m[2]
    tt = t[0] + t[1] + t[2]
    Ct = C[0] + C[1] + C[2]
    a = -tt
    b = -tt*mt + Ct
    c = Ct*mt - C[0]*m[0] - C[1]*m[1] - C[2]*m[2] -tt*(m[0]*m[1] + m[1]*m[2] + m[2]*m[0])
    d = C[0]*m[1]*m[2] + C[1]*m[2]*m[0] + C[2]*m[0]*m[1] - tt*m[0]*m[1]*m[2]
    D0 = b**2 - 3*a*c
    D1 = 2*b**3 - 9*a*b*c + 27*(a**2)*d
        
    if D0 == 0. and D1 == 0.:
        return -b/(3*a)
    
    C0 = ((D1 + np.sqrt(D1**2 - 4*D0**3 + 0j)) / 2)**(1/3)
    
    if C0 == 0:
        C0 = ((D1 - np.sqrt(D1**2 - 4*D0**3 + 0j)) / 2)**(1/3)
        
    x0 = -1/(3*a) * (b + C0 + D0/C0)
    
    if x0.real < 0:
        return 0.
    
    return x0.real

# %%
@njit
def logLcore(
    spec_binned,
    pointings,
    dets,
    resp_mats,
    num_sources,
    t_elapsed,
    counts
):
    logL=0
    for p_i in range(len(pointings)):
        for d_i in range(len(dets[p_i])):
            n_p = len(pointings[p_i])
            m = np.zeros((n_p, len(resp_mats[p_i][0][0][0,0,:])))
            
            t_b = np.zeros(n_p)
            for t_i in range(n_p):
                t_b[t_i] = t_elapsed[p_i][t_i][d_i]
            C_b = np.zeros(n_p)
            
            for s_i in range(num_sources):
                for m_i in range(n_p):
                    m[m_i,:] += np.dot(spec_binned[s_i,:], resp_mats[p_i][s_i][m_i][d_i])
            for e_i in range(len(m[0])):
                m_b = m[:,e_i]
                for C_i in range(n_p):
                    C_b[C_i] = counts[p_i][C_i][d_i, e_i]
                    
                if n_p == 2:
                    b = b_maxL_2(m_b, t_b, C_b)
                elif n_p == 3:
                    b = b_maxL_3(m_b, t_b, C_b)
                else:
                    print()
                    print("b_maxL is not defined")
                    print()
                    return 0.
                for m_i in range(n_p):
                    logL += (counts[p_i][m_i][d_i, e_i]*math.log(t_elapsed[p_i][m_i][d_i]*(m[m_i,e_i]+b))
                            -t_elapsed[p_i][0][d_i]*(m[m_i,e_i]+b))
    return logL

# %%
def extract_pointing_info(path, p_id):
    num_dets = 19
    with fits.open(f"{path}/pointing.fits") as file:
        t = Table.read(file[1])
        index = np.argwhere(t["PTID_ISOC"]==p_id[:8])
        
        if len(index) < 1:
            raise Exception(f"{p_id} not found")

        pointing_info = t[index[-1][0]]
        
        t1 = at.Time(f'{pointing_info["TSTART"]+2451544.5}', format='jd').datetime
        time_start = datetime.strftime(t1,'%y%m%d %H%M%S')
            
    with fits.open(f"{path}/dead_time.fits") as file:
        t = Table.read(file[1])
        
        time_elapsed = np.zeros(num_dets)
        
        for i in range(num_dets):
            for j in index:
                time_elapsed[i] += t["LIVETIME"][j[0]*85 + i]
        
    with fits.open(f"{path}/energy_boundaries.fits") as file:
        t = Table.read(file[1])
        
        energy_bins = np.append(t["E_MIN"], t["E_MAX"][-1])
    
    with fits.open(f"{path}/evts_det_spec.fits") as file:
        t = Table.read(file[1])
        
        counts = np.zeros((num_dets, len(energy_bins)-1))
        for i in range(num_dets):
            for j in index:
                counts[i, : ] += t["COUNTS"][j[0]*85 + i]

    return time_start, time_elapsed, energy_bins, counts

# %%
def generate_resp_mat(
    time,
    dets,
    ebs,
    emod,
    ra,
    dec,
    rsp_base,
):
    sds = np.empty(0)
    for d in dets:
        rsp = ResponseRMFGenerator.from_time(time, d, ebs, emod, rsp_base) ################## remove from update
        sd = SPIDRM(rsp, ra, dec)
        sds = np.append(sds, sd.matrix.T)
    return sds.reshape((len(dets), len(emod)-1, len(ebs)-1))

# %%
def calc_mahalanobis_dist(summary, cov, true_vals):
    fit_val = np.array([summary[i][1] for i in true_vals[0]])
    fit_cov = cov[1]
    rel_distance = []
    
    for i in range(len(true_vals[1])):
        dif = fit_val - true_vals[1][i]
        
        rel_distance.append(np.sqrt(
            np.linalg.multi_dot([dif, np.linalg.inv(fit_cov), dif])
        ))
        
    return np.array(rel_distance)

# %%
class MultinestClusterFit:
    def __init__(
        self,
        pointings,
        source_model,
        binning_func,
        energy_range,
        emod,
        true_values=None,
        folder=None,
    ):
        self._pointings = pointings
        self._source_model = source_model
        self._binning_func = binning_func
        self._energy_range = energy_range
        self._emod = emod
        
        self._true_values = true_values
        self.set_folder(folder)
        
        self._prepare_fit_data()
        
        self._initialize_resp_mats()
        
        self._find_updatable_sources()
        
        self._run_multinest()
                
        self._extract_parameter_names_simple()
        self._parameter_names.extend(["$z$"])
            
        self._cc = ChainConsumer()
        self._chain = np.loadtxt('./chains/1-post_equal_weights.dat')
        self._cc.add_chain(self._chain, parameters=self._parameter_names, name='fit')
        
    def _run_multinest(self):
        num_sources = len(self._source_model.sources)
        
        def logLba_mult(trial_values, ndim=None, params=None):
            spec_binned = np.zeros((num_sources, len(self._emod)-1))
            for i, parameter in enumerate(self._source_model.free_parameters.values()):
                parameter.value = trial_values[i]
            for i, source in enumerate(self._source_model.sources.values()):
                spec = source(self._emod)
                spec_binned[i,:] = (self._emod[1:]-self._emod[:-1])*(spec[:-1]+spec[1:])/2
            if self._updatable_sources:
                self._update_resp_mats()
            return logLcore(
                spec_binned,
                self._pointings,
                self._dets,
                self._resp_mats,
                num_sources,
                self._t_elapsed,
                self._counts,
            )
        
        def prior(params, ndim=None, nparams=None):
            for i, parameter in enumerate(self._source_model.free_parameters.values()):
                try:
                    params[i] = parameter.prior.from_unit_cube(params[i])

                except AttributeError:
                    raise RuntimeError(
                        "The prior you are trying to use for parameter %s is "
                        "not compatible with sampling from a unitcube"
                        % parameter.path
                    )

        num_params = len(self._source_model.free_parameters)
        
        # ###
        # trial_values = [4.5e-3, -2.08, 7e-3, -2.5]
        # spec_binned = np.zeros((num_sources, len(self._emod)-1))
        # for i, parameter in enumerate(self._source_model.free_parameters.values()):
        #     parameter.value = trial_values[i]
        # for i, source in enumerate(self._source_model.sources.values()):
        #     spec = source(self._emod)
        #     spec_binned[i,:] = (self._emod[1:]-self._emod[:-1])*(spec[:-1]+spec[1:])/2
        # print(logLcore(
        #     spec_binned,
        #     self._pointings,
        #     self._dets,
        #     self._resp_mats,
        #     num_sources,
        #     self._t_elapsed,
        #     self._counts,
        # ))
        # return None
        # ###

        if not os.path.exists("./chains"):
            os.mkdir("chains")
        sampler = pymultinest.run(
            logLba_mult, prior, num_params, num_params, n_live_points=800, resume=False, verbose=True
        )
    
    def _prepare_fit_data(self):
        ebs = []
        counts = []
        dets = []
        t_elapsed = []
        t_start = []
            
        for combination in self._pointings:
            c_time_start, c_time_elapsed = [], []
            for p_i, pointing in enumerate(combination):
                time_start, time_elapsed, energy_bins, counts_f = extract_pointing_info(pointing[1], pointing[0])
                c_time_start.append(time_start)
                dets_temp = get_live_dets(time=time_start, event_types=["single"])
                c_time_elapsed.append(time_elapsed[dets_temp])
                
                if p_i == 0:
                    dets_0 = dets_temp
                    energy_bins_0 = energy_bins
                    c_counts_f = counts_f[dets_0]
                else:
                    c_counts_f = np.append(c_counts_f, counts_f[dets_0], axis=0)
                    assert np.array_equal(dets_0, dets_temp), f"Active detectors are not the same for {combination[0][0]} and {combination[p_i][0]}"
                    assert np.array_equal(energy_bins_0, energy_bins), f"Energy bins are not the same for {combination[0][0]} and {combination[p_i][0]}"
                
            eb, c = self._binning_func(
                energy_bins_0,
                c_counts_f,
                self._energy_range
            )
            nd = len(dets_0)
            counts.append(tuple([c[i*nd : (i+1)*nd] for i in range(len(combination))]))
            ebs.append(eb)
            
            t_start.append(tuple(c_time_start))
            dets.append(dets_0)
            t_elapsed.append(tuple(c_time_elapsed))
                            
                
            # time_start1, time_elapsed1, energy_bins1, counts_f1 = extract_pointing_info(pair[0], pair[1])
            # time_start2, time_elapsed2, energy_bins2, counts_f2 = extract_pointing_info(pair[0], pair[2])
            # t_start.append((time_start1, time_start2))
            
            # dets1 = get_live_dets(time=time_start1, event_types=["single"])
            # dets2 = get_live_dets(time=time_start2, event_types=["single"])
            # assert np.array_equal(dets1, dets2), f"Active detectors are not the same for {pair[1]} and {pair[2]}"
            # dets.append(dets1)
            
            # t_elapsed.append((time_elapsed1[dets1], time_elapsed2[dets1]))
            
            # assert np.array_equal(energy_bins1, energy_bins2), f"Energy bins are not the same for {pair[1]} and {pair[2]}"
            
            # eb, c = binning_func(
            #     energy_bins1,
            #     np.append(counts_f1[dets1], counts_f2[dets1], axis=0),
            #     energy_range)
            # counts.append((c[:len(dets1)], c[len(dets1):]))
            # ebs.append(eb)
                
        self._ebs = tuple(ebs) 
        self._counts = tuple(counts)
        self._dets = tuple(dets)
        self._t_elapsed = tuple(t_elapsed)
        self._t_start = tuple(t_start)
    
    def _initialize_resp_mats(self): ########################### allow different response versions
        # index order: tuple(combination, source, pointing, np_array(dets, e_in, e_out))
        resp_mats = []
        
        for count, combination in enumerate(self._pointings):
            version1 = find_response_version(self._t_start[count][0])
            for pointing in range(1, len(combination)):
                version2 = find_response_version(self._t_start[count][pointing])
                assert version1 == version2, f"Response versions are not equal for {combination[0][0]} and {combination[pointing][0]}"
            
            rsp_base = rsp_bases[version1]
            source_resp_mats = []
            for source in self._source_model.sources.values():
                combination_resp_mats = []
                for pointing in range(len(combination)):
                    combination_resp_mats.append(
                        generate_resp_mat(
                            self._t_start[count][pointing],
                            self._dets[count],
                            self._ebs[count],
                            self._emod,
                            source.position.get_ra(),
                            source.position.get_dec(),
                            rsp_base,
                        )
                    )
                source_resp_mats.append(tuple(combination_resp_mats))
                
            #     sds1 = np.array([])
            #     sds2 = np.array([])
            #     for d in dets[count]:
            #         rsp1 = ResponseRMFGenerator.from_time(t_start[count][0], d, ebs[count], emod, rsp_base)
            #         sd1 = SPIDRM(rsp1, source[1].position.get_ra(), source[1].position.get_dec())
            #         sds1 = np.append(sds1, sd1.matrix.T)
            #         rsp2 = ResponseRMFGenerator.from_time(t_start[count][1], d, ebs[count], emod, rsp_base)
            #         sd2 = SPIDRM(rsp2, source[1].position.get_ra(), source[1].position.get_dec())
            #         sds2 = np.append(sds2, sd2.matrix.T)
            #     source_resp_mats.append((
            #         sds1.reshape((len(dets[count]), len(emod)-1, len(ebs[count])-1)),
            #         sds2.reshape((len(dets[count]), len(emod)-1, len(ebs[count])-1)),
            #     ))
            resp_mats.append(tuple(source_resp_mats))
            
        self._resp_mats = tuple(resp_mats)

    def _update_resp_mats(self):
        for count, combination in enumerate(self._pointings):
            version = find_response_version(self._t_start[count][0])
            rsp_base = rsp_bases[version]
            for source_num, (source_name, source) in enumerate(self._source_model.sources.items()):
                if source_name in self._updatable_sources:
                    for pointing in range(len(combination)):
                        self._resp_mats[count][source_num][pointing][:,:,:] = generate_resp_mat(
                            self._t_start[count][pointing],
                            self._dets[count],
                            self._ebs[count],
                            self._emod,
                            source.position.get_ra(),
                            source.position.get_dec(),
                            rsp_base,
                        )

    def _find_updatable_sources(self):
        keywords = ["position"]
        self._updatable_sources = []
        for parameter in self._source_model.free_parameters.values():
            first_pos = parameter.path.find(".")
            second_pos = parameter.path.find(".", first_pos+1)
            if parameter.path[first_pos+1 : second_pos] in keywords and not parameter.path[:first_pos] in self._updatable_sources:
                self._updatable_sources.extend([parameter.path[:first_pos]])

    def parameter_fit_distribution(self):
        assert not self._folder is None, "folder is not set"
        
        fig = self._cc.plotter.plot(
            filename="parameter_fit_distribution.pdf",
            parameters=self._parameter_names[:-1],
            # truth={'Crab K':true_values_main[0,0], 'Crab index':true_values_main[0,1]},
            figsize=1.5
        )
        
        plt.savefig(f"{self._folder}/parameter_fit_distributions.pdf")
        plt.close()
        
    def text_summaries(
        self,
        reference_values=True,
        pointing_combinations=True,
        parameter_fit_constraints=True
    ):
        assert not self._folder is None, "folder is not set"
        
        summary = self._cc.analysis.get_summary(parameters=self._parameter_names[:-1])
        
        if reference_values:
            assert not self._true_values is None, "true_values not set"
            cov = self._cc.analysis.get_covariance(parameters=self._true_values[0])
            rel_distances = calc_mahalanobis_dist(summary, cov, self._true_values)
            
            with open(f"{self._folder}/reference_values", "w") as f:
                f.write(f"{' : '.join(self._true_values[0])} : Rel. Dist.\n")
                for i in range(self._true_values[1].shape[0]):
                    f.write(f"{' : '.join([f'{j:.3}' for j in self._true_values[1][i,:]])} : {rel_distances[i]:.3}\n")
                
        if pointing_combinations:
            with open(f"{self._folder}/pointing_combinations", "w") as f:
                for combination in self._pointings:
                    f.write(f'{"  ".join(i[0] for i in combination)}\n')
        
        if parameter_fit_constraints:
            with open(f"{self._folder}/parameter_fit_constraints", "w") as f:
                for param in self._parameter_names[:-1]:
                    f.write(f"{param}:\n")
                    try:
                        f.write(f"{summary[param][0]:.5}  {summary[param][1]:.5}  {summary[param][2]:.5}\n")
                    except:
                        f.write(f"None  {summary[param][1]:.5}  None\n")
    
    def ppc(
        self,
        count_energy_plots=True,
        qq_plots=True
    ):
        assert self._folder is not None, "folder is not set"
        
        for c_i, combination in enumerate(self._pointings):
            s, b = self._calc_rates(
                self._resp_mats[c_i],
                self._ebs[c_i],
                self._counts[c_i],
                self._dets[c_i],
                self._t_elapsed[c_i],
            )
            
            if count_energy_plots:
                for p_i in range(len(combination)):
                    self._count_energy_plot(
                        b[p_i],
                        s[p_i],
                        self._ebs[c_i],
                        self._counts[c_i][p_i],
                        self._dets[c_i],
                        combination[p_i][0]
                    )
            
    def _calc_rates(
        self,
        resp_mats,
        eb,
        counts,
        dets,
        t_elapsed,
    ):
        source_rate = np.zeros((len(counts), len(dets), len(eb)-1, len(self._chain)))
        background_rate = np.zeros((len(dets), len(eb)-1, len(self._chain)))
        
        num_sources = len(self._source_model.sources)
        
        for p_i, params in enumerate(self._chain):
            spec_binned = np.zeros((num_sources, len(self._emod)-1))
            for fp_i, parameter in enumerate(self._source_model.free_parameters.values()):
                parameter.value = params[fp_i]
            for s_i, source in enumerate(self._source_model.sources.values()):
                spec = source(self._emod)
                spec_binned[s_i,:] = (self._emod[1:]-self._emod[:-1])*(spec[:-1]+spec[1:])/2
                
            for d_i in range(len(dets)):
                for s_i in range(num_sources):
                    for m_i in range(len(counts)):
                        source_rate[m_i,d_i,:,p_i] += np.dot(spec_binned[s_i,:], resp_mats[s_i][m_i][d_i])
                for e_i in range(len(eb)-1):
                    s_b = np.array([source_rate[i,d_i,e_i,p_i] for i in range(len(counts))])
                    t_b = np.array([t_elapsed[i][d_i] for i in range(len(counts))])
                    C_b = np.array([counts[i][d_i, e_i] for i in range(len(counts))])
                    if len(counts) == 2:
                        background_rate[d_i,e_i,p_i] = b_maxL_2(s_b, t_b, C_b)
                    elif len(counts) == 3:
                        background_rate[d_i,e_i,p_i] = b_maxL_3(s_b, t_b, C_b)
                        
        source_rates = []
        background_rates = []
        for i in range(len(counts)):
            source_rates.append(
                np.average(source_rate[i], axis=2) * t_elapsed[i][:,np.newaxis]
            )
            background_rates.append(
                np.average(background_rate, axis=2) * t_elapsed[i][:,np.newaxis]
            )

        return source_rates, background_rates

    def _count_energy_plot(
        self,
        b,
        s,
        eb,
        c,
        dets,
        name
    ):
        fig, axes = plt.subplots(5,4, sharex=True, sharey=True, figsize=(10,10))
        axes = axes.flatten()
        i=0
        predicted = b + s
        predicted_lower = poisson.ppf(0.05, predicted)
        predicted_upper = poisson.ppf(0.95, predicted)
        
        counts = c
        
        for d in range(19):
            axes[d].text(.5,.9,f"Det {d}",horizontalalignment='center',transform=axes[d].transAxes)
            if d in dets:
                line1, = axes[d].step(eb[:-1], predicted[i], c="r")
                line2, = axes[d].step(eb[:-1], counts[i], c="k")
                axes[d].fill_between(eb[:-1], predicted_lower[i], predicted_upper[i], color="r", alpha=0.5)
                if i==0:
                    line1.set_label("Predicted Counts")
                    line2.set_label("Real Counts")
                i += 1
            axes[d].set_yscale("log")
        plt.subplots_adjust(hspace=0, wspace=0)
        plt.subplots_adjust(hspace=0, top=0.96, bottom=0.1)
        lgd = fig.legend(loc='center left', bbox_to_anchor=(0.9, 0.5), fontsize='x-large')
        
        fig.add_subplot(111, frameon=False)
        plt.tick_params(labelcolor='none', which='both', top=False, bottom=False, left=False, right=False)
        plt.xlabel("Detected Energy [keV]")
        plt.ylabel("Cumulative Counts")
        
        fig.savefig(f"{self._folder}/{name}_count_energy.pdf")
        plt.close()
    
    def _qq_plot(self): pass
    
    def _extract_parameter_names_simple(self):
        self._parameter_names = []
        for full_name in self._source_model.free_parameters.keys():
            source = full_name[ : full_name.find(".")]
            source = source[1:] if source[0]=="_" else source
            source = source.replace("__", "+").replace("_", " ")
            parameter = full_name[-1 * full_name[::-1].find(".") : ]
            self._parameter_names.extend([f"{source} {parameter}"])
    
    def set_folder(self, folder):
        if not folder is None:
            if not os.path.exists(f"./{folder}"):
                os.mkdir(folder)
        self._folder = folder

# %%
def rebin_data_exp(
    bins,
    counts,
    energy_range
):

    if energy_range[0]:
        for i, e in enumerate(bins):
            if e > energy_range[0]:
                bins = bins[i:]
                counts = counts[:,i:] ############should these be the same?
                break
    if energy_range[1]:
        for i, e in enumerate(bins):
            if e > energy_range[1]:
                bins = bins[:i]
                counts = counts[:,:i-1]
                assert i > 1, "Max Energy is too low"
                break
        
    min_counts = 5
    
    max_num_bins = 120
    min_num_bins = 1
    
    finished = False
    
    while not finished:
        num_bins = round((max_num_bins + min_num_bins) / 2)
        
        if num_bins == max_num_bins or num_bins == min_num_bins:
            num_bins = min_num_bins
            finished = True
        
        temp_bins = np.geomspace(bins[0], bins[-1], num_bins+1)
        
        new_bins, new_counts = rebin_closest(bins, counts, temp_bins)
        
        if np.amin(new_counts) < min_counts:
            max_num_bins = num_bins
        else:
            min_num_bins = num_bins
            
    return new_bins, new_counts
    
# @njit
def rebin_closest(bins, counts, temp_bins):
    counts = np.copy(counts)
    closest1 = len(bins) - 1
    for i in range(len(temp_bins)-2, 0, -1):
        closest2 = np.argpartition(
            np.absolute(bins - temp_bins[i]),
            0
        )[0]
        if closest1 - closest2 >= 2:
            counts[:,closest2] += np.sum(counts[:, closest2+1 : closest1], axis=1)
            counts = np.delete(
                counts,
                [j for j in range(closest2+1, closest1)],
                axis=1
            )
            bins = np.delete(
                bins,
                [j for j in range(closest2+1, closest1)]
            )
        closest1 = closest2
    return bins, counts


# counts = np.linspace(1,40,40).reshape((2,20))
# bins = np.linspace(1,21,21)
# temp_bins = np.geomspace(1,21,11)
# b, c = rebin_closest(bins, counts, temp_bins)
# print(bins)
# print(counts)
# print(np.sum(counts, axis=1))
# print(temp_bins)
# print(b)
# print(c)
# print(np.sum(c, axis=1))

# %%
def save_clusters(pointings, folder):
    if not os.path.exists(f"./{folder}"):
        os.mkdir(folder)
    with open(f"./{folder}/pointings.pickle", "wb") as f:
        pickle.dump(pointings, f)
        
def load_clusters(folder):
    with open(f"./{folder}/pointings.pickle", "rb") as f:
        pointings = pickle.load(f)
    return pointings

# %%
def extract_date_range(path):
    with fits.open(f"{path}/pointing.fits") as file:
        t = Table.read(file[1])
        t1 = at.Time(f'{t["TSTART"][0]+2451544.5}', format='jd')
        t1.format = "isot"
        t2 = at.Time(f'{t["TSTOP"][-1]+2451544.5}', format='jd')
        t2.format = "isot"
    return t1.value, t2.value

# %%
class PointingClusters: #add min time diff
    def __init__(
        self,
        orbit_paths,
        min_angle_dif,
        max_angle_dif,
        max_time_dif,
        radius_around_crab,
        min_time_elapsed,
        cluster_size_range,
        random_angle_dif_range=None,
    ):
        self._orbit_paths = orbit_paths
        self._min_angle_dif = min_angle_dif
        self._max_angle_dif = max_angle_dif
        self._max_time_dif = max_time_dif
        self._radius_around_crab = radius_around_crab
        self._min_time_elapsed = min_time_elapsed
        self._cluster_size_range = cluster_size_range
        self._random_angle_dif_range = random_angle_dif_range
        
        pointings = []
        self._get_scw_ids()
        cq = ClusteredQuery(
            self._scw_ids,
            angle_weight=0.,
            time_weight=1./self._max_time_dif,
            max_distance=1.,
            min_ang_distance=self._min_angle_dif,
            max_ang_distance=self._max_angle_dif,
            cluster_size_range = self._cluster_size_range,
            failed_improvements_max=3,
            suboptimal_cluster_size=max(1,self._cluster_size_range[0]),
            close_suboptimal_cluster_size=max(1,self._cluster_size_range[0])
        ).get_clustered_scw_ids()
        
        for size in range(self._cluster_size_range[0], self._cluster_size_range[1] + 1):
            for cluster in cq[size]:
                pointings.append(tuple([(i, f"crab_data/{i[:4]}") for i in cluster]))
                
        self.pointings = tuple(pointings)             
    
    def _get_scw_ids(self, print_results=False):
        p = SkyCoord(83.6333, 22.0144, frame="icrs", unit="deg")
        searchquerry = SearchQuery(position=p, radius=f"{self._radius_around_crab} degree",)
        cat = IntegralQuery(searchquerry)

        scw_ids_all = None
        for path in self._orbit_paths:
            f = Filter(
                SCW_TYPE="POINTING",
                TIME=Range(*extract_date_range(path))
            )
            if scw_ids_all:
                scw_ids_all = np.append(
                    scw_ids_all,
                    cat.apply_filter(f, return_coordinates=True, remove_duplicates=True),
                    axis=0
                )
            else:
                scw_ids_all = cat.apply_filter(f, return_coordinates=True, remove_duplicates=True)
        
        scw_ids = []
        
        multiple_files = []
        no_files = []
        no_pyspi = []
        
        num_dets = 19
        eb = np.geomspace(18, 2000, 5)
        emod = np.geomspace(18, 2000, 5)
        for scw_id in scw_ids_all:
            good = True
            with fits.open(f"{path}/pointing.fits") as file:
                t = Table.read(file[1])
                index = np.argwhere(t["PTID_ISOC"]==scw_id[0][:8])
                
                if len(index) < 1:
                    no_files.append(scw_id)
                    good = False
                    continue
                    
                elif len(index) > 1:
                    multiple_files.append(scw_id)
                    good = False
                                
                pointing_info = t[index[-1][0]]
            
                t1 = at.Time(f'{pointing_info["TSTART"]+2451544.5}', format='jd').datetime
                time_start = datetime.strftime(t1,'%y%m%d %H%M%S')
                                
                with fits.open(f"{path}/dead_time.fits") as file2:
                    t2 = Table.read(file2[1])
                    
                    time_elapsed = np.zeros(num_dets)
                    
                    for i in range(num_dets):
                        for j in index:
                            time_elapsed[i] += t2["LIVETIME"][j[0]*85 + i]
                                
                dets = get_live_dets(time=time_start, event_types=["single"])
                                
                if not np.amin(time_elapsed[dets]) > self._min_time_elapsed:
                    good = False
            
            try: # investigate why this is necessary
                version = find_response_version(time_start)
                rsp = ResponseRMFGenerator.from_time(time_start, dets[0], eb, emod, rsp_bases[version])
            except:
                no_pyspi.append(scw_id)
                good = False
                
            if good:
                scw_ids.append(scw_id)
                
        if print_results:
            print("Multiple Files:")
            print(multiple_files)
            print("No Files:")
            print(no_files)
            print("No PySpi:")
            print(no_pyspi)
            print("Good:")
            print(scw_ids)
        
        self._scw_ids = np.array(scw_ids)

# %%
def define_sources(source_funcs):    
    model = Model()
    for source_func, params in source_funcs:
        source_func(model, *params)
    return model

# %%
def crab_pl_fixed_pos(model, piv):
    ra, dec = 83.6333, 22.0144
    
    pl = Powerlaw()
    pl.piv = piv
    pl.K.prior = Log_uniform_prior(lower_bound=1e-6, upper_bound=1e0)
    pl.index.prior = Uniform_prior(lower_bound=-4, upper_bound=0)
    component1 = SpectralComponent("pl", shape=pl)
    ps = PointSource("Crab", ra=ra, dec=dec, components=[component1])
    
    model.add_source(ps)
    return model

def crab_pl_free_pos(model, piv):
    ra, dec = 83.6333, 22.0144
    angle_range = 5.
    
    pl = Powerlaw()
    pl.piv = piv
    pl.K.prior = Log_uniform_prior(lower_bound=1e-6, upper_bound=1e0)
    pl.index.prior = Uniform_prior(lower_bound=-4, upper_bound=0)
    component1 = SpectralComponent("pl", shape=pl)
    ps = PointSource("Crab", ra=ra, dec=dec, components=[component1])
    ps.position.ra.free = True
    ps.position.ra.prior = Uniform_prior(
        lower_bound = ra - abs(angle_range/np.cos(dec)),
        upper_bound = ra + abs(angle_range/np.cos(dec))
    )
    ps.position.dec.free = True
    ps.position.dec.prior = Uniform_prior(
        lower_bound = dec - angle_range,
        upper_bound = dec + angle_range
    )
    
    model.add_source(ps)
    return model

def _1A_0535_262_pl(model, piv):
    ra, dec = 84.7270, 26.3160
    
    pl = Powerlaw()
    pl.piv = piv
    pl.K.prior = Log_uniform_prior(lower_bound=1e-10, upper_bound=1e0)
    pl.index.prior = Uniform_prior(lower_bound=-4, upper_bound=0)
    component1 = SpectralComponent("pl", shape=pl)
    ps = PointSource("_1A_0535__262", ra=ra, dec=dec, components=[component1])
    
    model.add_source(ps)
    return model

def _4U_0517_17_pl(model, piv):
    ra, dec = 77.6896, 16.4986
    
    pl = Powerlaw()
    pl.piv = piv
    pl.index.min_value = -20.
    pl.K.prior = Log_uniform_prior(lower_bound=1e-10, upper_bound=1e-4)
    pl.index.prior = Uniform_prior(lower_bound=-20, upper_bound=10)
    component1 = SpectralComponent("pl", shape=pl)
    ps = PointSource("_4U_0517__17", ra=ra, dec=dec, components=[component1])
    
    model.add_source(ps)
    return model

def _4U_0614_09_pl(model, piv):
    ra, dec = 94.2800, 9.13700
    
    pl = Powerlaw()
    pl.piv = piv
    pl.index.max_value = 20.
    pl.K.prior = Log_uniform_prior(lower_bound=1e-10, upper_bound=1e-4)
    pl.index.prior = Uniform_prior(lower_bound=-10, upper_bound=20)
    component1 = SpectralComponent("pl", shape=pl)
    ps = PointSource("_4U_0614__09", ra=ra, dec=dec, components=[component1])
    
    model.add_source(ps)
    return model

def geminga_pl(model, piv):
    ra, dec = 98.4750, 17.7670
    
    pl = Powerlaw()
    pl.piv = piv
    pl.index.max_value = 15.
    pl.K.prior = Log_uniform_prior(lower_bound=1e-15, upper_bound=1e-5)
    pl.index.prior = Uniform_prior(lower_bound=-10, upper_bound=15)
    component1 = SpectralComponent("pl", shape=pl)
    ps = PointSource("Geminga", ra=ra, dec=dec, components=[component1])
    
    model.add_source(ps)
    return model

# %%
def true_values():
    piv = 40
    
    crab_parameters = np.array([[9.3, 1, -2.08],
                                [7.52e-4, 100, -1.99],
                                [11.03, 1, -2.1]])
    
    crab_values = np.zeros((len(crab_parameters),2))
    crab_values[:,0] = crab_parameters[:,0] * (piv / crab_parameters[:,1])**crab_parameters[:,2]
    crab_values[:,1] = crab_parameters[:,2]
    
    crab_values = (["Crab K", "Crab index"], crab_values)
    
    return crab_values

# %%
folder = "orbit_1019"

# pointings = PointingClusters(
#     ("crab_data/1019",),
#     min_angle_dif=1.5,
#     max_angle_dif=4.,
#     max_time_dif=0.2,
#     radius_around_crab=5.,
#     min_time_elapsed=600.,
#     cluster_size_range=(2,2),
# ).pointings
# save_clusters(pointings, folder)

pointings = load_clusters(folder)
source_model = define_sources((
    (crab_pl_fixed_pos, (40,)),
    (_1A_0535_262_pl, (40,)),
))

multinest_fit = MultinestClusterFit(
    pointings,
    source_model,
    rebin_data_exp,
    (None, 80),
    np.geomspace(18, 150, 50),
    true_values(),
    folder,
)

multinest_fit.parameter_fit_distribution()
multinest_fit.text_summaries()
multinest_fit.ppc()
# Out:
#  *****************************************************
#  MultiNest v3.10
#  Copyright Farhan Feroz & Mike Hobson
#  Release Jul 2015
#
#  no. of live points =  800
#  dimensionality =    4
#  *****************************************************
#  Starting MultiNest
#  generating live points
#  live points generated, starting sampling
# Acceptance Rate:                        0.998825
# Replacements:                                850
# Total Samples:                               851
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999412
# Acceptance Rate:                        0.991189
# Replacements:                                900
# Total Samples:                               908
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999449
# Acceptance Rate:                        0.982420
# Replacements:                                950
# Total Samples:                               967
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999483
# Acceptance Rate:                        0.959693
# Replacements:                               1000
# Total Samples:                              1042
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999520
# Acceptance Rate:                        0.953678
# Replacements:                               1050
# Total Samples:                              1101
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999546
# Acceptance Rate:                        0.938567
# Replacements:                               1100
# Total Samples:                              1172
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999573
# Acceptance Rate:                        0.920737
# Replacements:                               1150
# Total Samples:                              1249
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999600
# Acceptance Rate:                        0.896861
# Replacements:                               1200
# Total Samples:                              1338
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999626
# Acceptance Rate:                        0.887154
# Replacements:                               1250
# Total Samples:                              1409
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999645
# Acceptance Rate:                        0.877193
# Replacements:                               1300
# Total Samples:                              1482
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999663
# Acceptance Rate:                        0.869285
# Replacements:                               1350
# Total Samples:                              1553
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999678
# Acceptance Rate:                        0.862600
# Replacements:                               1400
# Total Samples:                              1623
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999692
# Acceptance Rate:                        0.854953
# Replacements:                               1450
# Total Samples:                              1696
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999705
# Acceptance Rate:                        0.847937
# Replacements:                               1500
# Total Samples:                              1769
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999717
# Acceptance Rate:                        0.839653
# Replacements:                               1550
# Total Samples:                              1846
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999729
# Acceptance Rate:                        0.832033
# Replacements:                               1600
# Total Samples:                              1923
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999740
# Acceptance Rate:                        0.827482
# Replacements:                               1650
# Total Samples:                              1994
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999749
# Acceptance Rate:                        0.822448
# Replacements:                               1700
# Total Samples:                              2067
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999758
# Acceptance Rate:                        0.813575
# Replacements:                               1750
# Total Samples:                              2151
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999768
# Acceptance Rate:                        0.803930
# Replacements:                               1800
# Total Samples:                              2239
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999777
# Acceptance Rate:                        0.797414
# Replacements:                               1850
# Total Samples:                              2320
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999784
# Acceptance Rate:                        0.791997
# Replacements:                               1900
# Total Samples:                              2399
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999792
# Acceptance Rate:                        0.788197
# Replacements:                               1950
# Total Samples:                              2474
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999798
# Acceptance Rate:                        0.782167
# Replacements:                               2000
# Total Samples:                              2557
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999804
# Acceptance Rate:                        0.777989
# Replacements:                               2050
# Total Samples:                              2635
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999810
# Acceptance Rate:                        0.774622
# Replacements:                               2100
# Total Samples:                              2711
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999816
# Acceptance Rate:                        0.771162
# Replacements:                               2150
# Total Samples:                              2788
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999821
# Acceptance Rate:                        0.765750
# Replacements:                               2200
# Total Samples:                              2873
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999826
# Acceptance Rate:                        0.764526
# Replacements:                               2250
# Total Samples:                              2943
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999830
# Acceptance Rate:                        0.759577
# Replacements:                               2300
# Total Samples:                              3028
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999835
# Acceptance Rate:                        0.755384
# Replacements:                               2350
# Total Samples:                              3111
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999839
# Acceptance Rate:                        0.751409
# Replacements:                               2400
# Total Samples:                              3194
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999843
# Acceptance Rate:                        0.746951
# Replacements:                               2450
# Total Samples:                              3280
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999848
# Acceptance Rate:                        0.744713
# Replacements:                               2500
# Total Samples:                              3357
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999851
# Acceptance Rate:                        0.743874
# Replacements:                               2550
# Total Samples:                              3428
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999854
# Acceptance Rate:                        0.739477
# Replacements:                               2600
# Total Samples:                              3516
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999858
# Acceptance Rate:                        0.735702
# Replacements:                               2650
# Total Samples:                              3602
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999861
# Acceptance Rate:                        0.732501
# Replacements:                               2700
# Total Samples:                              3686
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999864
# Acceptance Rate:                        0.733138
# Replacements:                               2750
# Total Samples:                              3751
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999867
# Acceptance Rate:                        0.732601
# Replacements:                               2800
# Total Samples:                              3822
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999869
# Acceptance Rate:                        0.730208
# Replacements:                               2850
# Total Samples:                              3903
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999872
# Acceptance Rate:                        0.727364
# Replacements:                               2900
# Total Samples:                              3987
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999875
# Acceptance Rate:                        0.722862
# Replacements:                               2950
# Total Samples:                              4081
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999877
# Acceptance Rate:                        0.719424
# Replacements:                               3000
# Total Samples:                              4170
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999880
# Acceptance Rate:                        0.712617
# Replacements:                               3050
# Total Samples:                              4280
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999883
# Acceptance Rate:                        0.711335
# Replacements:                               3100
# Total Samples:                              4358
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999885
# Acceptance Rate:                        0.708024
# Replacements:                               3150
# Total Samples:                              4449
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999888
# Acceptance Rate:                        0.706870
# Replacements:                               3200
# Total Samples:                              4527
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999890
# Acceptance Rate:                        0.706215
# Replacements:                               3250
# Total Samples:                              4602
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999891
# Acceptance Rate:                        0.704225
# Replacements:                               3300
# Total Samples:                              4686
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999893
# Acceptance Rate:                        0.702159
# Replacements:                               3350
# Total Samples:                              4771
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999895
# Acceptance Rate:                        0.701754
# Replacements:                               3400
# Total Samples:                              4845
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999897
# Acceptance Rate:                        0.700792
# Replacements:                               3450
# Total Samples:                              4923
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999898
# Acceptance Rate:                        0.698742
# Replacements:                               3500
# Total Samples:                              5009
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999900
# Acceptance Rate:                        0.697172
# Replacements:                               3550
# Total Samples:                              5092
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999902
# Acceptance Rate:                        0.695921
# Replacements:                               3600
# Total Samples:                              5173
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999903
# Acceptance Rate:                        0.692994
# Replacements:                               3650
# Total Samples:                              5267
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999905
# Acceptance Rate:                        0.690685
# Replacements:                               3700
# Total Samples:                              5357
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999907
# Acceptance Rate:                        0.690481
# Replacements:                               3750
# Total Samples:                              5431
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999908
# Acceptance Rate:                        0.688905
# Replacements:                               3800
# Total Samples:                              5516
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999909
# Acceptance Rate:                        0.683715
# Replacements:                               3850
# Total Samples:                              5631
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999911
# Acceptance Rate:                        0.681223
# Replacements:                               3900
# Total Samples:                              5725
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999913
# Acceptance Rate:                        0.680682
# Replacements:                               3950
# Total Samples:                              5803
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999914
# Acceptance Rate:                        0.679117
# Replacements:                               4000
# Total Samples:                              5890
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999915
# Acceptance Rate:                        0.677824
# Replacements:                               4050
# Total Samples:                              5975
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999916
# Acceptance Rate:                        0.677574
# Replacements:                               4100
# Total Samples:                              6051
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999917
# Acceptance Rate:                        0.675676
# Replacements:                               4150
# Total Samples:                              6142
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999919
# Acceptance Rate:                        0.673293
# Replacements:                               4200
# Total Samples:                              6238
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999920
# Acceptance Rate:                        0.670241
# Replacements:                               4250
# Total Samples:                              6341
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999921
# Acceptance Rate:                        0.670408
# Replacements:                               4300
# Total Samples:                              6414
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999922
# Acceptance Rate:                        0.671296
# Replacements:                               4350
# Total Samples:                              6480
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999923
# Acceptance Rate:                        0.671141
# Replacements:                               4400
# Total Samples:                              6556
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999924
# Acceptance Rate:                        0.670787
# Replacements:                               4450
# Total Samples:                              6634
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999925
# Acceptance Rate:                        0.669842
# Replacements:                               4500
# Total Samples:                              6718
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999926
# Acceptance Rate:                        0.669511
# Replacements:                               4550
# Total Samples:                              6796
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999926
# Acceptance Rate:                        0.668507
# Replacements:                               4600
# Total Samples:                              6881
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999927
# Acceptance Rate:                        0.667912
# Replacements:                               4650
# Total Samples:                              6962
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999928
# Acceptance Rate:                        0.667614
# Replacements:                               4700
# Total Samples:                              7040
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999929
# Acceptance Rate:                        0.667322
# Replacements:                               4750
# Total Samples:                              7118
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999930
# Acceptance Rate:                        0.667408
# Replacements:                               4800
# Total Samples:                              7192
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999930
# Acceptance Rate:                        0.667676
# Replacements:                               4850
# Total Samples:                              7264
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999931
# Acceptance Rate:                        0.666757
# Replacements:                               4900
# Total Samples:                              7349
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999932
# Acceptance Rate:                        0.665680
# Replacements:                               4950
# Total Samples:                              7436
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999933
# Acceptance Rate:                        0.664805
# Replacements:                               5000
# Total Samples:                              7521
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999934
# Acceptance Rate:                        0.663950
# Replacements:                               5050
# Total Samples:                              7606
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999934
# Acceptance Rate:                        0.664062
# Replacements:                               5100
# Total Samples:                              7680
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999935
# Acceptance Rate:                        0.664345
# Replacements:                               5150
# Total Samples:                              7752
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999935
# Acceptance Rate:                        0.664707
# Replacements:                               5200
# Total Samples:                              7823
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999936
# Acceptance Rate:                        0.664557
# Replacements:                               5250
# Total Samples:                              7900
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999937
# Acceptance Rate:                        0.663911
# Replacements:                               5300
# Total Samples:                              7983
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999937
# Acceptance Rate:                        0.664266
# Replacements:                               5350
# Total Samples:                              8054
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999938
# Acceptance Rate:                        0.665107
# Replacements:                               5400
# Total Samples:                              8119
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999938
# Acceptance Rate:                        0.663663
# Replacements:                               5450
# Total Samples:                              8212
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999939
# Acceptance Rate:                        0.663210
# Replacements:                               5500
# Total Samples:                              8293
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999940
# Acceptance Rate:                        0.662528
# Replacements:                               5550
# Total Samples:                              8377
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999940
# Acceptance Rate:                        0.663036
# Replacements:                               5600
# Total Samples:                              8446
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999941
# Acceptance Rate:                        0.663146
# Replacements:                               5650
# Total Samples:                              8520
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999941
# Acceptance Rate:                        0.662560
# Replacements:                               5700
# Total Samples:                              8603
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999942
# Acceptance Rate:                        0.662061
# Replacements:                               5750
# Total Samples:                              8685
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999942
# Acceptance Rate:                        0.661270
# Replacements:                               5800
# Total Samples:                              8771
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999943
# Acceptance Rate:                        0.661465
# Replacements:                               5850
# Total Samples:                              8844
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999943
# Acceptance Rate:                        0.662103
# Replacements:                               5900
# Total Samples:                              8911
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999944
# Acceptance Rate:                        0.661994
# Replacements:                               5950
# Total Samples:                              8988
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999944
# Acceptance Rate:                        0.662617
# Replacements:                               6000
# Total Samples:                              9055
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999945
# Acceptance Rate:                        0.662433
# Replacements:                               6050
# Total Samples:                              9133
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999945
# Acceptance Rate:                        0.661533
# Replacements:                               6100
# Total Samples:                              9221
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999946
# Acceptance Rate:                        0.661148
# Replacements:                               6150
# Total Samples:                              9302
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999946
# Acceptance Rate:                        0.659785
# Replacements:                               6200
# Total Samples:                              9397
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999947
# Acceptance Rate:                        0.659144
# Replacements:                               6250
# Total Samples:                              9482
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999947
# Acceptance Rate:                        0.659134
# Replacements:                               6300
# Total Samples:                              9558
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999948
# Acceptance Rate:                        0.658987
# Replacements:                               6350
# Total Samples:                              9636
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999948
# Acceptance Rate:                        0.658098
# Replacements:                               6400
# Total Samples:                              9725
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999949
# Acceptance Rate:                        0.657761
# Replacements:                               6450
# Total Samples:                              9806
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999949
# Acceptance Rate:                        0.657362
# Replacements:                               6500
# Total Samples:                              9888
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999949
# Acceptance Rate:                        0.657829
# Replacements:                               6550
# Total Samples:                              9957
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999950
# Acceptance Rate:                        0.657109
# Replacements:                               6600
# Total Samples:                             10044
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999950
# Acceptance Rate:                        0.657374
# Replacements:                               6650
# Total Samples:                             10116
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999951
# Acceptance Rate:                        0.658024
# Replacements:                               6700
# Total Samples:                             10182
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999951
# Acceptance Rate:                        0.658151
# Replacements:                               6750
# Total Samples:                             10256
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999951
# Acceptance Rate:                        0.658341
# Replacements:                               6800
# Total Samples:                             10329
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999952
# Acceptance Rate:                        0.658654
# Replacements:                               6850
# Total Samples:                             10400
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999952
# Acceptance Rate:                        0.658271
# Replacements:                               6900
# Total Samples:                             10482
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999952
# Acceptance Rate:                        0.658518
# Replacements:                               6950
# Total Samples:                             10554
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999953
# Acceptance Rate:                        0.658142
# Replacements:                               7000
# Total Samples:                             10636
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999953
# Acceptance Rate:                        0.657711
# Replacements:                               7050
# Total Samples:                             10719
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999953
# Acceptance Rate:                        0.657468
# Replacements:                               7100
# Total Samples:                             10799
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999954
# Acceptance Rate:                        0.657895
# Replacements:                               7150
# Total Samples:                             10868
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999954
# Acceptance Rate:                        0.657114
# Replacements:                               7200
# Total Samples:                             10957
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999954
# Acceptance Rate:                        0.656643
# Replacements:                               7250
# Total Samples:                             11041
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999955
# Acceptance Rate:                        0.656298
# Replacements:                               7300
# Total Samples:                             11123
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999955
# Acceptance Rate:                        0.655665
# Replacements:                               7350
# Total Samples:                             11210
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999955
# Acceptance Rate:                        0.655447
# Replacements:                               7400
# Total Samples:                             11290
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999956
# Acceptance Rate:                        0.654772
# Replacements:                               7450
# Total Samples:                             11378
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999956
# Acceptance Rate:                        0.654793
# Replacements:                               7500
# Total Samples:                             11454
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999956
# Acceptance Rate:                        0.654133
# Replacements:                               7550
# Total Samples:                             11542
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999957
# Acceptance Rate:                        0.653763
# Replacements:                               7600
# Total Samples:                             11625
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999957
# Acceptance Rate:                        0.653344
# Replacements:                               7650
# Total Samples:                             11709
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999957
# Acceptance Rate:                        0.653096
# Replacements:                               7700
# Total Samples:                             11790
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999958
# Acceptance Rate:                        0.652851
# Replacements:                               7750
# Total Samples:                             11871
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999958
# Acceptance Rate:                        0.651248
# Replacements:                               7800
# Total Samples:                             11977
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999658
# Acceptance Rate:                        0.650104
# Replacements:                               7850
# Total Samples:                             12075
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999658
# Acceptance Rate:                        0.649244
# Replacements:                               7900
# Total Samples:                             12168
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999659
# Acceptance Rate:                        0.647763
# Replacements:                               7950
# Total Samples:                             12273
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999659
# Acceptance Rate:                        0.644797
# Replacements:                               8000
# Total Samples:                             12407
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999659
# Acceptance Rate:                        0.641946
# Replacements:                               8050
# Total Samples:                             12540
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999660
# Acceptance Rate:                        0.639912
# Replacements:                               8100
# Total Samples:                             12658
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999660
# Acceptance Rate:                        0.638415
# Replacements:                               8150
# Total Samples:                             12766
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999661
# Acceptance Rate:                        0.636498
# Replacements:                               8200
# Total Samples:                             12883
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999661
# Acceptance Rate:                        0.635740
# Replacements:                               8250
# Total Samples:                             12977
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999661
# Acceptance Rate:                        0.635528
# Replacements:                               8300
# Total Samples:                             13060
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999662
# Acceptance Rate:                        0.635223
# Replacements:                               8350
# Total Samples:                             13145
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999662
# Acceptance Rate:                        0.634825
# Replacements:                               8400
# Total Samples:                             13232
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999662
# Acceptance Rate:                        0.634480
# Replacements:                               8450
# Total Samples:                             13318
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.819496
# Acceptance Rate:                        0.634470
# Replacements:                               8500
# Total Samples:                             13397
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.812664
# Acceptance Rate:                        0.634367
# Replacements:                               8550
# Total Samples:                             13478
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.812668
# Acceptance Rate:                        0.634499
# Replacements:                               8600
# Total Samples:                             13554
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999961
# Acceptance Rate:                        0.634211
# Replacements:                               8650
# Total Samples:                             13639
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999961
# Acceptance Rate:                        0.634434
# Replacements:                               8700
# Total Samples:                             13713
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999961
# Acceptance Rate:                        0.633737
# Replacements:                               8750
# Total Samples:                             13807
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999961
# Acceptance Rate:                        0.634143
# Replacements:                               8800
# Total Samples:                             13877
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999961
# Acceptance Rate:                        0.633818
# Replacements:                               8850
# Total Samples:                             13963
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999253
# Acceptance Rate:                        0.633813
# Replacements:                               8900
# Total Samples:                             14042
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999964
# Acceptance Rate:                        0.633583
# Replacements:                               8950
# Total Samples:                             14126
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.765615
# Acceptance Rate:                        0.633401
# Replacements:                               9000
# Total Samples:                             14209
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.765611
# Acceptance Rate:                        0.632557
# Replacements:                               9050
# Total Samples:                             14307
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.765606
# Acceptance Rate:                        0.631506
# Replacements:                               9100
# Total Samples:                             14410
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.765601
# Acceptance Rate:                        0.630296
# Replacements:                               9150
# Total Samples:                             14517
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.765597
# Acceptance Rate:                        0.628544
# Replacements:                               9200
# Total Samples:                             14637
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.765593
# Acceptance Rate:                        0.627629
# Replacements:                               9250
# Total Samples:                             14738
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999966
# Acceptance Rate:                        0.627573
# Replacements:                               9300
# Total Samples:                             14819
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999965
# Acceptance Rate:                        0.627770
# Replacements:                               9350
# Total Samples:                             14894
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999966
# Acceptance Rate:                        0.627629
# Replacements:                               9400
# Total Samples:                             14977
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999966
# Acceptance Rate:                        0.627698
# Replacements:                               9450
# Total Samples:                             15055
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999964
# Acceptance Rate:                        0.627892
# Replacements:                               9500
# Total Samples:                             15130
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999964
# Acceptance Rate:                        0.627918
# Replacements:                               9550
# Total Samples:                             15209
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999964
# Acceptance Rate:                        0.627779
# Replacements:                               9600
# Total Samples:                             15292
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999964
# Acceptance Rate:                        0.627724
# Replacements:                               9650
# Total Samples:                             15373
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999964
# Acceptance Rate:                        0.628198
# Replacements:                               9700
# Total Samples:                             15441
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999965
# Acceptance Rate:                        0.628384
# Replacements:                               9750
# Total Samples:                             15516
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999965
# Acceptance Rate:                        0.628366
# Replacements:                               9800
# Total Samples:                             15596
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999965
# Acceptance Rate:                        0.628991
# Replacements:                               9850
# Total Samples:                             15660
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999965
# Acceptance Rate:                        0.629371
# Replacements:                               9900
# Total Samples:                             15730
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999965
# Acceptance Rate:                        0.629349
# Replacements:                               9950
# Total Samples:                             15810
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999965
# Acceptance Rate:                        0.628852
# Replacements:                              10000
# Total Samples:                             15902
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999965
# ...
# Acceptance Rate:                        0.696976
# Replacements:                              17400
# Total Samples:                             24965
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.072185
# Acceptance Rate:                        0.697414
# Replacements:                              17450
# Total Samples:                             25021
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.069808
# Acceptance Rate:                        0.697823
# Replacements:                              17500
# Total Samples:                             25078
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.067603
# Acceptance Rate:                        0.698146
# Replacements:                              17550
# Total Samples:                             25138
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.065387
# Acceptance Rate:                        0.698634
# Replacements:                              17600
# Total Samples:                             25192
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.062975
# Acceptance Rate:                        0.699010
# Replacements:                              17650
# Total Samples:                             25250
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.061862
# Acceptance Rate:                        0.699494
# Replacements:                              17700
# Total Samples:                             25304
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.059668
# Acceptance Rate:                        0.699866
# Replacements:                              17750
# Total Samples:                             25362
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.057945
# Acceptance Rate:                        0.700181
# Replacements:                              17800
# Total Samples:                             25422
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.055760
# Acceptance Rate:                        0.700494
# Replacements:                              17850
# Total Samples:                             25482
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.054153
# Acceptance Rate:                        0.700779
# Replacements:                              17900
# Total Samples:                             25543
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.052476
# Acceptance Rate:                        0.701227
# Replacements:                              17950
# Total Samples:                             25598
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.050981
# Acceptance Rate:                        0.701590
# Replacements:                              18000
# Total Samples:                             25656
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.049628
# Acceptance Rate:                        0.701788
# Replacements:                              18050
# Total Samples:                             25720
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.047943
# Acceptance Rate:                        0.702013
# Replacements:                              18100
# Total Samples:                             25783
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.046437
# Acceptance Rate:                        0.702318
# Replacements:                              18150
# Total Samples:                             25843
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.044885
# Acceptance Rate:                        0.702567
# Replacements:                              18200
# Total Samples:                             25905
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.043488
# Acceptance Rate:                        0.702896
# Replacements:                              18250
# Total Samples:                             25964
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.042310
# Acceptance Rate:                        0.703278
# Replacements:                              18300
# Total Samples:                             26021
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.041048
# Acceptance Rate:                        0.703523
# Replacements:                              18350
# Total Samples:                             26083
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.039540
# Acceptance Rate:                        0.703956
# Replacements:                              18400
# Total Samples:                             26138
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.038305
# Acceptance Rate:                        0.704225
# Replacements:                              18450
# Total Samples:                             26199
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.036998
# Acceptance Rate:                        0.704467
# Replacements:                              18500
# Total Samples:                             26261
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.035650
# Acceptance Rate:                        0.704760
# Replacements:                              18550
# Total Samples:                             26321
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.034699
# Acceptance Rate:                        0.704946
# Replacements:                              18600
# Total Samples:                             26385
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.033587
# Acceptance Rate:                        0.705211
# Replacements:                              18650
# Total Samples:                             26446
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.032585
# Acceptance Rate:                        0.705368
# Replacements:                              18700
# Total Samples:                             26511
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.031429
# Acceptance Rate:                        0.705550
# Replacements:                              18750
# Total Samples:                             26575
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.030361
# Acceptance Rate:                        0.705547
# Replacements:                              18800
# Total Samples:                             26646
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.029345
# Acceptance Rate:                        0.705675
# Replacements:                              18850
# Total Samples:                             26712
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.028325
# Acceptance Rate:                        0.705724
# Replacements:                              18900
# Total Samples:                             26781
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.027399
# Acceptance Rate:                        0.705852
# Replacements:                              18950
# Total Samples:                             26847
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.026548
# Acceptance Rate:                        0.706057
# Replacements:                              19000
# Total Samples:                             26910
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.025699
# Acceptance Rate:                        0.706052
# Replacements:                              19050
# Total Samples:                             26981
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.024787
# Acceptance Rate:                        0.706204
# Replacements:                              19100
# Total Samples:                             27046
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.024072
# Acceptance Rate:                        0.706355
# Replacements:                              19150
# Total Samples:                             27111
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.023342
# Acceptance Rate:                        0.706376
# Replacements:                              19200
# Total Samples:                             27181
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.022585
# Acceptance Rate:                        0.706267
# Replacements:                              19250
# Total Samples:                             27256
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.021913
# Acceptance Rate:                        0.706416
# Replacements:                              19300
# Total Samples:                             27321
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.021375
# Acceptance Rate:                        0.706669
# Replacements:                              19350
# Total Samples:                             27382
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.020827
# Acceptance Rate:                        0.706817
# Replacements:                              19400
# Total Samples:                             27447
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.020282
# Acceptance Rate:                        0.706990
# Replacements:                              19450
# Total Samples:                             27511
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.019794
# Acceptance Rate:                        0.707085
# Replacements:                              19500
# Total Samples:                             27578
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.019293
# Acceptance Rate:                        0.707308
# Replacements:                              19550
# Total Samples:                             27640
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.018838
# Acceptance Rate:                        0.707607
# Replacements:                              19600
# Total Samples:                             27699
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.018422
# Acceptance Rate:                        0.707879
# Replacements:                              19650
# Total Samples:                             27759
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.018031
# Acceptance Rate:                        0.708175
# Replacements:                              19700
# Total Samples:                             27818
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.017649
# Acceptance Rate:                        0.708546
# Replacements:                              19750
# Total Samples:                             27874
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.017291
# Acceptance Rate:                        0.708890
# Replacements:                              19800
# Total Samples:                             27931
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.016954
# Acceptance Rate:                        0.709131
# Replacements:                              19850
# Total Samples:                             27992
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.016619
# Acceptance Rate:                        0.709346
# Replacements:                              19900
# Total Samples:                             28054
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.016312
# Acceptance Rate:                        0.709636
# Replacements:                              19950
# Total Samples:                             28113
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.016024
# Acceptance Rate:                        0.709950
# Replacements:                              20000
# Total Samples:                             28171
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.015772
# Acceptance Rate:                        0.710288
# Replacements:                              20050
# Total Samples:                             28228
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.015551
# Acceptance Rate:                        0.710423
# Replacements:                              20100
# Total Samples:                             28293
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.015300
# Acceptance Rate:                        0.710633
# Replacements:                              20150
# Total Samples:                             28355
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.015065
# Acceptance Rate:                        0.710892
# Replacements:                              20200
# Total Samples:                             28415
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.014866
# Acceptance Rate:                        0.711000
# Replacements:                              20250
# Total Samples:                             28481
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.014667
# Acceptance Rate:                        0.711282
# Replacements:                              20300
# Total Samples:                             28540
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.014501
# Acceptance Rate:                        0.711489
# Replacements:                              20350
# Total Samples:                             28602
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.014336
# Acceptance Rate:                        0.711657
# Replacements:                              20384
# Total Samples:                             28643
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.014233
#  ln(ev)=   50323307.425478876      +/-  0.16206427903459483
#  Total Likelihood Evaluations:        28643
#  Sampling finished. Exiting MultiNest
