# %%
from pyspi.utils.data_builder.time_series_builder import TimeSeriesBuilderSPI
import numpy as np
from pyspi.utils.function_utils import find_response_version
from pyspi.utils.response.spi_response_data import ResponseDataRMF
from pyspi.utils.response.spi_response import ResponseRMFGenerator
from pyspi.utils.response.spi_drm import SPIDRM
from pyspi.utils.livedets import get_live_dets

grb_time = "120711 024453"
ebounds = np.geomspace(20,520,40)
ein = np.geomspace(20,800,150)
t1 = 3500
t2 = 3800
version = find_response_version(grb_time)
rsp_base = ResponseDataRMF.from_version(version)
dets = get_live_dets(time=grb_time, event_types=["single"])
# Out:
# [WARNING ] The naima package is not available. Models that depend on it will not be available
# [WARNING ] The GSL library or the pygsl wrapper cannot be loaded. Models that depend on it will not be available.
# [WARNING ] The ebltable package is not available. Models that depend on it will not be available
# [INFO    ] Starting 3ML!
# [WARNING ] no display variable set. using backend for graphics without display (agg)
# [WARNING ] ROOT minimizer not available
# [WARNING ] PyGMO is not available
# [WARNING ] The cthreeML package is not installed. You will not be able to use plugins which require the C/C++ interface (currently HAWC)
# [WARNING ] Could not import plugin HAWCLike.py. Do you have the relative instrument software installed and configured?
# [WARNING ] Could not import plugin FermiLATLike.py. Do you have the relative instrument software installed and configured?
# [WARNING ] No fermitools installed
# [WARNING ] Env. variable OMP_NUM_THREADS is not set. Please set it to 1 for optimal performances in 3ML
# [WARNING ] Env. variable MKL_NUM_THREADS is not set. Please set it to 1 for optimal performances in 3ML
# [WARNING ] Env. variable NUMEXPR_NUM_THREADS is not set. Please set it to 1 for optimal performances in 3ML
# Using the irfs that are valid between 10/05/27 12:45:00 and present (YY/MM/DD HH:MM:SS)

# %%
tsbs = []
sds1 = []
sds2 = []
ra1, dec1 = 94.67830, -70.99905
ra2, dec2 = 92.67830, -70.99905
for d in dets:
    tsb = TimeSeriesBuilderSPI.from_spi_grb(f"SPIDet{d}", 
                                        d, 
                                        #ebounds_sgl, 
                                        grb_time, 
                                        ebounds=ebounds,
                                        sgl_type="both",
                                        poly_order=-1,
                                        )
    rsp = ResponseRMFGenerator.from_time(grb_time,  d,
                                            ebounds, ein,
                                            rsp_base)
    sd1 = SPIDRM(rsp, ra1, dec1)
    sd2 = SPIDRM(rsp.clone(), ra2, dec2)
    tsbs.append(tsb)
    sds1.append(sd1)
    sds2.append(sd2)
# Out:
# AFS data access did not work. I will try the ISDC data archive.

# %%
bkgs=np.array([])
for tsb in tsbs:
    bkgs = np.append(bkgs, tsb.time_series.count_per_channel_over_interval(-1000,0)/tsb.time_series.exposure_over_interval(-1000,0))
bkgs=bkgs.reshape((len(dets), -1));

# %%
# source model
from astromodels import Powerlaw, Log_uniform_prior, Uniform_prior, PointSource, SpectralComponent
import numpy as np
pl = Powerlaw()
pl.index = -2.08
pl.K = 9.3#6.44*10**-4
pl.xiv = 1

pl.K.prior = Log_uniform_prior(lower_bound=0.001, upper_bound=1000)
pl.index.prior = Uniform_prior(lower_bound=-4, upper_bound=0)

component1 = SpectralComponent('pl',shape=pl)
ps = PointSource('plline',ra=94.67830, dec=-70.99905, components=[component1])

spec = ps(ein)

spec_binned = (ein[1:]-ein[:-1])*(spec[:-1]+spec[1:])/2

# %%
# model counts
model_count_rates1 = np.array([])#np.dot(spec_binned, sd_sgl1.matrix.T)
model_count_rates2 = np.array([])#np.dot(spec_binned, sd_sgl2.matrix.T)
for sd1, sd2 in zip(sds1, sds2):
    model_count_rates1 = np.append(model_count_rates1, np.dot(spec_binned, sd1.matrix.T))
    model_count_rates2 = np.append(model_count_rates2, np.dot(spec_binned, sd2.matrix.T))
model_count_rates1 = model_count_rates1.reshape((len(dets), -1));
model_count_rates2 = model_count_rates2.reshape((len(dets), -1));

# %%
import matplotlib.pyplot as plt
fig, axes = plt.subplots(5,4, sharex=True, sharey=True, figsize=(10,10))
axes = axes.flatten()
i=0
for d in range(19):
    axes[d].text(.5,.9,f"Det {d}",horizontalalignment='center',transform=axes[d].transAxes)
    if d in dets:
        if i==0:
            axes[d].step(ebounds[:-1], bkgs[i], label="background")
            axes[d].step(ebounds[:-1], model_count_rates1[i], label="model1")
            axes[d].step(ebounds[:-1], model_count_rates2[i], label="model2")
        else:
            axes[d].step(ebounds[:-1], bkgs[i])
            axes[d].step(ebounds[:-1], model_count_rates1[i])
            axes[d].step(ebounds[:-1], model_count_rates2[i])
        i+=1
    axes[d].set_yscale("log")
    axes[d].set_ylim(10**-3, 20)
for i in range(16,20):
    axes[i].set_xlabel("Detected Energy [keV]")
for i in range(0,20,4):
    axes[i].set_ylabel("Count Rates [1/s]")
plt.subplots_adjust(hspace=0, wspace=0)
plt.subplots_adjust(hspace=0, top=0.96, bottom=0.1)
lgd = fig.legend(loc='center left', bbox_to_anchor=(0.9, 0.5), fontsize='x-large')
fig.savefig("bkg_models.pdf")

# %%
data1 = np.array([])
data2 = np.array([])
for bkg, m1, m2 in zip(bkgs, model_count_rates1, model_count_rates2):
    data1 = np.append(data1, np.random.poisson(t1*(bkg+m1)))
    data2 = np.append(data2, np.random.poisson(t2*(bkg+m2)))
    
data1 = data1.reshape((len(dets), -1));
data2 = data2.reshape((len(dets), -1));

# %%
import math
from numba import njit

@njit
def bmaxba(m1, m2, t1, t2, C1, C2):
    first = C1+C2-(m1+m2)*(t1+t2)
    root = (C1+C2+(m1-m2)*(t1+t2))**2-4*C1*(m1-m2)*(t1+t2)
    res = (first+np.sqrt(root))/(2*(t1+t2))
    return res
matrices1 = np.array([])
sd_x, sd_y = sds1[0].matrix.T.shape
for sd in sds1:
    matrices1=np.append(matrices1,sd.matrix.T)
matrices1=matrices1.reshape((len(dets), sd_x, sd_y))

matrices2 = np.array([])
for sd in sds2:
    matrices2=np.append(matrices2,sd.matrix.T)
matrices2=matrices2.reshape((len(dets), sd_x, sd_y))

@njit
def logLcore(spec_binned):
    logL=0
    for j in range(len(dets)):
        m1 = np.dot(spec_binned, matrices1[j])
        m2 = np.dot(spec_binned, matrices2[j])
        for i in range(len(m1)):
            bm = bmaxba(m1[i], m2[i], t1, t2, data1[j, i], data2[j, i])
            logL += (data1[j,i]*math.log(t1*(m1[i]+bm))+
                    data2[j,i]*math.log(t2*(m2[i]+bm))-
                    t1*(m1[i]+bm)-
                    t2*(m2[i]+bm))
    return logL

def logLba_mult(trial_values, ndim=None, params=None):
    pl.index = trial_values[1]
    pl.K = trial_values[0]
    spec = pl(ein)
    spec_binned = (ein[1:]-ein[:-1])*(spec[:-1]+spec[1:])/2
    return logLcore(spec_binned)

# %%
def prior(params, ndim=None, nparams=None):
    for i, (parameter_name, parameter) in enumerate(
        ps.free_parameters.items()
    ):

        try:

            params[i] = parameter.prior.from_unit_cube(params[i])

        except AttributeError:

            raise RuntimeError(
                "The prior you are trying to use for parameter %s is "
                "not compatible with sampling from a unitcube"
                % parameter_name
            )

# %%
import pymultinest
import os
if not os.path.exists("./chains"):
    os.mkdir("chains")
sampler = pymultinest.run(
                    logLba_mult, prior, 2, 2, n_live_points=800, resume=False, verbose=True
                )
# Out:
#  *****************************************************
#  MultiNest v3.10
#  Copyright Farhan Feroz & Mike Hobson
#  Release Jul 2015
#
#  no. of live points =  800
#  dimensionality =    2
#  *****************************************************
#  Starting MultiNest
#  generating live points
#  live points generated, starting sampling
# Acceptance Rate:                        1.000000
# Replacements:                                850
# Total Samples:                               850
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999173
# Acceptance Rate:                        0.993377
# Replacements:                                900
# Total Samples:                               906
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999209
# Acceptance Rate:                        0.983437
# Replacements:                                950
# Total Samples:                               966
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999243
# Acceptance Rate:                        0.975610
# Replacements:                               1000
# Total Samples:                              1025
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999112
# Acceptance Rate:                        0.959781
# Replacements:                               1050
# Total Samples:                              1094
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.952384
# Acceptance Rate:                        0.940975
# Replacements:                               1100
# Total Samples:                              1169
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.806725
# Acceptance Rate:                        0.923695
# Replacements:                               1150
# Total Samples:                              1245
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.806757
# Acceptance Rate:                        0.914634
# Replacements:                               1200
# Total Samples:                              1312
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.806782
# Acceptance Rate:                        0.894775
# Replacements:                               1250
# Total Samples:                              1397
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.806811
# Acceptance Rate:                        0.880759
# Replacements:                               1300
# Total Samples:                              1476
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.806835
# Acceptance Rate:                        0.877193
# Replacements:                               1350
# Total Samples:                              1539
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.806840
# Acceptance Rate:                        0.875547
# Replacements:                               1400
# Total Samples:                              1599
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.761163
# Acceptance Rate:                        0.872968
# Replacements:                               1450
# Total Samples:                              1661
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.692316
# Acceptance Rate:                        0.872093
# Replacements:                               1500
# Total Samples:                              1720
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.691582
# Acceptance Rate:                        0.867375
# Replacements:                               1550
# Total Samples:                              1787
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.691599
# Acceptance Rate:                        0.864865
# Replacements:                               1600
# Total Samples:                              1850
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.594459
# Acceptance Rate:                        0.859823
# Replacements:                               1650
# Total Samples:                              1919
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.581431
# Acceptance Rate:                        0.858586
# Replacements:                               1700
# Total Samples:                              1980
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.546962
# Acceptance Rate:                        0.854492
# Replacements:                               1750
# Total Samples:                              2048
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.481268
# Acceptance Rate:                        0.851869
# Replacements:                               1800
# Total Samples:                              2113
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.481284
# Acceptance Rate:                        0.850966
# Replacements:                               1850
# Total Samples:                              2174
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.478713
# Acceptance Rate:                        0.848214
# Replacements:                               1900
# Total Samples:                              2240
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.469404
# Acceptance Rate:                        0.841606
# Replacements:                               1950
# Total Samples:                              2317
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.430538
# Acceptance Rate:                        0.836470
# Replacements:                               2000
# Total Samples:                              2391
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.430212
# Acceptance Rate:                        0.837076
# Replacements:                               2050
# Total Samples:                              2449
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.401193
# Acceptance Rate:                        0.833003
# Replacements:                               2100
# Total Samples:                              2521
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.401177
# Acceptance Rate:                        0.825970
# Replacements:                               2150
# Total Samples:                              2603
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.381139
# Acceptance Rate:                        0.822123
# Replacements:                               2200
# Total Samples:                              2676
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.378426
# Acceptance Rate:                        0.816104
# Replacements:                               2250
# Total Samples:                              2757
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.378434
# Acceptance Rate:                        0.811001
# Replacements:                               2300
# Total Samples:                              2836
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.378450
# Acceptance Rate:                        0.805346
# Replacements:                               2350
# Total Samples:                              2918
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.356430
# Acceptance Rate:                        0.801871
# Replacements:                               2400
# Total Samples:                              2993
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.333347
# Acceptance Rate:                        0.801177
# Replacements:                               2450
# Total Samples:                              3058
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.333081
# Acceptance Rate:                        0.796432
# Replacements:                               2500
# Total Samples:                              3139
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.331347
# Acceptance Rate:                        0.793157
# Replacements:                               2550
# Total Samples:                              3215
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.319800
# Acceptance Rate:                        0.789074
# Replacements:                               2600
# Total Samples:                              3295
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.297487
# Acceptance Rate:                        0.788221
# Replacements:                               2650
# Total Samples:                              3362
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.295533
# Acceptance Rate:                        0.782382
# Replacements:                               2700
# Total Samples:                              3451
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.284116
# Acceptance Rate:                        0.780585
# Replacements:                               2750
# Total Samples:                              3523
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.283892
# Acceptance Rate:                        0.777994
# Replacements:                               2800
# Total Samples:                              3599
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.263844
# Acceptance Rate:                        0.773616
# Replacements:                               2850
# Total Samples:                              3684
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.262632
# Acceptance Rate:                        0.771892
# Replacements:                               2900
# Total Samples:                              3757
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.239302
# Acceptance Rate:                        0.770436
# Replacements:                               2950
# Total Samples:                              3829
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.225111
# Acceptance Rate:                        0.769823
# Replacements:                               3000
# Total Samples:                              3897
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.219941
# Acceptance Rate:                        0.769619
# Replacements:                               3050
# Total Samples:                              3963
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.216928
# Acceptance Rate:                        0.770186
# Replacements:                               3100
# Total Samples:                              4025
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.212982
# Acceptance Rate:                        0.768293
# Replacements:                               3150
# Total Samples:                              4100
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.209146
# Acceptance Rate:                        0.765917
# Replacements:                               3200
# Total Samples:                              4178
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.202793
# Acceptance Rate:                        0.764346
# Replacements:                               3250
# Total Samples:                              4252
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.195706
# Acceptance Rate:                        0.763535
# Replacements:                               3300
# Total Samples:                              4322
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.195367
# Acceptance Rate:                        0.762056
# Replacements:                               3350
# Total Samples:                              4396
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.190058
# Acceptance Rate:                        0.758929
# Replacements:                               3400
# Total Samples:                              4480
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.180437
# Acceptance Rate:                        0.759076
# Replacements:                               3450
# Total Samples:                              4545
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.173891
# Acceptance Rate:                        0.758725
# Replacements:                               3500
# Total Samples:                              4613
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.171674
# Acceptance Rate:                        0.758547
# Replacements:                               3550
# Total Samples:                              4680
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.168405
# Acceptance Rate:                        0.757895
# Replacements:                               3600
# Total Samples:                              4750
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.161915
# Acceptance Rate:                        0.756477
# Replacements:                               3650
# Total Samples:                              4825
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.157381
# Acceptance Rate:                        0.755565
# Replacements:                               3700
# Total Samples:                              4897
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.152084
# Acceptance Rate:                        0.755591
# Replacements:                               3750
# Total Samples:                              4963
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.150607
# Acceptance Rate:                        0.755617
# Replacements:                               3800
# Total Samples:                              5029
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.145598
# Acceptance Rate:                        0.754902
# Replacements:                               3850
# Total Samples:                              5100
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.142640
# Acceptance Rate:                        0.754644
# Replacements:                               3900
# Total Samples:                              5168
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.136511
# Acceptance Rate:                        0.754105
# Replacements:                               3950
# Total Samples:                              5238
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.131155
# Acceptance Rate:                        0.755002
# Replacements:                               4000
# Total Samples:                              5298
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.130535
# Acceptance Rate:                        0.753488
# Replacements:                               4050
# Total Samples:                              5375
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.127992
# Acceptance Rate:                        0.752432
# Replacements:                               4100
# Total Samples:                              5449
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.121669
# Acceptance Rate:                        0.752766
# Replacements:                               4150
# Total Samples:                              5513
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.117562
# Acceptance Rate:                        0.751207
# Replacements:                               4200
# Total Samples:                              5591
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.113105
# Acceptance Rate:                        0.751813
# Replacements:                               4250
# Total Samples:                              5653
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.110072
# Acceptance Rate:                        0.750829
# Replacements:                               4300
# Total Samples:                              5727
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.107898
# Acceptance Rate:                        0.750000
# Replacements:                               4350
# Total Samples:                              5800
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.106177
# Acceptance Rate:                        0.749064
# Replacements:                               4400
# Total Samples:                              5874
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.103014
# Acceptance Rate:                        0.748025
# Replacements:                               4450
# Total Samples:                              5949
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.099932
# Acceptance Rate:                        0.747012
# Replacements:                               4500
# Total Samples:                              6024
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.097422
# Acceptance Rate:                        0.747617
# Replacements:                               4550
# Total Samples:                              6086
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.094878
# Acceptance Rate:                        0.747360
# Replacements:                               4600
# Total Samples:                              6155
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.092487
# Acceptance Rate:                        0.747588
# Replacements:                               4650
# Total Samples:                              6220
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.090355
# Acceptance Rate:                        0.747693
# Replacements:                               4700
# Total Samples:                              6286
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.087104
# Acceptance Rate:                        0.748031
# Replacements:                               4750
# Total Samples:                              6350
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.084600
# Acceptance Rate:                        0.748480
# Replacements:                               4800
# Total Samples:                              6413
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.082316
# Acceptance Rate:                        0.748341
# Replacements:                               4850
# Total Samples:                              6481
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.080342
# Acceptance Rate:                        0.748206
# Replacements:                               4900
# Total Samples:                              6549
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.078825
# Acceptance Rate:                        0.748073
# Replacements:                               4950
# Total Samples:                              6617
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.076373
# Acceptance Rate:                        0.747496
# Replacements:                               5000
# Total Samples:                              6689
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.074442
# Acceptance Rate:                        0.747373
# Replacements:                               5050
# Total Samples:                              6757
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.071808
# Acceptance Rate:                        0.747581
# Replacements:                               5100
# Total Samples:                              6822
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.069875
# Acceptance Rate:                        0.747243
# Replacements:                               5150
# Total Samples:                              6892
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.068191
# Acceptance Rate:                        0.747664
# Replacements:                               5200
# Total Samples:                              6955
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.065813
# Acceptance Rate:                        0.747863
# Replacements:                               5250
# Total Samples:                              7020
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.063815
# Acceptance Rate:                        0.748376
# Replacements:                               5300
# Total Samples:                              7082
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.061919
# Acceptance Rate:                        0.747415
# Replacements:                               5350
# Total Samples:                              7158
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.059864
# Acceptance Rate:                        0.747301
# Replacements:                               5400
# Total Samples:                              7226
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.057713
# Acceptance Rate:                        0.748010
# Replacements:                               5450
# Total Samples:                              7286
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.056357
# Acceptance Rate:                        0.748503
# Replacements:                               5500
# Total Samples:                              7348
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.054564
# Acceptance Rate:                        0.748988
# Replacements:                               5550
# Total Samples:                              7410
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.052864
# Acceptance Rate:                        0.749565
# Replacements:                               5600
# Total Samples:                              7471
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.051295
# Acceptance Rate:                        0.748741
# Replacements:                               5650
# Total Samples:                              7546
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.049653
# Acceptance Rate:                        0.749014
# Replacements:                               5700
# Total Samples:                              7610
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.048038
# Acceptance Rate:                        0.749674
# Replacements:                               5750
# Total Samples:                              7670
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.046366
# Acceptance Rate:                        0.749064
# Replacements:                               5800
# Total Samples:                              7743
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.044759
# Acceptance Rate:                        0.749616
# Replacements:                               5850
# Total Samples:                              7804
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.043384
# Acceptance Rate:                        0.749682
# Replacements:                               5900
# Total Samples:                              7870
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.041887
# Acceptance Rate:                        0.750032
# Replacements:                               5950
# Total Samples:                              7933
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.040527
# Acceptance Rate:                        0.750469
# Replacements:                               6000
# Total Samples:                              7995
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.039211
# Acceptance Rate:                        0.750434
# Replacements:                               6050
# Total Samples:                              8062
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.037837
# Acceptance Rate:                        0.750862
# Replacements:                               6100
# Total Samples:                              8124
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.036666
# Acceptance Rate:                        0.751099
# Replacements:                               6150
# Total Samples:                              8188
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.035459
# Acceptance Rate:                        0.751424
# Replacements:                               6200
# Total Samples:                              8251
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.034242
# Acceptance Rate:                        0.751834
# Replacements:                               6250
# Total Samples:                              8313
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.033121
# Acceptance Rate:                        0.751431
# Replacements:                               6300
# Total Samples:                              8384
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.031879
# Acceptance Rate:                        0.752013
# Replacements:                               6350
# Total Samples:                              8444
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.030839
# Acceptance Rate:                        0.752145
# Replacements:                               6400
# Total Samples:                              8509
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.029774
# Acceptance Rate:                        0.752889
# Replacements:                               6450
# Total Samples:                              8567
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.028856
# Acceptance Rate:                        0.752838
# Replacements:                               6500
# Total Samples:                              8634
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.027859
# Acceptance Rate:                        0.752874
# Replacements:                               6550
# Total Samples:                              8700
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.026942
# Acceptance Rate:                        0.752995
# Replacements:                               6600
# Total Samples:                              8765
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.026084
# Acceptance Rate:                        0.753200
# Replacements:                               6650
# Total Samples:                              8829
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.025256
# Acceptance Rate:                        0.752555
# Replacements:                               6700
# Total Samples:                              8903
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.024339
# Acceptance Rate:                        0.753012
# Replacements:                               6750
# Total Samples:                              8964
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.023592
# Acceptance Rate:                        0.752879
# Replacements:                               6800
# Total Samples:                              9032
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.022751
# Acceptance Rate:                        0.753161
# Replacements:                               6850
# Total Samples:                              9095
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.022034
# Acceptance Rate:                        0.753769
# Replacements:                               6900
# Total Samples:                              9154
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.021403
# Acceptance Rate:                        0.754533
# Replacements:                               6950
# Total Samples:                              9211
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.020800
# Acceptance Rate:                        0.755369
# Replacements:                               7000
# Total Samples:                              9267
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.020243
# Acceptance Rate:                        0.756113
# Replacements:                               7050
# Total Samples:                              9324
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.019688
# Acceptance Rate:                        0.756446
# Replacements:                               7100
# Total Samples:                              9386
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.019118
# Acceptance Rate:                        0.756934
# Replacements:                               7150
# Total Samples:                              9446
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.018600
# Acceptance Rate:                        0.756382
# Replacements:                               7200
# Total Samples:                              9519
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.018000
# Acceptance Rate:                        0.757101
# Replacements:                               7250
# Total Samples:                              9576
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.017562
# Acceptance Rate:                        0.757104
# Replacements:                               7300
# Total Samples:                              9642
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.017101
# Acceptance Rate:                        0.757498
# Replacements:                               7350
# Total Samples:                              9703
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.016701
# Acceptance Rate:                        0.757808
# Replacements:                               7400
# Total Samples:                              9765
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.016325
# Acceptance Rate:                        0.757884
# Replacements:                               7450
# Total Samples:                              9830
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.015951
# Acceptance Rate:                        0.757959
# Replacements:                               7500
# Total Samples:                              9895
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.015616
# Acceptance Rate:                        0.758184
# Replacements:                               7550
# Total Samples:                              9958
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.015312
# Acceptance Rate:                        0.757576
# Replacements:                               7600
# Total Samples:                             10032
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.014983
# Acceptance Rate:                        0.757585
# Replacements:                               7616
# Total Samples:                             10053
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.014897
#  ln(ev)=   32901099.055481162      +/-  0.10010794016880945
#  Total Likelihood Evaluations:        10053
#  Sampling finished. Exiting MultiNest

# %%
# %matplotlib inline
from chainconsumer import ChainConsumer
import numpy as np


def loadtxt2d(intext):
        try:
            return np.loadtxt(intext, ndmin=2)
        except:
            return np.loadtxt(intext)

c = ChainConsumer()

chain = loadtxt2d('./chains/1-post_equal_weights.dat')

#c.add_chain(chain, parameters=['K', 'index', 'F', 'mu','sigma', '$z$'], name='yeah')
c.add_chain(chain, parameters=['K', 'index', '$z$'], name='fit')

# %%
c.plotter.plot(filename="fit_corner.pdf", 
                parameters=['K', 'index'],
                truth=[9.3, -2.08],
                log_scales=[]);
