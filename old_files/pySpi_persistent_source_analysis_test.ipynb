# %%
from pyspi.utils.data_builder.time_series_builder import TimeSeriesBuilderSPI
import numpy as np
from pyspi.utils.function_utils import find_response_version
from pyspi.utils.response.spi_response_data import ResponseDataRMF
from pyspi.utils.response.spi_response import ResponseRMFGenerator
from pyspi.utils.response.spi_drm import SPIDRM
from pyspi.utils.livedets import get_live_dets

grb_time = "120711 024453"
ebounds = np.geomspace(20,520,40)
ein = np.geomspace(20,800,150)
t1 = 3500
t2 = 3800
version = find_response_version(grb_time)
rsp_base = ResponseDataRMF.from_version(version)
dets = get_live_dets(time=grb_time, event_types=["single"])
# Out:
# [WARNING ] The naima package is not available. Models that depend on it will not be available
# [WARNING ] The GSL library or the pygsl wrapper cannot be loaded. Models that depend on it will not be available.
# [WARNING ] The ebltable package is not available. Models that depend on it will not be available
# [INFO    ] Starting 3ML!
# [WARNING ] no display variable set. using backend for graphics without display (agg)
# [WARNING ] ROOT minimizer not available
# [WARNING ] PyGMO is not available
# [WARNING ] The cthreeML package is not installed. You will not be able to use plugins which require the C/C++ interface (currently HAWC)
# [WARNING ] Could not import plugin HAWCLike.py. Do you have the relative instrument software installed and configured?
# [WARNING ] Could not import plugin FermiLATLike.py. Do you have the relative instrument software installed and configured?
# [WARNING ] No fermitools installed
# [WARNING ] Env. variable OMP_NUM_THREADS is not set. Please set it to 1 for optimal performances in 3ML
# [WARNING ] Env. variable MKL_NUM_THREADS is not set. Please set it to 1 for optimal performances in 3ML
# [WARNING ] Env. variable NUMEXPR_NUM_THREADS is not set. Please set it to 1 for optimal performances in 3ML
# Using the irfs that are valid between 10/05/27 12:45:00 and present (YY/MM/DD HH:MM:SS)

# %%
tsbs = []
sds1 = []
sds2 = []
ra1, dec1 = 94.67830, -70.99905
ra2, dec2 = 92.67830, -70.99905
for d in dets:
    tsb = TimeSeriesBuilderSPI.from_spi_grb(f"SPIDet{d}", 
                                        d, 
                                        #ebounds_sgl, 
                                        grb_time, 
                                        ebounds=ebounds,
                                        sgl_type="both",
                                        poly_order=-1,
                                        )
    rsp = ResponseRMFGenerator.from_time(grb_time,  d,
                                            ebounds, ein,
                                            rsp_base)
    sd1 = SPIDRM(rsp, ra1, dec1)
    sd2 = SPIDRM(rsp.clone(), ra2, dec2)
    tsbs.append(tsb)
    sds1.append(sd1)
    sds2.append(sd2)

# %%
bkgs=np.array([])
for tsb in tsbs:
    bkgs = np.append(bkgs, tsb.time_series.count_per_channel_over_interval(-1000,0)/tsb.time_series.exposure_over_interval(-1000,0))
bkgs=bkgs.reshape((len(dets), -1));

# %%
# source model
from astromodels import Powerlaw, Log_uniform_prior, Uniform_prior, PointSource, SpectralComponent
import numpy as np
pl = Powerlaw()
pl.index = -2.08
pl.K = 9.3#6.44*10**-4
pl.xiv = 1

pl.K.prior = Log_uniform_prior(lower_bound=0.001, upper_bound=1000)
pl.index.prior = Uniform_prior(lower_bound=-4, upper_bound=0)

component1 = SpectralComponent('pl',shape=pl)
ps = PointSource('plline',ra=94.67830, dec=-70.99905, components=[component1])

spec = ps(ein)

spec_binned = (ein[1:]-ein[:-1])*(spec[:-1]+spec[1:])/2

# %%
# model counts
model_count_rates1 = np.array([])#np.dot(spec_binned, sd_sgl1.matrix.T)
model_count_rates2 = np.array([])#np.dot(spec_binned, sd_sgl2.matrix.T)
for sd1, sd2 in zip(sds1, sds2):
    model_count_rates1 = np.append(model_count_rates1, np.dot(spec_binned, sd1.matrix.T))
    model_count_rates2 = np.append(model_count_rates2, np.dot(spec_binned, sd2.matrix.T))
model_count_rates1 = model_count_rates1.reshape((len(dets), -1));
model_count_rates2 = model_count_rates2.reshape((len(dets), -1));

# %%
import matplotlib.pyplot as plt
fig, axes = plt.subplots(5,4, sharex=True, sharey=True, figsize=(10,10))
axes = axes.flatten()
i=0
for d in range(19):
    axes[d].text(.5,.9,f"Det {d}",horizontalalignment='center',transform=axes[d].transAxes)
    if d in dets:
        if i==0:
            axes[d].step(ebounds[:-1], bkgs[i], label="background")
            axes[d].step(ebounds[:-1], model_count_rates1[i], label="model1")
            axes[d].step(ebounds[:-1], model_count_rates2[i], label="model2")
        else:
            axes[d].step(ebounds[:-1], bkgs[i])
            axes[d].step(ebounds[:-1], model_count_rates1[i])
            axes[d].step(ebounds[:-1], model_count_rates2[i])
        i+=1
    axes[d].set_yscale("log")
    axes[d].set_ylim(10**-3, 20)
for i in range(16,20):
    axes[i].set_xlabel("Detected Energy [keV]")
for i in range(0,20,4):
    axes[i].set_ylabel("Count Rates [1/s]")
plt.subplots_adjust(hspace=0, wspace=0)
plt.subplots_adjust(hspace=0, top=0.96, bottom=0.1)
lgd = fig.legend(loc='center left', bbox_to_anchor=(0.9, 0.5), fontsize='x-large')
fig.savefig("bkg_models.pdf")

# %%
data1 = np.array([])
data2 = np.array([])
for bkg, m1, m2 in zip(bkgs, model_count_rates1, model_count_rates2):
    data1 = np.append(data1, np.random.poisson(t1*(bkg+m1)))
    data2 = np.append(data2, np.random.poisson(t2*(bkg+m2)))
    
data1 = data1.reshape((len(dets), -1));
data2 = data2.reshape((len(dets), -1));

# %%
import math
from numba import njit

@njit
def bmaxba(m1, m2, t1, t2, C1, C2):
    first = C1+C2-(m1+m2)*(t1+t2)
    root = (C1+C2+(m1-m2)*(t1+t2))**2-4*C1*(m1-m2)*(t1+t2)
    res = (first+np.sqrt(root))/(2*(t1+t2))
    return res
matrices1 = np.array([])
sd_x, sd_y = sds1[0].matrix.T.shape
for sd in sds1:
    matrices1=np.append(matrices1,sd.matrix.T)
matrices1=matrices1.reshape((len(dets), sd_x, sd_y))

matrices2 = np.array([])
for sd in sds2:
    matrices2=np.append(matrices2,sd.matrix.T)
matrices2=matrices2.reshape((len(dets), sd_x, sd_y))

@njit
def logLcore(spec_binned):
    logL=0
    for j in range(len(dets)):
        m1 = np.dot(spec_binned, matrices1[j])
        m2 = np.dot(spec_binned, matrices2[j])
        for i in range(len(m1)):
            bm = bmaxba(m1[i], m2[i], t1, t2, data1[j, i], data2[j, i])
            logL += (data1[j,i]*math.log(t1*(m1[i]+bm))+
                    data2[j,i]*math.log(t2*(m2[i]+bm))-
                    t1*(m1[i]+bm)-
                    t2*(m2[i]+bm))
    return logL

def logLba_mult(trial_values, ndim=None, params=None):
    pl.index = trial_values[1]
    pl.K = trial_values[0]
    spec = pl(ein)
    spec_binned = (ein[1:]-ein[:-1])*(spec[:-1]+spec[1:])/2
    return logLcore(spec_binned)

# %%
def prior(params, ndim=None, nparams=None):
    for i, (parameter_name, parameter) in enumerate(
        ps.free_parameters.items()
    ):

        try:

            params[i] = parameter.prior.from_unit_cube(params[i])

        except AttributeError:

            raise RuntimeError(
                "The prior you are trying to use for parameter %s is "
                "not compatible with sampling from a unitcube"
                % parameter_name
            )

# %%
print(spec_binned)
print(logLcore(spec_binned))
# Out:
# [0.00894186 0.00870593 0.00847624 0.0082526  0.00803487 0.00782288
#  0.00761648 0.00741553 0.00721988 0.00702939 0.00684392 0.00666335
#  0.00648755 0.00631638 0.00614973 0.00598748 0.00582951 0.0056757
#  0.00552595 0.00538016 0.00523821 0.0051     0.00496545 0.00483444
#  0.00470689 0.0045827  0.00446179 0.00434407 0.00422946 0.00411787
#  0.00400922 0.00390344 0.00380046 0.00370019 0.00360256 0.00350751
#  0.00341497 0.00332487 0.00323715 0.00315174 0.00306858 0.00298762
#  0.0029088  0.00283205 0.00275733 0.00268458 0.00261375 0.00254479
#  0.00247765 0.00241228 0.00234863 0.00228667 0.00222634 0.0021676
#  0.00211041 0.00205473 0.00200052 0.00194773 0.00189634 0.00184631
#  0.0017976  0.00175017 0.001704   0.00165904 0.00161527 0.00157265
#  0.00153116 0.00149076 0.00145143 0.00141313 0.00137585 0.00133955
#  0.00130421 0.0012698  0.00123629 0.00120367 0.00117192 0.001141
#  0.00111089 0.00108158 0.00105305 0.00102526 0.00099821 0.00097188
#  0.00094623 0.00092127 0.00089696 0.0008733  0.00085026 0.00082782
#  0.00080598 0.00078472 0.00076401 0.00074386 0.00072423 0.00070512
#  0.00068652 0.00066841 0.00065077 0.0006336  0.00061688 0.00060061
#  0.00058476 0.00056933 0.00055431 0.00053969 0.00052545 0.00051158
#  0.00049809 0.00048495 0.00047215 0.00045969 0.00044756 0.00043576
#  0.00042426 0.00041307 0.00040217 0.00039156 0.00038123 0.00037117
#  0.00036137 0.00035184 0.00034256 0.00033352 0.00032472 0.00031615
#  0.00030781 0.00029969 0.00029178 0.00028408 0.00027659 0.00026929
#  0.00026219 0.00025527 0.00024853 0.00024198 0.00023559 0.00022938
#  0.00022333 0.00021743 0.0002117  0.00020611 0.00020067 0.00019538
#  0.00019022 0.0001852  0.00018032 0.00017556 0.00017093]
# 32890971.33260327

# %%
import pymultinest
import os
if not os.path.exists("./chains"):
    os.mkdir("chains")
sampler = pymultinest.run(
                    logLba_mult, prior, 2, 2, n_live_points=800, resume=False, verbose=True
                )
# Out:
#  *****************************************************
#  MultiNest v3.10
#  Copyright Farhan Feroz & Mike Hobson
#  Release Jul 2015
#
#  no. of live points =  800
#  dimensionality =    2
#  *****************************************************
#  Starting MultiNest
#  generating live points
#  live points generated, starting sampling
# Acceptance Rate:                        0.995316
# Replacements:                                850
# Total Samples:                               854
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.604171
# Acceptance Rate:                        0.984683
# Replacements:                                900
# Total Samples:                               914
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.604225
# Acceptance Rate:                        0.980392
# Replacements:                                950
# Total Samples:                               969
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.604276
# Acceptance Rate:                        0.971817
# Replacements:                               1000
# Total Samples:                              1029
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.604300
# Acceptance Rate:                        0.959781
# Replacements:                               1050
# Total Samples:                              1094
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.604348
# Acceptance Rate:                        0.944206
# Replacements:                               1100
# Total Samples:                              1165
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.604394
# Acceptance Rate:                        0.928168
# Replacements:                               1150
# Total Samples:                              1239
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.604436
# Acceptance Rate:                        0.907029
# Replacements:                               1200
# Total Samples:                              1323
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.483054
# Acceptance Rate:                        0.891583
# Replacements:                               1250
# Total Samples:                              1402
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.483098
# Acceptance Rate:                        0.874832
# Replacements:                               1300
# Total Samples:                              1486
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.483139
# Acceptance Rate:                        0.849057
# Replacements:                               1350
# Total Samples:                              1590
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.483185
# Acceptance Rate:                        0.822562
# Replacements:                               1400
# Total Samples:                              1702
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.438701
# Acceptance Rate:                        0.803769
# Replacements:                               1450
# Total Samples:                              1804
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.419402
# Acceptance Rate:                        0.802568
# Replacements:                               1500
# Total Samples:                              1869
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.430461
# Acceptance Rate:                        0.804359
# Replacements:                               1550
# Total Samples:                              1927
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.430478
# Acceptance Rate:                        0.804424
# Replacements:                               1600
# Total Samples:                              1989
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.430495
# Acceptance Rate:                        0.804486
# Replacements:                               1650
# Total Samples:                              2051
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.430503
# Acceptance Rate:                        0.804163
# Replacements:                               1700
# Total Samples:                              2114
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.430465
# Acceptance Rate:                        0.806452
# Replacements:                               1750
# Total Samples:                              2170
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.429453
# Acceptance Rate:                        0.806090
# Replacements:                               1800
# Total Samples:                              2233
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.429261
# Acceptance Rate:                        0.803998
# Replacements:                               1850
# Total Samples:                              2301
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.418133
# Acceptance Rate:                        0.802365
# Replacements:                               1900
# Total Samples:                              2368
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.403423
# Acceptance Rate:                        0.800821
# Replacements:                               1950
# Total Samples:                              2435
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.370525
# Acceptance Rate:                        0.801925
# Replacements:                               2000
# Total Samples:                              2494
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.370519
# Acceptance Rate:                        0.798287
# Replacements:                               2050
# Total Samples:                              2568
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.348193
# Acceptance Rate:                        0.796058
# Replacements:                               2100
# Total Samples:                              2638
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.348208
# Acceptance Rate:                        0.790732
# Replacements:                               2150
# Total Samples:                              2719
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.328737
# Acceptance Rate:                        0.785995
# Replacements:                               2200
# Total Samples:                              2799
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.328376
# Acceptance Rate:                        0.779896
# Replacements:                               2250
# Total Samples:                              2885
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.313886
# Acceptance Rate:                        0.775194
# Replacements:                               2300
# Total Samples:                              2967
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.299207
# Acceptance Rate:                        0.775578
# Replacements:                               2350
# Total Samples:                              3030
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.295936
# Acceptance Rate:                        0.770465
# Replacements:                               2400
# Total Samples:                              3115
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.295951
# Acceptance Rate:                        0.766583
# Replacements:                               2450
# Total Samples:                              3196
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.295687
# Acceptance Rate:                        0.762893
# Replacements:                               2500
# Total Samples:                              3277
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.284283
# Acceptance Rate:                        0.758929
# Replacements:                               2550
# Total Samples:                              3360
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.280487
# Acceptance Rate:                        0.756914
# Replacements:                               2600
# Total Samples:                              3435
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.278102
# Acceptance Rate:                        0.755847
# Replacements:                               2650
# Total Samples:                              3506
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.275846
# Acceptance Rate:                        0.752299
# Replacements:                               2700
# Total Samples:                              3589
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.261143
# Acceptance Rate:                        0.750956
# Replacements:                               2750
# Total Samples:                              3662
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.260079
# Acceptance Rate:                        0.748663
# Replacements:                               2800
# Total Samples:                              3740
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.254406
# Acceptance Rate:                        0.747051
# Replacements:                               2850
# Total Samples:                              3815
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.251955
# Acceptance Rate:                        0.747230
# Replacements:                               2900
# Total Samples:                              3881
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.248296
# Acceptance Rate:                        0.744761
# Replacements:                               2950
# Total Samples:                              3961
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.246034
# Acceptance Rate:                        0.744232
# Replacements:                               3000
# Total Samples:                              4031
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.245527
# Acceptance Rate:                        0.743177
# Replacements:                               3050
# Total Samples:                              4104
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.237689
# Acceptance Rate:                        0.742159
# Replacements:                               3100
# Total Samples:                              4177
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.236747
# Acceptance Rate:                        0.739263
# Replacements:                               3150
# Total Samples:                              4261
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.227705
# Acceptance Rate:                        0.737837
# Replacements:                               3200
# Total Samples:                              4337
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.226905
# Acceptance Rate:                        0.736627
# Replacements:                               3250
# Total Samples:                              4412
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.221120
# Acceptance Rate:                        0.737101
# Replacements:                               3300
# Total Samples:                              4477
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.218516
# Acceptance Rate:                        0.734166
# Replacements:                               3350
# Total Samples:                              4563
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.210371
# Acceptance Rate:                        0.733233
# Replacements:                               3400
# Total Samples:                              4637
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.202626
# Acceptance Rate:                        0.733574
# Replacements:                               3450
# Total Samples:                              4703
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.200032
# Acceptance Rate:                        0.733291
# Replacements:                               3500
# Total Samples:                              4773
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.193675
# Acceptance Rate:                        0.734230
# Replacements:                               3550
# Total Samples:                              4835
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.180717
# Acceptance Rate:                        0.735595
# Replacements:                               3600
# Total Samples:                              4894
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.170951
# Acceptance Rate:                        0.735294
# Replacements:                               3650
# Total Samples:                              4964
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.165302
# Acceptance Rate:                        0.735879
# Replacements:                               3700
# Total Samples:                              5028
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.160060
# Acceptance Rate:                        0.734574
# Replacements:                               3750
# Total Samples:                              5105
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.148435
# Acceptance Rate:                        0.734158
# Replacements:                               3800
# Total Samples:                              5176
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.145456
# Acceptance Rate:                        0.733613
# Replacements:                               3850
# Total Samples:                              5248
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.140119
# Acceptance Rate:                        0.734049
# Replacements:                               3900
# Total Samples:                              5313
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.134365
# Acceptance Rate:                        0.733247
# Replacements:                               3950
# Total Samples:                              5387
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.129679
# Acceptance Rate:                        0.733407
# Replacements:                               4000
# Total Samples:                              5454
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.125018
# Acceptance Rate:                        0.732634
# Replacements:                               4050
# Total Samples:                              5528
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.120171
# Acceptance Rate:                        0.733584
# Replacements:                               4100
# Total Samples:                              5589
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.115080
# Acceptance Rate:                        0.731793
# Replacements:                               4150
# Total Samples:                              5671
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.111873
# Acceptance Rate:                        0.731707
# Replacements:                               4200
# Total Samples:                              5740
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.109787
# Acceptance Rate:                        0.732759
# Replacements:                               4250
# Total Samples:                              5800
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.107988
# Acceptance Rate:                        0.732788
# Replacements:                               4300
# Total Samples:                              5868
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.105727
# Acceptance Rate:                        0.732817
# Replacements:                               4350
# Total Samples:                              5936
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.102727
# Acceptance Rate:                        0.733089
# Replacements:                               4400
# Total Samples:                              6002
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.099049
# Acceptance Rate:                        0.732510
# Replacements:                               4450
# Total Samples:                              6075
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.096251
# Acceptance Rate:                        0.733018
# Replacements:                               4500
# Total Samples:                              6139
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.093815
# Acceptance Rate:                        0.733161
# Replacements:                               4550
# Total Samples:                              6206
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.090499
# Acceptance Rate:                        0.731901
# Replacements:                               4600
# Total Samples:                              6285
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.088305
# Acceptance Rate:                        0.730099
# Replacements:                               4650
# Total Samples:                              6369
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.086030
# Acceptance Rate:                        0.730494
# Replacements:                               4700
# Total Samples:                              6434
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.083370
# Acceptance Rate:                        0.731107
# Replacements:                               4750
# Total Samples:                              6497
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.080433
# Acceptance Rate:                        0.730260
# Replacements:                               4800
# Total Samples:                              6573
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.079115
# Acceptance Rate:                        0.730752
# Replacements:                               4850
# Total Samples:                              6637
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.077061
# Acceptance Rate:                        0.730036
# Replacements:                               4900
# Total Samples:                              6712
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.075498
# Acceptance Rate:                        0.730412
# Replacements:                               4950
# Total Samples:                              6777
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.073874
# Acceptance Rate:                        0.730140
# Replacements:                               5000
# Total Samples:                              6848
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.071772
# Acceptance Rate:                        0.730191
# Replacements:                               5050
# Total Samples:                              6916
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.070282
# Acceptance Rate:                        0.730659
# Replacements:                               5100
# Total Samples:                              6980
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.068518
# Acceptance Rate:                        0.730289
# Replacements:                               5150
# Total Samples:                              7052
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.067805
# Acceptance Rate:                        0.730645
# Replacements:                               5200
# Total Samples:                              7117
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.066056
# Acceptance Rate:                        0.728762
# Replacements:                               5250
# Total Samples:                              7204
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.064262
# Acceptance Rate:                        0.728823
# Replacements:                               5300
# Total Samples:                              7272
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.063068
# Acceptance Rate:                        0.728784
# Replacements:                               5350
# Total Samples:                              7341
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.061474
# Acceptance Rate:                        0.729434
# Replacements:                               5400
# Total Samples:                              7403
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.059800
# Acceptance Rate:                        0.729390
# Replacements:                               5450
# Total Samples:                              7472
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.058481
# Acceptance Rate:                        0.728187
# Replacements:                               5500
# Total Samples:                              7553
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.057431
# Acceptance Rate:                        0.727964
# Replacements:                               5550
# Total Samples:                              7624
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.055786
# Acceptance Rate:                        0.729167
# Replacements:                               5600
# Total Samples:                              7680
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.054221
# Acceptance Rate:                        0.730257
# Replacements:                               5650
# Total Samples:                              7737
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.052576
# Acceptance Rate:                        0.730769
# Replacements:                               5700
# Total Samples:                              7800
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.051779
# Acceptance Rate:                        0.730344
# Replacements:                               5750
# Total Samples:                              7873
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.050948
# Acceptance Rate:                        0.730755
# Replacements:                               5800
# Total Samples:                              7937
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.049874
# Acceptance Rate:                        0.731524
# Replacements:                               5850
# Total Samples:                              7997
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.048769
# Acceptance Rate:                        0.732192
# Replacements:                               5900
# Total Samples:                              8058
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.047839
# Acceptance Rate:                        0.732037
# Replacements:                               5950
# Total Samples:                              8128
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.047070
# Acceptance Rate:                        0.731975
# Replacements:                               6000
# Total Samples:                              8197
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.046175
# Acceptance Rate:                        0.731737
# Replacements:                               6050
# Total Samples:                              8268
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.045217
# Acceptance Rate:                        0.731327
# Replacements:                               6100
# Total Samples:                              8341
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.044329
# Acceptance Rate:                        0.731707
# Replacements:                               6150
# Total Samples:                              8405
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.043581
# Acceptance Rate:                        0.730701
# Replacements:                               6200
# Total Samples:                              8485
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.042925
# Acceptance Rate:                        0.730567
# Replacements:                               6250
# Total Samples:                              8555
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.042193
# Acceptance Rate:                        0.731198
# Replacements:                               6300
# Total Samples:                              8616
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.041500
# Acceptance Rate:                        0.731314
# Replacements:                               6350
# Total Samples:                              8683
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.040826
# Acceptance Rate:                        0.731094
# Replacements:                               6400
# Total Samples:                              8754
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.040190
# Acceptance Rate:                        0.731044
# Replacements:                               6450
# Total Samples:                              8823
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.039647
# Acceptance Rate:                        0.731159
# Replacements:                               6500
# Total Samples:                              8890
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.039133
# Acceptance Rate:                        0.731272
# Replacements:                               6550
# Total Samples:                              8957
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.038586
# Acceptance Rate:                        0.731788
# Replacements:                               6600
# Total Samples:                              9019
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.038117
# Acceptance Rate:                        0.731493
# Replacements:                               6650
# Total Samples:                              9091
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.037679
# Acceptance Rate:                        0.731681
# Replacements:                               6700
# Total Samples:                              9157
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.037275
# Acceptance Rate:                        0.731628
# Replacements:                               6750
# Total Samples:                              9226
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.036872
# Acceptance Rate:                        0.731340
# Replacements:                               6800
# Total Samples:                              9298
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.036541
# Acceptance Rate:                        0.731369
# Replacements:                               6850
# Total Samples:                              9366
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.036249
# Acceptance Rate:                        0.731165
# Replacements:                               6900
# Total Samples:                              9437
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.035938
# Acceptance Rate:                        0.731348
# Replacements:                               6950
# Total Samples:                              9503
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.035683
# Acceptance Rate:                        0.731300
# Replacements:                               7000
# Total Samples:                              9572
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.035447
# Acceptance Rate:                        0.731555
# Replacements:                               7050
# Total Samples:                              9637
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.035205
# Acceptance Rate:                        0.732110
# Replacements:                               7100
# Total Samples:                              9698
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.035004
# Acceptance Rate:                        0.732132
# Replacements:                               7150
# Total Samples:                              9766
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.034818
# Acceptance Rate:                        0.732526
# Replacements:                               7200
# Total Samples:                              9829
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.034643
# Acceptance Rate:                        0.732545
# Replacements:                               7250
# Total Samples:                              9897
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.034454
# Acceptance Rate:                        0.732858
# Replacements:                               7300
# Total Samples:                              9961
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.034309
# Acceptance Rate:                        0.732802
# Replacements:                               7350
# Total Samples:                             10030
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.034179
# Acceptance Rate:                        0.732601
# Replacements:                               7400
# Total Samples:                             10101
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.034064
# Acceptance Rate:                        0.732691
# Replacements:                               7450
# Total Samples:                             10168
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.033954
# Acceptance Rate:                        0.731993
# Replacements:                               7500
# Total Samples:                             10246
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.033854
# Acceptance Rate:                        0.731924
# Replacements:                               7511
# Total Samples:                             10262
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.033827
#  ln(ev)=   32890965.521956313      +/-  0.10387864696301201
#  Total Likelihood Evaluations:        10262
#  Sampling finished. Exiting MultiNest

# %%
# %matplotlib inline
from chainconsumer import ChainConsumer
import numpy as np


def loadtxt2d(intext):
        try:
            return np.loadtxt(intext, ndmin=2)
        except:
            return np.loadtxt(intext)

c = ChainConsumer()

chain = loadtxt2d('./chains/1-post_equal_weights.dat')

#c.add_chain(chain, parameters=['K', 'index', 'F', 'mu','sigma', '$z$'], name='yeah')
c.add_chain(chain, parameters=['K', 'index', '$z$'], name='fit')

# %%
c.plotter.plot(filename="fit_corner.pdf", 
                parameters=['K', 'index'],
                truth=[9.3, -2.08],
                log_scales=[]);
