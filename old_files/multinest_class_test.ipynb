# %%
from astropy.coordinates import SkyCoord
import numpy as np
from IntegralQuery import SearchQuery, IntegralQuery, Filter, Range
from IntegralPointingClustering import ClusteredQuery
import astropy.io.fits as fits
from astropy.table import Table
from datetime import datetime
import matplotlib.pyplot as plt
import math
from numba import njit
from pyspi.utils.function_utils import find_response_version
from pyspi.utils.response.spi_response_data import ResponseDataRMF
from pyspi.utils.response.spi_response import ResponseRMFGenerator
from pyspi.utils.response.spi_drm import SPIDRM
from pyspi.utils.livedets import get_live_dets
from astromodels import Powerlaw, Log_uniform_prior, Uniform_prior, PointSource, SpectralComponent, Model
from chainconsumer import ChainConsumer
import pymultinest
import os
import astropy.time as at
from scipy.stats import poisson
import pickle

# %%
rsp_bases = tuple([ResponseDataRMF.from_version(i) for i in range(5)])
# Out:
# Using the irfs that are valid between Start and 03/07/06 06:00:00 (YY/MM/DD HH:MM:SS)
# Using the irfs that are valid between 03/07/06 06:00:00 and 04/07/17 08:20:06 (YY/MM/DD HH:MM:SS)
# Using the irfs that are valid between 04/07/17 08:20:06 and 09/02/19 09:59:57 (YY/MM/DD HH:MM:SS)
# Using the irfs that are valid between 09/02/19 09:59:57 and 10/05/27 12:45:00 (YY/MM/DD HH:MM:SS)
# Using the irfs that are valid between 10/05/27 12:45:00 and present (YY/MM/DD HH:MM:SS)

# %%
@njit
def b_maxL_2(m, t, C):
    first = C[0]+C[1]-(m[0]+m[1])*(t[0]+t[1])
    root = (C[0]+C[1]+(m[0]-m[1])*(t[0]+t[1]))**2-4*C[0]*(m[0]-m[1])*(t[0]+t[1])
    res = (first+np.sqrt(root))/(2*(t[0]+t[1]))
    if res < 0:
        return 0
    return res

@njit #################### needs more testing, can do without error?
def b_maxL_3(m, t, C):
    mt = m[0] + m[1] + m[2]
    tt = t[0] + t[1] + t[2]
    Ct = C[0] + C[1] + C[2]
    a = -tt
    b = -tt*mt + Ct
    c = Ct*mt - C[0]*m[0] - C[1]*m[1] - C[2]*m[2] -tt*(m[0]*m[1] + m[1]*m[2] + m[2]*m[0])
    d = C[0]*m[1]*m[2] + C[1]*m[2]*m[0] + C[2]*m[0]*m[1] - tt*m[0]*m[1]*m[2]
    D0 = b**2 - 3*a*c
    D1 = 2*b**3 - 9*a*b*c + 27*(a**2)*d
        
    if D0 == 0. and D1 == 0.:
        return -b/(3*a)
    
    C0 = ((D1 + np.sqrt(D1**2 - 4*D0**3 + 0j)) / 2)**(1/3)
    
    if C0 == 0:
        C0 = ((D1 - np.sqrt(D1**2 - 4*D0**3 + 0j)) / 2)**(1/3)
        
    x0 = -1/(3*a) * (b + C0 + D0/C0)
    
    if x0.real < 0:
        return 0.
    
    return x0.real

# %%
@njit
def logLcore(
    spec_binned,
    pointings,
    dets,
    resp_mats,
    num_sources,
    t_elapsed,
    counts
):
    logL=0
    for p_i in range(len(pointings)):
        for d_i in range(len(dets[p_i])):
            n_p = len(pointings[p_i])
            m = np.zeros((n_p, len(resp_mats[p_i][0][0][0,0,:])))
            
            t_b = np.zeros(n_p)
            for t_i in range(n_p):
                t_b[t_i] = t_elapsed[p_i][t_i][d_i]
            C_b = np.zeros(n_p)
            
            for s_i in range(num_sources):
                for m_i in range(n_p):
                    m[m_i,:] += np.dot(spec_binned[s_i,:], resp_mats[p_i][s_i][m_i][d_i])
            for e_i in range(len(m[0])):
                m_b = m[:,e_i]
                for C_i in range(n_p):
                    C_b[C_i] = counts[p_i][C_i][d_i, e_i]
                    
                if n_p == 2:
                    b = b_maxL_2(m_b, t_b, C_b)
                elif n_p == 3:
                    b = b_maxL_3(m_b, t_b, C_b)
                else:
                    print()
                    print("b_maxL is not defined")
                    print()
                    return 0.
                for m_i in range(n_p):
                    logL += (counts[p_i][m_i][d_i, e_i]*math.log(t_elapsed[p_i][m_i][d_i]*(m[m_i,e_i]+b))
                            -t_elapsed[p_i][0][d_i]*(m[m_i,e_i]+b))
    return logL

# %%
def extract_pointing_info(path, p_id):
    num_dets = 19
    with fits.open(f"{path}/pointing.fits") as file:
        t = Table.read(file[1])
        index = np.argwhere(t["PTID_ISOC"]==p_id[:8])
        
        if len(index) < 1:
            raise Exception(f"{p_id} not found")

        pointing_info = t[index[-1][0]]
        
        t1 = at.Time(f'{pointing_info["TSTART"]+2451544.5}', format='jd').datetime
        time_start = datetime.strftime(t1,'%y%m%d %H%M%S')
            
    with fits.open(f"{path}/dead_time.fits") as file:
        t = Table.read(file[1])
        
        time_elapsed = np.zeros(num_dets)
        
        for i in range(num_dets):
            for j in index:
                time_elapsed[i] += t["LIVETIME"][j[0]*85 + i]
        
    with fits.open(f"{path}/energy_boundaries.fits") as file:
        t = Table.read(file[1])
        
        energy_bins = np.append(t["E_MIN"], t["E_MAX"][-1])
    
    with fits.open(f"{path}/evts_det_spec.fits") as file:
        t = Table.read(file[1])
        
        counts = np.zeros((num_dets, len(energy_bins)-1))
        for i in range(num_dets):
            for j in index:
                counts[i, : ] += t["COUNTS"][j[0]*85 + i]

    return time_start, time_elapsed, energy_bins, counts

# %%
def generate_resp_mat(
    rmfs,
    len_dets,
    len_ebs,
    len_emod,
    ra,
    dec,
):
    sds = np.empty(0)
    for d in range(len_dets):
        sd = SPIDRM(rmfs[d], ra, dec)
        sds = np.append(sds, sd.matrix.T)
    return sds.reshape((len_dets, len_emod-1, len_ebs-1))

# %%
def calc_mahalanobis_dist(summary, cov, true_vals):
    fit_val = np.array([i[1] for i in summary.values()])
    fit_cov = cov[1]
    rel_distance = []
    
    for i in range(len(true_vals)):
        dif = fit_val - true_vals[i]
        
        rel_distance.append(np.sqrt(
            np.linalg.multi_dot([dif, np.linalg.inv(fit_cov), dif])
        ))
        
    return np.array(rel_distance)

# %%
class MultinestClusterFit:
    def __init__(
        self,
        pointings,
        source_model,
        energy_range,
        emod,
        binning_func,
        true_values=None,
        folder=None,
    ):
        self._pointings = pointings
        self._source_model = source_model
        self._binning_func = binning_func
        self._energy_range = energy_range
        self._emod = emod
        
        self._true_values = true_values
        self.set_folder(folder)
        
        self._prepare_fit_data()
        
        self._find_updatable_sources()
        
        self._initialize_resp_mats()
        
        self._run_multinest()
                
        self._extract_parameter_names_simple()
        self._parameter_names.extend(["$z$"])
            
        self._cc = ChainConsumer()
        self._chain = np.loadtxt('./chains/1-post_equal_weights.dat')
        self._cc.add_chain(self._chain, parameters=self._parameter_names, name='fit')
        
    def _run_multinest(self):
        num_sources = len(self._source_model.sources)
        
        def logLba_mult(trial_values, ndim=None, params=None):
            spec_binned = np.zeros((num_sources, len(self._emod)-1))
            for i, parameter in enumerate(self._source_model.free_parameters.values()):
                parameter.value = trial_values[i]
            for i, source in enumerate(self._source_model.sources.values()):
                spec = source(self._emod)
                spec_binned[i,:] = (self._emod[1:]-self._emod[:-1])*(spec[:-1]+spec[1:])/2
            if 1 in self._updatable_sources:
                self._update_resp_mats()
            return logLcore(
                spec_binned,
                self._pointings,
                self._dets,
                self._resp_mats,
                num_sources,
                self._t_elapsed,
                self._counts,
            )
        
        def prior(params, ndim=None, nparams=None):
            for i, parameter in enumerate(self._source_model.free_parameters.values()):
                try:
                    params[i] = parameter.prior.from_unit_cube(params[i])

                except AttributeError:
                    raise RuntimeError(
                        "The prior you are trying to use for parameter %s is "
                        "not compatible with sampling from a unitcube"
                        % parameter.path
                    )

        num_params = len(self._source_model.free_parameters)
        
        # ###
        # trial_values = [4.5e-3, -2.08, 7e-3, -2.5]
        # spec_binned = np.zeros((num_sources, len(self._emod)-1))
        # for i, parameter in enumerate(self._source_model.free_parameters.values()):
        #     parameter.value = trial_values[i]
        # for i, source in enumerate(self._source_model.sources.values()):
        #     spec = source(self._emod)
        #     spec_binned[i,:] = (self._emod[1:]-self._emod[:-1])*(spec[:-1]+spec[1:])/2
        # print(logLcore(
        #     spec_binned,
        #     self._pointings,
        #     self._dets,
        #     self._resp_mats,
        #     num_sources,
        #     self._t_elapsed,
        #     self._counts,
        # ))
        # return None
        # ###

        if not os.path.exists("./chains"):
            os.mkdir("chains")
        sampler = pymultinest.run(
            logLba_mult, prior, num_params, num_params, n_live_points=800, resume=False, verbose=True
        )
    
    def _prepare_fit_data(self):
        ebs = []
        counts = []
        dets = []
        t_elapsed = []
        t_start = []
            
        for combination in self._pointings:
            c_time_start, c_time_elapsed = [], []
            for p_i, pointing in enumerate(combination):
                time_start, time_elapsed, energy_bins, counts_f = extract_pointing_info(pointing[1], pointing[0])
                c_time_start.append(time_start)
                dets_temp = get_live_dets(time=time_start, event_types=["single"])
                c_time_elapsed.append(time_elapsed[dets_temp])
                
                if p_i == 0:
                    dets_0 = dets_temp
                    energy_bins_0 = energy_bins
                    c_counts_f = counts_f[dets_0]
                else:
                    c_counts_f = np.append(c_counts_f, counts_f[dets_0], axis=0)
                    assert np.array_equal(dets_0, dets_temp), f"Active detectors are not the same for {combination[0][0]} and {combination[p_i][0]}"
                    assert np.array_equal(energy_bins_0, energy_bins), f"Energy bins are not the same for {combination[0][0]} and {combination[p_i][0]}"
                
            eb, c = self._binning_func(
                energy_bins_0,
                c_counts_f,
                self._energy_range
            )
            nd = len(dets_0)
            counts.append(tuple([c[i*nd : (i+1)*nd] for i in range(len(combination))]))
            ebs.append(eb)
            
            t_start.append(tuple(c_time_start))
            dets.append(dets_0)
            t_elapsed.append(tuple(c_time_elapsed))
                            
                
            # time_start1, time_elapsed1, energy_bins1, counts_f1 = extract_pointing_info(pair[0], pair[1])
            # time_start2, time_elapsed2, energy_bins2, counts_f2 = extract_pointing_info(pair[0], pair[2])
            # t_start.append((time_start1, time_start2))
            
            # dets1 = get_live_dets(time=time_start1, event_types=["single"])
            # dets2 = get_live_dets(time=time_start2, event_types=["single"])
            # assert np.array_equal(dets1, dets2), f"Active detectors are not the same for {pair[1]} and {pair[2]}"
            # dets.append(dets1)
            
            # t_elapsed.append((time_elapsed1[dets1], time_elapsed2[dets1]))
            
            # assert np.array_equal(energy_bins1, energy_bins2), f"Energy bins are not the same for {pair[1]} and {pair[2]}"
            
            # eb, c = binning_func(
            #     energy_bins1,
            #     np.append(counts_f1[dets1], counts_f2[dets1], axis=0),
            #     energy_range)
            # counts.append((c[:len(dets1)], c[len(dets1):]))
            # ebs.append(eb)
                
        self._ebs = tuple(ebs) 
        self._counts = tuple(counts)
        self._dets = tuple(dets)
        self._t_elapsed = tuple(t_elapsed)
        self._t_start = tuple(t_start)
    
    def _initialize_resp_mats(self):
        # index order: tuple(combination, source, pointing, np_array(dets, e_in, e_out))
        resp_mats = []
        rmfs = []
        
        for count, combination in enumerate(self._pointings):
            # version1 = find_response_version(self._t_start[count][0])
            # for pointing in range(1, len(combination)):
            #     version2 = find_response_version(self._t_start[count][pointing])
            #     assert version1 == version2, f"Response versions are not equal for {combination[0][0]} and {combination[pointing][0]}"
            # rsp_base = rsp_bases[version1]
            
            source_resp_mats = []
            
            dets = self._dets[count]
            ebs = self._ebs[count]
            
            for source in self._source_model.sources.values():
                combination_resp_mats = []
                combination_rmfs = []
                
                for pointing in range(len(combination)):
                    time = self._t_start[count][pointing]
                    version = find_response_version(time)
                    rsp_base = rsp_bases[version]
                    
                    pointing_rmfs = []
                    for d in dets:
                        pointing_rmfs.append(ResponseRMFGenerator.from_time(time, d, ebs, self._emod, rsp_base))
                    pointing_rmfs = tuple(pointing_rmfs)
                                        
                    combination_resp_mats.append(
                        generate_resp_mat(
                            pointing_rmfs,
                            len(dets),
                            len(ebs),
                            len(self._emod),
                            source.position.get_ra(),
                            source.position.get_dec(),
                        )
                    )
                    combination_rmfs.append(pointing_rmfs)
                    
                source_resp_mats.append(tuple(combination_resp_mats))
                    
            resp_mats.append(tuple(source_resp_mats))
            rmfs.append(tuple(combination_rmfs))
            
        self._resp_mats = tuple(resp_mats)
        if 1 in self._updatable_sources:
            self._updatable_rmfs = tuple(rmfs)

    def _update_resp_mats(self):
        for count, combination in enumerate(self._pointings):
            for source_num, source in enumerate(self._source_model.sources.values()):
                if self._updatable_sources[source_num] == 1:
                    for pointing in range(len(combination)):
                        self._resp_mats[count][source_num][pointing][:,:,:] = generate_resp_mat(
                            self._updatable_rmfs[count][pointing],
                            len(self._dets[count]),
                            len(self._ebs[count]),
                            len(self._emod),
                            source.position.get_ra(),
                            source.position.get_dec(),
                        )

    def _find_updatable_sources(self):
        keywords = ["position"]
        self._updatable_sources = np.zeros(len(self._source_model.sources), np.int8)
        for s_i, source in enumerate(self._source_model.sources.values()):
            for parameter in source.free_parameters.values():
                first_pos = parameter.path.find(".")
                second_pos = parameter.path.find(".", first_pos+1)
                if parameter.path[first_pos+1 : second_pos] in keywords:
                    self._updatable_sources[s_i] = 1

    def parameter_fit_distribution(self):
        assert not self._folder is None, "folder is not set"
        
        fig = self._cc.plotter.plot(
            parameters=self._parameter_names[:-1],
            # truth={'Crab K':true_values_main[0,0], 'Crab index':true_values_main[0,1]},
            figsize=1.5
        )
        
        plt.savefig(f"{self._folder}/parameter_fit_distributions.pdf")
        plt.close()
        
    def text_summaries(
        self,
        reference_values=True,
        pointing_combinations=True,
        parameter_fit_constraints=True
    ):
        assert not self._folder is None, "folder is not set"
        
        
        if reference_values:
            assert not self._true_values is None, "true_values not set"
            summary = self._cc.analysis.get_summary(parameters=self._true_values[0])
            cov = self._cc.analysis.get_covariance(parameters=self._true_values[0])
            rel_distances = calc_mahalanobis_dist(summary, cov, self._true_values[1])
            
            with open(f"{self._folder}/reference_values", "w") as f:
                f.write(f"{' : '.join(self._true_values[0])} : Rel. Dist.\n")
                for i in range(self._true_values[1].shape[0]):
                    f.write(f"{' : '.join([f'{j:.3}' for j in self._true_values[1][i,:]])} : {rel_distances[i]:.3}\n")
                
        if pointing_combinations:
            with open(f"{self._folder}/pointing_combinations", "w") as f:
                for combination in self._pointings:
                    f.write(f'{"  ".join(i[0] for i in combination)}\n')
        
        if parameter_fit_constraints:
            summary = self._cc.analysis.get_summary(parameters=self._parameter_names[:-1])
            with open(f"{self._folder}/parameter_fit_constraints", "w") as f:
                for param in self._parameter_names[:-1]:
                    f.write(f"{param}:\n")
                    try:
                        f.write(f"{summary[param][0]:.5}  {summary[param][1]:.5}  {summary[param][2]:.5}\n")
                    except:
                        f.write(f"None  {summary[param][1]:.5}  None\n")
    
    def ppc( # allow updatable sources!
        self,
        count_energy_plots=True,
        qq_plots=True
    ):
        assert self._folder is not None, "folder is not set"
        
        s, b = self._calc_rates()
        
        for c_i, combination in enumerate(self._pointings):
            for p_i in range(len(combination)):
            
                if count_energy_plots:
                    self._count_energy_plot(
                        b[c_i][p_i],
                        s[c_i][p_i],
                        self._ebs[c_i],
                        self._counts[c_i][p_i],
                        self._dets[c_i],
                        combination[p_i][0]
                    )
                if qq_plots:
                    self._qq_plot(
                        b[c_i][p_i],
                        s[c_i][p_i],
                        self._counts[c_i][p_i],
                        self._dets[c_i],
                        combination[p_i][0]
                    )
            
    def _calc_rates(self):
        source_rate = []
        background_rate = []
        for c_i, combination in enumerate(self._pointings):
            source_rate.append(np.zeros((len(combination), len(self._dets[c_i]), len(self._ebs[c_i])-1, len(self._chain))))
            background_rate.append(np.zeros((len(self._dets[c_i]), len(self._ebs[c_i])-1, len(self._chain))))
        
        num_sources = len(self._source_model.sources)
        
        for p_i, params in enumerate(self._chain):
            spec_binned = np.zeros((num_sources, len(self._emod)-1))
            for fp_i, parameter in enumerate(self._source_model.free_parameters.values()):
                parameter.value = params[fp_i]
            for s_i, source in enumerate(self._source_model.sources.values()):
                spec = source(self._emod)
                spec_binned[s_i,:] = (self._emod[1:]-self._emod[:-1])*(spec[:-1]+spec[1:])/2
            if 1 in self._updatable_sources:
                self._update_resp_mats()
            
            for c_i, combination in enumerate(self._pointings):
                for d_i in range(len(self._dets[c_i])):
                    for s_i in range(num_sources):
                        for m_i in range(len(combination)):
                            source_rate[c_i][m_i,d_i,:,p_i] += np.dot(spec_binned[s_i,:], self._resp_mats[c_i][s_i][m_i][d_i])
                    for e_i in range(len(self._ebs[c_i])-1):
                        s_b = np.array([source_rate[c_i][i,d_i,e_i,p_i] for i in range(len(combination))])
                        t_b = np.array([self._t_elapsed[c_i][i][d_i] for i in range(len(combination))])
                        C_b = np.array([self._counts[c_i][i][d_i, e_i] for i in range(len(combination))])
                        if len(combination) == 2:
                            background_rate[c_i][d_i,e_i,p_i] = b_maxL_2(s_b, t_b, C_b)
                        elif len(combination) == 3:
                            background_rate[c_i][d_i,e_i,p_i] = b_maxL_3(s_b, t_b, C_b)
                        
        source_rates = []
        background_rates = []
        for c_i, combination in enumerate(self._pointings):
            c_source_rates = []
            c_background_rates = []
            
            for p_i in range(len(combination)):
                c_source_rates.append(
                    np.average(source_rate[c_i][p_i], axis=2) * self._t_elapsed[c_i][p_i][:,np.newaxis]
                )
                c_background_rates.append(
                    np.average(background_rate[c_i], axis=2) * self._t_elapsed[c_i][p_i][:,np.newaxis]
                )
            
            source_rates.append(c_source_rates)
            background_rates.append(c_background_rates)

        return source_rates, background_rates

    def _count_energy_plot(
        self,
        b,
        s,
        eb,
        c,
        dets,
        name
    ):
        fig, axes = plt.subplots(5,4, sharex=True, sharey=True, figsize=(10,10))
        axes = axes.flatten()
        
        predicted = b + s
        predicted_lower = poisson.ppf(0.16, predicted)
        predicted_upper = poisson.ppf(0.84, predicted)
        counts = c
        
        i=0
        for d in range(19):
            axes[d].text(.5,.9,f"Det {d}",horizontalalignment='center',transform=axes[d].transAxes)
            if d in dets:
                line1, = axes[d].step(eb[:-1], predicted[i], c="r")
                line2, = axes[d].step(eb[:-1], counts[i], c="k")
                axes[d].fill_between(eb[:-1], predicted_lower[i], predicted_upper[i], color="r", alpha=0.5)
                if i==0:
                    line1.set_label("Predicted Counts")
                    line2.set_label("Real Counts")
                i += 1
            axes[d].set_yscale("log")
        plt.subplots_adjust(hspace=0, wspace=0)
        plt.subplots_adjust(hspace=0, top=0.96, bottom=0.1)
        lgd = fig.legend(loc='center left', bbox_to_anchor=(0.9, 0.5), fontsize='x-large')
        
        fig.add_subplot(111, frameon=False)
        plt.tick_params(labelcolor='none', which='both', top=False, bottom=False, left=False, right=False)
        plt.xlabel("Detected Energy [keV]")
        plt.ylabel("Cumulative Counts")
        
        fig.savefig(f"{self._folder}/{name}_count_energy.pdf")
        plt.close()
    
    def _qq_plot(
        self,
        b,
        s,
        c,
        dets,
        name
    ):
        fig, axes = plt.subplots(5,4, sharex=True, sharey=True, figsize=(10,10))
        axes = axes.flatten()
        
        p = b + s
        predicted = np.cumsum(p, axis=1)
        predicted_lower = np.cumsum(poisson.ppf(0.16, p), axis=1)
        predicted_upper = np.cumsum(poisson.ppf(0.84, p), axis=1)
        counts = np.cumsum(c, axis=1)
        ma = np.amax(
            np.array([np.amax(counts, axis=1), np.amax(predicted, axis=1)]),
            axis=0
        )
        
        i=0
        for d in range(19):
            axes[d].text(.5,.9,f"Det {d}",horizontalalignment='center',transform=axes[d].transAxes)
            if d in dets:
                line2, = axes[d].plot([0, ma[i]], [0, ma[i]], ls="--", c="k")
                line1, = axes[d].plot(counts[i], predicted[i], c="r")
                axes[d].fill_between(counts[i], predicted_lower[i], predicted_upper[i], color="r", alpha=0.5)
                i += 1
        plt.subplots_adjust(hspace=0, wspace=0)
        plt.subplots_adjust(hspace=0, top=0.96, bottom=0.1)
                
        fig.add_subplot(111, frameon=False)
        plt.tick_params(labelcolor='none', which='both', top=False, bottom=False, left=False, right=False)
        plt.xlabel("Cumulative Real Counts")
        plt.ylabel("Cumulative Predicted Counts", labelpad=27)
        
        fig.savefig(f"{self._folder}/{name}_qq.pdf")
        plt.close()
        
    def _extract_parameter_names_simple(self):
        self._parameter_names = []
        for full_name in self._source_model.free_parameters.keys():
            source = full_name[ : full_name.find(".")]
            source = source[1:] if source[0]=="_" else source
            source = source.replace("__", "+").replace("_", " ")
            parameter = full_name[-1 * full_name[::-1].find(".") : ]
            self._parameter_names.extend([f"{source} {parameter}"])
    
    def set_folder(self, folder):
        if not folder is None:
            if not os.path.exists(f"./{folder}"):
                os.mkdir(folder)
        self._folder = folder

# %%
def rebin_data_exp(
    bins,
    counts,
    energy_range
):

    if energy_range[0]:
        for i, e in enumerate(bins):
            if e > energy_range[0]:
                bins = bins[i:]
                counts = counts[:,i:] ############should these be the same?
                break
    if energy_range[1]:
        for i, e in enumerate(bins):
            if e > energy_range[1]:
                bins = bins[:i]
                counts = counts[:,:i-1]
                assert i > 1, "Max Energy is too low"
                break
        
    min_counts = 5
    
    max_num_bins = 120
    min_num_bins = 1
    
    finished = False
    
    while not finished:
        num_bins = round((max_num_bins + min_num_bins) / 2)
        
        if num_bins == max_num_bins or num_bins == min_num_bins:
            num_bins = min_num_bins
            finished = True
        
        temp_bins = np.geomspace(bins[0], bins[-1], num_bins+1)
        
        new_bins, new_counts = rebin_closest(bins, counts, temp_bins)
        
        if np.amin(new_counts) < min_counts:
            max_num_bins = num_bins
        else:
            min_num_bins = num_bins
            
    return new_bins, new_counts
    
# @njit
def rebin_closest(bins, counts, temp_bins):
    counts = np.copy(counts)
    closest1 = len(bins) - 1
    for i in range(len(temp_bins)-2, 0, -1):
        closest2 = np.argpartition(
            np.absolute(bins - temp_bins[i]),
            0
        )[0]
        if closest1 - closest2 >= 2:
            counts[:,closest2] += np.sum(counts[:, closest2+1 : closest1], axis=1)
            counts = np.delete(
                counts,
                [j for j in range(closest2+1, closest1)],
                axis=1
            )
            bins = np.delete(
                bins,
                [j for j in range(closest2+1, closest1)]
            )
        closest1 = closest2
    return bins, counts


# counts = np.linspace(1,40,40).reshape((2,20))
# bins = np.linspace(1,21,21)
# temp_bins = np.geomspace(1,21,11)
# b, c = rebin_closest(bins, counts, temp_bins)
# print(bins)
# print(counts)
# print(np.sum(counts, axis=1))
# print(temp_bins)
# print(b)
# print(c)
# print(np.sum(c, axis=1))

# %%
def save_clusters(pointings, folder):
    if not os.path.exists(f"./{folder}"):
        os.mkdir(folder)
    with open(f"./{folder}/pointings.pickle", "wb") as f:
        pickle.dump(pointings, f)
        
def load_clusters(folder):
    with open(f"./{folder}/pointings.pickle", "rb") as f:
        pointings = pickle.load(f)
    return pointings

# %%
def extract_date_range(path):
    with fits.open(f"{path}/pointing.fits") as file:
        t = Table.read(file[1])
        t1 = at.Time(f'{t["TSTART"][0]+2451544.5}', format='jd')
        t1.format = "isot"
        t2 = at.Time(f'{t["TSTOP"][-1]+2451544.5}', format='jd')
        t2.format = "isot"
    return t1.value, t2.value

# %%
class PointingClusters: #add min time diff
    def __init__(
        self,
        orbit_paths,
        min_angle_dif,
        max_angle_dif,
        max_time_dif,
        radius_around_crab,
        min_time_elapsed,
        cluster_size_range,
        random_angle_dif_range=None,
    ):
        self._orbit_paths = orbit_paths
        self._min_angle_dif = min_angle_dif
        self._max_angle_dif = max_angle_dif
        self._max_time_dif = max_time_dif
        self._radius_around_crab = radius_around_crab
        self._min_time_elapsed = min_time_elapsed
        self._cluster_size_range = cluster_size_range
        self._random_angle_dif_range = random_angle_dif_range
        
        pointings = []
        self._get_scw_ids()
        cq = ClusteredQuery(
            self._scw_ids,
            angle_weight=0.,
            time_weight=1./self._max_time_dif,
            max_distance=1.,
            min_ang_distance=self._min_angle_dif,
            max_ang_distance=self._max_angle_dif,
            cluster_size_range = self._cluster_size_range,
            failed_improvements_max=3,
            suboptimal_cluster_size=max(1,self._cluster_size_range[0]),
            close_suboptimal_cluster_size=max(1,self._cluster_size_range[0])
        ).get_clustered_scw_ids()
        
        for size in range(self._cluster_size_range[0], self._cluster_size_range[1] + 1):
            for cluster in cq[size]:
                pointings.append(tuple([(i, f"crab_data/{i[:4]}") for i in cluster]))
                
        self.pointings = tuple(pointings)             
    
    def _get_scw_ids(self, print_results=False):
        p = SkyCoord(83.6333, 22.0144, frame="icrs", unit="deg")
        searchquerry = SearchQuery(position=p, radius=f"{self._radius_around_crab} degree",)
        cat = IntegralQuery(searchquerry)

        scw_ids_all = None
        for path in self._orbit_paths:
            f = Filter(
                SCW_TYPE="POINTING",
                TIME=Range(*extract_date_range(path))
            )
            if scw_ids_all:
                scw_ids_all = np.append(
                    scw_ids_all,
                    cat.apply_filter(f, return_coordinates=True, remove_duplicates=True),
                    axis=0
                )
            else:
                scw_ids_all = cat.apply_filter(f, return_coordinates=True, remove_duplicates=True)
        
        scw_ids = []
        
        multiple_files = []
        no_files = []
        no_pyspi = []
        
        num_dets = 19
        eb = np.geomspace(18, 2000, 5)
        emod = np.geomspace(18, 2000, 5)
        for scw_id in scw_ids_all:
            good = True
            with fits.open(f"{path}/pointing.fits") as file:
                t = Table.read(file[1])
                index = np.argwhere(t["PTID_ISOC"]==scw_id[0][:8])
                
                if len(index) < 1:
                    no_files.append(scw_id)
                    good = False
                    continue
                    
                elif len(index) > 1:
                    multiple_files.append(scw_id)
                    good = False
                                
                pointing_info = t[index[-1][0]]
            
                t1 = at.Time(f'{pointing_info["TSTART"]+2451544.5}', format='jd').datetime
                time_start = datetime.strftime(t1,'%y%m%d %H%M%S')
                                
                with fits.open(f"{path}/dead_time.fits") as file2:
                    t2 = Table.read(file2[1])
                    
                    time_elapsed = np.zeros(num_dets)
                    
                    for i in range(num_dets):
                        for j in index:
                            time_elapsed[i] += t2["LIVETIME"][j[0]*85 + i]
                                
                dets = get_live_dets(time=time_start, event_types=["single"])
                                
                if not np.amin(time_elapsed[dets]) > self._min_time_elapsed:
                    good = False
            
            try: # investigate why this is necessary
                version = find_response_version(time_start)
                rsp = ResponseRMFGenerator.from_time(time_start, dets[0], eb, emod, rsp_bases[version])
            except:
                no_pyspi.append(scw_id)
                good = False
                
            if good:
                scw_ids.append(scw_id)
                
        if print_results:
            print("Multiple Files:")
            print(multiple_files)
            print("No Files:")
            print(no_files)
            print("No PySpi:")
            print(no_pyspi)
            print("Good:")
            print(scw_ids)
        
        self._scw_ids = np.array(scw_ids)

# %%
def define_sources(source_funcs):    
    model = Model()
    for source_func, params in source_funcs:
        source_func(model, *params)
    return model

# %%
def crab_pl_fixed_pos(model, piv):
    ra, dec = 83.6333, 22.0144
    
    pl = Powerlaw()
    pl.piv = piv
    pl.K.prior = Log_uniform_prior(lower_bound=1e-6, upper_bound=1e0)
    pl.index.prior = Uniform_prior(lower_bound=-4, upper_bound=0)
    component1 = SpectralComponent("pl", shape=pl)
    ps = PointSource("Crab", ra=ra, dec=dec, components=[component1])
    
    model.add_source(ps)
    return model

def crab_pl_free_pos(model, piv):
    ra, dec = 83.6333, 22.0144
    angle_range = 5.
    
    pl = Powerlaw()
    pl.piv = piv
    pl.K.prior = Log_uniform_prior(lower_bound=1e-6, upper_bound=1e0)
    pl.index.prior = Uniform_prior(lower_bound=-4, upper_bound=0)
    component1 = SpectralComponent("pl", shape=pl)
    ps = PointSource("Crab", ra=ra, dec=dec, components=[component1])
    ps.position.ra.free = True
    ps.position.ra.prior = Uniform_prior(
        lower_bound = ra - abs(angle_range/np.cos(dec)),
        upper_bound = ra + abs(angle_range/np.cos(dec))
    )
    ps.position.dec.free = True
    ps.position.dec.prior = Uniform_prior(
        lower_bound = dec - angle_range,
        upper_bound = dec + angle_range
    )
    
    model.add_source(ps)
    return model

def _1A_0535_262_pl(model, piv):
    ra, dec = 84.7270, 26.3160
    
    pl = Powerlaw()
    pl.piv = piv
    pl.K.prior = Log_uniform_prior(lower_bound=1e-10, upper_bound=1e0)
    pl.index.prior = Uniform_prior(lower_bound=-4, upper_bound=0)
    component1 = SpectralComponent("pl", shape=pl)
    ps = PointSource("_1A_0535__262", ra=ra, dec=dec, components=[component1])
    
    model.add_source(ps)
    return model

def _4U_0517_17_pl(model, piv):
    ra, dec = 77.6896, 16.4986
    
    pl = Powerlaw()
    pl.piv = piv
    pl.index.min_value = -20.
    pl.K.prior = Log_uniform_prior(lower_bound=1e-10, upper_bound=1e-4)
    pl.index.prior = Uniform_prior(lower_bound=-20, upper_bound=10)
    component1 = SpectralComponent("pl", shape=pl)
    ps = PointSource("_4U_0517__17", ra=ra, dec=dec, components=[component1])
    
    model.add_source(ps)
    return model

def _4U_0614_09_pl(model, piv):
    ra, dec = 94.2800, 9.13700
    
    pl = Powerlaw()
    pl.piv = piv
    pl.index.max_value = 20.
    pl.K.prior = Log_uniform_prior(lower_bound=1e-10, upper_bound=1e-4)
    pl.index.prior = Uniform_prior(lower_bound=-10, upper_bound=20)
    component1 = SpectralComponent("pl", shape=pl)
    ps = PointSource("_4U_0614__09", ra=ra, dec=dec, components=[component1])
    
    model.add_source(ps)
    return model

def geminga_pl(model, piv):
    ra, dec = 98.4750, 17.7670
    
    pl = Powerlaw()
    pl.piv = piv
    pl.index.max_value = 15.
    pl.K.prior = Log_uniform_prior(lower_bound=1e-15, upper_bound=1e-5)
    pl.index.prior = Uniform_prior(lower_bound=-10, upper_bound=15)
    component1 = SpectralComponent("pl", shape=pl)
    ps = PointSource("Geminga", ra=ra, dec=dec, components=[component1])
    
    model.add_source(ps)
    return model

# %%
def true_values(include_position=False):
    piv = 40
    
    crab_parameters = np.array([[9.3, 1, -2.08, 83.6333, 22.0144],
                                [7.52e-4, 100, -1.99, 83.6333, 22.0144],
                                [11.03, 1, -2.1, 83.6333, 22.0144]])
    
    crab_values = np.zeros((len(crab_parameters), len(crab_parameters[0]) - 1))
    crab_values[:,0] = crab_parameters[:,0] * (piv / crab_parameters[:,1])**crab_parameters[:,2]
    crab_values[:,1:] = crab_parameters[:,2:]
    
    names = ["Crab K", "Crab index", "Crab ra", "Crab dec"]
    if include_position:
        crab_values = (names, crab_values)
    else:
        crab_values = (names[:-2], crab_values[:,:-2])
    
    return crab_values

# %%
folder = "orbit_1019"

# pointings = PointingClusters(
#     ("crab_data/1019",),
#     min_angle_dif=1.5,
#     max_angle_dif=4.,
#     max_time_dif=0.2,
#     radius_around_crab=5.,
#     min_time_elapsed=600.,
#     cluster_size_range=(2,2),
# ).pointings
# save_clusters(pointings, folder)

pointings = load_clusters(folder)
source_model = define_sources((
    (crab_pl_fixed_pos, (40,)),
    (_1A_0535_262_pl, (40,)),
))

multinest_fit = MultinestClusterFit(
    pointings,
    source_model,
    (None, 80),
    np.geomspace(18, 150, 50),
    rebin_data_exp,
    true_values=true_values(),
    folder=folder,
)

multinest_fit.parameter_fit_distribution()
multinest_fit.text_summaries()
multinest_fit.ppc()
# Out:
#  *****************************************************
#  MultiNest v3.10
#  Copyright Farhan Feroz & Mike Hobson
#  Release Jul 2015
#
#  no. of live points =  800
#  dimensionality =    4
#  *****************************************************
#  Starting MultiNest
#  generating live points
#  live points generated, starting sampling
# Acceptance Rate:                        0.998825
# Replacements:                                850
# Total Samples:                               851
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999412
# Acceptance Rate:                        0.998890
# Replacements:                                900
# Total Samples:                               901
# Nested Sampling ln(Z):            5172337.139658
# Importance Nested Sampling ln(Z): ************** +/-  0.999445
# Acceptance Rate:                        0.989583
# Replacements:                                950
# Total Samples:                               960
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999479
# Acceptance Rate:                        0.978474
# Replacements:                               1000
# Total Samples:                              1022
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999511
# Acceptance Rate:                        0.958904
# Replacements:                               1050
# Total Samples:                              1095
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999543
# Acceptance Rate:                        0.941781
# Replacements:                               1100
# Total Samples:                              1168
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999572
# Acceptance Rate:                        0.922953
# Replacements:                               1150
# Total Samples:                              1246
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999599
# Acceptance Rate:                        0.911854
# Replacements:                               1200
# Total Samples:                              1316
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999620
# Acceptance Rate:                        0.892220
# Replacements:                               1250
# Total Samples:                              1401
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999643
# Acceptance Rate:                        0.884956
# Replacements:                               1300
# Total Samples:                              1469
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999660
# Acceptance Rate:                        0.877763
# Replacements:                               1350
# Total Samples:                              1538
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999675
# Acceptance Rate:                        0.869565
# Replacements:                               1400
# Total Samples:                              1610
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999689
# Acceptance Rate:                        0.862582
# Replacements:                               1450
# Total Samples:                              1681
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999703
# Acceptance Rate:                        0.858615
# Replacements:                               1500
# Total Samples:                              1747
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999714
# Acceptance Rate:                        0.849781
# Replacements:                               1550
# Total Samples:                              1824
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999726
# Acceptance Rate:                        0.838135
# Replacements:                               1600
# Total Samples:                              1909
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999738
# Acceptance Rate:                        0.830816
# Replacements:                               1650
# Total Samples:                              1986
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999748
# Acceptance Rate:                        0.828864
# Replacements:                               1700
# Total Samples:                              2051
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999756
# Acceptance Rate:                        0.821211
# Replacements:                               1750
# Total Samples:                              2131
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999765
# Acceptance Rate:                        0.814111
# Replacements:                               1800
# Total Samples:                              2211
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999774
# Acceptance Rate:                        0.808920
# Replacements:                               1850
# Total Samples:                              2287
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999781
# Acceptance Rate:                        0.798991
# Replacements:                               1900
# Total Samples:                              2378
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999790
# Acceptance Rate:                        0.794297
# Replacements:                               1950
# Total Samples:                              2455
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999796
# Acceptance Rate:                        0.786782
# Replacements:                               2000
# Total Samples:                              2542
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999803
# Acceptance Rate:                        0.781548
# Replacements:                               2050
# Total Samples:                              2623
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999809
# Acceptance Rate:                        0.778066
# Replacements:                               2100
# Total Samples:                              2699
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999815
# Acceptance Rate:                        0.769506
# Replacements:                               2150
# Total Samples:                              2794
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999821
# Acceptance Rate:                        0.764951
# Replacements:                               2200
# Total Samples:                              2876
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999826
# Acceptance Rate:                        0.758853
# Replacements:                               2250
# Total Samples:                              2965
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999831
# Acceptance Rate:                        0.757576
# Replacements:                               2300
# Total Samples:                              3036
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999835
# Acceptance Rate:                        0.753688
# Replacements:                               2350
# Total Samples:                              3118
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999840
# Acceptance Rate:                        0.750469
# Replacements:                               2400
# Total Samples:                              3198
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999844
# Acceptance Rate:                        0.745587
# Replacements:                               2450
# Total Samples:                              3286
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999848
# Acceptance Rate:                        0.744269
# Replacements:                               2500
# Total Samples:                              3359
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999851
# Acceptance Rate:                        0.741710
# Replacements:                               2550
# Total Samples:                              3438
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999855
# Acceptance Rate:                        0.739266
# Replacements:                               2600
# Total Samples:                              3517
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999858
# Acceptance Rate:                        0.737340
# Replacements:                               2650
# Total Samples:                              3594
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999861
# Acceptance Rate:                        0.733297
# Replacements:                               2700
# Total Samples:                              3682
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999864
# Acceptance Rate:                        0.732162
# Replacements:                               2750
# Total Samples:                              3756
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999867
# Acceptance Rate:                        0.729737
# Replacements:                               2800
# Total Samples:                              3837
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999870
# Acceptance Rate:                        0.726855
# Replacements:                               2850
# Total Samples:                              3921
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999872
# Acceptance Rate:                        0.727364
# Replacements:                               2900
# Total Samples:                              3987
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999875
# Acceptance Rate:                        0.726243
# Replacements:                               2950
# Total Samples:                              4062
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999877
# Acceptance Rate:                        0.722892
# Replacements:                               3000
# Total Samples:                              4150
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999880
# Acceptance Rate:                        0.721381
# Replacements:                               3050
# Total Samples:                              4228
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999882
# Acceptance Rate:                        0.720093
# Replacements:                               3100
# Total Samples:                              4305
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999884
# Acceptance Rate:                        0.719835
# Replacements:                               3150
# Total Samples:                              4376
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999886
# Acceptance Rate:                        0.718133
# Replacements:                               3200
# Total Samples:                              4456
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999888
# Acceptance Rate:                        0.715386
# Replacements:                               3250
# Total Samples:                              4543
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999890
# Acceptance Rate:                        0.712743
# Replacements:                               3300
# Total Samples:                              4630
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999892
# Acceptance Rate:                        0.709595
# Replacements:                               3350
# Total Samples:                              4721
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999894
# Acceptance Rate:                        0.709368
# Replacements:                               3400
# Total Samples:                              4793
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999896
# Acceptance Rate:                        0.707983
# Replacements:                               3450
# Total Samples:                              4873
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999897
# Acceptance Rate:                        0.706928
# Replacements:                               3500
# Total Samples:                              4951
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999899
# Acceptance Rate:                        0.704785
# Replacements:                               3550
# Total Samples:                              5037
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999901
# Acceptance Rate:                        0.704225
# Replacements:                               3600
# Total Samples:                              5112
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999902
# Acceptance Rate:                        0.701249
# Replacements:                               3650
# Total Samples:                              5205
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999904
# Acceptance Rate:                        0.700095
# Replacements:                               3700
# Total Samples:                              5285
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999905
# Acceptance Rate:                        0.699236
# Replacements:                               3750
# Total Samples:                              5363
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999907
# Acceptance Rate:                        0.697888
# Replacements:                               3800
# Total Samples:                              5445
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999908
# Acceptance Rate:                        0.695574
# Replacements:                               3850
# Total Samples:                              5535
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999910
# Acceptance Rate:                        0.694568
# Replacements:                               3900
# Total Samples:                              5615
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999911
# Acceptance Rate:                        0.694444
# Replacements:                               3950
# Total Samples:                              5688
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999912
# Acceptance Rate:                        0.694203
# Replacements:                               4000
# Total Samples:                              5762
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999913
# Acceptance Rate:                        0.691953
# Replacements:                               4050
# Total Samples:                              5853
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999915
# Acceptance Rate:                        0.690120
# Replacements:                               4100
# Total Samples:                              5941
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999916
# Acceptance Rate:                        0.686859
# Replacements:                               4150
# Total Samples:                              6042
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999917
# Acceptance Rate:                        0.686499
# Replacements:                               4200
# Total Samples:                              6118
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999918
# Acceptance Rate:                        0.684821
# Replacements:                               4250
# Total Samples:                              6206
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999919
# Acceptance Rate:                        0.682973
# Replacements:                               4300
# Total Samples:                              6296
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999921
# Acceptance Rate:                        0.682246
# Replacements:                               4350
# Total Samples:                              6376
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999922
# Acceptance Rate:                        0.681009
# Replacements:                               4400
# Total Samples:                              6461
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999923
# Acceptance Rate:                        0.679701
# Replacements:                               4450
# Total Samples:                              6547
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999924
# Acceptance Rate:                        0.679040
# Replacements:                               4500
# Total Samples:                              6627
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999925
# Acceptance Rate:                        0.677890
# Replacements:                               4550
# Total Samples:                              6712
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999926
# Acceptance Rate:                        0.678566
# Replacements:                               4600
# Total Samples:                              6779
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999926
# Acceptance Rate:                        0.677250
# Replacements:                               4650
# Total Samples:                              6866
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999927
# Acceptance Rate:                        0.675967
# Replacements:                               4700
# Total Samples:                              6953
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999928
# Acceptance Rate:                        0.675291
# Replacements:                               4750
# Total Samples:                              7034
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999929
# Acceptance Rate:                        0.674347
# Replacements:                               4800
# Total Samples:                              7118
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999930
# Acceptance Rate:                        0.674736
# Replacements:                               4850
# Total Samples:                              7188
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999930
# Acceptance Rate:                        0.673447
# Replacements:                               4900
# Total Samples:                              7276
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999931
# Acceptance Rate:                        0.673103
# Replacements:                               4950
# Total Samples:                              7354
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999932
# Acceptance Rate:                        0.672766
# Replacements:                               5000
# Total Samples:                              7432
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999933
# Acceptance Rate:                        0.672347
# Replacements:                               5050
# Total Samples:                              7511
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999933
# Acceptance Rate:                        0.671671
# Replacements:                               5100
# Total Samples:                              7593
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999934
# Acceptance Rate:                        0.671622
# Replacements:                               5150
# Total Samples:                              7668
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999935
# Acceptance Rate:                        0.671054
# Replacements:                               5200
# Total Samples:                              7749
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999935
# Acceptance Rate:                        0.670156
# Replacements:                               5250
# Total Samples:                              7834
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999936
# Acceptance Rate:                        0.669699
# Replacements:                               5300
# Total Samples:                              7914
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999937
# Acceptance Rate:                        0.669252
# Replacements:                               5350
# Total Samples:                              7994
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999937
# Acceptance Rate:                        0.669477
# Replacements:                               5400
# Total Samples:                              8066
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999938
# Acceptance Rate:                        0.668630
# Replacements:                               5450
# Total Samples:                              8151
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999939
# Acceptance Rate:                        0.668856
# Replacements:                               5500
# Total Samples:                              8223
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999939
# Acceptance Rate:                        0.668916
# Replacements:                               5550
# Total Samples:                              8297
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999940
# Acceptance Rate:                        0.667620
# Replacements:                               5600
# Total Samples:                              8388
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999940
# Acceptance Rate:                        0.667849
# Replacements:                               5650
# Total Samples:                              8460
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999941
# Acceptance Rate:                        0.667682
# Replacements:                               5700
# Total Samples:                              8537
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999941
# Acceptance Rate:                        0.665972
# Replacements:                               5750
# Total Samples:                              8634
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999942
# Acceptance Rate:                        0.665672
# Replacements:                               5800
# Total Samples:                              8713
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999943
# Acceptance Rate:                        0.665151
# Replacements:                               5850
# Total Samples:                              8795
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999943
# Acceptance Rate:                        0.664639
# Replacements:                               5900
# Total Samples:                              8877
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999944
# Acceptance Rate:                        0.663618
# Replacements:                               5950
# Total Samples:                              8966
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999944
# Acceptance Rate:                        0.663350
# Replacements:                               6000
# Total Samples:                              9045
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999945
# Acceptance Rate:                        0.661781
# Replacements:                               6050
# Total Samples:                              9142
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999945
# Acceptance Rate:                        0.660960
# Replacements:                               6100
# Total Samples:                              9229
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999946
# Acceptance Rate:                        0.661148
# Replacements:                               6150
# Total Samples:                              9302
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999946
# Acceptance Rate:                        0.661051
# Replacements:                               6200
# Total Samples:                              9379
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999947
# Acceptance Rate:                        0.661236
# Replacements:                               6250
# Total Samples:                              9452
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999947
# Acceptance Rate:                        0.660516
# Replacements:                               6300
# Total Samples:                              9538
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999948
# Acceptance Rate:                        0.660015
# Replacements:                               6350
# Total Samples:                              9621
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999948
# Acceptance Rate:                        0.658165
# Replacements:                               6400
# Total Samples:                              9724
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999949
# Acceptance Rate:                        0.657425
# Replacements:                               6450
# Total Samples:                              9811
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999949
# Acceptance Rate:                        0.657495
# Replacements:                               6500
# Total Samples:                              9886
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999949
# Acceptance Rate:                        0.657103
# Replacements:                               6550
# Total Samples:                              9968
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999950
# Acceptance Rate:                        0.657240
# Replacements:                               6600
# Total Samples:                             10042
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999950
# Acceptance Rate:                        0.657050
# Replacements:                               6650
# Total Samples:                             10121
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999951
# Acceptance Rate:                        0.657056
# Replacements:                               6700
# Total Samples:                             10197
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999951
# Acceptance Rate:                        0.656743
# Replacements:                               6750
# Total Samples:                             10278
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999951
# Acceptance Rate:                        0.656878
# Replacements:                               6800
# Total Samples:                             10352
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999952
# Acceptance Rate:                        0.657453
# Replacements:                               6850
# Total Samples:                             10419
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999952
# Acceptance Rate:                        0.656705
# Replacements:                               6900
# Total Samples:                             10507
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999952
# Acceptance Rate:                        0.656341
# Replacements:                               6950
# Total Samples:                             10589
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999953
# Acceptance Rate:                        0.655553
# Replacements:                               7000
# Total Samples:                             10678
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999953
# Acceptance Rate:                        0.654961
# Replacements:                               7050
# Total Samples:                             10764
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999954
# Acceptance Rate:                        0.654800
# Replacements:                               7100
# Total Samples:                             10843
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999954
# Acceptance Rate:                        0.654522
# Replacements:                               7150
# Total Samples:                             10924
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999954
# Acceptance Rate:                        0.653951
# Replacements:                               7200
# Total Samples:                             11010
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999955
# Acceptance Rate:                        0.651217
# Replacements:                               7250
# Total Samples:                             11133
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999955
# Acceptance Rate:                        0.649408
# Replacements:                               7300
# Total Samples:                             11241
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999956
# Acceptance Rate:                        0.647406
# Replacements:                               7350
# Total Samples:                             11353
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999956
# Acceptance Rate:                        0.647023
# Replacements:                               7400
# Total Samples:                             11437
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999956
# Acceptance Rate:                        0.645413
# Replacements:                               7450
# Total Samples:                             11543
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999758
# Acceptance Rate:                        0.644275
# Replacements:                               7500
# Total Samples:                             11641
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999759
# Acceptance Rate:                        0.642991
# Replacements:                               7550
# Total Samples:                             11742
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999759
# Acceptance Rate:                        0.641026
# Replacements:                               7600
# Total Samples:                             11856
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999759
# Acceptance Rate:                        0.639846
# Replacements:                               7650
# Total Samples:                             11956
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999760
# Acceptance Rate:                        0.635576
# Replacements:                               7700
# Total Samples:                             12115
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.910604
# Acceptance Rate:                        0.634051
# Replacements:                               7750
# Total Samples:                             12223
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.910612
# Acceptance Rate:                        0.633271
# Replacements:                               7800
# Total Samples:                             12317
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.910618
# Acceptance Rate:                        0.632503
# Replacements:                               7850
# Total Samples:                             12411
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.910623
# Acceptance Rate:                        0.631798
# Replacements:                               7900
# Total Samples:                             12504
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.910629
# Acceptance Rate:                        0.631002
# Replacements:                               7950
# Total Samples:                             12599
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.910634
# Acceptance Rate:                        0.630567
# Replacements:                               8000
# Total Samples:                             12687
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.910640
# Acceptance Rate:                        0.629841
# Replacements:                               8050
# Total Samples:                             12781
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999961
# Acceptance Rate:                        0.629468
# Replacements:                               8100
# Total Samples:                             12868
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999961
# Acceptance Rate:                        0.628907
# Replacements:                               8150
# Total Samples:                             12959
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999961
# Acceptance Rate:                        0.628112
# Replacements:                               8200
# Total Samples:                             13055
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999961
# Acceptance Rate:                        0.627758
# Replacements:                               8250
# Total Samples:                             13142
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999961
# Acceptance Rate:                        0.627125
# Replacements:                               8300
# Total Samples:                             13235
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999962
# Acceptance Rate:                        0.627065
# Replacements:                               8350
# Total Samples:                             13316
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999962
# Acceptance Rate:                        0.626772
# Replacements:                               8400
# Total Samples:                             13402
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999962
# Acceptance Rate:                        0.626343
# Replacements:                               8450
# Total Samples:                             13491
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999962
# Acceptance Rate:                        0.626197
# Replacements:                               8500
# Total Samples:                             13574
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999963
# Acceptance Rate:                        0.625915
# Replacements:                               8550
# Total Samples:                             13660
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999963
# Acceptance Rate:                        0.626001
# Replacements:                               8600
# Total Samples:                             13738
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999963
# Acceptance Rate:                        0.625904
# Replacements:                               8650
# Total Samples:                             13820
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999963
# Acceptance Rate:                        0.625899
# Replacements:                               8700
# Total Samples:                             13900
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999963
# Acceptance Rate:                        0.625760
# Replacements:                               8750
# Total Samples:                             13983
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999964
# Acceptance Rate:                        0.625800
# Replacements:                               8800
# Total Samples:                             14062
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999964
# Acceptance Rate:                        0.625397
# Replacements:                               8850
# Total Samples:                             14151
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999964
# Acceptance Rate:                        0.625088
# Replacements:                               8900
# Total Samples:                             14238
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999964
# Acceptance Rate:                        0.625437
# Replacements:                               8950
# Total Samples:                             14310
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999964
# Acceptance Rate:                        0.625087
# Replacements:                               9000
# Total Samples:                             14398
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999965
# Acceptance Rate:                        0.624267
# Replacements:                               9050
# Total Samples:                             14497
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999965
# Acceptance Rate:                        0.624442
# Replacements:                               9100
# Total Samples:                             14573
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999965
# Acceptance Rate:                        0.624829
# Replacements:                               9150
# Total Samples:                             14644
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999965
# Acceptance Rate:                        0.625723
# Replacements:                               9200
# Total Samples:                             14703
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999965
# Acceptance Rate:                        0.625761
# Replacements:                               9250
# Total Samples:                             14782
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.905304
# Acceptance Rate:                        0.625799
# Replacements:                               9300
# Total Samples:                             14861
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.905304
# Acceptance Rate:                        0.626088
# Replacements:                               9350
# Total Samples:                             14934
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.905304
# Acceptance Rate:                        0.625541
# Replacements:                               9400
# Total Samples:                             15027
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.905305
# Acceptance Rate:                        0.626492
# Replacements:                               9450
# Total Samples:                             15084
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.905305
# Acceptance Rate:                        0.626525
# Replacements:                               9500
# Total Samples:                             15163
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.905305
# Acceptance Rate:                        0.626764
# Replacements:                               9550
# Total Samples:                             15237
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.905305
# Acceptance Rate:                        0.626877
# Replacements:                               9600
# Total Samples:                             15314
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.907179
# Acceptance Rate:                        0.627520
# Replacements:                               9650
# Total Samples:                             15378
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.907179
# Acceptance Rate:                        0.627954
# Replacements:                               9700
# Total Samples:                             15447
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.907179
# Acceptance Rate:                        0.628060
# Replacements:                               9750
# Total Samples:                             15524
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.907179
# Acceptance Rate:                        0.628326
# Replacements:                               9800
# Total Samples:                             15597
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.907179
# Acceptance Rate:                        0.628509
# Replacements:                               9850
# Total Samples:                             15672
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.907179
# Acceptance Rate:                        0.629051
# Replacements:                               9900
# Total Samples:                             15738
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.907180
# Acceptance Rate:                        0.629349
# Replacements:                               9950
# Total Samples:                             15810
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.907180
# Acceptance Rate:                        0.629763
# Replacements:                              10000
# Total Samples:                             15879
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.907180
# ...
# Acceptance Rate:                        0.665997
# Replacements:                              17250
# Total Samples:                             25901
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.073578
# Acceptance Rate:                        0.665948
# Replacements:                              17300
# Total Samples:                             25978
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.070344
# Acceptance Rate:                        0.666129
# Replacements:                              17350
# Total Samples:                             26046
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.068292
# Acceptance Rate:                        0.666258
# Replacements:                              17400
# Total Samples:                             26116
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.066112
# Acceptance Rate:                        0.666183
# Replacements:                              17450
# Total Samples:                             26194
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.063542
# Acceptance Rate:                        0.666159
# Replacements:                              17500
# Total Samples:                             26270
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.061663
# Acceptance Rate:                        0.666414
# Replacements:                              17550
# Total Samples:                             26335
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.059931
# Acceptance Rate:                        0.666490
# Replacements:                              17600
# Total Samples:                             26407
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.058216
# Acceptance Rate:                        0.666516
# Replacements:                              17650
# Total Samples:                             26481
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.056580
# Acceptance Rate:                        0.666717
# Replacements:                              17700
# Total Samples:                             26548
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.054553
# Acceptance Rate:                        0.666792
# Replacements:                              17750
# Total Samples:                             26620
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.052715
# Acceptance Rate:                        0.666866
# Replacements:                              17800
# Total Samples:                             26692
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.050971
# Acceptance Rate:                        0.666318
# Replacements:                              17850
# Total Samples:                             26789
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.049131
# Acceptance Rate:                        0.666047
# Replacements:                              17900
# Total Samples:                             26875
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.047492
# Acceptance Rate:                        0.666122
# Replacements:                              17950
# Total Samples:                             26947
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.045821
# Acceptance Rate:                        0.666124
# Replacements:                              18000
# Total Samples:                             27022
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.045019
# Acceptance Rate:                        0.665880
# Replacements:                              18050
# Total Samples:                             27107
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.043229
# Acceptance Rate:                        0.665759
# Replacements:                              18100
# Total Samples:                             27187
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.042106
# Acceptance Rate:                        0.665737
# Replacements:                              18150
# Total Samples:                             27263
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.040568
# Acceptance Rate:                        0.665764
# Replacements:                              18200
# Total Samples:                             27337
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.039194
# Acceptance Rate:                        0.665767
# Replacements:                              18250
# Total Samples:                             27412
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.038122
# Acceptance Rate:                        0.665866
# Replacements:                              18300
# Total Samples:                             27483
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.036823
# Acceptance Rate:                        0.666062
# Replacements:                              18350
# Total Samples:                             27550
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.035595
# Acceptance Rate:                        0.666449
# Replacements:                              18400
# Total Samples:                             27609
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.035013
# Acceptance Rate:                        0.666618
# Replacements:                              18450
# Total Samples:                             27677
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.033891
# Acceptance Rate:                        0.666739
# Replacements:                              18500
# Total Samples:                             27747
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.032814
# Acceptance Rate:                        0.666786
# Replacements:                              18550
# Total Samples:                             27820
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.031682
# Acceptance Rate:                        0.667049
# Replacements:                              18600
# Total Samples:                             27884
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.030806
# Acceptance Rate:                        0.667382
# Replacements:                              18650
# Total Samples:                             27945
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.029952
# Acceptance Rate:                        0.667738
# Replacements:                              18700
# Total Samples:                             28005
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.029146
# Acceptance Rate:                        0.667759
# Replacements:                              18750
# Total Samples:                             28079
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.028161
# Acceptance Rate:                        0.667946
# Replacements:                              18800
# Total Samples:                             28146
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.027283
# Acceptance Rate:                        0.668226
# Replacements:                              18850
# Total Samples:                             28209
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.026447
# Acceptance Rate:                        0.668506
# Replacements:                              18900
# Total Samples:                             28272
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.025751
# Acceptance Rate:                        0.668713
# Replacements:                              18950
# Total Samples:                             28338
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.024969
# Acceptance Rate:                        0.668991
# Replacements:                              19000
# Total Samples:                             28401
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.024355
# Acceptance Rate:                        0.669172
# Replacements:                              19050
# Total Samples:                             28468
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.023584
# Acceptance Rate:                        0.669213
# Replacements:                              19100
# Total Samples:                             28541
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.022834
# Acceptance Rate:                        0.669346
# Replacements:                              19150
# Total Samples:                             28610
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.022172
# Acceptance Rate:                        0.669596
# Replacements:                              19200
# Total Samples:                             28674
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.021656
# Acceptance Rate:                        0.669821
# Replacements:                              19250
# Total Samples:                             28739
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.021040
# Acceptance Rate:                        0.669976
# Replacements:                              19300
# Total Samples:                             28807
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.020454
# Acceptance Rate:                        0.670083
# Replacements:                              19350
# Total Samples:                             28877
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.019902
# Acceptance Rate:                        0.670260
# Replacements:                              19400
# Total Samples:                             28944
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.019347
# Acceptance Rate:                        0.670458
# Replacements:                              19450
# Total Samples:                             29010
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.018856
# Acceptance Rate:                        0.670748
# Replacements:                              19500
# Total Samples:                             29072
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.018426
# Acceptance Rate:                        0.670945
# Replacements:                              19550
# Total Samples:                             29138
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.017964
# Acceptance Rate:                        0.671233
# Replacements:                              19600
# Total Samples:                             29200
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.017551
# Acceptance Rate:                        0.671313
# Replacements:                              19650
# Total Samples:                             29271
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.017112
# Acceptance Rate:                        0.671278
# Replacements:                              19700
# Total Samples:                             29347
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.016661
# Acceptance Rate:                        0.671472
# Replacements:                              19750
# Total Samples:                             29413
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.016304
# Acceptance Rate:                        0.671323
# Replacements:                              19800
# Total Samples:                             29494
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.015877
# Acceptance Rate:                        0.671606
# Replacements:                              19850
# Total Samples:                             29556
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.015587
# Acceptance Rate:                        0.671843
# Replacements:                              19900
# Total Samples:                             29620
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.015302
# Acceptance Rate:                        0.672238
# Replacements:                              19950
# Total Samples:                             29677
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.015071
# Acceptance Rate:                        0.672382
# Replacements:                              20000
# Total Samples:                             29745
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.014795
# Acceptance Rate:                        0.672706
# Replacements:                              20050
# Total Samples:                             29805
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.014579
# Acceptance Rate:                        0.672826
# Replacements:                              20100
# Total Samples:                             29874
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.014338
# Acceptance Rate:                        0.672968
# Replacements:                              20150
# Total Samples:                             29942
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.014125
# Acceptance Rate:                        0.673087
# Replacements:                              20200
# Total Samples:                             30011
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.013917
# Acceptance Rate:                        0.673087
# Replacements:                              20233
# Total Samples:                             30060
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.013779
#  ln(ev)=   50323307.596470840      +/-  0.14965032578563739
#  Total Likelihood Evaluations:        30060
#  Sampling finished. Exiting MultiNest

# %%
folder = "triple_1019"

# save_clusters(
#     ((('101900550010', "crab_data/1019"), ('101900590010', "crab_data/1019"), ('101900600010', "crab_data/1019")),),
#     folder
# )

pointings = load_clusters(folder)
source_model = define_sources((
    (crab_pl_fixed_pos, (40,)),
    (_1A_0535_262_pl, (40,)),
))

multinest_fit = MultinestClusterFit(
    pointings,
    source_model,
    (None, 80),
    np.geomspace(18, 150, 50),
    rebin_data_exp,
    true_values=true_values(),
    folder=folder,
)

multinest_fit.parameter_fit_distribution()
multinest_fit.text_summaries()
multinest_fit.ppc()
# Out:
#  *****************************************************
#  MultiNest v3.10
#  Copyright Farhan Feroz & Mike Hobson
#  Release Jul 2015
#
#  no. of live points =  800
#  dimensionality =    4
#  *****************************************************
#  Starting MultiNest
#  generating live points
#  live points generated, starting sampling
# Acceptance Rate:                        0.994152
# Replacements:                                850
# Total Samples:                               855
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): 6375212.611014 +/-  0.999415
# Acceptance Rate:                        0.991189
# Replacements:                                900
# Total Samples:                               908
# Nested Sampling ln(Z):            -618895.344040
# Importance Nested Sampling ln(Z): 6375212.550871 +/-  0.999449
# Acceptance Rate:                        0.980392
# Replacements:                                950
# Total Samples:                               969
# Nested Sampling ln(Z):            3115620.912452
# Importance Nested Sampling ln(Z): 6375212.485851 +/-  0.999484
# Acceptance Rate:                        0.970874
# Replacements:                               1000
# Total Samples:                              1030
# Nested Sampling ln(Z):            4795283.479906
# Importance Nested Sampling ln(Z): 6375212.424802 +/-  0.999514
# Acceptance Rate:                        0.958029
# Replacements:                               1050
# Total Samples:                              1096
# Nested Sampling ln(Z):            5602421.499194
# Importance Nested Sampling ln(Z): 6375212.362693 +/-  0.999544
# Acceptance Rate:                        0.948276
# Replacements:                               1100
# Total Samples:                              1160
# Nested Sampling ln(Z):            6074700.887860
# Importance Nested Sampling ln(Z): 6375212.305940 +/-  0.999569
# Acceptance Rate:                        0.930421
# Replacements:                               1150
# Total Samples:                              1236
# Nested Sampling ln(Z):            6253752.645861
# Importance Nested Sampling ln(Z): 6375212.242480 +/-  0.999595
# Acceptance Rate:                        0.918133
# Replacements:                               1200
# Total Samples:                              1307
# Nested Sampling ln(Z):            6331843.750434
# Importance Nested Sampling ln(Z): 6375212.186626 +/-  0.999617
# Acceptance Rate:                        0.905797
# Replacements:                               1250
# Total Samples:                              1380
# Nested Sampling ln(Z):            6359714.150217
# Importance Nested Sampling ln(Z): 6375212.108366 +/-  0.999638
# Acceptance Rate:                        0.898411
# Replacements:                               1300
# Total Samples:                              1447
# Nested Sampling ln(Z):            6367566.814682
# Importance Nested Sampling ln(Z): 6375212.013299 +/-  0.999654
# Acceptance Rate:                        0.889328
# Replacements:                               1350
# Total Samples:                              1518
# Nested Sampling ln(Z):            6371591.417796
# Importance Nested Sampling ln(Z): 6375211.921071 +/-  0.999671
# Acceptance Rate:                        0.870647
# Replacements:                               1400
# Total Samples:                              1608
# Nested Sampling ln(Z):            6372707.821809
# Importance Nested Sampling ln(Z): 6375211.821796 +/-  0.999689
# Acceptance Rate:                        0.866189
# Replacements:                               1450
# Total Samples:                              1674
# Nested Sampling ln(Z):            6372755.532120
# Importance Nested Sampling ln(Z): 6375211.738029 +/-  0.999701
# Acceptance Rate:                        0.862069
# Replacements:                               1500
# Total Samples:                              1740
# Nested Sampling ln(Z):            6372756.579984
# Importance Nested Sampling ln(Z): 6375211.658769 +/-  0.999713
# Acceptance Rate:                        0.857301
# Replacements:                               1550
# Total Samples:                              1808
# Nested Sampling ln(Z):            6372757.555063
# Importance Nested Sampling ln(Z): 6375211.582630 +/-  0.999723
# Acceptance Rate:                        0.845666
# Replacements:                               1600
# Total Samples:                              1892
# Nested Sampling ln(Z):            6372759.083123
# Importance Nested Sampling ln(Z): 6375211.485333 +/-  0.999736
# Acceptance Rate:                        0.837563
# Replacements:                               1650
# Total Samples:                              1970
# Nested Sampling ln(Z):            6372761.237027
# Importance Nested Sampling ln(Z): 6375211.402444 +/-  0.999746
# Acceptance Rate:                        0.829673
# Replacements:                               1700
# Total Samples:                              2049
# Nested Sampling ln(Z):            6372764.450394
# Importance Nested Sampling ln(Z): 6375211.310619 +/-  0.999756
# Acceptance Rate:                        0.827032
# Replacements:                               1750
# Total Samples:                              2116
# Nested Sampling ln(Z):            6372769.060842
# Importance Nested Sampling ln(Z): 6375211.238893 +/-  0.999764
# Acceptance Rate:                        0.822293
# Replacements:                               1800
# Total Samples:                              2189
# Nested Sampling ln(Z):            6372774.034579
# Importance Nested Sampling ln(Z): 6375211.166815 +/-  0.999772
# Acceptance Rate:                        0.813544
# Replacements:                               1850
# Total Samples:                              2274
# Nested Sampling ln(Z):            6372780.678368
# Importance Nested Sampling ln(Z): 6375211.088776 +/-  0.999780
# Acceptance Rate:                        0.805085
# Replacements:                               1900
# Total Samples:                              2360
# Nested Sampling ln(Z):            6372788.928014
# Importance Nested Sampling ln(Z): 6375211.010025 +/-  0.999788
# Acceptance Rate:                        0.800821
# Replacements:                               1950
# Total Samples:                              2435
# Nested Sampling ln(Z):            6372797.927306
# Importance Nested Sampling ln(Z): 6375210.938015 +/-  0.999795
# Acceptance Rate:                        0.795229
# Replacements:                               2000
# Total Samples:                              2515
# Nested Sampling ln(Z):            6372807.874096
# Importance Nested Sampling ln(Z): 6375210.871570 +/-  0.999801
# Acceptance Rate:                        0.791506
# Replacements:                               2050
# Total Samples:                              2590
# Nested Sampling ln(Z):            6372819.638015
# Importance Nested Sampling ln(Z): 6375210.804640 +/-  0.999807
# Acceptance Rate:                        0.788881
# Replacements:                               2100
# Total Samples:                              2662
# Nested Sampling ln(Z):            6372834.432178
# Importance Nested Sampling ln(Z): 6375210.743509 +/-  0.999812
# Acceptance Rate:                        0.786969
# Replacements:                               2150
# Total Samples:                              2732
# Nested Sampling ln(Z):            6372846.071692
# Importance Nested Sampling ln(Z): 6375210.673613 +/-  0.999817
# Acceptance Rate:                        0.784593
# Replacements:                               2200
# Total Samples:                              2804
# Nested Sampling ln(Z):            6372857.859956
# Importance Nested Sampling ln(Z): 6375210.609039 +/-  0.999822
# Acceptance Rate:                        0.779356
# Replacements:                               2250
# Total Samples:                              2887
# Nested Sampling ln(Z):            6372870.134719
# Importance Nested Sampling ln(Z): 6375210.547110 +/-  0.999827
# Acceptance Rate:                        0.773890
# Replacements:                               2300
# Total Samples:                              2972
# Nested Sampling ln(Z):            6372881.542889
# Importance Nested Sampling ln(Z): 6375210.473130 +/-  0.999832
# Acceptance Rate:                        0.764476
# Replacements:                               2350
# Total Samples:                              3074
# Nested Sampling ln(Z):            6372896.819370
# Importance Nested Sampling ln(Z): 6375210.381391 +/-  0.999837
# Acceptance Rate:                        0.761663
# Replacements:                               2400
# Total Samples:                              3151
# Nested Sampling ln(Z):            6372911.104204
# Importance Nested Sampling ln(Z): 6375210.316579 +/-  0.999841
# Acceptance Rate:                        0.758279
# Replacements:                               2450
# Total Samples:                              3231
# Nested Sampling ln(Z):            6372923.874498
# Importance Nested Sampling ln(Z): 6375210.244284 +/-  0.999845
# Acceptance Rate:                        0.753466
# Replacements:                               2500
# Total Samples:                              3318
# Nested Sampling ln(Z):            6372935.836343
# Importance Nested Sampling ln(Z): 6375210.169911 +/-  0.999849
# Acceptance Rate:                        0.749779
# Replacements:                               2550
# Total Samples:                              3401
# Nested Sampling ln(Z):            6372947.941729
# Importance Nested Sampling ln(Z): 6375210.105525 +/-  0.999853
# Acceptance Rate:                        0.747556
# Replacements:                               2600
# Total Samples:                              3478
# Nested Sampling ln(Z):            6372962.407505
# Importance Nested Sampling ln(Z): 6375210.047054 +/-  0.999856
# Acceptance Rate:                        0.741674
# Replacements:                               2650
# Total Samples:                              3573
# Nested Sampling ln(Z):            6372976.963254
# Importance Nested Sampling ln(Z): 6375209.968784 +/-  0.999860
# Acceptance Rate:                        0.735695
# Replacements:                               2700
# Total Samples:                              3670
# Nested Sampling ln(Z):            6372988.383866
# Importance Nested Sampling ln(Z): 6375209.883357 +/-  0.999864
# Acceptance Rate:                        0.736476
# Replacements:                               2750
# Total Samples:                              3734
# Nested Sampling ln(Z):            6373001.039324
# Importance Nested Sampling ln(Z): 6375209.830997 +/-  0.999866
# Acceptance Rate:                        0.732218
# Replacements:                               2800
# Total Samples:                              3824
# Nested Sampling ln(Z):            6373013.054343
# Importance Nested Sampling ln(Z): 6375209.756563 +/-  0.999869
# Acceptance Rate:                        0.731520
# Replacements:                               2850
# Total Samples:                              3896
# Nested Sampling ln(Z):            6373022.064126
# Importance Nested Sampling ln(Z): 6375209.699375 +/-  0.999872
# Acceptance Rate:                        0.726999
# Replacements:                               2900
# Total Samples:                              3989
# Nested Sampling ln(Z):            6373035.421245
# Importance Nested Sampling ln(Z): 6375209.629925 +/-  0.999875
# Acceptance Rate:                        0.724282
# Replacements:                               2950
# Total Samples:                              4073
# Nested Sampling ln(Z):            6373046.076366
# Importance Nested Sampling ln(Z): 6375209.561072 +/-  0.999877
# Acceptance Rate:                        0.721848
# Replacements:                               3000
# Total Samples:                              4156
# Nested Sampling ln(Z):            6373055.586298
# Importance Nested Sampling ln(Z): 6375209.494673 +/-  0.999880
# Acceptance Rate:                        0.720699
# Replacements:                               3050
# Total Samples:                              4232
# Nested Sampling ln(Z):            6373063.366937
# Importance Nested Sampling ln(Z): 6375209.432887 +/-  0.999882
# Acceptance Rate:                        0.719759
# Replacements:                               3100
# Total Samples:                              4307
# Nested Sampling ln(Z):            6373084.829034
# Importance Nested Sampling ln(Z): 6375209.372427 +/-  0.999884
# Acceptance Rate:                        0.715746
# Replacements:                               3150
# Total Samples:                              4401
# Nested Sampling ln(Z):            6373116.863230
# Importance Nested Sampling ln(Z): 6375209.300387 +/-  0.999886
# Acceptance Rate:                        0.714126
# Replacements:                               3200
# Total Samples:                              4481
# Nested Sampling ln(Z):            6373145.920621
# Importance Nested Sampling ln(Z): 6375267.865557 +/-  0.999888
# Acceptance Rate:                        0.714600
# Replacements:                               3250
# Total Samples:                              4548
# Nested Sampling ln(Z):            6373173.718627
# Importance Nested Sampling ln(Z): 6375267.803230 +/-  0.999890
# Acceptance Rate:                        0.714595
# Replacements:                               3300
# Total Samples:                              4618
# Nested Sampling ln(Z):            6373211.072519
# Importance Nested Sampling ln(Z): 6375267.745918 +/-  0.999892
# Acceptance Rate:                        0.713677
# Replacements:                               3350
# Total Samples:                              4694
# Nested Sampling ln(Z):            6373247.578947
# Importance Nested Sampling ln(Z): 6375267.681637 +/-  0.999893
# Acceptance Rate:                        0.712340
# Replacements:                               3400
# Total Samples:                              4773
# Nested Sampling ln(Z):            6373277.610551
# Importance Nested Sampling ln(Z): 6375267.615329 +/-  0.999895
# Acceptance Rate:                        0.711194
# Replacements:                               3450
# Total Samples:                              4851
# Nested Sampling ln(Z):            6373306.801621
# Importance Nested Sampling ln(Z): 6375267.548524 +/-  0.999897
# Acceptance Rate:                        0.709220
# Replacements:                               3500
# Total Samples:                              4935
# Nested Sampling ln(Z):            6373336.400688
# Importance Nested Sampling ln(Z): 6375267.479839 +/-  0.999899
# Acceptance Rate:                        0.709149
# Replacements:                               3550
# Total Samples:                              5006
# Nested Sampling ln(Z):            6373368.521521
# Importance Nested Sampling ln(Z): 6375267.424209 +/-  0.999900
# Acceptance Rate:                        0.707547
# Replacements:                               3600
# Total Samples:                              5088
# Nested Sampling ln(Z):            6373408.670859
# Importance Nested Sampling ln(Z): 6375267.363227 +/-  0.999902
# Acceptance Rate:                        0.707090
# Replacements:                               3650
# Total Samples:                              5162
# Nested Sampling ln(Z):            6373448.186695
# Importance Nested Sampling ln(Z): 6375267.309874 +/-  0.999903
# Acceptance Rate:                        0.707457
# Replacements:                               3700
# Total Samples:                              5230
# Nested Sampling ln(Z):            6373485.504210
# Importance Nested Sampling ln(Z): 6375267.259626 +/-  0.999904
# Acceptance Rate:                        0.706082
# Replacements:                               3750
# Total Samples:                              5311
# Nested Sampling ln(Z):            6373521.360071
# Importance Nested Sampling ln(Z): 6375267.195606 +/-  0.999906
# Acceptance Rate:                        0.705664
# Replacements:                               3800
# Total Samples:                              5385
# Nested Sampling ln(Z):            6373563.519184
# Importance Nested Sampling ln(Z): 6375267.137447 +/-  0.999907
# Acceptance Rate:                        0.705257
# Replacements:                               3850
# Total Samples:                              5459
# Nested Sampling ln(Z):            6373603.593394
# Importance Nested Sampling ln(Z): 6375290.044098 +/-  0.999908
# Acceptance Rate:                        0.705627
# Replacements:                               3900
# Total Samples:                              5527
# Nested Sampling ln(Z):            6373630.785568
# Importance Nested Sampling ln(Z): 6375289.987193 +/-  0.999910
# Acceptance Rate:                        0.704979
# Replacements:                               3950
# Total Samples:                              5603
# Nested Sampling ln(Z):            6373661.791976
# Importance Nested Sampling ln(Z): 6375289.925735 +/-  0.999911
# Acceptance Rate:                        0.702988
# Replacements:                               4000
# Total Samples:                              5690
# Nested Sampling ln(Z):            6373687.779097
# Importance Nested Sampling ln(Z): 6375289.847918 +/-  0.999912
# Acceptance Rate:                        0.702759
# Replacements:                               4050
# Total Samples:                              5763
# Nested Sampling ln(Z):            6373717.189213
# Importance Nested Sampling ln(Z): 6375289.788922 +/-  0.999913
# Acceptance Rate:                        0.702295
# Replacements:                               4100
# Total Samples:                              5838
# Nested Sampling ln(Z):            6373743.684508
# Importance Nested Sampling ln(Z): 6375289.727240 +/-  0.999914
# Acceptance Rate:                        0.702437
# Replacements:                               4150
# Total Samples:                              5908
# Nested Sampling ln(Z):            6373771.962661
# Importance Nested Sampling ln(Z): 6375289.673250 +/-  0.999915
# Acceptance Rate:                        0.701754
# Replacements:                               4200
# Total Samples:                              5985
# Nested Sampling ln(Z):            6373800.545891
# Importance Nested Sampling ln(Z): 6375289.608018 +/-  0.999916
# ERROR: Interrupt received: Terminating
# Exception ignored on calling ctypes callback function: <function run.<locals>.loglike at 0x7f8dacdd8820>
# Traceback (most recent call last):
#   File "/home/moej56153/.pyenv/versions/MT/lib/python3.9/site-packages/pymultinest/run.py", line 221, in loglike
#     return LogLikelihood(cube, ndim, nparams)
#   File "/tmp/ipykernel_342/2937187804.py", line 48, in logLba_mult
#   File "/home/moej56153/.pyenv/versions/MT/lib/python3.9/site-packages/pymultinest/run.py", line 70, in interrupt_handler
#     sys.exit(1)
# SystemExit: 1
# Acceptance Rate:                        0.699934
# Replacements:                               4250
# Total Samples:                              6072
# Nested Sampling ln(Z):            6373819.642252
# Importance Nested Sampling ln(Z): 6375289.539037 +/-  0.999918
# Acceptance Rate:                        0.697712
# Replacements:                               4300
# Total Samples:                              6163
# Nested Sampling ln(Z):            6373840.524432
# Importance Nested Sampling ln(Z): 6375289.460006 +/-  0.999919
# Acceptance Rate:                        0.697227
# Replacements:                               4350
# Total Samples:                              6239
# Nested Sampling ln(Z):            6373860.068280
# Importance Nested Sampling ln(Z): 6375289.398077 +/-  0.999920
# Acceptance Rate:                        0.695872
# Replacements:                               4400
# Total Samples:                              6323
# Nested Sampling ln(Z):            6373874.234335
# Importance Nested Sampling ln(Z): 6375289.330098 +/-  0.999921
# Acceptance Rate:                        0.695204
# Replacements:                               4450
# Total Samples:                              6401
# Nested Sampling ln(Z):            6373888.318353
# Importance Nested Sampling ln(Z): 6375289.266763 +/-  0.999922
# Acceptance Rate:                        0.695625
# Replacements:                               4500
# Total Samples:                              6469
# Nested Sampling ln(Z):            6373903.258747
# Importance Nested Sampling ln(Z): 6375289.210807 +/-  0.999923
# Acceptance Rate:                        0.695187
# Replacements:                               4550
# Total Samples:                              6545
# Nested Sampling ln(Z):            6373914.985496
# Importance Nested Sampling ln(Z): 6375317.215781 +/-  0.999924
# Acceptance Rate:                        0.694235
# Replacements:                               4600
# Total Samples:                              6626
# Nested Sampling ln(Z):            6373924.722894
# Importance Nested Sampling ln(Z): 6375317.152105 +/-  0.999925
# Acceptance Rate:                        0.692996
# Replacements:                               4650
# Total Samples:                              6710
# Nested Sampling ln(Z):            6373933.197052
# Importance Nested Sampling ln(Z): 6375317.083708 +/-  0.999925
# Acceptance Rate:                        0.692194
# Replacements:                               4700
# Total Samples:                              6790
# Nested Sampling ln(Z):            6373952.916345
# Importance Nested Sampling ln(Z): 6375317.021304 +/-  0.999926
# Acceptance Rate:                        0.691110
# Replacements:                               4750
# Total Samples:                              6873
# Nested Sampling ln(Z):            6373981.635178
# Importance Nested Sampling ln(Z): 6375316.951689 +/-  0.999927
# Acceptance Rate:                        0.689556
# Replacements:                               4800
# Total Samples:                              6961
# Nested Sampling ln(Z):            6374014.466432
# Importance Nested Sampling ln(Z): 6375316.880930 +/-  0.999928
# Acceptance Rate:                        0.688236
# Replacements:                               4850
# Total Samples:                              7047
# Nested Sampling ln(Z):            6374046.893401
# Importance Nested Sampling ln(Z): 6375316.813712 +/-  0.999929
# Acceptance Rate:                        0.687430
# Replacements:                               4900
# Total Samples:                              7128
# Nested Sampling ln(Z):            6374073.633217
# Importance Nested Sampling ln(Z): 6375316.749732 +/-  0.999930
# Acceptance Rate:                        0.687500
# Replacements:                               4950
# Total Samples:                              7200
# Nested Sampling ln(Z):            6374105.620902
# Importance Nested Sampling ln(Z): 6375316.691773 +/-  0.999931
# Acceptance Rate:                        0.686248
# Replacements:                               5000
# Total Samples:                              7286
# Nested Sampling ln(Z):            6374131.869989
# Importance Nested Sampling ln(Z): 6375316.645115 +/-  0.981125
# Acceptance Rate:                        0.684839
# Replacements:                               5050
# Total Samples:                              7374
# Nested Sampling ln(Z):            6374163.802237
# Importance Nested Sampling ln(Z): 6375316.572031 +/-  0.981125
# Acceptance Rate:                        0.683463
# Replacements:                               5100
# Total Samples:                              7462
# Nested Sampling ln(Z):            6374198.416315
# Importance Nested Sampling ln(Z): 6375316.501427 +/-  0.981124
# Acceptance Rate:                        0.682210
# Replacements:                               5150
# Total Samples:                              7549
# Nested Sampling ln(Z):            6374228.794309
# Importance Nested Sampling ln(Z): 6375316.435891 +/-  0.981124
# Acceptance Rate:                        0.681163
# Replacements:                               5200
# Total Samples:                              7634
# Nested Sampling ln(Z):            6374260.978310
# Importance Nested Sampling ln(Z): 6375316.364671 +/-  0.981123
# Acceptance Rate:                        0.681199
# Replacements:                               5250
# Total Samples:                              7707
# Nested Sampling ln(Z):            6374285.214397
# Importance Nested Sampling ln(Z): 6375316.303960 +/-  0.981123
# Acceptance Rate:                        0.680622
# Replacements:                               5300
# Total Samples:                              7787
# Nested Sampling ln(Z):            6374314.914206
# Importance Nested Sampling ln(Z): 6375320.407485 +/-  0.984557
# Acceptance Rate:                        0.679365
# Replacements:                               5350
# Total Samples:                              7875
# Nested Sampling ln(Z):            6374350.009763
# Importance Nested Sampling ln(Z): 6375320.336890 +/-  0.984557
# Acceptance Rate:                        0.678989
# Replacements:                               5400
# Total Samples:                              7953
# Nested Sampling ln(Z):            6374379.097822
# Importance Nested Sampling ln(Z): 6375320.277843 +/-  0.984558
# Acceptance Rate:                        0.678198
# Replacements:                               5450
# Total Samples:                              8036
# Nested Sampling ln(Z):            6374412.857676
# Importance Nested Sampling ln(Z): 6375320.212143 +/-  0.984558
# Acceptance Rate:                        0.677423
# Replacements:                               5500
# Total Samples:                              8119
# Nested Sampling ln(Z):            6374444.418114
# Importance Nested Sampling ln(Z): 6375320.145738 +/-  0.984559
# Acceptance Rate:                        0.675923
# Replacements:                               5550
# Total Samples:                              8211
# Nested Sampling ln(Z):            6374470.229246
# Importance Nested Sampling ln(Z): 6375320.075553 +/-  0.984559
# Acceptance Rate:                        0.672996
# Replacements:                               5600
# Total Samples:                              8321
# Nested Sampling ln(Z):            6374501.484432
# Importance Nested Sampling ln(Z): 6375319.995860 +/-  0.984560
# Acceptance Rate:                        0.671500
# Replacements:                               5650
# Total Samples:                              8414
# Nested Sampling ln(Z):            6374523.549957
# Importance Nested Sampling ln(Z): 6375319.932662 +/-  0.984561
# Acceptance Rate:                        0.669879
# Replacements:                               5700
# Total Samples:                              8509
# Nested Sampling ln(Z):            6374551.608801
# Importance Nested Sampling ln(Z): 6375319.868176 +/-  0.984561
# Acceptance Rate:                        0.668527
# Replacements:                               5750
# Total Samples:                              8601
# Nested Sampling ln(Z):            6374570.468854
# Importance Nested Sampling ln(Z): 6375323.091904 +/-  0.963193
# Acceptance Rate:                        0.667203
# Replacements:                               5800
# Total Samples:                              8693
# Nested Sampling ln(Z):            6374590.460390
# Importance Nested Sampling ln(Z): 6375323.037039 +/-  0.963195
# Acceptance Rate:                        0.666135
# Replacements:                               5850
# Total Samples:                              8782
# Nested Sampling ln(Z):            6374608.704915
# Importance Nested Sampling ln(Z): 6375322.986150 +/-  0.963196
# Acceptance Rate:                        0.662921
# Replacements:                               5900
# Total Samples:                              8900
# Nested Sampling ln(Z):            6374634.578739
# Importance Nested Sampling ln(Z): 6375322.916529 +/-  0.963184
# Acceptance Rate:                        0.663100
# Replacements:                               5950
# Total Samples:                              8973
# Nested Sampling ln(Z):            6374654.838759
# Importance Nested Sampling ln(Z): 6375322.865551 +/-  0.963186
# Acceptance Rate:                        0.662179
# Replacements:                               6000
# Total Samples:                              9061
# Nested Sampling ln(Z):            6374679.266348
# Importance Nested Sampling ln(Z): 6375322.798505 +/-  0.963187
# Acceptance Rate:                        0.661347
# Replacements:                               6050
# Total Samples:                              9148
# Nested Sampling ln(Z):            6374699.439523
# Importance Nested Sampling ln(Z): 6375322.732841 +/-  0.963189
# Acceptance Rate:                        0.661175
# Replacements:                               6100
# Total Samples:                              9226
# Nested Sampling ln(Z):            6374716.544141
# Importance Nested Sampling ln(Z): 6375322.676046 +/-  0.963190
# Acceptance Rate:                        0.660225
# Replacements:                               6150
# Total Samples:                              9315
# Nested Sampling ln(Z):            6374740.035132
# Importance Nested Sampling ln(Z): 6375322.614694 +/-  0.963191
# Acceptance Rate:                        0.659645
# Replacements:                               6200
# Total Samples:                              9399
# Nested Sampling ln(Z):            6374758.446248
# Importance Nested Sampling ln(Z): 6375328.128947 +/-  0.996141
# Acceptance Rate:                        0.658866
# Replacements:                               6250
# Total Samples:                              9486
# Nested Sampling ln(Z):            6374776.688601
# Importance Nested Sampling ln(Z): 6375328.060014 +/-  0.996142
# Acceptance Rate:                        0.657277
# Replacements:                               6300
# Total Samples:                              9585
# Nested Sampling ln(Z):            6374794.322502
# Importance Nested Sampling ln(Z): 6375335.171697 +/-  0.999193
# Acceptance Rate:                        0.656127
# Replacements:                               6350
# Total Samples:                              9678
# Nested Sampling ln(Z):            6374810.791642
# Importance Nested Sampling ln(Z): 6375335.103258 +/-  0.998911
# Acceptance Rate:                        0.654798
# Replacements:                               6400
# Total Samples:                              9774
# Nested Sampling ln(Z):            6374826.899843
# Importance Nested Sampling ln(Z): 6375335.035794 +/-  0.998912
# Acceptance Rate:                        0.652900
# Replacements:                               6450
# Total Samples:                              9879
# Nested Sampling ln(Z):            6374838.665464
# Importance Nested Sampling ln(Z): 6375334.964198 +/-  0.998912
# Acceptance Rate:                        0.650390
# Replacements:                               6500
# Total Samples:                              9994
# Nested Sampling ln(Z):            6374850.592193
# Importance Nested Sampling ln(Z): 6375334.924562 +/-  0.965077
# Acceptance Rate:                        0.648708
# Replacements:                               6550
# Total Samples:                             10097
# Nested Sampling ln(Z):            6374864.529987
# Importance Nested Sampling ln(Z): 6375334.862937 +/-  0.962970
# Acceptance Rate:                        0.646678
# Replacements:                               6600
# Total Samples:                             10206
# Nested Sampling ln(Z):            6374883.165296
# Importance Nested Sampling ln(Z): 6375334.802727 +/-  0.960788
# Acceptance Rate:                        0.644005
# Replacements:                               6650
# Total Samples:                             10326
# Nested Sampling ln(Z):            6374895.050319
# Importance Nested Sampling ln(Z): 6375337.510530 +/-  0.939268
# Acceptance Rate:                        0.642008
# Replacements:                               6700
# Total Samples:                             10436
# Nested Sampling ln(Z):            6374906.963544
# Importance Nested Sampling ln(Z): 6375337.508455 +/-  0.941020
# Acceptance Rate:                        0.639265
# Replacements:                               6750
# Total Samples:                             10559
# Nested Sampling ln(Z):            6374919.223341
# Importance Nested Sampling ln(Z): 6375337.505136 +/-  0.943954
# Acceptance Rate:                        0.637301
# Replacements:                               6800
# Total Samples:                             10670
# Nested Sampling ln(Z):            6374930.574291
# Importance Nested Sampling ln(Z): 6375337.502648 +/-  0.946168
# Acceptance Rate:                        0.635436
# Replacements:                               6850
# Total Samples:                             10780
# Nested Sampling ln(Z):            6374943.898385
# Importance Nested Sampling ln(Z): 6375337.500677 +/-  0.947930
# Acceptance Rate:                        0.633725
# Replacements:                               6900
# Total Samples:                             10888
# Nested Sampling ln(Z):            6374957.511770
# Importance Nested Sampling ln(Z): 6375361.068925 +/-  0.999954
# Acceptance Rate:                        0.632048
# Replacements:                               6950
# Total Samples:                             10996
# Nested Sampling ln(Z):            6374968.483056
# Importance Nested Sampling ln(Z): 6375361.025222 +/-  0.999955
# Acceptance Rate:                        0.630460
# Replacements:                               7000
# Total Samples:                             11103
# Nested Sampling ln(Z):            6374978.205393
# Importance Nested Sampling ln(Z): 6375360.983450 +/-  0.999951
# Acceptance Rate:                        0.629127
# Replacements:                               7050
# Total Samples:                             11206
# Nested Sampling ln(Z):            6374985.247936
# Importance Nested Sampling ln(Z): 6375360.943098 +/-  0.999952
# Acceptance Rate:                        0.626434
# Replacements:                               7100
# Total Samples:                             11334
# Nested Sampling ln(Z):            6374996.049093
# Importance Nested Sampling ln(Z): 6375360.893113 +/-  0.999952
# Acceptance Rate:                        0.623800
# Replacements:                               7150
# Total Samples:                             11462
# Nested Sampling ln(Z):            6375006.605864
# Importance Nested Sampling ln(Z): 6375360.839381 +/-  0.999953
# Acceptance Rate:                        0.621601
# Replacements:                               7200
# Total Samples:                             11583
# Nested Sampling ln(Z):            6375015.214184
# Importance Nested Sampling ln(Z): 6375360.779808 +/-  0.999953
# Acceptance Rate:                        0.619076
# Replacements:                               7250
# Total Samples:                             11711
# Nested Sampling ln(Z):            6375026.020803
# Importance Nested Sampling ln(Z): 6375360.747746 +/-  0.974242
# Acceptance Rate:                        0.618225
# Replacements:                               7300
# Total Samples:                             11808
# Nested Sampling ln(Z):            6375033.687247
# Importance Nested Sampling ln(Z): 6375360.708402 +/-  0.974242
# Acceptance Rate:                        0.616249
# Replacements:                               7350
# Total Samples:                             11927
# Nested Sampling ln(Z):            6375043.004462
# Importance Nested Sampling ln(Z): 6375360.660372 +/-  0.974242
# Acceptance Rate:                        0.613192
# Replacements:                               7400
# Total Samples:                             12068
# Nested Sampling ln(Z):            6375053.430468
# Importance Nested Sampling ln(Z): 6375360.604718 +/-  0.974242
# Acceptance Rate:                        0.612060
# Replacements:                               7450
# Total Samples:                             12172
# Nested Sampling ln(Z):            6375062.442322
# Importance Nested Sampling ln(Z): 6375360.554832 +/-  0.974242
# Acceptance Rate:                        0.611197
# Replacements:                               7500
# Total Samples:                             12271
# Nested Sampling ln(Z):            6375068.427432
# Importance Nested Sampling ln(Z): 6375360.507292 +/-  0.974238
# Acceptance Rate:                        0.610545
# Replacements:                               7550
# Total Samples:                             12366
# Nested Sampling ln(Z):            6375075.591135
# Importance Nested Sampling ln(Z): 6375360.469969 +/-  0.965979
# Acceptance Rate:                        0.609267
# Replacements:                               7600
# Total Samples:                             12474
# Nested Sampling ln(Z):            6375083.493233
# Importance Nested Sampling ln(Z): 6375360.444610 +/-  0.938122
# Acceptance Rate:                        0.609125
# Replacements:                               7650
# Total Samples:                             12559
# Nested Sampling ln(Z):            6375092.301234
# Importance Nested Sampling ln(Z): 6375360.393801 +/-  0.938122
# Acceptance Rate:                        0.609033
# Replacements:                               7700
# Total Samples:                             12643
# Nested Sampling ln(Z):            6375100.917919
# Importance Nested Sampling ln(Z): 6375360.343928 +/-  0.938122
# Acceptance Rate:                        0.608750
# Replacements:                               7750
# Total Samples:                             12731
# Nested Sampling ln(Z):            6375108.245387
# Importance Nested Sampling ln(Z): 6375360.292927 +/-  0.938122
# Acceptance Rate:                        0.608045
# Replacements:                               7800
# Total Samples:                             12828
# Nested Sampling ln(Z):            6375115.601750
# Importance Nested Sampling ln(Z): 6375360.237585 +/-  0.938122
# Acceptance Rate:                        0.607397
# Replacements:                               7850
# Total Samples:                             12924
# Nested Sampling ln(Z):            6375124.878590
# Importance Nested Sampling ln(Z): 6375360.182766 +/-  0.938122
# Acceptance Rate:                        0.607039
# Replacements:                               7900
# Total Samples:                             13014
# Nested Sampling ln(Z):            6375133.024621
# Importance Nested Sampling ln(Z): 6375360.130287 +/-  0.938122
# Acceptance Rate:                        0.606778
# Replacements:                               7950
# Total Samples:                             13102
# Nested Sampling ln(Z):            6375138.986500
# Importance Nested Sampling ln(Z): 6375360.081442 +/-  0.938107
# Acceptance Rate:                        0.605602
# Replacements:                               8000
# Total Samples:                             13210
# Nested Sampling ln(Z):            6375145.044434
# Importance Nested Sampling ln(Z): 6375360.021222 +/-  0.938107
# Acceptance Rate:                        0.605354
# Replacements:                               8050
# Total Samples:                             13298
# Nested Sampling ln(Z):            6375151.907961
# Importance Nested Sampling ln(Z): 6375359.980094 +/-  0.928573
# Acceptance Rate:                        0.604703
# Replacements:                               8100
# Total Samples:                             13395
# Nested Sampling ln(Z):            6375158.121268
# Importance Nested Sampling ln(Z): 6375359.924269 +/-  0.928573
# Acceptance Rate:                        0.603436
# Replacements:                               8150
# Total Samples:                             13506
# Nested Sampling ln(Z):            6375164.503053
# Importance Nested Sampling ln(Z): 6375359.855436 +/-  0.928550
# Acceptance Rate:                        0.603030
# Replacements:                               8200
# Total Samples:                             13598
# Nested Sampling ln(Z):            6375171.191466
# Importance Nested Sampling ln(Z): 6375359.791402 +/-  0.928549
# Acceptance Rate:                        0.602982
# Replacements:                               8250
# Total Samples:                             13682
# Nested Sampling ln(Z):            6375176.928770
# Importance Nested Sampling ln(Z): 6375359.736091 +/-  0.928544
# Acceptance Rate:                        0.602410
# Replacements:                               8300
# Total Samples:                             13778
# Nested Sampling ln(Z):            6375183.017729
# Importance Nested Sampling ln(Z): 6375359.677760 +/-  0.925940
# Acceptance Rate:                        0.602366
# Replacements:                               8350
# Total Samples:                             13862
# Nested Sampling ln(Z):            6375187.652486
# Importance Nested Sampling ln(Z): 6375359.626190 +/-  0.925875
# Acceptance Rate:                        0.602885
# Replacements:                               8400
# Total Samples:                             13933
# Nested Sampling ln(Z):            6375191.496225
# Importance Nested Sampling ln(Z): 6375359.902583 +/-  0.720845
# Acceptance Rate:                        0.602667
# Replacements:                               8450
# Total Samples:                             14021
# Nested Sampling ln(Z):            6375195.534977
# Importance Nested Sampling ln(Z): 6375359.843143 +/-  0.720845
# Acceptance Rate:                        0.602239
# Replacements:                               8500
# Total Samples:                             14114
# Nested Sampling ln(Z):            6375200.223067
# Importance Nested Sampling ln(Z): 6375359.783943 +/-  0.720845
# Acceptance Rate:                        0.601943
# Replacements:                               8550
# Total Samples:                             14204
# Nested Sampling ln(Z):            6375204.337420
# Importance Nested Sampling ln(Z): 6375359.725134 +/-  0.720689
# Acceptance Rate:                        0.601693
# Replacements:                               8600
# Total Samples:                             14293
# Nested Sampling ln(Z):            6375209.453537
# Importance Nested Sampling ln(Z): 6375359.663759 +/-  0.720679
# Acceptance Rate:                        0.601028
# Replacements:                               8650
# Total Samples:                             14392
# Nested Sampling ln(Z):            6375215.763775
# Importance Nested Sampling ln(Z): 6375359.596637 +/-  0.720677
# Acceptance Rate:                        0.601119
# Replacements:                               8700
# Total Samples:                             14473
# Nested Sampling ln(Z):            6375219.979227
# Importance Nested Sampling ln(Z): 6375359.537905 +/-  0.720676
# Acceptance Rate:                        0.600796
# Replacements:                               8750
# Total Samples:                             14564
# Nested Sampling ln(Z):            6375224.869852
# Importance Nested Sampling ln(Z): 6375359.474953 +/-  0.720639
# Acceptance Rate:                        0.600150
# Replacements:                               8800
# Total Samples:                             14663
# Nested Sampling ln(Z):            6375229.536989
# Importance Nested Sampling ln(Z): 6375359.410637 +/-  0.720639
# Acceptance Rate:                        0.600611
# Replacements:                               8850
# Total Samples:                             14735
# Nested Sampling ln(Z):            6375233.737915
# Importance Nested Sampling ln(Z): 6375359.357530 +/-  0.720142
# Acceptance Rate:                        0.601067
# Replacements:                               8900
# Total Samples:                             14807
# Nested Sampling ln(Z):            6375237.108606
# Importance Nested Sampling ln(Z): 6375359.304110 +/-  0.715059
# Acceptance Rate:                        0.601155
# Replacements:                               8950
# Total Samples:                             14888
# Nested Sampling ln(Z):            6375241.061750
# Importance Nested Sampling ln(Z): 6375359.240080 +/-  0.713925
# Acceptance Rate:                        0.601443
# Replacements:                               9000
# Total Samples:                             14964
# Nested Sampling ln(Z):            6375244.675973
# Importance Nested Sampling ln(Z): 6375359.177369 +/-  0.713925
# Acceptance Rate:                        0.602129
# Replacements:                               9050
# Total Samples:                             15030
# Nested Sampling ln(Z):            6375248.208082
# Importance Nested Sampling ln(Z): 6375360.819692 +/-  0.826683
# Acceptance Rate:                        0.602769
# Replacements:                               9100
# Total Samples:                             15097
# Nested Sampling ln(Z):            6375251.755936
# Importance Nested Sampling ln(Z): 6375360.875559 +/-  0.748151
# Acceptance Rate:                        0.602727
# Replacements:                               9150
# Total Samples:                             15181
# Nested Sampling ln(Z):            6375254.959700
# Importance Nested Sampling ln(Z): 6375360.808673 +/-  0.748152
# Acceptance Rate:                        0.603120
# Replacements:                               9200
# Total Samples:                             15254
# Nested Sampling ln(Z):            6375257.812917
# Importance Nested Sampling ln(Z): 6375361.581821 +/-  0.631838
# Acceptance Rate:                        0.603313
# Replacements:                               9250
# Total Samples:                             15332
# Nested Sampling ln(Z):            6375260.588413
# Importance Nested Sampling ln(Z): 6375361.551732 +/-  0.612490
# Acceptance Rate:                        0.603857
# Replacements:                               9300
# Total Samples:                             15401
# Nested Sampling ln(Z):            6375263.799066
# Importance Nested Sampling ln(Z): 6375361.499751 +/-  0.612481
# Acceptance Rate:                        0.604083
# Replacements:                               9350
# Total Samples:                             15478
# Nested Sampling ln(Z):            6375267.020103
# Importance Nested Sampling ln(Z): 6375361.762436 +/-  0.522122
# Acceptance Rate:                        0.604463
# Replacements:                               9400
# Total Samples:                             15551
# Nested Sampling ln(Z):            6375270.360954
# Importance Nested Sampling ln(Z): 6375361.704311 +/-  0.522053
# Acceptance Rate:                        0.604761
# Replacements:                               9450
# Total Samples:                             15626
# Nested Sampling ln(Z):            6375272.732110
# Importance Nested Sampling ln(Z): 6375361.639024 +/-  0.522053
# Acceptance Rate:                        0.605288
# Replacements:                               9500
# Total Samples:                             15695
# Nested Sampling ln(Z):            6375275.843629
# Importance Nested Sampling ln(Z): 6375361.579312 +/-  0.522031
# Acceptance Rate:                        0.605657
# Replacements:                               9550
# Total Samples:                             15768
# Nested Sampling ln(Z):            6375278.341941
# Importance Nested Sampling ln(Z): 6375361.682155 +/-  0.462620
# Acceptance Rate:                        0.606405
# Replacements:                               9600
# Total Samples:                             15831
# Nested Sampling ln(Z):            6375281.086697
# Importance Nested Sampling ln(Z): 6375361.629135 +/-  0.462132
# Acceptance Rate:                        0.606842
# Replacements:                               9650
# Total Samples:                             15902
# Nested Sampling ln(Z):            6375284.000319
# Importance Nested Sampling ln(Z): 6375361.566882 +/-  0.462131
# Acceptance Rate:                        0.606857
# Replacements:                               9700
# Total Samples:                             15984
# Nested Sampling ln(Z):            6375286.684115
# Importance Nested Sampling ln(Z): 6375361.494929 +/-  0.462130
# Acceptance Rate:                        0.607666
# Replacements:                               9750
# Total Samples:                             16045
# Nested Sampling ln(Z):            6375289.091877
# Importance Nested Sampling ln(Z): 6375361.441286 +/-  0.462130
# Acceptance Rate:                        0.607978
# Replacements:                               9800
# Total Samples:                             16119
# Nested Sampling ln(Z):            6375291.714742
# Importance Nested Sampling ln(Z): 6375361.376172 +/-  0.462130
# Acceptance Rate:                        0.608062
# Replacements:                               9850
# Total Samples:                             16199
# Nested Sampling ln(Z):            6375294.056355
# Importance Nested Sampling ln(Z): 6375361.326399 +/-  0.454013
# Acceptance Rate:                        0.608444
# Replacements:                               9900
# Total Samples:                             16271
# Nested Sampling ln(Z):            6375296.421703
# ...
# Total Samples:                             16747
# Nested Sampling ln(Z):            6375308.062937
# Importance Nested Sampling ln(Z): 6375361.028685 +/-  0.405594
# Acceptance Rate:                        0.609394
# Replacements:                              10250
# Total Samples:                             16820
# Nested Sampling ln(Z):            6375309.722750
# Importance Nested Sampling ln(Z): 6375360.973529 +/-  0.404093
# Acceptance Rate:                        0.609179
# Replacements:                              10300
# Total Samples:                             16908
# Nested Sampling ln(Z):            6375311.218364
# Importance Nested Sampling ln(Z): 6375360.906593 +/-  0.404066
# Acceptance Rate:                        0.609254
# Replacements:                              10350
# Total Samples:                             16988
# Nested Sampling ln(Z):            6375313.161518
# Importance Nested Sampling ln(Z): 6375360.840899 +/-  0.403916
# Acceptance Rate:                        0.609363
# Replacements:                              10400
# Total Samples:                             17067
# Nested Sampling ln(Z):            6375314.824619
# Importance Nested Sampling ln(Z): 6375360.788124 +/-  0.398088
# Acceptance Rate:                        0.609365
# Replacements:                              10450
# Total Samples:                             17149
# Nested Sampling ln(Z):            6375316.463833
# Importance Nested Sampling ln(Z): 6375360.731029 +/-  0.392986
# Acceptance Rate:                        0.609473
# Replacements:                              10500
# Total Samples:                             17228
# Nested Sampling ln(Z):            6375318.257612
# Importance Nested Sampling ln(Z): 6375360.669918 +/-  0.390595
# Acceptance Rate:                        0.609298
# Replacements:                              10550
# Total Samples:                             17315
# Nested Sampling ln(Z):            6375319.847972
# Importance Nested Sampling ln(Z): 6375360.597364 +/-  0.390174
# Acceptance Rate:                        0.609896
# Replacements:                              10600
# Total Samples:                             17380
# Nested Sampling ln(Z):            6375321.136848
# Importance Nested Sampling ln(Z): 6375360.616550 +/-  0.369027
# Acceptance Rate:                        0.610140
# Replacements:                              10650
# Total Samples:                             17455
# Nested Sampling ln(Z):            6375322.531350
# Importance Nested Sampling ln(Z): 6375360.555971 +/-  0.367934
# Acceptance Rate:                        0.610208
# Replacements:                              10700
# Total Samples:                             17535
# Nested Sampling ln(Z):            6375323.858586
# Importance Nested Sampling ln(Z): 6375360.539414 +/-  0.351394
# Acceptance Rate:                        0.609894
# Replacements:                              10750
# Total Samples:                             17626
# Nested Sampling ln(Z):            6375325.083148
# Importance Nested Sampling ln(Z): 6375360.481053 +/-  0.345371
# Acceptance Rate:                        0.609997
# Replacements:                              10800
# Total Samples:                             17705
# Nested Sampling ln(Z):            6375326.183591
# Importance Nested Sampling ln(Z): 6375360.420374 +/-  0.343689
# Acceptance Rate:                        0.610168
# Replacements:                              10850
# Total Samples:                             17782
# Nested Sampling ln(Z):            6375327.295864
# Importance Nested Sampling ln(Z): 6375360.478374 +/-  0.314940
# Acceptance Rate:                        0.610200
# Replacements:                              10900
# Total Samples:                             17863
# Nested Sampling ln(Z):            6375328.324054
# Importance Nested Sampling ln(Z): 6375360.430199 +/-  0.309480
# Acceptance Rate:                        0.610572
# Replacements:                              10950
# Total Samples:                             17934
# Nested Sampling ln(Z):            6375329.303503
# Importance Nested Sampling ln(Z): 6375360.400112 +/-  0.301541
# Acceptance Rate:                        0.610602
# Replacements:                              11000
# Total Samples:                             18015
# Nested Sampling ln(Z):            6375330.174157
# Importance Nested Sampling ln(Z): 6375360.350301 +/-  0.296840
# Acceptance Rate:                        0.610666
# Replacements:                              11050
# Total Samples:                             18095
# Nested Sampling ln(Z):            6375331.036736
# Importance Nested Sampling ln(Z): 6375360.311103 +/-  0.290485
# Acceptance Rate:                        0.610796
# Replacements:                              11100
# Total Samples:                             18173
# Nested Sampling ln(Z):            6375332.002982
# Importance Nested Sampling ln(Z): 6375360.279219 +/-  0.282487
# Acceptance Rate:                        0.610892
# Replacements:                              11150
# Total Samples:                             18252
# Nested Sampling ln(Z):            6375333.023477
# Importance Nested Sampling ln(Z): 6375360.223083 +/-  0.280806
# Acceptance Rate:                        0.610854
# Replacements:                              11200
# Total Samples:                             18335
# Nested Sampling ln(Z):            6375334.093979
# Importance Nested Sampling ln(Z): 6375360.177170 +/-  0.275425
# Acceptance Rate:                        0.610948
# Replacements:                              11250
# Total Samples:                             18414
# Nested Sampling ln(Z):            6375335.140520
# Importance Nested Sampling ln(Z): 6375360.113890 +/-  0.275259
# Acceptance Rate:                        0.610778
# Replacements:                              11300
# Total Samples:                             18501
# Nested Sampling ln(Z):            6375336.052082
# Importance Nested Sampling ln(Z): 6375360.195528 +/-  0.268486
# Acceptance Rate:                        0.611069
# Replacements:                              11350
# Total Samples:                             18574
# Nested Sampling ln(Z):            6375336.843762
# Importance Nested Sampling ln(Z): 6375360.165506 +/-  0.261892
# Acceptance Rate:                        0.611162
# Replacements:                              11400
# Total Samples:                             18653
# Nested Sampling ln(Z):            6375337.620797
# Importance Nested Sampling ln(Z): 6375360.531355 +/-  0.309937
# Acceptance Rate:                        0.611449
# Replacements:                              11450
# Total Samples:                             18726
# Nested Sampling ln(Z):            6375338.428055
# Importance Nested Sampling ln(Z): 6375360.482570 +/-  0.306568
# Acceptance Rate:                        0.611279
# Replacements:                              11500
# Total Samples:                             18813
# Nested Sampling ln(Z):            6375339.187364
# Importance Nested Sampling ln(Z): 6375360.580751 +/-  0.297141
# Acceptance Rate:                        0.611694
# Replacements:                              11550
# Total Samples:                             18882
# Nested Sampling ln(Z):            6375339.924942
# Importance Nested Sampling ln(Z): 6375360.553029 +/-  0.289494
# Acceptance Rate:                        0.611976
# Replacements:                              11600
# Total Samples:                             18955
# Nested Sampling ln(Z):            6375340.628144
# Importance Nested Sampling ln(Z): 6375360.505259 +/-  0.286148
# Acceptance Rate:                        0.612191
# Replacements:                              11650
# Total Samples:                             19030
# Nested Sampling ln(Z):            6375341.303073
# Importance Nested Sampling ln(Z): 6375360.575000 +/-  0.267760
# Acceptance Rate:                        0.612565
# Replacements:                              11700
# Total Samples:                             19100
# Nested Sampling ln(Z):            6375341.943422
# Importance Nested Sampling ln(Z): 6375360.824024 +/-  0.321833
# Acceptance Rate:                        0.612905
# Replacements:                              11750
# Total Samples:                             19171
# Nested Sampling ln(Z):            6375342.597965
# Importance Nested Sampling ln(Z): 6375360.865566 +/-  0.298873
# Acceptance Rate:                        0.612796
# Replacements:                              11800
# Total Samples:                             19256
# Nested Sampling ln(Z):            6375343.231347
# Importance Nested Sampling ln(Z): 6375360.894532 +/-  0.276321
# Acceptance Rate:                        0.613291
# Replacements:                              11850
# Total Samples:                             19322
# Nested Sampling ln(Z):            6375343.868673
# Importance Nested Sampling ln(Z): 6375360.904373 +/-  0.264397
# Acceptance Rate:                        0.613529
# Replacements:                              11900
# Total Samples:                             19396
# Nested Sampling ln(Z):            6375344.481738
# Importance Nested Sampling ln(Z): 6375360.902391 +/-  0.253729
# Acceptance Rate:                        0.613355
# Replacements:                              11950
# Total Samples:                             19483
# Nested Sampling ln(Z):            6375345.067005
# Importance Nested Sampling ln(Z): 6375360.871792 +/-  0.245084
# Acceptance Rate:                        0.613654
# Replacements:                              12000
# Total Samples:                             19555
# Nested Sampling ln(Z):            6375345.577878
# Importance Nested Sampling ln(Z): 6375360.875128 +/-  0.234251
# Acceptance Rate:                        0.613919
# Replacements:                              12050
# Total Samples:                             19628
# Nested Sampling ln(Z):            6375346.060090
# Importance Nested Sampling ln(Z): 6375360.931877 +/-  0.216319
# Acceptance Rate:                        0.614588
# Replacements:                              12100
# Total Samples:                             19688
# Nested Sampling ln(Z):            6375346.555241
# Importance Nested Sampling ln(Z): 6375360.948702 +/-  0.204441
# Acceptance Rate:                        0.614910
# Replacements:                              12150
# Total Samples:                             19759
# Nested Sampling ln(Z):            6375347.043343
# Importance Nested Sampling ln(Z): 6375360.910098 +/-  0.200538
# Acceptance Rate:                        0.615198
# Replacements:                              12200
# Total Samples:                             19831
# Nested Sampling ln(Z):            6375347.516176
# Importance Nested Sampling ln(Z): 6375360.867662 +/-  0.197101
# Acceptance Rate:                        0.615145
# Replacements:                              12250
# Total Samples:                             19914
# Nested Sampling ln(Z):            6375347.987142
# Importance Nested Sampling ln(Z): 6375360.882544 +/-  0.186983
# Acceptance Rate:                        0.615585
# Replacements:                              12300
# Total Samples:                             19981
# Nested Sampling ln(Z):            6375348.447179
# Importance Nested Sampling ln(Z): 6375360.912972 +/-  0.184713
# Acceptance Rate:                        0.615622
# Replacements:                              12350
# Total Samples:                             20061
# Nested Sampling ln(Z):            6375348.950677
# Importance Nested Sampling ln(Z): 6375360.900461 +/-  0.177091
# Acceptance Rate:                        0.615446
# Replacements:                              12400
# Total Samples:                             20148
# Nested Sampling ln(Z):            6375349.406685
# Importance Nested Sampling ln(Z): 6375360.988967 +/-  0.185102
# Acceptance Rate:                        0.615666
# Replacements:                              12450
# Total Samples:                             20222
# Nested Sampling ln(Z):            6375349.849845
# Importance Nested Sampling ln(Z): 6375361.045291 +/-  0.180879
# Acceptance Rate:                        0.615824
# Replacements:                              12500
# Total Samples:                             20298
# Nested Sampling ln(Z):            6375350.268785
# Importance Nested Sampling ln(Z): 6375361.111504 +/-  0.168489
# Acceptance Rate:                        0.615770
# Replacements:                              12550
# Total Samples:                             20381
# Nested Sampling ln(Z):            6375350.687114
# Importance Nested Sampling ln(Z): 6375361.103408 +/-  0.161938
# Acceptance Rate:                        0.615836
# Replacements:                              12600
# Total Samples:                             20460
# Nested Sampling ln(Z):            6375351.065612
# Importance Nested Sampling ln(Z): 6375361.073113 +/-  0.157422
# Acceptance Rate:                        0.615841
# Replacements:                              12650
# Total Samples:                             20541
# Nested Sampling ln(Z):            6375351.439850
# Importance Nested Sampling ln(Z): 6375361.048866 +/-  0.152220
# Acceptance Rate:                        0.616086
# Replacements:                              12700
# Total Samples:                             20614
# Nested Sampling ln(Z):            6375351.817272
# Importance Nested Sampling ln(Z): 6375361.181696 +/-  0.149052
# Acceptance Rate:                        0.616448
# Replacements:                              12750
# Total Samples:                             20683
# Nested Sampling ln(Z):            6375352.179775
# Importance Nested Sampling ln(Z): 6375361.175561 +/-  0.144574
# Acceptance Rate:                        0.616778
# Replacements:                              12800
# Total Samples:                             20753
# Nested Sampling ln(Z):            6375352.521406
# Importance Nested Sampling ln(Z): 6375361.181389 +/-  0.138388
# Acceptance Rate:                        0.616928
# Replacements:                              12850
# Total Samples:                             20829
# Nested Sampling ln(Z):            6375352.855708
# Importance Nested Sampling ln(Z): 6375361.226161 +/-  0.139056
# Acceptance Rate:                        0.617018
# Replacements:                              12900
# Total Samples:                             20907
# Nested Sampling ln(Z):            6375353.169601
# Importance Nested Sampling ln(Z): 6375361.175527 +/-  0.137247
# Acceptance Rate:                        0.616931
# Replacements:                              12950
# Total Samples:                             20991
# Nested Sampling ln(Z):            6375353.470774
# Importance Nested Sampling ln(Z): 6375361.197464 +/-  0.132833
# Acceptance Rate:                        0.616581
# Replacements:                              13000
# Total Samples:                             21084
# Nested Sampling ln(Z):            6375353.748285
# Importance Nested Sampling ln(Z): 6375361.159393 +/-  0.128953
# Acceptance Rate:                        0.616730
# Replacements:                              13050
# Total Samples:                             21160
# Nested Sampling ln(Z):            6375354.023764
# Importance Nested Sampling ln(Z): 6375361.181337 +/-  0.123069
# Acceptance Rate:                        0.616732
# Replacements:                              13100
# Total Samples:                             21241
# Nested Sampling ln(Z):            6375354.289647
# Importance Nested Sampling ln(Z): 6375361.219082 +/-  0.116808
# Acceptance Rate:                        0.616965
# Replacements:                              13150
# Total Samples:                             21314
# Nested Sampling ln(Z):            6375354.545625
# Importance Nested Sampling ln(Z): 6375361.234516 +/-  0.111105
# Acceptance Rate:                        0.616909
# Replacements:                              13200
# Total Samples:                             21397
# Nested Sampling ln(Z):            6375354.791628
# Importance Nested Sampling ln(Z): 6375361.225476 +/-  0.107083
# Acceptance Rate:                        0.617025
# Replacements:                              13250
# Total Samples:                             21474
# Nested Sampling ln(Z):            6375355.023134
# Importance Nested Sampling ln(Z): 6375361.201856 +/-  0.104957

# %%
folder = "orbit_1019_extended"

# pointings = PointingClusters(
#     ("crab_data/1019",),
#     min_angle_dif=1.5,
#     max_angle_dif=4.,
#     max_time_dif=0.2,
#     radius_around_crab=5.,
#     min_time_elapsed=600.,
#     cluster_size_range=(2,2),
# ).pointings
# save_clusters(pointings, folder)

pointings = load_clusters(folder)
source_model = define_sources((
    (crab_pl_free_pos, (40,)),
    (_1A_0535_262_pl, (40,)),
    (geminga_pl, (40,)),
    (_4U_0517_17_pl, (40,)),
    (_4U_0614_09_pl, (40,)),
))

multinest_fit = MultinestClusterFit(
    pointings,
    source_model,
    (None, 80),
    np.geomspace(18, 150, 50),
    rebin_data_exp,
    true_values=true_values(),
    folder=folder,
)

multinest_fit.parameter_fit_distribution()
multinest_fit.text_summaries()
multinest_fit.ppc()
# Out:
#  *****************************************************
#  MultiNest v3.10
#  Copyright Farhan Feroz & Mike Hobson
#  Release Jul 2015
#
#  no. of live points =  800
#  dimensionality =   12
#  *****************************************************
#  Starting MultiNest
#  generating live points
#  live points generated, starting sampling
# Acceptance Rate:                        0.997653
# Replacements:                                850
# Total Samples:                               852
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999413
# Acceptance Rate:                        0.994475
# Replacements:                                900
# Total Samples:                               905
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999447
# Acceptance Rate:                        0.988554
# Replacements:                                950
# Total Samples:                               961
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999480
# Acceptance Rate:                        0.980392
# Replacements:                               1000
# Total Samples:                              1020
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999510
# Acceptance Rate:                        0.962420
# Replacements:                               1050
# Total Samples:                              1091
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999542
# Acceptance Rate:                        0.945830
# Replacements:                               1100
# Total Samples:                              1163
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999570
# Acceptance Rate:                        0.925181
# Replacements:                               1150
# Total Samples:                              1243
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999598
# ERROR: Interrupt received: Terminating
# Exception ignored on calling ctypes callback function: <function run.<locals>.loglike at 0x7f37743ef310>
# Traceback (most recent call last):
#   File "/home/moej56153/.pyenv/versions/MT/lib/python3.9/site-packages/pymultinest/run.py", line 221, in loglike
#     return LogLikelihood(cube, ndim, nparams)
#   File "/tmp/ipykernel_326/1986421315.py", line 47, in logLba_mult
#   File "/tmp/ipykernel_326/1986421315.py", line 219, in _update_resp_mats
#   File "/tmp/ipykernel_326/3405850027.py", line 11, in generate_resp_mat
#   File "/home/moej56153/.pyenv/versions/MT/lib/python3.9/site-packages/pyspi/utils/response/spi_drm.py", line 18, in __init__
#     self._drm_generator.set_location(ra, dec)
#   File "/home/moej56153/.pyenv/versions/MT/lib/python3.9/site-packages/pyspi/utils/response/spi_response.py", line 282, in set_location
#     self._recalculate_response()
#   File "/home/moej56153/.pyenv/versions/MT/lib/python3.9/site-packages/pyspi/utils/response/spi_response.py", line 686, in _recalculate_response
#     self._transpose_matrix = mat1+mat2+(interph*self._ph_matrix.T).T
#   File "/home/moej56153/.pyenv/versions/MT/lib/python3.9/site-packages/pymultinest/run.py", line 70, in interrupt_handler
#     sys.exit(1)
# SystemExit: 1
# Acceptance Rate:                        0.916730
# Replacements:                               1200
# Total Samples:                              1309
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999618
# Acceptance Rate:                        0.899928
# Replacements:                               1250
# Total Samples:                              1389
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999640
# Acceptance Rate:                        0.890411
# Replacements:                               1300
# Total Samples:                              1460
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999657
# Acceptance Rate:                        0.886991
# Replacements:                               1350
# Total Samples:                              1522
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.999671

# %%
folder = "movable_crab_1644_pair"

# save_clusters(
#     ((('164400150010', "crab_data/1644"), ('164400220010', "crab_data/1644")),),
#     folder
# )

pointings = load_clusters(folder)
source_model = define_sources((
    (crab_pl_free_pos, (40,)),
))

multinest_fit = MultinestClusterFit(
    pointings,
    source_model,
    (None, 80),
    np.geomspace(18, 150, 50),
    rebin_data_exp,
    true_values=true_values(),
    folder=folder,
)

multinest_fit.parameter_fit_distribution()
multinest_fit.text_summaries()
multinest_fit.ppc()
# Out:
#  *****************************************************
#  MultiNest v3.10
#  Copyright Farhan Feroz & Mike Hobson
#  Release Jul 2015
#
#  no. of live points =  800
#  dimensionality =    4
#  *****************************************************
#  Starting MultiNest
#  generating live points
#  live points generated, starting sampling
# Acceptance Rate:                        0.995316
# Replacements:                                850
# Total Samples:                               854
# Nested Sampling ln(Z):            -441291.759004
# Importance Nested Sampling ln(Z): 3534231.838453 +/-  0.999414
# Acceptance Rate:                        0.990099
# Replacements:                                900
# Total Samples:                               909
# Nested Sampling ln(Z):            2320782.623115
# Importance Nested Sampling ln(Z): 3534231.776039 +/-  0.999450
# Acceptance Rate:                        0.980392
# Replacements:                                950
# Total Samples:                               969
# Nested Sampling ln(Z):            3138310.427967
# Importance Nested Sampling ln(Z): 3534231.712119 +/-  0.999484
# Acceptance Rate:                        0.967118
# Replacements:                               1000
# Total Samples:                              1034
# Nested Sampling ln(Z):            3426222.936976
# Importance Nested Sampling ln(Z): 3534231.647194 +/-  0.999516
# Acceptance Rate:                        0.955414
# Replacements:                               1050
# Total Samples:                              1099
# Nested Sampling ln(Z):            3503645.907004
# Importance Nested Sampling ln(Z): 3534231.586228 +/-  0.999545
# Acceptance Rate:                        0.933786
# Replacements:                               1100
# Total Samples:                              1178
# Nested Sampling ln(Z):            3527898.291725
# Importance Nested Sampling ln(Z): 3534231.516811 +/-  0.999575
# Acceptance Rate:                        0.916335
# Replacements:                               1150
# Total Samples:                              1255
# Nested Sampling ln(Z):            3531990.359696
# Importance Nested Sampling ln(Z): 3534231.453493 +/-  0.999602
# Acceptance Rate:                        0.890208
# Replacements:                               1200
# Total Samples:                              1348
# Nested Sampling ln(Z):            3533138.178107
# Importance Nested Sampling ln(Z): 3534231.382007 +/-  0.999629
# Acceptance Rate:                        0.872296
# Replacements:                               1250
# Total Samples:                              1433
# Nested Sampling ln(Z):            3533491.106865
# Importance Nested Sampling ln(Z): 3534231.320859 +/-  0.999651
# Acceptance Rate:                        0.837629
# Replacements:                               1300
# Total Samples:                              1552
# Nested Sampling ln(Z):            3533587.284847
# Importance Nested Sampling ln(Z): 3534231.241084 +/-  0.999678
# Acceptance Rate:                        0.805009
# Replacements:                               1350
# Total Samples:                              1677
# Nested Sampling ln(Z):            3533622.222292
# Importance Nested Sampling ln(Z): 3534231.163622 +/-  0.999702
# Acceptance Rate:                        0.800000
# Replacements:                               1400
# Total Samples:                              1750
# Nested Sampling ln(Z):            3533640.843382
# Importance Nested Sampling ln(Z): 3534231.082811 +/-  0.999714
# Acceptance Rate:                        0.798458
# Replacements:                               1450
# Total Samples:                              1816
# Nested Sampling ln(Z):            3533649.217763
# Importance Nested Sampling ln(Z): 3534230.997946 +/-  0.999725
# Acceptance Rate:                        0.795334
# Replacements:                               1500
# Total Samples:                              1886
# Nested Sampling ln(Z):            3533653.606491
# Importance Nested Sampling ln(Z): 3534230.911353 +/-  0.999735
# Acceptance Rate:                        0.791624
# Replacements:                               1550
# Total Samples:                              1958
# Nested Sampling ln(Z):            3533656.324773
# Importance Nested Sampling ln(Z): 3534230.818585 +/-  0.999745
# Acceptance Rate:                        0.786627
# Replacements:                               1600
# Total Samples:                              2034
# Nested Sampling ln(Z):            3533657.781142
# Importance Nested Sampling ln(Z): 3534230.721311 +/-  0.999754
# Acceptance Rate:                        0.786089
# Replacements:                               1650
# Total Samples:                              2099
# Nested Sampling ln(Z):            3533658.766253
# Importance Nested Sampling ln(Z): 3534230.645164 +/-  0.999762
# Acceptance Rate:                        0.784495
# Replacements:                               1700
# Total Samples:                              2167
# Nested Sampling ln(Z):            3533659.474725
# Importance Nested Sampling ln(Z): 3534230.573096 +/-  0.999769
# Acceptance Rate:                        0.778124
# Replacements:                               1750
# Total Samples:                              2249
# Nested Sampling ln(Z):            3533659.967239
# Importance Nested Sampling ln(Z): 3534230.481081 +/-  0.999778
# Acceptance Rate:                        0.774860
# Replacements:                               1800
# Total Samples:                              2323
# Nested Sampling ln(Z):            3533660.325496
# Importance Nested Sampling ln(Z): 3534230.402421 +/-  0.999785
# Acceptance Rate:                        0.768911
# Replacements:                               1850
# Total Samples:                              2406
# Nested Sampling ln(Z):            3533660.598321
# Importance Nested Sampling ln(Z): 3534230.302266 +/-  0.999792
# Acceptance Rate:                        0.763052
# Replacements:                               1900
# Total Samples:                              2490
# Nested Sampling ln(Z):            3533660.816973
# Importance Nested Sampling ln(Z): 3534230.213780 +/-  0.999799
# Acceptance Rate:                        0.758165
# Replacements:                               1950
# Total Samples:                              2572
# Nested Sampling ln(Z):            3533660.998608
# Importance Nested Sampling ln(Z): 3534230.134682 +/-  0.999806
# Acceptance Rate:                        0.752729
# Replacements:                               2000
# Total Samples:                              2657
# Nested Sampling ln(Z):            3533661.154574
# Importance Nested Sampling ln(Z): 3534230.053011 +/-  0.999812
# Acceptance Rate:                        0.749543
# Replacements:                               2050
# Total Samples:                              2735
# Nested Sampling ln(Z):            3533661.291185
# Importance Nested Sampling ln(Z): 3534229.978704 +/-  0.999817
# Acceptance Rate:                        0.743626
# Replacements:                               2100
# Total Samples:                              2824
# Nested Sampling ln(Z):            3533661.415907
# Importance Nested Sampling ln(Z): 3534229.895456 +/-  0.999823
# Acceptance Rate:                        0.735797
# Replacements:                               2150
# Total Samples:                              2922
# Nested Sampling ln(Z):            3533661.535293
# Importance Nested Sampling ln(Z): 3534229.804242 +/-  0.999829
# Acceptance Rate:                        0.725833
# Replacements:                               2200
# Total Samples:                              3031
# Nested Sampling ln(Z):            3533661.650503
# Importance Nested Sampling ln(Z): 3534229.714433 +/-  0.999835
# Acceptance Rate:                        0.720923
# Replacements:                               2250
# Total Samples:                              3121
# Nested Sampling ln(Z):            3533661.767577
# Importance Nested Sampling ln(Z): 3534229.641294 +/-  0.999840
# Acceptance Rate:                        0.715174
# Replacements:                               2300
# Total Samples:                              3216
# Nested Sampling ln(Z):            3533661.889665
# Importance Nested Sampling ln(Z): 3534229.560612 +/-  0.999845
# Acceptance Rate:                        0.712769
# Replacements:                               2350
# Total Samples:                              3297
# Nested Sampling ln(Z):            3533662.019768
# Importance Nested Sampling ln(Z): 3534229.496523 +/-  0.999848
# Acceptance Rate:                        0.708174
# Replacements:                               2400
# Total Samples:                              3389
# Nested Sampling ln(Z):            3533662.170294
# Importance Nested Sampling ln(Z): 3534229.422394 +/-  0.999852
# Acceptance Rate:                        0.704428
# Replacements:                               2450
# Total Samples:                              3478
# Nested Sampling ln(Z):            3533662.364141
# Importance Nested Sampling ln(Z): 3534229.352461 +/-  0.999856
# Acceptance Rate:                        0.699888
# Replacements:                               2500
# Total Samples:                              3572
# Nested Sampling ln(Z):            3533662.609238
# Importance Nested Sampling ln(Z): 3534229.278969 +/-  0.999860
# Acceptance Rate:                        0.696151
# Replacements:                               2550
# Total Samples:                              3663
# Nested Sampling ln(Z):            3533662.927423
# Importance Nested Sampling ln(Z): 3534229.208065 +/-  0.999863
# Acceptance Rate:                        0.687649
# Replacements:                               2600
# Total Samples:                              3781
# Nested Sampling ln(Z):            3533663.331134
# Importance Nested Sampling ln(Z): 3534229.124567 +/-  0.999868
# Acceptance Rate:                        0.683342
# Replacements:                               2650
# Total Samples:                              3878
# Nested Sampling ln(Z):            3533664.007280
# Importance Nested Sampling ln(Z): 3534229.053771 +/-  0.999871
# Acceptance Rate:                        0.679929
# Replacements:                               2700
# Total Samples:                              3971
# Nested Sampling ln(Z):            3533665.009338
# Importance Nested Sampling ln(Z): 3534228.981616 +/-  0.999874
# Acceptance Rate:                        0.679516
# Replacements:                               2750
# Total Samples:                              4047
# Nested Sampling ln(Z):            3533666.199796
# Importance Nested Sampling ln(Z): 3534228.923766 +/-  0.999876
# Acceptance Rate:                        0.679447
# Replacements:                               2800
# Total Samples:                              4121
# Nested Sampling ln(Z):            3533667.403748
# Importance Nested Sampling ln(Z): 3534267.017214 +/-  0.999879
# Acceptance Rate:                        0.676317
# Replacements:                               2850
# Total Samples:                              4214
# Nested Sampling ln(Z):            3533668.797801
# Importance Nested Sampling ln(Z): 3534391.520688 +/-  0.999881
# Acceptance Rate:                        0.673166
# Replacements:                               2900
# Total Samples:                              4308
# Nested Sampling ln(Z):            3533670.265761
# Importance Nested Sampling ln(Z): 3534391.455624 +/-  0.999884
# Acceptance Rate:                        0.672441
# Replacements:                               2950
# Total Samples:                              4387
# Nested Sampling ln(Z):            3533671.792737
# Importance Nested Sampling ln(Z): 3534391.398506 +/-  0.999886
# Acceptance Rate:                        0.670841
# Replacements:                               3000
# Total Samples:                              4472
# Nested Sampling ln(Z):            3533673.380998
# Importance Nested Sampling ln(Z): 3534391.343602 +/-  0.999888
# Acceptance Rate:                        0.668713
# Replacements:                               3050
# Total Samples:                              4561
# Nested Sampling ln(Z):            3533675.242504
# Importance Nested Sampling ln(Z): 3534391.283458 +/-  0.999890
# Acceptance Rate:                        0.662818
# Replacements:                               3100
# Total Samples:                              4677
# Nested Sampling ln(Z):            3533677.153249
# Importance Nested Sampling ln(Z): 3534391.227200 +/-  0.985745
# Acceptance Rate:                        0.660516
# Replacements:                               3150
# Total Samples:                              4769
# Nested Sampling ln(Z):            3533679.462277
# Importance Nested Sampling ln(Z): 3534391.163261 +/-  0.985746
# Acceptance Rate:                        0.659386
# Replacements:                               3200
# Total Samples:                              4853
# Nested Sampling ln(Z):            3533681.688536
# Importance Nested Sampling ln(Z): 3534391.107793 +/-  0.985748
# Acceptance Rate:                        0.656698
# Replacements:                               3250
# Total Samples:                              4949
# Nested Sampling ln(Z):            3533684.367793
# Importance Nested Sampling ln(Z): 3534391.044965 +/-  0.985749
# Acceptance Rate:                        0.652819
# Replacements:                               3300
# Total Samples:                              5055
# Nested Sampling ln(Z):            3533686.968269
# Importance Nested Sampling ln(Z): 3534390.980395 +/-  0.985751
# Acceptance Rate:                        0.648722
# Replacements:                               3350
# Total Samples:                              5164
# Nested Sampling ln(Z):            3533690.885456
# Importance Nested Sampling ln(Z): 3534390.914555 +/-  0.985753
# Acceptance Rate:                        0.648731
# Replacements:                               3400
# Total Samples:                              5241
# Nested Sampling ln(Z):            3533693.779831
# Importance Nested Sampling ln(Z): 3534390.863245 +/-  0.985754
# Acceptance Rate:                        0.645946
# Replacements:                               3450
# Total Samples:                              5341
# Nested Sampling ln(Z):            3533697.798861
# Importance Nested Sampling ln(Z): 3534390.791657 +/-  0.985755
# Acceptance Rate:                        0.643974
# Replacements:                               3500
# Total Samples:                              5435
# Nested Sampling ln(Z):            3533701.955809
# Importance Nested Sampling ln(Z): 3534390.720982 +/-  0.985756
# Acceptance Rate:                        0.640910
# Replacements:                               3550
# Total Samples:                              5539
# Nested Sampling ln(Z):            3533707.017176
# Importance Nested Sampling ln(Z): 3534390.649614 +/-  0.985758
# Acceptance Rate:                        0.635593
# Replacements:                               3600
# Total Samples:                              5664
# Nested Sampling ln(Z):            3533711.464180
# Importance Nested Sampling ln(Z): 3534390.563890 +/-  0.985759
# Acceptance Rate:                        0.633461
# Replacements:                               3650
# Total Samples:                              5762
# Nested Sampling ln(Z):            3533715.794659
# Importance Nested Sampling ln(Z): 3534390.493623 +/-  0.985761
# Acceptance Rate:                        0.632587
# Replacements:                               3700
# Total Samples:                              5849
# Nested Sampling ln(Z):            3533719.871307
# Importance Nested Sampling ln(Z): 3534390.435432 +/-  0.985761
# Acceptance Rate:                        0.630994
# Replacements:                               3750
# Total Samples:                              5943
# Nested Sampling ln(Z):            3533724.499712
# Importance Nested Sampling ln(Z): 3534403.919817 +/-  0.999915
# Acceptance Rate:                        0.629660
# Replacements:                               3800
# Total Samples:                              6035
# Nested Sampling ln(Z):            3533730.032495
# Importance Nested Sampling ln(Z): 3534403.867433 +/-  0.999916
# Acceptance Rate:                        0.628571
# Replacements:                               3850
# Total Samples:                              6125
# Nested Sampling ln(Z):            3533736.191143
# Importance Nested Sampling ln(Z): 3534403.818382 +/-  0.999917
# Acceptance Rate:                        0.624400
# Replacements:                               3900
# Total Samples:                              6246
# Nested Sampling ln(Z):            3533743.358796
# Importance Nested Sampling ln(Z): 3534403.754929 +/-  0.999919
# Acceptance Rate:                        0.622832
# Replacements:                               3950
# Total Samples:                              6342
# Nested Sampling ln(Z):            3533748.949316
# Importance Nested Sampling ln(Z): 3534403.705383 +/-  0.999920
# Acceptance Rate:                        0.622471
# Replacements:                               4000
# Total Samples:                              6426
# Nested Sampling ln(Z):            3533756.462150
# Importance Nested Sampling ln(Z): 3534403.665270 +/-  0.999921
# Acceptance Rate:                        0.619550
# Replacements:                               4050
# Total Samples:                              6537
# Nested Sampling ln(Z):            3533763.437261
# Importance Nested Sampling ln(Z): 3534403.615537 +/-  0.999922
# Acceptance Rate:                        0.616449
# Replacements:                               4100
# Total Samples:                              6651
# Nested Sampling ln(Z):            3533769.629547
# Importance Nested Sampling ln(Z): 3534403.551664 +/-  0.999924
# Acceptance Rate:                        0.613815
# Replacements:                               4150
# Total Samples:                              6761
# Nested Sampling ln(Z):            3533776.793348
# Importance Nested Sampling ln(Z): 3534403.484616 +/-  0.999925
# Acceptance Rate:                        0.610643
# Replacements:                               4200
# Total Samples:                              6878
# Nested Sampling ln(Z):            3533785.491087
# Importance Nested Sampling ln(Z): 3534425.304105 +/-  0.999927
# Acceptance Rate:                        0.607316
# Replacements:                               4250
# Total Samples:                              6998
# Nested Sampling ln(Z):            3533791.822236
# Importance Nested Sampling ln(Z): 3534425.247009 +/-  0.999929
# Acceptance Rate:                        0.605634
# Replacements:                               4300
# Total Samples:                              7100
# Nested Sampling ln(Z):            3533798.623734
# Importance Nested Sampling ln(Z): 3534425.199412 +/-  0.999929
# Acceptance Rate:                        0.600663
# Replacements:                               4350
# Total Samples:                              7242
# Nested Sampling ln(Z):            3533808.201082
# Importance Nested Sampling ln(Z): 3534425.134827 +/-  0.999777
# Acceptance Rate:                        0.598558
# Replacements:                               4400
# Total Samples:                              7351
# Nested Sampling ln(Z):            3533816.405463
# Importance Nested Sampling ln(Z): 3534425.081015 +/-  0.999778
# Acceptance Rate:                        0.596275
# Replacements:                               4450
# Total Samples:                              7463
# Nested Sampling ln(Z):            3533823.384772
# Importance Nested Sampling ln(Z): 3534425.023222 +/-  0.999779
# Acceptance Rate:                        0.593042
# Replacements:                               4500
# Total Samples:                              7588
# Nested Sampling ln(Z):            3533831.496143
# Importance Nested Sampling ln(Z): 3534424.961127 +/-  0.999193
# Acceptance Rate:                        0.590832
# Replacements:                               4550
# Total Samples:                              7701
# Nested Sampling ln(Z):            3533840.432702
# Importance Nested Sampling ln(Z): 3534424.909686 +/-  0.999194
# Acceptance Rate:                        0.590652
# Replacements:                               4600
# Total Samples:                              7788
# Nested Sampling ln(Z):            3533848.858693
# Importance Nested Sampling ln(Z): 3534424.868088 +/-  0.999194
# Acceptance Rate:                        0.589204
# Replacements:                               4650
# Total Samples:                              7892
# Nested Sampling ln(Z):            3533857.454085
# Importance Nested Sampling ln(Z): 3534424.817957 +/-  0.999195
# Acceptance Rate:                        0.587206
# Replacements:                               4700
# Total Samples:                              8004
# Nested Sampling ln(Z):            3533866.149555
# Importance Nested Sampling ln(Z): 3534424.762108 +/-  0.999196
# Acceptance Rate:                        0.585913
# Replacements:                               4750
# Total Samples:                              8107
# Nested Sampling ln(Z):            3533874.109718
# Importance Nested Sampling ln(Z): 3534424.709412 +/-  0.999197
# Acceptance Rate:                        0.584368
# Replacements:                               4800
# Total Samples:                              8214
# Nested Sampling ln(Z):            3533882.198613
# Importance Nested Sampling ln(Z): 3534424.658482 +/-  0.999197
# Acceptance Rate:                        0.584831
# Replacements:                               4850
# Total Samples:                              8293
# Nested Sampling ln(Z):            3533892.497901
# Importance Nested Sampling ln(Z): 3534424.618575 +/-  0.999198
# Acceptance Rate:                        0.584935
# Replacements:                               4900
# Total Samples:                              8377
# Nested Sampling ln(Z):            3533903.544109
# Importance Nested Sampling ln(Z): 3534424.574041 +/-  0.999198
# Acceptance Rate:                        0.582216
# Replacements:                               4950
# Total Samples:                              8502
# Nested Sampling ln(Z):            3533911.880150
# Importance Nested Sampling ln(Z): 3534424.504466 +/-  0.999199
# Acceptance Rate:                        0.581058
# Replacements:                               5000
# Total Samples:                              8605
# Nested Sampling ln(Z):            3533921.961861
# Importance Nested Sampling ln(Z): 3534424.448901 +/-  0.999200
# Acceptance Rate:                        0.580193
# Replacements:                               5050
# Total Samples:                              8704
# Nested Sampling ln(Z):            3533931.760203
# Importance Nested Sampling ln(Z): 3534424.508847 +/-  0.888067
# Acceptance Rate:                        0.578691
# Replacements:                               5100
# Total Samples:                              8813
# Nested Sampling ln(Z):            3533943.678914
# Importance Nested Sampling ln(Z): 3534424.438086 +/-  0.888054
# Acceptance Rate:                        0.577873
# Replacements:                               5150
# Total Samples:                              8912
# Nested Sampling ln(Z):            3533955.330628
# Importance Nested Sampling ln(Z): 3534424.388285 +/-  0.886766
# Acceptance Rate:                        0.576369
# Replacements:                               5200
# Total Samples:                              9022
# Nested Sampling ln(Z):            3533963.786762
# Importance Nested Sampling ln(Z): 3534424.333502 +/-  0.886757
# Acceptance Rate:                        0.574964
# Replacements:                               5250
# Total Samples:                              9131
# Nested Sampling ln(Z):            3533977.727931
# Importance Nested Sampling ln(Z): 3534424.274455 +/-  0.886748
# Acceptance Rate:                        0.574588
# Replacements:                               5300
# Total Samples:                              9224
# Nested Sampling ln(Z):            3533989.647476
# Importance Nested Sampling ln(Z): 3534424.225925 +/-  0.886741
# Acceptance Rate:                        0.573235
# Replacements:                               5350
# Total Samples:                              9333
# Nested Sampling ln(Z):            3534000.855706
# Importance Nested Sampling ln(Z): 3534424.169965 +/-  0.886733
# Acceptance Rate:                        0.574041
# Replacements:                               5400
# Total Samples:                              9407
# Nested Sampling ln(Z):            3534009.916357
# Importance Nested Sampling ln(Z): 3534424.128655 +/-  0.886728
# Acceptance Rate:                        0.573926
# Replacements:                               5450
# Total Samples:                              9496
# Nested Sampling ln(Z):            3534025.111236
# Importance Nested Sampling ln(Z): 3534424.076430 +/-  0.886721
# Acceptance Rate:                        0.573514
# Replacements:                               5500
# Total Samples:                              9590
# Nested Sampling ln(Z):            3534035.735215
# Importance Nested Sampling ln(Z): 3534424.021526 +/-  0.886714
# Acceptance Rate:                        0.572815
# Replacements:                               5550
# Total Samples:                              9689
# Nested Sampling ln(Z):            3534045.963950
# Importance Nested Sampling ln(Z): 3534423.961784 +/-  0.886708
# Acceptance Rate:                        0.573007
# Replacements:                               5600
# Total Samples:                              9773
# Nested Sampling ln(Z):            3534053.329685
# Importance Nested Sampling ln(Z): 3534448.953919 +/-  0.997912
# Acceptance Rate:                        0.571920
# Replacements:                               5650
# Total Samples:                              9879
# Nested Sampling ln(Z):            3534062.949670
# Importance Nested Sampling ln(Z): 3534454.806635 +/-  0.997259
# Acceptance Rate:                        0.571887
# Replacements:                               5700
# Total Samples:                              9967
# Nested Sampling ln(Z):            3534073.296645
# Importance Nested Sampling ln(Z): 3534454.754641 +/-  0.997259
# Acceptance Rate:                        0.570663
# Replacements:                               5750
# Total Samples:                             10076
# Nested Sampling ln(Z):            3534083.333982
# Importance Nested Sampling ln(Z): 3534454.692682 +/-  0.997260
# Acceptance Rate:                        0.569130
# Replacements:                               5800
# Total Samples:                             10191
# Nested Sampling ln(Z):            3534090.890839
# Importance Nested Sampling ln(Z): 3534454.627076 +/-  0.997260
# Acceptance Rate:                        0.568900
# Replacements:                               5850
# Total Samples:                             10283
# Nested Sampling ln(Z):            3534099.192407
# Importance Nested Sampling ln(Z): 3534454.576718 +/-  0.996209
# Acceptance Rate:                        0.568456
# Replacements:                               5900
# Total Samples:                             10379
# Nested Sampling ln(Z):            3534106.762755
# Importance Nested Sampling ln(Z): 3534454.524239 +/-  0.996209
# Acceptance Rate:                        0.567261
# Replacements:                               5950
# Total Samples:                             10489
# Nested Sampling ln(Z):            3534115.540486
# Importance Nested Sampling ln(Z): 3534454.467066 +/-  0.996210
# Acceptance Rate:                        0.566679
# Replacements:                               6000
# Total Samples:                             10588
# Nested Sampling ln(Z):            3534126.834335
# Importance Nested Sampling ln(Z): 3534454.417574 +/-  0.996210
# Acceptance Rate:                        0.564734
# Replacements:                               6050
# Total Samples:                             10713
# Nested Sampling ln(Z):            3534134.515271
# Importance Nested Sampling ln(Z): 3534454.349125 +/-  0.996211
# Acceptance Rate:                        0.564292
# Replacements:                               6100
# Total Samples:                             10810
# Nested Sampling ln(Z):            3534142.826142
# Importance Nested Sampling ln(Z): 3534454.288509 +/-  0.996159
# Acceptance Rate:                        0.562003
# Replacements:                               6150
# Total Samples:                             10943
# Nested Sampling ln(Z):            3534151.980045
# Importance Nested Sampling ln(Z): 3534455.510027 +/-  0.777238
# Acceptance Rate:                        0.560427
# Replacements:                               6200
# Total Samples:                             11063
# Nested Sampling ln(Z):            3534160.241023
# Importance Nested Sampling ln(Z): 3534455.445221 +/-  0.777239
# Acceptance Rate:                        0.559384
# Replacements:                               6250
# Total Samples:                             11173
# Nested Sampling ln(Z):            3534168.297900
# Importance Nested Sampling ln(Z): 3534455.384796 +/-  0.777244
# Acceptance Rate:                        0.559105
# Replacements:                               6300
# Total Samples:                             11268
# Nested Sampling ln(Z):            3534177.097047
# Importance Nested Sampling ln(Z): 3534455.337069 +/-  0.777247
# Acceptance Rate:                        0.558487
# Replacements:                               6350
# Total Samples:                             11370
# Nested Sampling ln(Z):            3534184.795445
# Importance Nested Sampling ln(Z): 3534455.285668 +/-  0.777251
# Acceptance Rate:                        0.556909
# Replacements:                               6400
# Total Samples:                             11492
# Nested Sampling ln(Z):            3534195.060960
# Importance Nested Sampling ln(Z): 3534455.218303 +/-  0.777255
# Acceptance Rate:                        0.555364
# Replacements:                               6450
# Total Samples:                             11614
# Nested Sampling ln(Z):            3534203.671190
# Importance Nested Sampling ln(Z): 3534455.155023 +/-  0.777259
# Acceptance Rate:                        0.554560
# Replacements:                               6500
# Total Samples:                             11721
# Nested Sampling ln(Z):            3534210.297374
# Importance Nested Sampling ln(Z): 3534455.099530 +/-  0.777263
# Acceptance Rate:                        0.553303
# Replacements:                               6550
# Total Samples:                             11838
# Nested Sampling ln(Z):            3534217.663047
# Importance Nested Sampling ln(Z): 3534455.825825 +/-  0.626253
# Acceptance Rate:                        0.551010
# Replacements:                               6600
# Total Samples:                             11978
# Nested Sampling ln(Z):            3534224.202602
# Importance Nested Sampling ln(Z): 3534455.755085 +/-  0.626233
# Acceptance Rate:                        0.550406
# Replacements:                               6650
# Total Samples:                             12082
# Nested Sampling ln(Z):            3534230.805467
# Importance Nested Sampling ln(Z): 3534455.701905 +/-  0.626167
# Acceptance Rate:                        0.548731
# Replacements:                               6700
# Total Samples:                             12210
# Nested Sampling ln(Z):            3534236.994771
# Importance Nested Sampling ln(Z): 3534455.635037 +/-  0.626167
# Acceptance Rate:                        0.545896
# Replacements:                               6750
# Total Samples:                             12365
# Nested Sampling ln(Z):            3534243.461053
# Importance Nested Sampling ln(Z): 3534455.550987 +/-  0.626167
# Acceptance Rate:                        0.544610
# Replacements:                               6800
# Total Samples:                             12486
# Nested Sampling ln(Z):            3534249.369648
# Importance Nested Sampling ln(Z): 3534455.489480 +/-  0.626159
# Acceptance Rate:                        0.543521
# Replacements:                               6850
# Total Samples:                             12603
# Nested Sampling ln(Z):            3534256.273103
# Importance Nested Sampling ln(Z): 3534455.425157 +/-  0.626159
# Acceptance Rate:                        0.543136
# Replacements:                               6900
# Total Samples:                             12704
# Nested Sampling ln(Z):            3534261.389232
# Importance Nested Sampling ln(Z): 3534455.368198 +/-  0.626159
# Acceptance Rate:                        0.543478
# Replacements:                               6950
# Total Samples:                             12788
# Nested Sampling ln(Z):            3534267.645669
# Importance Nested Sampling ln(Z): 3534455.321726 +/-  0.626159
# Acceptance Rate:                        0.542888
# Replacements:                               7000
# Total Samples:                             12894
# Nested Sampling ln(Z):            3534272.318808
# Importance Nested Sampling ln(Z): 3534456.306225 +/-  0.683723
# Acceptance Rate:                        0.543562
# Replacements:                               7050
# Total Samples:                             12970
# Nested Sampling ln(Z):            3534276.862927
# Importance Nested Sampling ln(Z): 3534456.255667 +/-  0.683723
# Acceptance Rate:                        0.543895
# Replacements:                               7100
# Total Samples:                             13054
# Nested Sampling ln(Z):            3534282.155247
# Importance Nested Sampling ln(Z): 3534456.198989 +/-  0.683723
# Acceptance Rate:                        0.543974
# Replacements:                               7150
# Total Samples:                             13144
# Nested Sampling ln(Z):            3534286.514399
# Importance Nested Sampling ln(Z): 3534456.141491 +/-  0.683722
# Acceptance Rate:                        0.543971
# Replacements:                               7200
# Total Samples:                             13236
# Nested Sampling ln(Z):            3534291.677260
# Importance Nested Sampling ln(Z): 3534456.151696 +/-  0.643361
# Acceptance Rate:                        0.543193
# Replacements:                               7250
# Total Samples:                             13347
# Nested Sampling ln(Z):            3534296.483259
# Importance Nested Sampling ln(Z): 3534456.085899 +/-  0.643358
# Acceptance Rate:                        0.542590
# Replacements:                               7300
# Total Samples:                             13454
# Nested Sampling ln(Z):            3534302.054849
# Importance Nested Sampling ln(Z): 3534456.019320 +/-  0.643358
# Acceptance Rate:                        0.541716
# Replacements:                               7350
# Total Samples:                             13568
# Nested Sampling ln(Z):            3534306.951266
# Importance Nested Sampling ln(Z): 3534455.947324 +/-  0.643357
# Acceptance Rate:                        0.540975
# Replacements:                               7400
# Total Samples:                             13679
# Nested Sampling ln(Z):            3534311.518262
# Importance Nested Sampling ln(Z): 3534455.881395 +/-  0.643261
# Acceptance Rate:                        0.540678
# Replacements:                               7450
# Total Samples:                             13779
# Nested Sampling ln(Z):            3534315.654420
# Importance Nested Sampling ln(Z): 3534455.822631 +/-  0.643261
# Acceptance Rate:                        0.540541
# Replacements:                               7500
# Total Samples:                             13875
# Nested Sampling ln(Z):            3534319.997665
# Importance Nested Sampling ln(Z): 3534455.770559 +/-  0.641289
# Acceptance Rate:                        0.539903
# Replacements:                               7550
# Total Samples:                             13984
# Nested Sampling ln(Z):            3534323.853893
# Importance Nested Sampling ln(Z): 3534455.714451 +/-  0.637580
# Acceptance Rate:                        0.538892
# Replacements:                               7600
# Total Samples:                             14103
# Nested Sampling ln(Z):            3534328.858959
# Importance Nested Sampling ln(Z): 3534455.884228 +/-  0.543380
# Acceptance Rate:                        0.538164
# Replacements:                               7650
# Total Samples:                             14215
# Nested Sampling ln(Z):            3534333.013085
# Importance Nested Sampling ln(Z): 3534455.813423 +/-  0.543375
# Acceptance Rate:                        0.538048
# Replacements:                               7700
# Total Samples:                             14311
# Nested Sampling ln(Z):            3534336.306813
# Importance Nested Sampling ln(Z): 3534455.756303 +/-  0.543371
# Acceptance Rate:                        0.538194
# Replacements:                               7750
# Total Samples:                             14400
# Nested Sampling ln(Z):            3534339.705999
# Importance Nested Sampling ln(Z): 3534455.703809 +/-  0.542982
# Acceptance Rate:                        0.537634
# Replacements:                               7800
# Total Samples:                             14508
# Nested Sampling ln(Z):            3534343.530099
# Importance Nested Sampling ln(Z): 3534455.636937 +/-  0.542978
# Acceptance Rate:                        0.538409
# Replacements:                               7850
# Total Samples:                             14580
# Nested Sampling ln(Z):            3534347.878361
# Importance Nested Sampling ln(Z): 3534455.590918 +/-  0.542975
# Acceptance Rate:                        0.538441
# Replacements:                               7900
# Total Samples:                             14672
# Nested Sampling ln(Z):            3534351.650085
# Importance Nested Sampling ln(Z): 3534455.529248 +/-  0.542972
# Acceptance Rate:                        0.538508
# Replacements:                               7950
# Total Samples:                             14763
# Nested Sampling ln(Z):            3534354.802317
# Importance Nested Sampling ln(Z): 3534455.469810 +/-  0.542935
# Acceptance Rate:                        0.538503
# Replacements:                               8000
# Total Samples:                             14856
# Nested Sampling ln(Z):            3534358.548543
# Importance Nested Sampling ln(Z): 3534455.407097 +/-  0.542932
# Acceptance Rate:                        0.538642
# Replacements:                               8050
# Total Samples:                             14945
# Nested Sampling ln(Z):            3534361.647765
# Importance Nested Sampling ln(Z): 3534455.346603 +/-  0.542612
# Acceptance Rate:                        0.538886
# Replacements:                               8100
# Total Samples:                             15031
# Nested Sampling ln(Z):            3534364.246910
# Importance Nested Sampling ln(Z): 3534455.290518 +/-  0.542602
# Acceptance Rate:                        0.539164
# Replacements:                               8150
# Total Samples:                             15116
# Nested Sampling ln(Z):            3534367.269813
# Importance Nested Sampling ln(Z): 3534455.232683 +/-  0.542500
# Acceptance Rate:                        0.539013
# Replacements:                               8200
# Total Samples:                             15213
# Nested Sampling ln(Z):            3534370.429836
# Importance Nested Sampling ln(Z): 3534455.301626 +/-  0.490706
# Acceptance Rate:                        0.538617
# Replacements:                               8250
# Total Samples:                             15317
# Nested Sampling ln(Z):            3534373.329133
# Importance Nested Sampling ln(Z): 3534457.344883 +/-  0.881442
# Acceptance Rate:                        0.538786
# Replacements:                               8300
# Total Samples:                             15405
# Nested Sampling ln(Z):            3534376.369374
# Importance Nested Sampling ln(Z): 3534457.821488 +/-  0.659158
# Acceptance Rate:                        0.538988
# Replacements:                               8350
# Total Samples:                             15492
# Nested Sampling ln(Z):            3534378.903425
# Importance Nested Sampling ln(Z): 3534457.775824 +/-  0.651317
# Acceptance Rate:                        0.539222
# Replacements:                               8400
# Total Samples:                             15578
# Nested Sampling ln(Z):            3534381.174154
# Importance Nested Sampling ln(Z): 3534457.720243 +/-  0.650795
# Acceptance Rate:                        0.539247
# Replacements:                               8450
# Total Samples:                             15670
# Nested Sampling ln(Z):            3534383.416257
# Importance Nested Sampling ln(Z): 3534459.138226 +/-  0.785831
# Acceptance Rate:                        0.538725
# Replacements:                               8500
# Total Samples:                             15778
# Nested Sampling ln(Z):            3534385.375322
# Importance Nested Sampling ln(Z): 3534459.121972 +/-  0.746847
# Acceptance Rate:                        0.537905
# Replacements:                               8550
# Total Samples:                             15895
# Nested Sampling ln(Z):            3534387.850140
# Importance Nested Sampling ln(Z): 3534459.168164 +/-  0.669195
# Acceptance Rate:                        0.538240
# Replacements:                               8600
# Total Samples:                             15978
# Nested Sampling ln(Z):            3534390.162126
# Importance Nested Sampling ln(Z): 3534459.117020 +/-  0.667585
# Acceptance Rate:                        0.538505
# Replacements:                               8650
# Total Samples:                             16063
# Nested Sampling ln(Z):            3534391.949892
# Importance Nested Sampling ln(Z): 3534459.053691 +/-  0.667583
# Acceptance Rate:                        0.538867
# Replacements:                               8700
# Total Samples:                             16145
# Nested Sampling ln(Z):            3534394.213670
# Importance Nested Sampling ln(Z): 3534458.995261 +/-  0.666703
# Acceptance Rate:                        0.539192
# Replacements:                               8750
# Total Samples:                             16228
# Nested Sampling ln(Z):            3534396.526125
# Importance Nested Sampling ln(Z): 3534460.176324 +/-  0.735630
# Acceptance Rate:                        0.538885
# Replacements:                               8800
# Total Samples:                             16330
# Nested Sampling ln(Z):            3534398.608610
# Importance Nested Sampling ln(Z): 3534460.108767 +/-  0.735625
# Acceptance Rate:                        0.538780
# Replacements:                               8850
# Total Samples:                             16426
# Nested Sampling ln(Z):            3534400.548313
# Importance Nested Sampling ln(Z): 3534460.045020 +/-  0.735588
# Acceptance Rate:                        0.539361
# Replacements:                               8900
# Total Samples:                             16501
# Nested Sampling ln(Z):            3534402.238317
# Importance Nested Sampling ln(Z): 3534459.994922 +/-  0.732075
# Acceptance Rate:                        0.540002
# Replacements:                               8950
# Total Samples:                             16574
# Nested Sampling ln(Z):            3534403.796932
# Importance Nested Sampling ln(Z): 3534460.049741 +/-  0.663177
# Acceptance Rate:                        0.540541
# Replacements:                               9000
# Total Samples:                             16650
# Nested Sampling ln(Z):            3534405.546857
# Importance Nested Sampling ln(Z): 3534459.999362 +/-  0.659354
# Acceptance Rate:                        0.540880
# Replacements:                               9050
# Total Samples:                             16732
# Nested Sampling ln(Z):            3534407.117530
# Importance Nested Sampling ln(Z): 3534459.939498 +/-  0.658155
# Acceptance Rate:                        0.540830
# Replacements:                               9100
# Total Samples:                             16826
# Nested Sampling ln(Z):            3534408.621128
# Importance Nested Sampling ln(Z): 3534460.116680 +/-  0.553350
# Acceptance Rate:                        0.540588
# Replacements:                               9150
# Total Samples:                             16926
# Nested Sampling ln(Z):            3534410.182340
# Importance Nested Sampling ln(Z): 3534460.048025 +/-  0.553324
# Acceptance Rate:                        0.541240
# Replacements:                               9200
# Total Samples:                             16998
# Nested Sampling ln(Z):            3534412.187601
# Importance Nested Sampling ln(Z): 3534460.005699 +/-  0.548865
# Acceptance Rate:                        0.541157
# Replacements:                               9250
# Total Samples:                             17093
# Nested Sampling ln(Z):            3534414.065069
# Importance Nested Sampling ln(Z): 3534460.253066 +/-  0.478153
# Acceptance Rate:                        0.540949
# Replacements:                               9300
# Total Samples:                             17192
# Nested Sampling ln(Z):            3534415.437178
# Importance Nested Sampling ln(Z): 3534460.190371 +/-  0.475809
# Acceptance Rate:                        0.540431
# Replacements:                               9350
# Total Samples:                             17301
# Nested Sampling ln(Z):            3534416.953076
# Importance Nested Sampling ln(Z): 3534460.133778 +/-  0.469627
# Acceptance Rate:                        0.540416
# Replacements:                               9400
# Total Samples:                             17394
# Nested Sampling ln(Z):            3534418.481856
# Importance Nested Sampling ln(Z): 3534460.070363 +/-  0.469627
# Acceptance Rate:                        0.540463
# Replacements:                               9450
# Total Samples:                             17485
# Nested Sampling ln(Z):            3534419.791751
# Importance Nested Sampling ln(Z): 3534460.022765 +/-  0.462465
# Acceptance Rate:                        0.541280
# Replacements:                               9500
# Total Samples:                             17551
# Nested Sampling ln(Z):            3534420.937185
# Importance Nested Sampling ln(Z): 3534460.087401 +/-  0.421074
# Acceptance Rate:                        0.541721
# Replacements:                               9550
# Total Samples:                             17629
# Nested Sampling ln(Z):            3534422.164068
# Importance Nested Sampling ln(Z): 3534460.027419 +/-  0.421024
# Acceptance Rate:                        0.542250
# Replacements:                               9600
# Total Samples:                             17704
# Nested Sampling ln(Z):            3534423.417917
# Importance Nested Sampling ln(Z): 3534460.122218 +/-  0.388050
# Acceptance Rate:                        0.542470
# Replacements:                               9650
# Total Samples:                             17789
# Nested Sampling ln(Z):            3534424.560629
# Importance Nested Sampling ln(Z): 3534460.060717 +/-  0.388050
# Acceptance Rate:                        0.542931
# Replacements:                               9700
# Total Samples:                             17866
# Nested Sampling ln(Z):            3534425.824512
# Importance Nested Sampling ln(Z): 3534460.035334 +/-  0.375491
# Acceptance Rate:                        0.543448
# Replacements:                               9750
# Total Samples:                             17941
# Nested Sampling ln(Z):            3534426.838847
# Importance Nested Sampling ln(Z): 3534459.980568 +/-  0.374883
# Acceptance Rate:                        0.543780
# Replacements:                               9800
# Total Samples:                             18022
# Nested Sampling ln(Z):            3534427.862928
# Importance Nested Sampling ln(Z): 3534459.932739 +/-  0.370846
# Acceptance Rate:                        0.544109
# Replacements:                               9850
# Total Samples:                             18103
# Nested Sampling ln(Z):            3534428.892229
# Importance Nested Sampling ln(Z): 3534459.982302 +/-  0.335652
# Acceptance Rate:                        0.544465
# Replacements:                               9900
# Total Samples:                             18183
# Nested Sampling ln(Z):            3534429.952073
# Importance Nested Sampling ln(Z): 3534459.937572 +/-  0.330866
# Acceptance Rate:                        0.544519
# Replacements:                               9950
# Total Samples:                             18273
# Nested Sampling ln(Z):            3534430.942818
# Importance Nested Sampling ln(Z): 3534459.870982 +/-  0.330580
# Acceptance Rate:                        0.544573
# Replacements:                              10000
# Total Samples:                             18363
# Nested Sampling ln(Z):            3534431.845278
# Importance Nested Sampling ln(Z): 3534459.841966 +/-  0.319277
# ...
# Acceptance Rate:                        0.562235
# Replacements:                              13000
# Total Samples:                             23122
# Nested Sampling ln(Z):            3534457.247661
# Importance Nested Sampling ln(Z): 3534460.183125 +/-  0.064019
# Acceptance Rate:                        0.562621
# Replacements:                              13050
# Total Samples:                             23195
# Nested Sampling ln(Z):            3534457.362779
# Importance Nested Sampling ln(Z): 3534460.164431 +/-  0.062476
# Acceptance Rate:                        0.563029
# Replacements:                              13100
# Total Samples:                             23267
# Nested Sampling ln(Z):            3534457.472347
# Importance Nested Sampling ln(Z): 3534460.163957 +/-  0.060528
# Acceptance Rate:                        0.563097
# Replacements:                              13150
# Total Samples:                             23353
# Nested Sampling ln(Z):            3534457.577641
# Importance Nested Sampling ln(Z): 3534460.166518 +/-  0.059275
# Acceptance Rate:                        0.563862
# Replacements:                              13200
# Total Samples:                             23410
# Nested Sampling ln(Z):            3534457.679424
# Importance Nested Sampling ln(Z): 3534460.177629 +/-  0.057231
# Acceptance Rate:                        0.564310
# Replacements:                              13250
# Total Samples:                             23480
# Nested Sampling ln(Z):            3534457.780034
# Importance Nested Sampling ln(Z): 3534460.176934 +/-  0.055517
# Acceptance Rate:                        0.564372
# Replacements:                              13300
# Total Samples:                             23566
# Nested Sampling ln(Z):            3534457.879172
# Importance Nested Sampling ln(Z): 3534460.185665 +/-  0.053856
# Acceptance Rate:                        0.564721
# Replacements:                              13350
# Total Samples:                             23640
# Nested Sampling ln(Z):            3534457.973785
# Importance Nested Sampling ln(Z): 3534460.192850 +/-  0.052175
# Acceptance Rate:                        0.565162
# Replacements:                              13400
# Total Samples:                             23710
# Nested Sampling ln(Z):            3534458.066844
# Importance Nested Sampling ln(Z): 3534460.191915 +/-  0.050962
# Acceptance Rate:                        0.565554
# Replacements:                              13450
# Total Samples:                             23782
# Nested Sampling ln(Z):            3534458.158116
# Importance Nested Sampling ln(Z): 3534460.184676 +/-  0.049317
# Acceptance Rate:                        0.565706
# Replacements:                              13500
# Total Samples:                             23864
# Nested Sampling ln(Z):            3534458.245243
# Importance Nested Sampling ln(Z): 3534460.178743 +/-  0.047514
# Acceptance Rate:                        0.566022
# Replacements:                              13550
# Total Samples:                             23939
# Nested Sampling ln(Z):            3534458.328763
# Importance Nested Sampling ln(Z): 3534460.185156 +/-  0.045788
# Acceptance Rate:                        0.566383
# Replacements:                              13600
# Total Samples:                             24012
# Nested Sampling ln(Z):            3534458.409893
# Importance Nested Sampling ln(Z): 3534460.179718 +/-  0.044370
# Acceptance Rate:                        0.566508
# Replacements:                              13650
# Total Samples:                             24095
# Nested Sampling ln(Z):            3534458.489042
# Importance Nested Sampling ln(Z): 3534460.186231 +/-  0.042908
# Acceptance Rate:                        0.566654
# Replacements:                              13700
# Total Samples:                             24177
# Nested Sampling ln(Z):            3534458.563391
# Importance Nested Sampling ln(Z): 3534460.181634 +/-  0.041232
# Acceptance Rate:                        0.567010
# Replacements:                              13750
# Total Samples:                             24250
# Nested Sampling ln(Z):            3534458.635180
# Importance Nested Sampling ln(Z): 3534460.196152 +/-  0.040098
# Acceptance Rate:                        0.566968
# Replacements:                              13800
# Total Samples:                             24340
# Nested Sampling ln(Z):            3534458.703401
# Importance Nested Sampling ln(Z): 3534460.190382 +/-  0.038782
# Acceptance Rate:                        0.567390
# Replacements:                              13850
# Total Samples:                             24410
# Nested Sampling ln(Z):            3534458.768663
# Importance Nested Sampling ln(Z): 3534460.196460 +/-  0.037640
# Acceptance Rate:                        0.567509
# Replacements:                              13900
# Total Samples:                             24493
# Nested Sampling ln(Z):            3534458.831448
# Importance Nested Sampling ln(Z): 3534460.198760 +/-  0.036846
# Acceptance Rate:                        0.567696
# Replacements:                              13950
# Total Samples:                             24573
# Nested Sampling ln(Z):            3534458.891276
# Importance Nested Sampling ln(Z): 3534460.208010 +/-  0.035921
# Acceptance Rate:                        0.567836
# Replacements:                              14000
# Total Samples:                             24655
# Nested Sampling ln(Z):            3534458.949306
# Importance Nested Sampling ln(Z): 3534460.206516 +/-  0.034631
# Acceptance Rate:                        0.568297
# Replacements:                              14050
# Total Samples:                             24723
# Nested Sampling ln(Z):            3534459.005005
# Importance Nested Sampling ln(Z): 3534460.210881 +/-  0.033567
# Acceptance Rate:                        0.568503
# Replacements:                              14100
# Total Samples:                             24802
# Nested Sampling ln(Z):            3534459.058918
# Importance Nested Sampling ln(Z): 3534460.203413 +/-  0.032320
# Acceptance Rate:                        0.568867
# Replacements:                              14150
# Total Samples:                             24874
# Nested Sampling ln(Z):            3534459.111234
# Importance Nested Sampling ln(Z): 3534460.213543 +/-  0.031507
# Acceptance Rate:                        0.569184
# Replacements:                              14200
# Total Samples:                             24948
# Nested Sampling ln(Z):            3534459.162021
# Importance Nested Sampling ln(Z): 3534460.219730 +/-  0.030596
# Acceptance Rate:                        0.569385
# Replacements:                              14250
# Total Samples:                             25027
# Nested Sampling ln(Z):            3534459.210986
# Importance Nested Sampling ln(Z): 3534460.216570 +/-  0.029791
# Acceptance Rate:                        0.569721
# Replacements:                              14300
# Total Samples:                             25100
# Nested Sampling ln(Z):            3534459.257566
# Importance Nested Sampling ln(Z): 3534460.220185 +/-  0.028963
# Acceptance Rate:                        0.570101
# Replacements:                              14350
# Total Samples:                             25171
# Nested Sampling ln(Z):            3534459.302871
# Importance Nested Sampling ln(Z): 3534460.224525 +/-  0.027992
# Acceptance Rate:                        0.570274
# Replacements:                              14400
# Total Samples:                             25251
# Nested Sampling ln(Z):            3534459.346690
# Importance Nested Sampling ln(Z): 3534460.222164 +/-  0.027045
# Acceptance Rate:                        0.570673
# Replacements:                              14450
# Total Samples:                             25321
# Nested Sampling ln(Z):            3534459.388788
# Importance Nested Sampling ln(Z): 3534460.222366 +/-  0.026305
# Acceptance Rate:                        0.571046
# Replacements:                              14500
# Total Samples:                             25392
# Nested Sampling ln(Z):            3534459.429781
# Importance Nested Sampling ln(Z): 3534460.232003 +/-  0.025735
# Acceptance Rate:                        0.571305
# Replacements:                              14550
# Total Samples:                             25468
# Nested Sampling ln(Z):            3534459.468880
# Importance Nested Sampling ln(Z): 3534460.233093 +/-  0.024970
# Acceptance Rate:                        0.571406
# Replacements:                              14600
# Total Samples:                             25551
# Nested Sampling ln(Z):            3534459.506690
# Importance Nested Sampling ln(Z): 3534460.230111 +/-  0.024108
# Acceptance Rate:                        0.571707
# Replacements:                              14650
# Total Samples:                             25625
# Nested Sampling ln(Z):            3534459.543109
# Importance Nested Sampling ln(Z): 3534460.231131 +/-  0.023360
# Acceptance Rate:                        0.571940
# Replacements:                              14700
# Total Samples:                             25702
# Nested Sampling ln(Z):            3534459.578126
# Importance Nested Sampling ln(Z): 3534460.232192 +/-  0.022651
# Acceptance Rate:                        0.572193
# Replacements:                              14750
# Total Samples:                             25778
# Nested Sampling ln(Z):            3534459.612202
# Importance Nested Sampling ln(Z): 3534460.233301 +/-  0.021982
# Acceptance Rate:                        0.572202
# Replacements:                              14800
# Total Samples:                             25865
# Nested Sampling ln(Z):            3534459.645067
# Importance Nested Sampling ln(Z): 3534460.233631 +/-  0.021313
# Acceptance Rate:                        0.572475
# Replacements:                              14850
# Total Samples:                             25940
# Nested Sampling ln(Z):            3534459.676996
# Importance Nested Sampling ln(Z): 3534460.236772 +/-  0.020769
# Acceptance Rate:                        0.572614
# Replacements:                              14900
# Total Samples:                             26021
# Nested Sampling ln(Z):            3534459.707708
# Importance Nested Sampling ln(Z): 3534460.236359 +/-  0.020156
# Acceptance Rate:                        0.572797
# Replacements:                              14950
# Total Samples:                             26100
# Nested Sampling ln(Z):            3534459.737328
# Importance Nested Sampling ln(Z): 3534460.240056 +/-  0.019642
# Acceptance Rate:                        0.572978
# Replacements:                              15000
# Total Samples:                             26179
# Nested Sampling ln(Z):            3534459.765765
# Importance Nested Sampling ln(Z): 3534460.238667 +/-  0.019057
# Acceptance Rate:                        0.573443
# Replacements:                              15050
# Total Samples:                             26245
# Nested Sampling ln(Z):            3534459.793074
# Importance Nested Sampling ln(Z): 3534460.242441 +/-  0.018644
# Acceptance Rate:                        0.573665
# Replacements:                              15100
# Total Samples:                             26322
# Nested Sampling ln(Z):            3534459.819330
# Importance Nested Sampling ln(Z): 3534460.241909 +/-  0.018118
# Acceptance Rate:                        0.573733
# Replacements:                              15150
# Total Samples:                             26406
# Nested Sampling ln(Z):            3534459.844468
# Importance Nested Sampling ln(Z): 3534460.240516 +/-  0.017570
# Acceptance Rate:                        0.574213
# Replacements:                              15200
# Total Samples:                             26471
# Nested Sampling ln(Z):            3534459.868469
# Importance Nested Sampling ln(Z): 3534460.239803 +/-  0.017157
# Acceptance Rate:                        0.574431
# Replacements:                              15250
# Total Samples:                             26548
# Nested Sampling ln(Z):            3534459.891503
# Importance Nested Sampling ln(Z): 3534460.237900 +/-  0.016705
# Acceptance Rate:                        0.574518
# Replacements:                              15300
# Total Samples:                             26631
# Nested Sampling ln(Z):            3534459.913718
# Importance Nested Sampling ln(Z): 3534460.235834 +/-  0.016258
# Acceptance Rate:                        0.574111
# Replacements:                              15350
# Total Samples:                             26737
# Nested Sampling ln(Z):            3534459.934965
# Importance Nested Sampling ln(Z): 3534460.231539 +/-  0.015732
# Acceptance Rate:                        0.574498
# Replacements:                              15400
# Total Samples:                             26806
# Nested Sampling ln(Z):            3534459.955417
# Importance Nested Sampling ln(Z): 3534460.231493 +/-  0.015393
# Acceptance Rate:                        0.574734
# Replacements:                              15450
# Total Samples:                             26882
# Nested Sampling ln(Z):            3534459.974874
# Importance Nested Sampling ln(Z): 3534460.229646 +/-  0.015040
# Acceptance Rate:                        0.575011
# Replacements:                              15500
# Total Samples:                             26956
# Nested Sampling ln(Z):            3534459.993469
# Importance Nested Sampling ln(Z): 3534460.229985 +/-  0.014748
# Acceptance Rate:                        0.575287
# Replacements:                              15550
# Total Samples:                             27030
# Nested Sampling ln(Z):            3534460.011325
# Importance Nested Sampling ln(Z): 3534460.230836 +/-  0.014483
# Acceptance Rate:                        0.575306
# Replacements:                              15600
# Total Samples:                             27116
# Nested Sampling ln(Z):            3534460.028468
# Importance Nested Sampling ln(Z): 3534460.230265 +/-  0.014175
# Acceptance Rate:                        0.575727
# Replacements:                              15650
# Total Samples:                             27183
# Nested Sampling ln(Z):            3534460.044858
# Importance Nested Sampling ln(Z): 3534460.230932 +/-  0.013950
# Acceptance Rate:                        0.575809
# Replacements:                              15700
# Total Samples:                             27266
# Nested Sampling ln(Z):            3534460.060467
# Importance Nested Sampling ln(Z): 3534460.230459 +/-  0.013687
# Acceptance Rate:                        0.576016
# Replacements:                              15750
# Total Samples:                             27343
# Nested Sampling ln(Z):            3534460.075308
# Importance Nested Sampling ln(Z): 3534460.231216 +/-  0.013473
# Acceptance Rate:                        0.576411
# Replacements:                              15800
# Total Samples:                             27411
# Nested Sampling ln(Z):            3534460.089371
# Importance Nested Sampling ln(Z): 3534460.231419 +/-  0.013282
# Acceptance Rate:                        0.576636
# Replacements:                              15850
# Total Samples:                             27487
# Nested Sampling ln(Z):            3534460.102807
# Importance Nested Sampling ln(Z): 3534460.230001 +/-  0.013079
# Acceptance Rate:                        0.576651
# Replacements:                              15900
# Total Samples:                             27573
# Nested Sampling ln(Z):            3534460.115578
# Importance Nested Sampling ln(Z): 3534460.229207 +/-  0.012879
# Acceptance Rate:                        0.576749
# Replacements:                              15950
# Total Samples:                             27655
# Nested Sampling ln(Z):            3534460.127736
# Importance Nested Sampling ln(Z): 3534460.228692 +/-  0.012702
# Acceptance Rate:                        0.576759
# Replacements:                              15952
# Total Samples:                             27658
# Nested Sampling ln(Z):            3534460.128210
# Importance Nested Sampling ln(Z): 3534460.228689 +/-  0.012696
#  ln(ev)=   3534460.3608608907      +/-  0.14072549658740774
#  Total Likelihood Evaluations:        27658
#  Sampling finished. Exiting MultiNest
