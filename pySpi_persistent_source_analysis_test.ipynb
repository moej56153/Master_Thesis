# %%
from pyspi.utils.data_builder.time_series_builder import TimeSeriesBuilderSPI
import numpy as np
from pyspi.utils.function_utils import find_response_version
from pyspi.utils.response.spi_response_data import ResponseDataRMF
from pyspi.utils.response.spi_response import ResponseRMFGenerator
from pyspi.utils.response.spi_drm import SPIDRM
from pyspi.utils.livedets import get_live_dets

grb_time = "120711 024453"
ebounds = np.geomspace(20,520,40)
ein = np.geomspace(20,800,150)
t1 = 3500
t2 = 3800
version = find_response_version(grb_time)
rsp_base = ResponseDataRMF.from_version(version)
dets = get_live_dets(time=grb_time, event_types=["single"])
# Out:
# [WARNING ] The naima package is not available. Models that depend on it will not be available
# [WARNING ] The GSL library or the pygsl wrapper cannot be loaded. Models that depend on it will not be available.
# [WARNING ] The ebltable package is not available. Models that depend on it will not be available
# [INFO    ] Starting 3ML!
# [WARNING ] no display variable set. using backend for graphics without display (agg)
# [WARNING ] ROOT minimizer not available
# [WARNING ] PyGMO is not available
# [WARNING ] The cthreeML package is not installed. You will not be able to use plugins which require the C/C++ interface (currently HAWC)
# [WARNING ] Could not import plugin HAWCLike.py. Do you have the relative instrument software installed and configured?
# [WARNING ] Could not import plugin FermiLATLike.py. Do you have the relative instrument software installed and configured?
# [WARNING ] No fermitools installed
# [WARNING ] Env. variable OMP_NUM_THREADS is not set. Please set it to 1 for optimal performances in 3ML
# [WARNING ] Env. variable MKL_NUM_THREADS is not set. Please set it to 1 for optimal performances in 3ML
# [WARNING ] Env. variable NUMEXPR_NUM_THREADS is not set. Please set it to 1 for optimal performances in 3ML
# Using the irfs that are valid between 10/05/27 12:45:00 and present (YY/MM/DD HH:MM:SS)

# %%
tsbs = []
sds1 = []
sds2 = []
ra1, dec1 = 94.67830, -70.99905
ra2, dec2 = 92.67830, -70.99905
for d in dets:
    tsb = TimeSeriesBuilderSPI.from_spi_grb(f"SPIDet{d}", 
                                        d, 
                                        #ebounds_sgl, 
                                        grb_time, 
                                        ebounds=ebounds,
                                        sgl_type="both",
                                        poly_order=-1,
                                        )
    rsp = ResponseRMFGenerator.from_time(grb_time,  d,
                                            ebounds, ein,
                                            rsp_base)
    sd1 = SPIDRM(rsp, ra1, dec1)
    sd2 = SPIDRM(rsp.clone(), ra2, dec2)
    tsbs.append(tsb)
    sds1.append(sd1)
    sds2.append(sd2)

# %%
bkgs=np.array([])
for tsb in tsbs:
    bkgs = np.append(bkgs, tsb.time_series.count_per_channel_over_interval(-1000,0)/tsb.time_series.exposure_over_interval(-1000,0))
bkgs=bkgs.reshape((len(dets), -1));

# %%
# source model
from astromodels import Powerlaw, Log_uniform_prior, Uniform_prior, PointSource, SpectralComponent
import numpy as np
pl = Powerlaw()
pl.index = -2.08
pl.K = 9.3#6.44*10**-4
pl.xiv = 1

pl.K.prior = Log_uniform_prior(lower_bound=0.001, upper_bound=1000)
pl.index.prior = Uniform_prior(lower_bound=-4, upper_bound=0)

component1 = SpectralComponent('pl',shape=pl)
ps = PointSource('plline',ra=94.67830, dec=-70.99905, components=[component1])

spec = ps(ein)

spec_binned = (ein[1:]-ein[:-1])*(spec[:-1]+spec[1:])/2

# %%
# model counts
model_count_rates1 = np.array([])#np.dot(spec_binned, sd_sgl1.matrix.T)
model_count_rates2 = np.array([])#np.dot(spec_binned, sd_sgl2.matrix.T)
for sd1, sd2 in zip(sds1, sds2):
    model_count_rates1 = np.append(model_count_rates1, np.dot(spec_binned, sd1.matrix.T))
    model_count_rates2 = np.append(model_count_rates2, np.dot(spec_binned, sd2.matrix.T))
model_count_rates1 = model_count_rates1.reshape((len(dets), -1));
model_count_rates2 = model_count_rates2.reshape((len(dets), -1));

# %%
import matplotlib.pyplot as plt
fig, axes = plt.subplots(5,4, sharex=True, sharey=True, figsize=(10,10))
axes = axes.flatten()
i=0
for d in range(19):
    axes[d].text(.5,.9,f"Det {d}",horizontalalignment='center',transform=axes[d].transAxes)
    if d in dets:
        if i==0:
            axes[d].step(ebounds[:-1], bkgs[i], label="background")
            axes[d].step(ebounds[:-1], model_count_rates1[i], label="model1")
            axes[d].step(ebounds[:-1], model_count_rates2[i], label="model2")
        else:
            axes[d].step(ebounds[:-1], bkgs[i])
            axes[d].step(ebounds[:-1], model_count_rates1[i])
            axes[d].step(ebounds[:-1], model_count_rates2[i])
        i+=1
    axes[d].set_yscale("log")
    axes[d].set_ylim(10**-3, 20)
for i in range(16,20):
    axes[i].set_xlabel("Detected Energy [keV]")
for i in range(0,20,4):
    axes[i].set_ylabel("Count Rates [1/s]")
plt.subplots_adjust(hspace=0, wspace=0)
plt.subplots_adjust(hspace=0, top=0.96, bottom=0.1)
lgd = fig.legend(loc='center left', bbox_to_anchor=(0.9, 0.5), fontsize='x-large')
fig.savefig("bkg_models.pdf")

# %%
data1 = np.array([])
data2 = np.array([])
for bkg, m1, m2 in zip(bkgs, model_count_rates1, model_count_rates2):
    data1 = np.append(data1, np.random.poisson(t1*(bkg+m1)))
    data2 = np.append(data2, np.random.poisson(t2*(bkg+m2)))
    
data1 = data1.reshape((len(dets), -1));
data2 = data2.reshape((len(dets), -1));

# %%
import math
from numba import njit

@njit
def bmaxba(m1, m2, t1, t2, C1, C2):
    first = C1+C2-(m1+m2)*(t1+t2)
    root = (C1+C2+(m1-m2)*(t1+t2))**2-4*C1*(m1-m2)*(t1+t2)
    res = (first+np.sqrt(root))/(2*(t1+t2))
    return res
matrices1 = np.array([])
sd_x, sd_y = sds1[0].matrix.T.shape
for sd in sds1:
    matrices1=np.append(matrices1,sd.matrix.T)
matrices1=matrices1.reshape((len(dets), sd_x, sd_y))

matrices2 = np.array([])
for sd in sds2:
    matrices2=np.append(matrices2,sd.matrix.T)
matrices2=matrices2.reshape((len(dets), sd_x, sd_y))

@njit
def logLcore(spec_binned):
    logL=0
    for j in range(len(dets)):
        m1 = np.dot(spec_binned, matrices1[j])
        m2 = np.dot(spec_binned, matrices2[j])
        for i in range(len(m1)):
            bm = bmaxba(m1[i], m2[i], t1, t2, data1[j, i], data2[j, i])
            logL += (data1[j,i]*math.log(t1*(m1[i]+bm))+
                    data2[j,i]*math.log(t2*(m2[i]+bm))-
                    t1*(m1[i]+bm)-
                    t2*(m2[i]+bm))
    return logL

def logLba_mult(trial_values, ndim=None, params=None):
    pl.index = trial_values[1]
    pl.K = trial_values[0]
    spec = pl(ein)
    spec_binned = (ein[1:]-ein[:-1])*(spec[:-1]+spec[1:])/2
    return logLcore(spec_binned)

# %%
def prior(params, ndim=None, nparams=None):
    for i, (parameter_name, parameter) in enumerate(
        ps.free_parameters.items()
    ):

        try:

            params[i] = parameter.prior.from_unit_cube(params[i])

        except AttributeError:

            raise RuntimeError(
                "The prior you are trying to use for parameter %s is "
                "not compatible with sampling from a unitcube"
                % parameter_name
            )

# %%
import pymultinest
import os
if not os.path.exists("./chains"):
    os.mkdir("chains")
sampler = pymultinest.run(
                    logLba_mult, prior, 2, 2, n_live_points=800, resume=False, verbose=True
                )
# Out:
#  *****************************************************
#  MultiNest v3.10
#  Copyright Farhan Feroz & Mike Hobson
#  Release Jul 2015
#
#  no. of live points =  800
#  dimensionality =    2
#  *****************************************************
#  Starting MultiNest
#  generating live points
#  live points generated, starting sampling
# Acceptance Rate:                        0.996483
# Replacements:                                850
# Total Samples:                               853
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.862979
# Acceptance Rate:                        0.994475
# Replacements:                                900
# Total Samples:                               905
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.837031
# Acceptance Rate:                        0.990615
# Replacements:                                950
# Total Samples:                               959
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.836197
# Acceptance Rate:                        0.977517
# Replacements:                               1000
# Total Samples:                              1023
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.836236
# Acceptance Rate:                        0.966851
# Replacements:                               1050
# Total Samples:                              1086
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.836270
# Acceptance Rate:                        0.953206
# Replacements:                               1100
# Total Samples:                              1154
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.836299
# Acceptance Rate:                        0.935720
# Replacements:                               1150
# Total Samples:                              1229
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.644477
# Acceptance Rate:                        0.920245
# Replacements:                               1200
# Total Samples:                              1304
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.644513
# Acceptance Rate:                        0.900576
# Replacements:                               1250
# Total Samples:                              1388
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.644546
# Acceptance Rate:                        0.881954
# Replacements:                               1300
# Total Samples:                              1474
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.644577
# Acceptance Rate:                        0.853890
# Replacements:                               1350
# Total Samples:                              1581
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.618247
# Acceptance Rate:                        0.825959
# Replacements:                               1400
# Total Samples:                              1695
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.618281
# Acceptance Rate:                        0.823396
# Replacements:                               1450
# Total Samples:                              1761
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.617721
# Acceptance Rate:                        0.824176
# Replacements:                               1500
# Total Samples:                              1820
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.615934
# Acceptance Rate:                        0.824468
# Replacements:                               1550
# Total Samples:                              1880
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.615640
# Acceptance Rate:                        0.824742
# Replacements:                               1600
# Total Samples:                              1940
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.615653
# Acceptance Rate:                        0.823353
# Replacements:                               1650
# Total Samples:                              2004
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.615666
# Acceptance Rate:                        0.822050
# Replacements:                               1700
# Total Samples:                              2068
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.615481
# Acceptance Rate:                        0.821982
# Replacements:                               1750
# Total Samples:                              2129
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.605061
# Acceptance Rate:                        0.821168
# Replacements:                               1800
# Total Samples:                              2192
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.604198
# Acceptance Rate:                        0.820763
# Replacements:                               1850
# Total Samples:                              2254
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.604145
# Acceptance Rate:                        0.817556
# Replacements:                               1900
# Total Samples:                              2324
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.604146
# Acceptance Rate:                        0.811486
# Replacements:                               1950
# Total Samples:                              2403
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.432083
# Acceptance Rate:                        0.810373
# Replacements:                               2000
# Total Samples:                              2468
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.420732
# Acceptance Rate:                        0.805185
# Replacements:                               2050
# Total Samples:                              2546
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.391755
# Acceptance Rate:                        0.804906
# Replacements:                               2100
# Total Samples:                              2609
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.391767
# Acceptance Rate:                        0.801940
# Replacements:                               2150
# Total Samples:                              2681
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.391745
# Acceptance Rate:                        0.798548
# Replacements:                               2200
# Total Samples:                              2755
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.391755
# Acceptance Rate:                        0.792812
# Replacements:                               2250
# Total Samples:                              2838
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.364069
# Acceptance Rate:                        0.785251
# Replacements:                               2300
# Total Samples:                              2929
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.363382
# Acceptance Rate:                        0.781510
# Replacements:                               2350
# Total Samples:                              3007
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.363383
# Acceptance Rate:                        0.779981
# Replacements:                               2400
# Total Samples:                              3077
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.362604
# Acceptance Rate:                        0.775316
# Replacements:                               2450
# Total Samples:                              3160
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.338870
# Acceptance Rate:                        0.770179
# Replacements:                               2500
# Total Samples:                              3246
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.325937
# Acceptance Rate:                        0.767379
# Replacements:                               2550
# Total Samples:                              3323
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.325943
# Acceptance Rate:                        0.764256
# Replacements:                               2600
# Total Samples:                              3402
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.307323
# Acceptance Rate:                        0.762371
# Replacements:                               2650
# Total Samples:                              3476
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.307253
# Acceptance Rate:                        0.758640
# Replacements:                               2700
# Total Samples:                              3559
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.304214
# Acceptance Rate:                        0.755287
# Replacements:                               2750
# Total Samples:                              3641
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.287497
# Acceptance Rate:                        0.751476
# Replacements:                               2800
# Total Samples:                              3726
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.272552
# Acceptance Rate:                        0.748228
# Replacements:                               2850
# Total Samples:                              3809
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.258138
# Acceptance Rate:                        0.747808
# Replacements:                               2900
# Total Samples:                              3878
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.259295
# Acceptance Rate:                        0.745891
# Replacements:                               2950
# Total Samples:                              3955
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.235618
# Acceptance Rate:                        0.745342
# Replacements:                               3000
# Total Samples:                              4025
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.225301
# Acceptance Rate:                        0.745175
# Replacements:                               3050
# Total Samples:                              4093
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.227550
# Acceptance Rate:                        0.745371
# Replacements:                               3100
# Total Samples:                              4159
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.216013
# Acceptance Rate:                        0.741351
# Replacements:                               3150
# Total Samples:                              4249
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.218667
# Acceptance Rate:                        0.742115
# Replacements:                               3200
# Total Samples:                              4312
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.214624
# Acceptance Rate:                        0.740488
# Replacements:                               3250
# Total Samples:                              4389
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.206331
# Acceptance Rate:                        0.737101
# Replacements:                               3300
# Total Samples:                              4477
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.196045
# Acceptance Rate:                        0.736912
# Replacements:                               3350
# Total Samples:                              4546
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.196162
# Acceptance Rate:                        0.735931
# Replacements:                               3400
# Total Samples:                              4620
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.192316
# Acceptance Rate:                        0.735451
# Replacements:                               3450
# Total Samples:                              4691
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.194638
# Acceptance Rate:                        0.734831
# Replacements:                               3500
# Total Samples:                              4763
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.192986
# Acceptance Rate:                        0.735294
# Replacements:                               3550
# Total Samples:                              4828
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.191476
# Acceptance Rate:                        0.735745
# Replacements:                               3600
# Total Samples:                              4893
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.187499
# Acceptance Rate:                        0.734259
# Replacements:                               3650
# Total Samples:                              4971
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.185176
# Acceptance Rate:                        0.734127
# Replacements:                               3700
# Total Samples:                              5040
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.187374
# Acceptance Rate:                        0.735583
# Replacements:                               3750
# Total Samples:                              5098
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.185575
# Acceptance Rate:                        0.734158
# Replacements:                               3800
# Total Samples:                              5176
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.187961
# Acceptance Rate:                        0.734452
# Replacements:                               3850
# Total Samples:                              5242
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.188792
# Acceptance Rate:                        0.733910
# Replacements:                               3900
# Total Samples:                              5314
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.191181
# Acceptance Rate:                        0.732431
# Replacements:                               3950
# Total Samples:                              5393
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.183132
# Acceptance Rate:                        0.732467
# Replacements:                               4000
# Total Samples:                              5461
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.177618
# Acceptance Rate:                        0.731707
# Replacements:                               4050
# Total Samples:                              5535
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.178324
# Acceptance Rate:                        0.731620
# Replacements:                               4100
# Total Samples:                              5604
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.180280
# Acceptance Rate:                        0.731535
# Replacements:                               4150
# Total Samples:                              5673
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.183791
# Acceptance Rate:                        0.732856
# Replacements:                               4200
# Total Samples:                              5731
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.183933
# Acceptance Rate:                        0.733138
# Replacements:                               4250
# Total Samples:                              5797
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.181686
# Acceptance Rate:                        0.734290
# Replacements:                               4300
# Total Samples:                              5856
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.179921
# Acceptance Rate:                        0.734053
# Replacements:                               4350
# Total Samples:                              5926
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.179357
# Acceptance Rate:                        0.734435
# Replacements:                               4400
# Total Samples:                              5991
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.182302
# Acceptance Rate:                        0.735416
# Replacements:                               4450
# Total Samples:                              6051
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.181709
# Acceptance Rate:                        0.736257
# Replacements:                               4500
# Total Samples:                              6112
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.180759
# Acceptance Rate:                        0.737081
# Replacements:                               4550
# Total Samples:                              6173
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.175745
# Acceptance Rate:                        0.737416
# Replacements:                               4600
# Total Samples:                              6238
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.173558
# Acceptance Rate:                        0.737393
# Replacements:                               4650
# Total Samples:                              6306
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.171816
# Acceptance Rate:                        0.737024
# Replacements:                               4700
# Total Samples:                              6377
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.171388
# Acceptance Rate:                        0.737921
# Replacements:                               4750
# Total Samples:                              6437
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.169324
# Acceptance Rate:                        0.739258
# Replacements:                               4800
# Total Samples:                              6493
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.165629
# Acceptance Rate:                        0.740119
# Replacements:                               4850
# Total Samples:                              6553
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.161921
# Acceptance Rate:                        0.740741
# Replacements:                               4900
# Total Samples:                              6615
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.162065
# Acceptance Rate:                        0.740575
# Replacements:                               4950
# Total Samples:                              6684
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.163483
# Acceptance Rate:                        0.740850
# Replacements:                               5000
# Total Samples:                              6749
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.164110
# Acceptance Rate:                        0.740578
# Replacements:                               5050
# Total Samples:                              6819
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.165026
# Acceptance Rate:                        0.741602
# Replacements:                               5100
# Total Samples:                              6877
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.164017
# Acceptance Rate:                        0.742824
# Replacements:                               5150
# Total Samples:                              6933
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.162679
# Acceptance Rate:                        0.743601
# Replacements:                               5200
# Total Samples:                              6993
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.160068
# Acceptance Rate:                        0.744470
# Replacements:                               5250
# Total Samples:                              7052
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.160022
# Acceptance Rate:                        0.744382
# Replacements:                               5300
# Total Samples:                              7120
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.160418
# Acceptance Rate:                        0.744710
# Replacements:                               5350
# Total Samples:                              7184
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.159938
# Acceptance Rate:                        0.744930
# Replacements:                               5400
# Total Samples:                              7249
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.159966
# Acceptance Rate:                        0.745554
# Replacements:                               5450
# Total Samples:                              7310
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.160390
# Acceptance Rate:                        0.746370
# Replacements:                               5500
# Total Samples:                              7369
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.158915
# Acceptance Rate:                        0.747273
# Replacements:                               5550
# Total Samples:                              7427
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.159553
# Acceptance Rate:                        0.747564
# Replacements:                               5600
# Total Samples:                              7491
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.158022
# Acceptance Rate:                        0.747849
# Replacements:                               5650
# Total Samples:                              7555
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.158156
# Acceptance Rate:                        0.748621
# Replacements:                               5700
# Total Samples:                              7614
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.158884
# Acceptance Rate:                        0.749186
# Replacements:                               5750
# Total Samples:                              7675
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.158293
# Acceptance Rate:                        0.749935
# Replacements:                               5800
# Total Samples:                              7734
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.158050
# Acceptance Rate:                        0.750577
# Replacements:                               5850
# Total Samples:                              7794
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.158292
# Acceptance Rate:                        0.750541
# Replacements:                               5900
# Total Samples:                              7861
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.158583
# Acceptance Rate:                        0.751168
# Replacements:                               5950
# Total Samples:                              7921
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.158936
# Acceptance Rate:                        0.751409
# Replacements:                               6000
# Total Samples:                              7985
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.158917
# Acceptance Rate:                        0.751833
# Replacements:                               6050
# Total Samples:                              8047
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.158039
# Acceptance Rate:                        0.751880
# Replacements:                               6100
# Total Samples:                              8113
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.157002
# Acceptance Rate:                        0.752570
# Replacements:                               6150
# Total Samples:                              8172
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.156535
# Acceptance Rate:                        0.753891
# Replacements:                               6200
# Total Samples:                              8224
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.155941
# Acceptance Rate:                        0.754466
# Replacements:                               6250
# Total Samples:                              8284
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.155212
# Acceptance Rate:                        0.754401
# Replacements:                               6300
# Total Samples:                              8351
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.154908
# Acceptance Rate:                        0.755323
# Replacements:                               6350
# Total Samples:                              8407
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.154192
# Acceptance Rate:                        0.755876
# Replacements:                               6400
# Total Samples:                              8467
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.154011
# Acceptance Rate:                        0.756953
# Replacements:                               6450
# Total Samples:                              8521
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.153514
# Acceptance Rate:                        0.757664
# Replacements:                               6500
# Total Samples:                              8579
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.152718
# Acceptance Rate:                        0.758014
# Replacements:                               6550
# Total Samples:                              8641
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.152726
# Acceptance Rate:                        0.758359
# Replacements:                               6600
# Total Samples:                              8703
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.152632
# Acceptance Rate:                        0.759306
# Replacements:                               6650
# Total Samples:                              8758
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.152243
# Acceptance Rate:                        0.759982
# Replacements:                               6700
# Total Samples:                              8816
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.151804
# Acceptance Rate:                        0.760992
# Replacements:                               6750
# Total Samples:                              8870
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.151485
# Acceptance Rate:                        0.761905
# Replacements:                               6800
# Total Samples:                              8925
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.151402
# Acceptance Rate:                        0.762891
# Replacements:                               6850
# Total Samples:                              8979
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.151302
# Acceptance Rate:                        0.763781
# Replacements:                               6900
# Total Samples:                              9034
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.151088
# Acceptance Rate:                        0.764745
# Replacements:                               6950
# Total Samples:                              9088
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.150833
# Acceptance Rate:                        0.765278
# Replacements:                               7000
# Total Samples:                              9147
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.150614
# Acceptance Rate:                        0.765389
# Replacements:                               7050
# Total Samples:                              9211
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.150507
# Acceptance Rate:                        0.765664
# Replacements:                               7100
# Total Samples:                              9273
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.150253
# Acceptance Rate:                        0.766592
# Replacements:                               7150
# Total Samples:                              9327
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.150156
# Acceptance Rate:                        0.767263
# Replacements:                               7200
# Total Samples:                              9384
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.150180
# Acceptance Rate:                        0.767683
# Replacements:                               7250
# Total Samples:                              9444
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.149981
# Acceptance Rate:                        0.768098
# Replacements:                               7300
# Total Samples:                              9504
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.149982
# Acceptance Rate:                        0.767945
# Replacements:                               7350
# Total Samples:                              9571
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.150047
# Acceptance Rate:                        0.768592
# Replacements:                               7400
# Total Samples:                              9628
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.150004
# Acceptance Rate:                        0.768834
# Replacements:                               7450
# Total Samples:                              9690
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.150043
# Acceptance Rate:                        0.769152
# Replacements:                               7500
# Total Samples:                              9751
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.150108
# Acceptance Rate:                        0.769623
# Replacements:                               7550
# Total Samples:                              9810
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.150055
# Acceptance Rate:                        0.770400
# Replacements:                               7600
# Total Samples:                              9865
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.150041
# Acceptance Rate:                        0.770639
# Replacements:                               7617
# Total Samples:                              9884
# Nested Sampling ln(Z):            **************
# Importance Nested Sampling ln(Z): ************** +/-  0.150064
#  ln(ev)=   32914407.821634714      +/-   9.5725072806085443E-002
#  Total Likelihood Evaluations:         9884
#  Sampling finished. Exiting MultiNest

# %%
# %matplotlib inline
from chainconsumer import ChainConsumer
import numpy as np


def loadtxt2d(intext):
        try:
            return np.loadtxt(intext, ndmin=2)
        except:
            return np.loadtxt(intext)

c = ChainConsumer()

chain = loadtxt2d('./chains/1-post_equal_weights.dat')

#c.add_chain(chain, parameters=['K', 'index', 'F', 'mu','sigma', '$z$'], name='yeah')
c.add_chain(chain, parameters=['K', 'index', '$z$'], name='fit')

# %%
c.plotter.plot(filename="fit_corner.pdf", 
                parameters=['K', 'index'],
                truth=[9.3, -2.08],
                log_scales=[]);
